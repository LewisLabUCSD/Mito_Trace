# %% [markdown]
# ## Run after python split_script_14515X1.MT.py

# %%
import glob
import os
import pandas as pd
from tqdm import tqdm
import numpy as np
import pysam
import time
from collections import defaultdict
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import subprocess
# %matplotlib inline

from os.path import join

# %%
FUNC_PATH = "/home/isshamie/software/mito-genotyping/exampleProcessing/"
BAM = "../data/raw/14515X1.MT.bam"
BARCODES = "../data/raw/Human2_002_Barcodes.txt"
NUM_CORES = 32
IN = "../data/raw/scBam"
OUT_DIR = "../data/raw/scPileup/"
BARCODE_INFO = "../data/scBam/barcode_data.p"
maxBP = 16571

if not os.path.exists(OUT_DIR):
    os.mkdir(OUT_DIR)

# %%
files = glob.glob(IN + "/*")
print(len(files))
# Out:
# 24767

# %% [markdown]
# ## Load CB's, get ones that have over average read coverage of 1x

# %%
[CR_read_number,CB_read_number,BC_read_number, barcodes, corrected_barcodes, barcode_pairs] = pickle.load(open(BARCODE_INFO,"rb"))

# %%
CB_read_MT = dict()
for i in CB_read_number:
    if CB_read_number[i] >= maxBP:
        CB_read_MT[i] = CB_read_number[i]
    
print(len(CB_read_MT))
plt.figure()
sns.distplot(list(CB_read_MT.values()))
plt.title(f"Number of reads per cell\nN cells with > 1x read coverage ={len(CB_read_MT)}")

plt.figure()
sns.distplot(np.array(list(CB_read_MT.values()))/maxBP)
plt.title(f"Number of reads per MT length per cell\nN cells with > 1x read coverage ={len(CB_read_MT)}")

plt.figure()
plt.hist(np.array(list(CB_read_MT.values()))/maxBP,log=True)
plt.title(f"LOG Number of nts per MT length per cell\nN cells with > 1x read coverage ={len(CB_read_MT)}")
# Out:
# 207
# Text(0.5, 1.0, 'LOG Number of nts per MT length per cell\nN cells with > 1x read coverage =207')

# %% [markdown]
# ## Assume read length is 100bp

# %%
CB_read_MT = dict()
for i in CB_read_number:
    if CB_read_number[i]*100 >= maxBP:
        CB_read_MT[i] = CB_read_number[i]*100
    
print(len(CB_read_MT))
plt.figure()
sns.distplot(list(CB_read_MT.values()))
plt.title(f"Number of nts per cell\nN cells with > 1x read coverage ={len(CB_read_MT)}")

plt.figure()
sns.distplot(np.array(list(CB_read_MT.values()))/maxBP)
plt.title(f"Number of nts per MT length per cell\nN cells with > 1x read coverage ={len(CB_read_MT)}")

plt.figure()
plt.hist(np.array(list(CB_read_MT.values()))/maxBP,log=True)
plt.title(f"LOG Number of nts per MT length per cell\nN cells with > 1x read coverage ={len(CB_read_MT)}")
plt.savefig("../figures/CB_coverage_hist.png")
# Out:
# 76253

# %% [markdown]
# ## Get the hamming distance of all barcodes

# %%
len(CB_read_MT)
# Out:
# 76253

# %%
def hamming_distance(pattern1, pattern2):
    '''
    This function calculates the number of mismatches between two patterns ("pattern1" and "pattern2")
    of equal lenght.
    '''
    assert len(pattern1) == len(pattern2)
    return sum(p1 != p2 for p1, p2 in zip(pattern1, pattern2))

# %%
del CB_read_number

# %%
ind1
# Out:
# 0

# %% [markdown]
# ### Didnt finish all of them b/c of time

# %%
CBs = list(CB_read_MT.keys())
hamming_df = pd.DataFrame(index=CBs, columns=CBs,dtype=int)
for ind1,val1 in tqdm(enumerate(CBs)):
    for _,val2 in enumerate(CBs[ind1+1:]):
        hamming_df.loc[val1, val2] = hamming_distance(val1, val2)
# Out:
# 3003it [29:28:22, 34.17s/it]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 8945it [84:18:03, 31.23s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-7231aafa0510> in <module>
#       3 for ind1,val1 in tqdm(enumerate(CBs)):
#       4     for _,val2 in enumerate(CBs[ind1+1:]):
# ----> 5         hamming_df.loc[val1, val2] = hamming_distance(val1, val2)
#
# ~/software/anaconda2/envs/mito_trace/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     203             key = com.apply_if_callable(key, self.obj)
#     204         indexer = self._get_setitem_indexer(key)
# --> 205         self._setitem_with_indexer(indexer, value)
#     206
#     207     def _validate_key(self, key, axis: int):
#
# ~/software/anaconda2/envs/mito_trace/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     591             # actually do the set
#     592             self.obj._consolidate_inplace()
# --> 593             self.obj._data = self.obj._data.setitem(indexer=indexer, value=value)
#     594             self.obj._maybe_update_cacher(clear=True)
#     595
#
# ~/software/anaconda2/envs/mito_trace/lib/python3.7/site-packages/pandas/core/internals/managers.py in setitem(self, **kwargs)
#     558
#     559     def setitem(self, **kwargs):
# --> 560         return self.apply("setitem", **kwargs)
#     561
#     562     def putmask(self, **kwargs):
#
# ~/software/anaconda2/envs/mito_trace/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     442             return self.make_empty(axes or self.axes)
#     443         bm = self.__class__(
# --> 444             result_blocks, axes or self.axes, do_integrity_check=do_integrity_check
#     445         )
#     446         bm._consolidate_inplace()
#
# ~/software/anaconda2/envs/mito_trace/lib/python3.7/site-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, do_integrity_check)
#     145         self._consolidate_check()
#     146
# --> 147         self._rebuild_blknos_and_blklocs()
#     148
#     149     def make_empty(self, axes=None):
#
# ~/software/anaconda2/envs/mito_trace/lib/python3.7/site-packages/pandas/core/internals/managers.py in _rebuild_blknos_and_blklocs(self)
#     226             rl = blk.mgr_locs
#     227             new_blknos[rl.indexer] = blkno
# --> 228             new_blklocs[rl.indexer] = np.arange(len(rl))
#     229
#     230         if (new_blknos == -1).any():
#
# KeyboardInterrupt:

# %%
hamming_df
# Out:
#                   AAACCTGAGATGCGAC  AAACGGGAGGGTGTGT  AAACGGGCATGGTCTA  \
# AAACCTGAGATGCGAC               NaN               9.0              10.0
# AAACGGGAGGGTGTGT               NaN               NaN               8.0
# AAACGGGCATGGTCTA               NaN               NaN               NaN
# AAACGGGTCTAGCACA               NaN               NaN               NaN
# AAAGATGCACGTTGGC               NaN               NaN               NaN
# ...                            ...               ...               ...
# TGACGGCCAGATCTGT               NaN               NaN               NaN
# TACTCATCAGCCAATT               NaN               NaN               NaN
# TTAACTCGTTGGGACA               NaN               NaN               NaN
# CACACTCAGTCTCAAC               NaN               NaN               NaN
# ACACCCTAGGCTCATT               NaN               NaN               NaN
#
#                   AAACGGGTCTAGCACA  AAAGATGCACGTTGGC  AAAGATGCAGTCGATT  \
# AAACCTGAGATGCGAC               9.0               9.0              10.0
# AAACGGGAGGGTGTGT               9.0               9.0               9.0
# AAACGGGCATGGTCTA               6.0               8.0               9.0
# AAACGGGTCTAGCACA               NaN              12.0              11.0
# AAAGATGCACGTTGGC               NaN               NaN               7.0
# ...                            ...               ...               ...
# TGACGGCCAGATCTGT               NaN               NaN               NaN
# TACTCATCAGCCAATT               NaN               NaN               NaN
# TTAACTCGTTGGGACA               NaN               NaN               NaN
# CACACTCAGTCTCAAC               NaN               NaN               NaN
# ACACCCTAGGCTCATT               NaN               NaN               NaN
#
#                   AAAGATGCATTGGGCC  AAAGATGGTGCACCAC  AAAGATGTCTCGAGTA  \
# AAACCTGAGATGCGAC               7.0               8.0               9.0
# AAACGGGAGGGTGTGT              11.0              11.0              12.0
# AAACGGGCATGGTCTA               8.0              11.0               8.0
# AAACGGGTCTAGCACA               9.0              11.0               7.0
# AAAGATGCACGTTGGC               5.0               8.0               8.0
# ...                            ...               ...               ...
# TGACGGCCAGATCTGT               NaN               NaN               NaN
# TACTCATCAGCCAATT               NaN               NaN               NaN
# TTAACTCGTTGGGACA               NaN               NaN               NaN
# CACACTCAGTCTCAAC               NaN               NaN               NaN
# ACACCCTAGGCTCATT               NaN               NaN               NaN
#
#                   AAAGCAAAGTGTGGCA  ...  TAGTGGTGTGGCGAAT  GACGGCTAGGAGCGTT  \
# AAACCTGAGATGCGAC               9.0  ...              14.0              10.0
# AAACGGGAGGGTGTGT               8.0  ...               9.0              10.0
# AAACGGGCATGGTCTA              10.0  ...              12.0              12.0
# AAACGGGTCTAGCACA              10.0  ...              12.0              11.0
# AAAGATGCACGTTGGC               9.0  ...              14.0              13.0
# ...                            ...  ...               ...               ...
# TGACGGCCAGATCTGT               NaN  ...               NaN               NaN
# TACTCATCAGCCAATT               NaN  ...               NaN               NaN
# TTAACTCGTTGGGACA               NaN  ...               NaN               NaN
# CACACTCAGTCTCAAC               NaN  ...               NaN               NaN
# ACACCCTAGGCTCATT               NaN  ...               NaN               NaN
#
#                   ACTGAACAGGAGTTGC  CCTTACGCAAAGGTGC  CCGGTAGGTTAGATGA  \
# AAACCTGAGATGCGAC              11.0              12.0              14.0
# AAACGGGAGGGTGTGT              10.0              12.0              13.0
# AAACGGGCATGGTCTA              13.0              12.0              12.0
# AAACGGGTCTAGCACA              13.0              13.0              11.0
# AAAGATGCACGTTGGC              10.0              10.0              13.0
# ...                            ...               ...               ...
# TGACGGCCAGATCTGT               NaN               NaN               NaN
# TACTCATCAGCCAATT               NaN               NaN               NaN
# TTAACTCGTTGGGACA               NaN               NaN               NaN
# CACACTCAGTCTCAAC               NaN               NaN               NaN
# ACACCCTAGGCTCATT               NaN               NaN               NaN
#
#                   TGACGGCCAGATCTGT  TACTCATCAGCCAATT  TTAACTCGTTGGGACA  \
# AAACCTGAGATGCGAC              13.0              14.0              12.0
# AAACGGGAGGGTGTGT               7.0              13.0              13.0
# AAACGGGCATGGTCTA              10.0              12.0              11.0
# AAACGGGTCTAGCACA              10.0              14.0              10.0
# AAAGATGCACGTTGGC              11.0              13.0              13.0
# ...                            ...               ...               ...
# TGACGGCCAGATCTGT               NaN               NaN               NaN
# TACTCATCAGCCAATT               NaN               NaN               NaN
# TTAACTCGTTGGGACA               NaN               NaN               NaN
# CACACTCAGTCTCAAC               NaN               NaN               NaN
# ACACCCTAGGCTCATT               NaN               NaN               NaN
#
#                   CACACTCAGTCTCAAC  ACACCCTAGGCTCATT
# AAACCTGAGATGCGAC               8.0               9.0
# AAACGGGAGGGTGTGT              12.0               8.0
# AAACGGGCATGGTCTA              14.0              12.0
# AAACGGGTCTAGCACA              12.0              11.0
# AAAGATGCACGTTGGC              12.0              13.0
# ...                            ...               ...
# TGACGGCCAGATCTGT               NaN               NaN
# TACTCATCAGCCAATT               NaN               NaN
# TTAACTCGTTGGGACA               NaN               NaN
# CACACTCAGTCTCAAC               NaN               NaN
# ACACCCTAGGCTCATT               NaN               NaN
#
# [76253 rows x 76253 columns]

# %%
hamming_df.isnull().all(axis=1).sum()
# Out:
# 67307

# %%
(hamming_df.fillna(np.infty) <= 1).any()
# Out:
# AAACCTGAGATGCGAC    False
# AAACGGGAGGGTGTGT    False
# AAACGGGCATGGTCTA    False
# AAACGGGTCTAGCACA    False
# AAAGATGCACGTTGGC    False
#                     ...
# TGACGGCCAGATCTGT    False
# TACTCATCAGCCAATT    False
# TTAACTCGTTGGGACA    False
# CACACTCAGTCTCAAC    False
# ACACCCTAGGCTCATT    False
# Length: 76253, dtype: bool

# %%
(hamming_df.fillna(np.infty) <= 1).sum().sum()
# Out:
# 0

# %%
hamming_full = hamming_df.values.flatten()
hamming_full = hamming_full[~np.isnan(hamming_full)]

# %%
plt.hist(hamming_full)
plt.title(f"Hamming distance of cell barcodes\n Number comparisons={len(hamming_full)}")
plt.savefig("../figures/CB_barcode_hamming")
