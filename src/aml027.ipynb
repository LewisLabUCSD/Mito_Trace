# %%
import glob
import os
import pandas as pd
from tqdm import tqdm
import numpy as np
import pysam
import time
from collections import defaultdict
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
from bam_barcodes_function import extract_barcode_info

# %%
BAM = "../data/test/aml027_post_transplant_possorted_genome_bam.MT.bam"
BARCODES = "../data/raw/Human2_002_Barcodes.txt"
NUM_CORES = 32
OUT_DIR = "../data/scBam/"
BARCODE_INFO = "../data/test/barcode_data_aml027_post_transplant_possorted_genome_bam.MT.p"

# %% [markdown]
# ## Get info from BAM files

# %%
extract_barcode_info(BAM, BARCODE_INFO)
# Out:
# 8292887it [01:32, 89290.45it/s]
# (defaultdict(int,
#              {'CCGCCGGGCTGGCC': 1,
#               'GGGGGGGGGGTTGG': 25,
#               'GGTGAACCTATTCA': 17,
#               'GCGCACGACAGCGG': 1,
#               'GGGGGGGGGGGGGG': 50467,
#               'GTTGAGTTGAGTTG': 1,
#               'GTGGATCTCGGCTT': 1,
#               'ACCCCCGCGGCGCC': 2,
#               'CTTGCACTCACTGA': 4,
#               'AATTACACACTATA': 1,
#               'CGATAATCTTACAA': 1,
#               'AGTGCAACCCAATA': 1,
#               'TAAGCACTGGTCCC': 1,
#               'TTTGTACTGTCTTT': 1,
#               'ATGTACCTCTACCA': 5,
#               'ATACCACTCGCACT': 2,
#               'TTGATCTGAATAAG': 1,
#               'CAGTAGCTGGCCTT': 1,
#               'AAACGCACACGCAT': 190,
#               'AAACGGCTTGTCCC': 346,
#               'AACAATACTCTAGG': 30,
#               'AACAGAGACGAGAG': 1200,
#               'AACCAGTGTTTCGT': 157,
#               'AACCTACTCCAACA': 157,
#               'AACGTGTGTTGTCT': 31,
#               'AACGTTCTACAGTC': 1661,
#               'AACTACCTTTATCC': 48,
#               'AACTCGGATAGCCA': 1000,
#               'AAGCAAGAAAGAAC': 1847,
#               'AAGCAAGATGCTCG': 1,
#               'AAGCAAGATGCTAG': 741,
#               'AAGCCAACGGTTAC': 6,
#               'AAGCCAACGGTTCC': 1,
#               'ACGGTGCTTTGGTG': 2,
#               'AAGGTGCTTTGGTG': 533,
#               'AATGAGGAATGCCA': 32,
#               'AATGATACCTCAGA': 296,
#               'AATGTAACTATGCG': 1553,
#               'ACCCCAGAGGAGCA': 13,
#               'ACACCAGAGGAGCA': 666,
#               'ACACGATGCACCAA': 827,
#               'ACAGGTACAGTCTG': 530,
#               'ACAGTGTGCGTTGA': 15,
#               'ACAGTGTGCGGTGA': 3,
#               'ACCATTACTCTCGC': 988,
#               'ACCCTCGAACGACT': 430,
#               'ACCTATTGCCCTAC': 1582,
#               'ACGAACTGTATGGC': 664,
#               'ACGGATTGCACACA': 410,
#               'ACGTCGCTTCGTAG': 1044,
#               'ACTCAGGATTCGCC': 687,
#               'ACTGGCCTAAGGTA': 839,
#               'ACTTAAGAGTGCTA': 119,
#               'AGAAACGATCCGAA': 18,
#               'AGAGAAACGGATCT': 978,
#               'AGCACTGATTGAGC': 431,
#               'AGCGGCTGGGGAGT': 175,
#               'AGGATAGAGGTACT': 2325,
#               'AGGATAGAGTCTAG': 627,
#               'AGTAATTGAAGTGA': 322,
#               'AGTACGTGAAAGCA': 178,
#               'AGTGCAACCCATGA': 49,
#               'ATACCACTCGAACT': 34,
#               'ATAGCTCTTGCCTC': 31,
#               'ATAGGCTGGTCGTT': 8,
#               'ATCCGCACAGCGTT': 1267,
#               'ATGAGCACTCGTTG': 2,
#               'ATGAGCACTGGTTG': 88,
#               'ATGAGCACTGCTTG': 2,
#               'ATGCAGACTTTCGT': 2132,
#               'ATGTACCTCTACCC': 201,
#               'ATTCTTCTTTGACG': 1379,
#               'ATTGAATGTAAGCC': 2092,
#               'ATTTCCGACTCAAG': 1590,
#               'ATTTCGTGGCGGAA': 119,
#               'CACCCAGACGTAAC': 16,
#               'CAACGTGAATGACC': 840,
#               'CAACGTGAATGCCC': 46,
#               'CACATACTGAAACA': 26,
#               'CACCGTACTATCGG': 21,
#               'CACGGGACAAGTGA': 8,
#               'CACGGGACTTGCGA': 2,
#               'CAGACATGTTAGGC': 11,
#               'CAGCACCTCTAAGC': 1136,
#               'CAGCGTCTACTACG': 371,
#               'CAGCTCACACCTCC': 367,
#               'CAGCTCACTTGACG': 272,
#               'CAGGGCACGTCCTC': 91,
#               'CATACTACAGGCGA': 480,
#               'CATTACACAGTAGA': 3628,
#               'CCACCTGACCATAG': 2011,
#               'CCAGAAACGGAGAG': 1,
#               'CCAGTCTGCTTCGC': 1790,
#               'CCATTAACACACTG': 1847,
#               'CCCAGACTAGGCGA': 14,
#               'CCCAGTTGATGTCG': 36,
#               'CCCTAGTGGCCCTT': 987,
#               'CCGTAAGACTTCGC': 660,
#               'CCTGACTGCATGGT': 448,
#               'CGACGTCTCGACTA': 170,
#               'CGAGATTGTTACCT': 541,
#               'CGATCAGATGCAGT': 219,
#               'CGCAAATGGGACGA': 33,
#               'CGCCATACGACAAA': 1916,
#               'CGGACCGAAGAAGT': 1550,
#               'CGGACCGACTACCC': 62,
#               'CGGAGGCTACGGTT': 70,
#               'CGGAGGCTGAAGGC': 4,
#               'CGGATAACCTTATC': 1323,
#               'CGTAACGAAGTAGA': 31,
#               'CGTACAGATCGTGA': 1701,
#               'CGTCAAGAAATCGC': 353,
#               'CTACCGCTCACTCC': 1,
#               'CTACTCCTGTTGTG': 734,
#               'CTATCCCTTCTATC': 11,
#               'CTCAGAGAGCTTCC': 11,
#               'CTCAGCACAGGTCT': 344,
#               'CTCAGGCTACGCAT': 2338,
#               'CTGACAGAAGTTCG': 317,
#               'CTGACAGAGTTTGG': 1328,
#               'CTGGCACTTAACGC': 55,
#               'CTTTGATGTTCATC': 1540,
#               'GAATGCACAAACAG': 186,
#               'GAATGCACAACCAG': 2,
#               'GAATGCTGAGGCGA': 362,
#               'GACCAAACGGGAGT': 233,
#               'GACCCTACACCTAG': 8,
#               'GAGCGGCTTGAGGG': 1410,
#               'GAGGATCTGCTAAC': 76,
#               'GAGGATCTTTCCGC': 913,
#               'GAGGGAACGTAAAG': 559,
#               'GAGGTTACCAGTCA': 878,
#               'GATATCCTACCTGA': 52,
#               'GATGACACAAGAAC': 1719,
#               'GATGACACTTTACC': 138,
#               'GCACGTCTTGCTGA': 371,
#               'GCAGATACACCCTC': 62,
#               'GCAGGGCTCGACAT': 310,
#               'GCATCAGAGGCGAA': 1268,
#               'GCATGATCGTTCTT': 1,
#               'GCATGTGACCGAAT': 4,
#               'GCCTGACTAGTCGT': 6748,
#               'GGAATGCTTCAGAC': 4,
#               'GGACCTCTGTCACA': 912,
#               'GGAGGATGATTCGG': 180,
#               'GGAGTTTGTACTCT': 279,
#               'GGATAGCTCGACTA': 59,
#               'GGCCCAGAACTGGT': 807,
#               'GGCTAAACGTAAGA': 1536,
#               'GGGACCACAGTACC': 24,
#               'GGTACATGAGGGTG': 238,
#               'GGTACTGAGTCTTT': 21,
#               'GGTGATACCCAACA': 298,
#               'GTTATGCTTTCACT': 1651,
#               'GTTCAACTCCTTCG': 892,
#               'TAAACAACCCCTTG': 2031,
#               'TAAATGTGCACTCC': 141,
#               'TAACACCTCCTAAG': 1925,
#               'TAAGAACTTGTCCC': 1862,
#               'TAATGATGTCTAGG': 23,
#               'TACGTACTGGATTC': 1894,
#               'TACTGGGACAGGAG': 236,
#               'TAGAATACTAGATG': 1,
#               'TAGGAGCTCCCAAA': 367,
#               'TATCCCACTCATTC': 10,
#               'TATACCACTCATTC': 1208,
#               'TATCCGGATCTTAC': 1,
#               'TATGTGCTTGTTCT': 807,
#               'TCAGTACTTTGTCT': 435,
#               'TCCATCCTAACGAA': 10,
#               'TCCCGAACACGGTT': 9,
#               'TCCGAGCTGCCAAT': 86,
#               'TCGCAAGACAGAGG': 7,
#               'TCGGACCTTGCTCC': 581,
#               'TCGTTATGCAGAGG': 1233,
#               'TCGTTATCCAGAGG': 3,
#               'TGATAAACACGAGT': 1,
#               'TGATAAACACGACT': 644,
#               'TGGAACTGGTGAGG': 813,
#               'TGGAGGGACAGAGG': 56,
#               'TGGATCGAATGCTG': 1305,
#               'TGGTAGACGTCCTC': 70,
#               'TGGTCAGAGACACT': 5,
#               'TGTAAAACAGTGCT': 129,
#               'TGTATGCTCCACCT': 1168,
#               'TGTTACACTGAGAA': 1233,
#               'TTACTCGAGGAAAT': 1501,
#               'TTAGTCTGTCGCCT': 1008,
#               'TTGGGAACTGCCTC': 15,
#               'TTGTACACCTATGG': 19,
#               'TTTAGAGAATTCCT': 1757,
#               'TTTAGGCTCACTGA': 4460,
#               'TTTAGGCTAACTGA': 18,
#               'TTTATCCTGGTGTT': 281,
#               'TTTCACGATGTAGC': 553,
#               'GAAGTAACACGTGT': 1,
#               'AATCGGTGCCCACA': 6,
#               'CGTGCGCCCGCGGG': 1,
#               'TGGCACCGGGTTGC': 1,
#               'ACTTGTCACGCATA': 1,
#               'TGCGAAACCTATTA': 13,
#               'TTCTTACTCCGCGG': 1,
#               'CCCGATCTCCAGAA': 1,
#               'TTGGAGCCCCTCCC': 3,
#               'GGGCAAGGATCGCC': 1,
#               'AACCATCACCTTGC': 1,
#               'ATCCCGGACCCACA': 5,
#               'ACCACACAGTAACA': 1,
#               'TAAGCGGCTGCGAC': 1,
#               'TTCCTTCTCGGTGA': 1,
#               'TAACTAGCCGTCAC': 1,
#               'CTGAAGTGCCTCTT': 1,
#               'TCACCCCTCTATGC': 1,
#               'AAACGCTGAGTTCG': 20,
#               'AACCGCTGAGTTCG': 1,
#               'AAAGACGATAGAAG': 1520,
#               'AAAGAGACCTCTTA': 371,
#               'AAATCAACTTCCAT': 21,
#               'AAATCATGTCTCAT': 869,
#               'AAATTGACAGTAGA': 49,
#               'AAATTGACTTAGGC': 562,
#               'AACCTACTAAGATG': 25,
#               'AACCTTACAAGTGA': 7,
#               'AACGGTTGTTGTCT': 29,
#               'AACGTGTGTGATGC': 1420,
#               'AACGTTCTAACGTC': 761,
#               'AAGGTCACTACGAC': 72,
#               'AAGTCCGATGCCCT': 1281,
#               'AATAGGGAAACCAC': 97,
#               'AATATCGACTATGG': 1325,
#               'AATCAAACTGCAAC': 304,
#               'AATCGTACCGATAC': 1,
#               'AATCCTTGCTTTAC': 1743,
#               'AATGAGGACTGAGT': 119,
#               'AATGATACTTTCAC': 134,
#               'AATGTAACGAGGCC': 3,
#               'AATGTAACGAGGAC': 152,
#               'AATTACTGTCTATC': 3,
#               'ACAATCACCGTGAT': 2,
#               'ACAATAACGGTGAG': 188,
#               'ACAGTGTGCTTCCG': 38,
#               'ACCCAGCTAGTCGT': 214,
#               'CCCGCGGAAGTCGT': 1,
#               'ACGAGTACCGACAT': 283,
#               'ACGGAACTAGTACC': 34,
#               'ACGGCTCTTTGGTG': 435,
#               'ACTACGGAACAGTC': 2045,
#               'ANTGTTACTTGCTT': 1,
#               'ACTGTTACTTGCTT': 270,
#               'ACTTCTGATATGGC': 33,
#               'ACTTGTACTAGAGA': 1179,
#               'AGACACACAACGAA': 121,
#               'AGCCACACACGGGA': 10,
#               'AGAGAATGTCCTTA': 1284,
#               'AGATTAACGTGCTA': 550,
#               'AGCGCTCTCGGAGA': 7,
#               'AGCTGTGAGTCTGA': 126,
#               'AGGCCTCTACCTGA': 2915,
#               'AGGGAGTGATCACG': 918,
#               'AGGGCCACTACTTC': 392,
#               'AGTAATACGTTACG': 535,
#               'ATACACCTTTCGTT': 10,
#               'ATACGGACACCCTC': 225,
#               'ATCACGGACACACA': 1371,
#               'ATCATGCTTCTCGC': 25,
#               'ATCGAGTGCTGAAC': 3,
#               'ATCTACACTAGAGA': 417,
#               'ATGATATGGGATCT': 206,
#               'ATGCGCCTGGATCT': 10,
#               'ATGGTGACCCGATA': 104,
#               'ATGTTGCTGTCAAG': 1,
#               'ATTATGGAGAGAGC': 2474,
#               'ATTGGGTGTCCCAC': 35,
#               'ATTTGCACCAGATC': 71,
#               'CAAATATGCAGGAG': 13,
#               'CAACTTTGCTCTCG': 246,
#               'CAAGAACACAACTG': 3,
#               'CAAGAAGCCAACTG': 3,
#               'CACAGAACGAAGGC': 1074,
#               'CACCCATGATCAGC': 287,
#               'CACCGGGAATCCCG': 40,
#               'CACCGTACCTGTCC': 2,
#               'CACCTGACGTACAC': 36,
#               'CGCCTGACGTACAC': 1,
#               'CACTCCGACTCCCA': 66,
#               'CACTCTCTCATTGG': 351,
#               'CACTTAACAGGGTC': 6,
#               'CAGGGCACAGAACA': 327,
#               'CATAAAACTTCCAT': 689,
#               'CATCATACCCTCGT': 729,
#               'CATTGTCCTCCCGT': 4,
#               'CCAGCGGAGGTCAT': 1430,
#               'CCAGCGGATGGTAC': 1332,
#               'CCCTAGTCTAGAAG': 3,
#               'CCCTTACTTCGTTT': 1026,
#               'CCGACTACTCCAGA': 160,
#               'CGACTGCTTGACAC': 24,
#               'CGAGGAGATTGCGA': 1149,
#               'CGCATAGATGGATC': 249,
#               'CGCGAGCCTCGCCT': 2,
#               'CGGAATTGTTGCAG': 9,
#               'CGGATAACCCTCGT': 189,
#               'CGGGCATGAGTCGT': 540,
#               'CGTTAACTCGCCTT': 38,
#               'CTACTATGGAGCAG': 88,
#               'CTCAGCACTGTGGT': 14,
#               'CTCAGGCTGCGATT': 120,
#               'CTCGAGCTAGTGTC': 955,
#               'CTCGAGCTTTATCC': 359,
#               'CTGAACGACCACAA': 436,
#               'CTGAAGACCTCCAC': 53,
#               'CTGAAGTGACTCTT': 11,
#               'CTGAAGTGCCTCGT': 2,
#               'CTGATTTGGGTGGA': 74,
#               'CTGGATACCTTAGG': 2,
#               'CTTACAACTAGCGT': 63,
#               'CTTGTATGCCTCGT': 1179,
#               'CTTTGATGGTACCA': 1334,
#               'GAAATACTAGAATG': 1067,
#               'GAAGATGACTCGAA': 794,
#               'GAAGTCACACGTGT': 155,
#               'GACAGTACTACTCT': 153,
#               'GACCCTACTCCAGA': 171,
#               'GACGTATGTGACCA': 1290,
#               'GAGGTACTGCCATA': 33,
#               'GAGTACACAAGCAA': 1868,
#               'GAGTGTTGGGTATC': 590,
#               'GATAGCACCTCAGA': 368,
#               'GATATATGCCAAGT': 501,
#               'GCACCTTGAGATGA': 359,
#               'GCACGGACCTATTC': 5,
#               'GCACTGCTCGCCTT': 257,
#               'GGAGACGACGTAAC': 74,
#               'GGAGCCGACGTAAC': 2,
#               'GGAGCGCTTTGCGA': 869,
#               'GGAGCGCTTTGCGC': 29,
#               'GGAGTTACTAAGGA': 127,
#               'GGATGTACTACTGG': 1986,
#               'GGGACCTGAATGCC': 1526,
#               'GGGACCTGCTTGTT': 1091,
#               'GGGCAAGAATTGGC': 163,
#               'GGGTAACTGCATCA': 175,
#               'GGTACATGGTTGAC': 1007,
#               'GGTCAAACGATCAG': 1,
#               'GGTCAAACGATAAG': 726,
#               'GTAAGCTGCCAATG': 94,
#               'GTAAGCTGCTTACT': 486,
#               'GTAGCTGATTAGGG': 3,
#               'GTAGCTGATTAGGC': 341,
#               'GTCAACGAGAAGGC': 913,
#               'GTCAACGATGTGAC': 6,
#               'GTCACAGATTAGGC': 931,
#               'GTCCCAGATTAGGC': 9,
#               'GTCCCATGGAATGA': 265,
#               'GTCGAATGTGGTTG': 324,
#               'GTTAAATGATGTCG': 1236,
#               'GTTATGCTGTCACA': 16,
#               'TAACTCGAAGCGTT': 1,
#               'TAAATCGAAGCGTT': 15,
#               'TAACGTCTGGAGGT': 736,
#               'TAAGAGGATGCCAA': 880,
#               'TAATGCCTCGACTA': 89,
#               'TAATGCCACGACTA': 1,
#               'TACACACTAAACGA': 7,
#               'TACGCCACTGTAGC': 24,
#               'TACTAAGATCGCTC': 50,
#               'TACTTGACAGCGTT': 1327,
#               'TAGGTCGAAGTACC': 978,
#               'TAGGTGTGTCGTGA': 22,
#               'TCAACACTCTATTC': 536,
#               'TCAAGGTGAAAGCA': 8,
#               'TCACAACTCGCATA': 195,
#               'TCATCAACTTGTCT': 598,
#               'TCATCATGACCTTT': 215,
#               'TCCCAGACAAGATG': 1348,
#               'TCCCAGACGTAAGA': 1325,
#               'TGACGAACACGGGA': 86,
#               'TGATATGAGACGTT': 245,
#               'TGCAAGTGGAAGGC': 15,
#               'TGCAGATGGTTGGT': 1819,
#               'TGCGAAACAGGCGA': 173,
#               'TGTAAAGACTGTGA': 1,
#               'TGTTACTGCACTCC': 455,
#               'TGTTACTGTCTCAT': 171,
#               'TTACCATGTTCGCC': 156,
#               'TTCACCCTTCCTCG': 230,
#               'TTCGATTGTGCGTA': 60,
#               'TTCTTACTCCGCTT': 86,
#               'TTGACACTATTCTC': 95,
#               'TTGACACTCCTGAA': 8,
#               'TTGCTATGGGACTT': 186,
#               'TTGGAGACCCTCCA': 120,
#               'TTGGAGACGACAGG': 62,
#               'TTGTCATGTACTCT': 414,
#               'TTTCAGTGGCTTCC': 1115,
#               'TTTCTACTGCGGAA': 44,
#               'AGATTAACAGCGGA': 1146,
#               'AGCATTCTACCGAT': 1995,
#               'CAACCAGACGTAAC': 641,
#               'CACTAACTTGCCCT': 730,
#               'CAGCTCACCCCTCC': 26,
#               'CATAAAACTGTCTT': 2705,
#               'CCCAGTTGACGGTT': 406,
#               'CTATCATGAGAACA': 42,
#               'GCAGGCACGTCAAC': 13,
#               'TACATCACAAAGCA': 852,
#               'TAGAATACTAGAAG': 22,
#               'TAGATCCTTCTCTA': 454,
#               'TAGCGATGAGAGGC': 16,
#               'TTACGACTGCTGAT': 32,
#               'GCCCCGGAGTAAGG': 1,
#               'CTCAGCCCGGTGGG': 1,
#               'ATACACCTGGTAGG': 267,
#               'ATTAACGAGCTTCC': 227,
#               'CACTAGGATCCTAT': 605,
#               'CATTGGGACTCTCG': 8,
#               'CCCTAGTGTAGAAT': 2,
#               'GCAATCGACTGATG': 634,
#               'GCTAGAACCCTAAG': 605,
#               'GGAGCAGATTCCAT': 5,
#               'GTTAGGTGCGAGTT': 793,
#               'ACAAACCATCCCAA': 1,
#               'AGGCAAGATGCTTG': 1,
#               'ACCTATTGCCCTCC': 11,
#               'CGTCAAGAGTTGCA': 293,
#               'GCCATGCTGCTTCC': 387,
#               'TGACGCCTCTATTC': 432,
#               'TGACGCCTGCGGAA': 22,
#               'TAGGCAACGGCCGC': 2,
#               'AATTGATGGCGAGA': 1077,
#               'ATTACCTGCCTTAT': 46,
#               'ATTGAATGTTGAGC': 550,
#               'CTGAGCCTTGTGCA': 515,
#               'CTTGAGGAAGTCAC': 998,
#               'GCTCAAGAAACGAA': 227,
#               'GTGTCAGATAAGGA': 669,
#               'TACACACTAAACGC': 1,
#               'TAGAAACTGCCCTT': 50,
#               'TATAAGACACTGTG': 14,
#               'TCCATCCTTCCTAT': 1344,
#               'GAGCTTACCAGTCA': 1,
#               'AACTCGGATAGACA': 2,
#               'AGAAACGCTCCGAA': 1,
#               'ATTACCTGGCGATT': 1000,
#               'CTTGAACTCACTGA': 254,
#               'GAAGTCTGTCTAGG': 826,
#               'TAGTTCACCCGTAA': 22,
#               'TAGTTCACTCAGAC': 39,
#               'TGTGACGCACCTTT': 15,
#               'CGTTAAATCGCCTA': 1,
#               'ATCACGGCCCCCCA': 3,
#               'AAGTGGCTCCGCTT': 46,
#               'AGCTGTGACCATCA': 9,
#               'AGGTTCGACGCCTT': 179,
#               'ATAGGAGAACTCTT': 31,
#               'CATTGGGATTACCT': 160,
#               'CGAGCCGACCATAG': 873,
#               'CGTACAGATCACCC': 794,
#               'GGACAGGATCAGAC': 56,
#               'CTTATCGCCCCGCA': 1,
#               'AGTTGTCTGAAAGT': 494,
#               'CCACCTGATCGCTC': 1528,
#               'CCAGAAACGGACAG': 286,
#               'CCATAGGAGTAGGG': 58,
#               'CTACAACTCAGAAA': 389,
#               'GAGATAGAGCTTCC': 1449,
#               'GATCGAACCACCGA': 1,
#               'GTGAGGGAAGTGTC': 210,
#               'GTTGTACTGTCTGA': 101,
#               'TAGGAGCTGGACAG': 110,
#               'TATCTGACCTCCAC': 1322,
#               'TCGCAAGCCAGAGG': 2,
#               'TGACTTTGACGTAC': 384,
#               'TGAAAAACACGACT': 5,
#               'TCCCCTCTCTATTC': 21,
#               'AACTGTCTCGACAT': 2268,
#               'CCTATTGATCACCC': 328,
#               'GACTGAACTGCAGT': 968,
#               'GGATAGCTTAAAGG': 354,
#               'TACGAGTGGCATCA': 370,
#               'TAGCATCTGTTCAG': 160,
#               'AGCTAACACACAAA': 1,
#               'CGCGGTGTTCCACG': 1,
#               'GCCCGGGTTGCTGC': 1,
#               'ATAGGCTGTTCGTT': 1244,
#               'CACTTTGATTACTC': 81,
#               'CAGACAACGCTATG': 1805,
#               'CATAGTCTCATTTC': 1560,
#               'CGCAAATGGGACCA': 1,
#               'CTATGTTGGGGAGT': 665,
#               'GGAGGTGATAGCCA': 50,
#               'GGTACTGAATGGTC': 1872,
#               'CTCCTATGGCGCCG': 1,
#               'AATTCCTGTCTATC': 246,
#               'ACGTCGCTAAGTAG': 455,
#               'AGCTGTGACAGAAA': 9,
#               'ATACGGCCACCCTC': 6,
#               'ATCATCTGTGTTCT': 23,
#               'GTCCAGCTATGTGC': 423,
#               'GTTATAGAAGAACA': 1026,
#               'TACATAGAATAAGG': 1687,
#               'TCATCCCTTACGAC': 228,
#               'AGGCCGACCCAGAG': 1,
#               'AACCTTTGCCGATA': 591,
#               'ACGAAGCTCATGCA': 28,
#               'AGCCACCTTGCGTA': 5,
#               'AGCGGGTGGGGAGT': 1,
#               'ATTACCTGCAACTG': 262,
#               'CACTAGGCCTCCAC': 21,
#               'CAGGGCACACTAGC': 399,
#               'CTACAACTAAAGTG': 51,
#               'CTGTAACTCTACCC': 457,
#               'GAGGCAGAACCATG': 172,
#               'GGCCGATGTACTCT': 1314,
#               'GTCCAAGAAGTGTC': 510,
#               'TGATCGGAGACACT': 5,
#               'CTGCCGCCCGCCAC': 1,
#               'CTTACATGTGTCTT': 176,
#               'GCTACAGAAGGCGA': 72,
#               'TCGTAGGAGGAGCA': 17,
#               'AAAGCAGATTTACA': 27,
#               'CAAGTCGAGTTCGA': 1779,
#               'CACCACTGCAGAAA': 12,
#               'GATGCATGTTCGTT': 15,
#               'GGTACATGGGGATG': 1185,
#               'ACCGTGCTTCACGA': 153,
#               'ATCGTTTGATGTCG': 766,
#               'CAAGAAGACAACTG': 80,
#               'CCTATTGAATAAGG': 193,
#               'CGAGGAGATTGCGC': 33,
#               'GAATGGCTCGTAGT': 3,
#               'GATTGGTGCCGATA': 54,
#               'GCACCACTCGCATA': 1,
#               'GCACGGCCCTATTC': 1,
#               'GGTTGAACGCCTTC': 181,
#               'TAGGCAACGGACGA': 155,
#               'TAGTCACTACGGAG': 995,
#               'TATACGCTCATGGT': 1,
#               'TGGATCGAATGGTG': 5,
#               'TGTATCTGGGGATG': 260,
#               'GGAGAACCTATTCA': 1,
#               'CAACGACTCTATCA': 12,
#               'AACCACGATGAACC': 279,
#               'CAGACAGACTTAGG': 1,
#               'GACGCCGACCGCTT': 49,
#               'GACGCCGCCCGCTT': 7,
#               'GGTACTGATGTCAG': 59,
#               'TCTTGATGACCATG': 148,
#               'TTACGTACTTGTGG': 1036,
#               'GCACATACACTTTC': 5,
#               'AATCGGTGCCCTCC': 2,
#               'ACGGATTGTCCGTC': 731,
#               'ACTGAGACGGTTTG': 340,
#               'ATGGGCTGTCCCAC': 1,
#               'CCAATTTGTGCCTC': 532,
#               'CTGAGCCTTGTGCC': 5,
#               'GCCCCTACTCCAGA': 17,
#               'TGCAAGTGGAAGGG': 1,
#               'CCCCCTGCCGCGAG': 1,
#               'CGGGCGCCCCGGGG': 1,
#               'CTAGGCCTGTTCTT': 63,
#               'GGATACTGACAGTC': 789,
#               'GGATAGCTAAGCAA': 6,
#               'TATCCTGATCTTAC': 196,
#               'TCCCTACTACCTCC': 84,
#               'ACGATCGAGCTACA': 321,
#               'GTTATGCTGTCACC': 1,
#               'AAATTCGAGGTTTG': 42,
#               'ACTTGTACGTAAAG': 2,
#               'ATTTCCGCCTCAAG': 67,
#               'CGCAGGACAAGAAC': 398,
#               'CGTGCACTGCCTTC': 304,
#               'GGACCCGAAAGAAC': 100,
#               'TAGCGATGAGCGGC': 2,
#               'TAGGCAACAGGAGC': 4,
#               'ACGTCCGCGCCGCG': 3,
#               'AAGCAAGAGTCTGA': 142,
#               'AAGGTCTGGTTCGA': 394,
#               'AGCAAGCTCAGAAA': 103,
#               'AGCTGTGACCCTCA': 703,
#               'AGGGCGCTGAGACG': 26,
#               'CACCCATGGCCTAC': 2,
#               'CTGAAGCCCTCCAC': 3,
#               'GAACCAACGAGGGT': 65,
#               'GACGTCCTGGAAAT': 288,
#               'TAATCGCTTGACCC': 48,
#               'TCCCATCTAGCCTA': 1747,
#               'TTAGGGACATGTGC': 24,
#               'TTGGAGACGTATCG': 21,
#               'AGAGCAACCCAAGA': 4,
#               'ACTCCCGAGTCTAG': 2573,
#               'CACTAACTTGCTTT': 184,
#               'CTAGTTTGTGCGTA': 51,
#               'GCACAAACTAGCGT': 251,
#               'GTGTATCTCGCCTT': 920,
#               'TTACTCGATCTCTA': 7,
#               'GGGCAGCGCTGGTG': 1,
#               'AAGGCTTGCAGATC': 913,
#               'CAATATGACGATAC': 229,
#               'CATTAGCTGTCCTC': 37,
#               'GTAATAACATGTGC': 80,
#               'TAGCATCTCCTTGC': 250,
#               'TCCTATGACTAGCA': 475,
#               'TAACCCCCCCCGTG': 2,
#               'CAGCTCACTAGACG': 2,
#               'GCCATGCTGCGTCG': 1,
#               'AACGTTCTAAGAAC': 74,
#               'AGCCTCACTCCAAG': 7,
#               'CTGGATGATCCTGC': 460,
#               'GCACGTCTTCCTTA': 47,
#               'TTGAGGTGACGCTA': 92,
#               'TTTCTACTCACACA': 245,
#               'AAGTCCGAGACGAG': 1571,
#               'AATCGGTGCACAAC': 82,
#               'CCCGTGCTTCACGA': 4,
#               'ATATACGATCCAAG': 579,
#               'ATATGAACCCTCCA': 60,
#               'ATCTACTGGGATTC': 1788,
#               'CCACCGGATCGCTC': 2,
#               'CGCGAGACTCGCCT': 50,
#               'CTCAGCACGAGCAG': 513,
#               'GTCCAGCTACGCAT': 181,
#               'TCACCGTGCTTCCG': 11,
#               'TTCATGTGCACCAC': 9,
#               'TTCATGTGCACAAC': 873,
#               'AGGGCCCGGGATTG': 1,
#               'AAATTCGATGGTTG': 15,
#               'AGTAATTGACACGT': 30,
#               'GGAATCTGATTCTA': 2,
#               'GTGATGACAGCATC': 36,
#               'GTTAAAACGCTGAT': 1155,
#               'TACCGGCTCTCAGA': 95,
#               'TAGGAGCTGGACAC': 2,
#               'TATTGGTGGTGCAT': 2,
#               'TCCCGATGTTGTCT': 12,
#               'TGGAGACTTAGCCA': 1280,
#               'TTCGGAGAACGTAC': 768,
#               'ACCGCGGAAGTCGT': 5,
#               'ACCGCGCAAGTCGT': 1,
#               'AGTTAAACCCTTAT': 280,
#               'ATGTCACTGTAGGG': 505,
#               'CAATCTACGAGGTG': 66,
#               'GATGCAACCGTTGA': 336,
#               'GGAACACTGACGGA': 534,
#               'ACCGCCGAGGGCCG': 1,
#               'AGCGCTCTTCCAAG': 745,
#               'CTACGGCTCACTAG': 220,
#               'GAATGATGGTTCTT': 1,
#               'GGTATGACAGGTTC': 1441,
#               'AGACACCCACGGGA': 1,
#               'CAAGTCGAGCTTCC': 53,
#               'TAAACCCTAACTAC': 1,
#               'AAACATACAACAGA': 625,
#               'AACACTCTCCGTAA': 18,
#               'ACTTAAGATAGCGT': 397,
#               'ATTGAATGTCCGCC': 1,
#               'GACGCTCTCCTACC': 335,
#               'GCCATGCGGCTTCC': 1,
#               'TGCTATACATACCG': 1722,
#               'TTATCCGAGCATAC': 318,
#               'TTCAAAGACATTCT': 551,
#               'AACGCAACCATTTC': 695,
#               'ACGTTGGAAGGAGC': 276,
#               'ATTAGATGGTAGGG': 1754,
#               'ATTAGTGAGAGGTG': 5,
#               'CGCTACTGTCTAGG': 186,
#               'GAGGGTGATTTGTC': 3,
#               'TAACCCCTCCTACG': 4,
#               'AATGAGGAATGTCA': 1,
#               'ACGATTCTTAAGGA': 1232,
#               'CGTGATGAGTAGCT': 335,
#               'GAAGCTTGGCCAGG': 3,
#               'GATAAGGAGCATCA': 265,
#               'GCCGGAACTTCGTT': 72,
#               'TCCCGAACGAATCC': 370,
#               'TCTGAAACAGAGGC': 1,
#               'AATATCGCCTATGG': 37,
#               'ACTTAAGACAGCTA': 111,
#               'ATGTTAGAGTCCTC': 993,
#               'GAACGGGAACACGT': 16,
#               'GTCCCATGGGATCT': 843,
#               'TAGGTTCTGGGAGT': 30,
#               'CATTAGCTGGACTT': 332,
#               'GCCTCATGGTCCTC': 158,
#               'GGTACTGACTGATG': 33,
#               'AGCCCACTCCCGCA': 1,
#               'AATGGTGCTGCGGC': 1,
#               'AGAGAATGTCATTA': 5,
#               'AGGACCCTTTCTCA': 3,
#               'ATGATATGGGATAT': 2,
#               'TAGGCGCTCCCCAA': 2,
#               'ACCACTCCTCGAGG': 1,
#               'CGGACCGAAGAACA': 9,
#               'AGCGAACTTTCCGC': 181,
#               'CACGACCTAGGGTG': 27,
#               'CCGCTATGAGTTCG': 1202,
#               'GTGGAGGATCTGGA': 17,
#               'TGTTAAGACTGTGA': 491,
#               'TTAAGACAATTCCT': 2,
#               'GTTAGAGACCATGC': 1,
#               'AAATCTGACTTTAC': 941,
#               'AAGCCTGAAGGTCT': 119,
#               'ACACCAGAGGTACT': 1863,
#               'ATCAACCTTAACCG': 35,
#               'ATGTTAGATTACCT': 792,
#               'CAAATACTGAAACA': 1,
#               'CACTAGGACTCCAC': 585,
#               'TACATCACAAAGCC': 9,
#               'AGACTTATTAATGC': 1,
#               'ATAACATGAGTCAC': 218,
#               'ATCAGGTGCTGTGA': 312,
#               'ATGGCCACGTAAAG': 18,
#               'CGGTCACTGATACC': 6,
#               'GTGGATTGGGTACT': 1542,
#               'TAACAGGACTTTAC': 2,
#               'TAGGACTGTAACGC': 8,
#               'TCTCAAACTTGCAG': 31,
#               'TTCATTCTCGTTGA': 2580,
#               'ATCGGCTGGTCGTC': 1,
#               'ACGGATTGCCCACA': 6,
#               'ATAGGCTGGTCGTA': 136,
#               'GAGCAACTGACGAG': 23,
#               'GTTAACCTCCTTCG': 529,
#               'CCCCTCCTCCGCTG': 1,
#               'AACTGTCTCGCCAT': 82,
#               'ACTTGACTCAGCTA': 933,
#               'AGACGTACAGCGGA': 145,
#               'AGCTCGCTCTGTTT': 446,
#               'ATACCCCTGGTAGG': 11,
#               'TGGACCACCTTGTT': 1,
#               'ATAGCCTCATCCTT': 1,
#               'TGCTATCCCTCGCG': 1,
#               'AGCAAAGAGAGATA': 6,
#               'ATCCCGTGTGCCCT': 61,
#               'ATGTAAACGTTCGA': 825,
#               'GAGTCAACCTTACT': 1156,
#               'TAACCAACCCCTTG': 18,
#               'ATACACCTGTACCA': 4026,
#               'CCAGCGGAGGTCCT': 10,
#               'CAGACTACTCCAGA': 4,
#               'TTCATTCTCAACCA': 1166,
#               'CCCAAGAGGCCGTA': 1,
#               'GACAGTTGAAAGTG': 23,
#               'GCTAGCACCTCAGC': 1,
#               'ATTGCGCTTGGTTG': 2,
#               'ATCCCCCTGGTAGG': 3,
#               'TGACGCCCACGGGA': 2,
#               'AAGCGTACTTGTGG': 71,
#               'ATTGGGTGGCCCAC': 1,
#               'CAGATCGATAGAGA': 229,
#               'GGCGACTGAAGTAG': 26,
#               'TAAGAGGATTCAGG': 19,
#               'TAATCGCTTGAACC': 1717,
#               'TAGAAACTTGGTTG': 1088,
#               'TTCCTAGATGTAGC': 990,
#               'TTGGAGCCGTATCG': 1,
#               'GGATAGCTTCGCCA': 1,
#               'CGCTCAGAGGCAGT': 1,
#               'TACAATGACACTGA': 135,
#               'AATCCTACCGATAC': 40,
#               'AGCCTCACTCCTTA': 565,
#               'ATGTTGCTGTCATG': 269,
#               'CAGACCCTCTCCCA': 94,
#               'GGGACCTGAATCCC': 8,
#               'AGTCCAGAGTGAGG': 1690,
#               'CTCCTGTGGGGTCT': 1,
#               'AAAGAGCGCTCGTC': 1,
#               'ACGCTCACGGTGTG': 1,
#               'AGTTATGAGAGGAC': 975,
#               'GTTGTACTAGCAAA': 202,
#               'CACTAGGCCTCCCC': 7,
#               'ACGCGGTGTTCACT': 46,
#               'AGCCTCACTACAAG': 1,
#               'CAAATTGACCAATG': 140,
#               'CAATATGATCCCAC': 2438,
#               'CACCTGACCAGCTA': 332,
#               'CTCAGAGATATTCC': 1488,
#               'CGGATAACCCTCNN': 1,
#               'ACACATCTGTGCAT': 158,
#               'ACTAAAACAGAACA': 88,
#               'CAATATGATCACCC': 667,
#               'CCAACTACTCCAGA': 1,
#               'GCAGTCCTAGATCC': 491,
#               'TATGTCACTGGCCT': 1,
#               'TATGTCACTGGCAT': 53,
#               'TGTGACGAACCTTT': 1247,
#               'TTAGGGTGTAGTCT': 2,
#               'CCATTAACACAATG': 9,
#               'GTACAGTGGAGGAC': 1087,
#               'TTTCCAGAATTTCC': 1494,
#               'ACCAAATACTAGCA': 1,
#               'ACCTCCCGGGCGCC': 3,
#               'AAGTGCACCGCTAC': 15,
#               'CCATCACTGGCGAA': 11,
#               'GAGCGAACGTAAAC': 1,
#               'CTAAGGATAAGCAT': 1,
#               'CTAGTTTGCTGAGT': 26,
#               'ACCACAGAGATACC': 55,
#               'ACGGACCTAGTACC': 1,
#               'ACTACTACAGCTCA': 245,
#               'ATCACGGACCCACA': 28,
#               'CGACGTCTTCTATC': 21,
#               'TCTTACGACGCATA': 1569,
#               'AATGCATGTTCGTT': 1,
#               'GCACGGCTTCCTGA': 1,
#               'ACTGCCTGATTGGC': 893,
#               'AGGACACTTCAAAC': 1,
#               'AGGACACTTCATTC': 316,
#               'GAGGGCCTCTAGCA': 50,
#               'GTTAGTCTGGACGA': 898,
#               'TATGGTCTTGCCAA': 8,
#               'TTTAGAGACCATGA': 50,
#               'ACAAGCACCGTGAT': 1498,
#               'AGTTGTCTCGCATA': 54,
#               'CGCCCTACACCCTC': 5,
#               'GAAAGATGGTCACA': 113,
#               'TAAGAGGACTTTAC': 205,
#               'TCACCCCTCTATTC': 3,
#               'TGATTAGAAGGTCT': 13,
#               'CTCAGGATAAGCAT': 1,
#               'GGGCCCACAGTACC': 1,
#               'CATACTTGTCTATC': 774,
#               'GTTATCTGTGACTG': 61,
#               'TACCGCTGATTCCT': 3,
#               'TTGAGGACCTCAGA': 916,
#               'TTGATCTGAATAAC': 1,
#               'TGGTTACTGGCGCC': 1,
#               'ACGCGGTGTCTATC': 1417,
#               'AAGGTGTGGTGTCT': 1,
#               'ACCTCGTGCGACTA': 394,
#               'CCCCCTGATCGCTC': 86,
#               'CAGAACAAATCCAC': 1,
#               'AGGACACTTTCTCA': 42,
#               'GACGTCCTTTTCGT': 274,
#               'GAGCATACTGCGTT': 1,
#               'GCATGATGGTTCTT': 5,
#               'TATAGCCTCAGGAG': 221,
#               'TATCACTGACCAAC': 110,
#               'AACAGAGACCATAG': 34,
#               'AATGGAGAGTTCGA': 405,
#               'ACTCCTCTTTCTGT': 284,
#               'ATACCACTATGTGC': 553,
#               'ATCTACACGTTAGC': 183,
#               'GACTGAACTCCCGT': 269,
#               'AAAGATCTCCTTAT': 507,
#               'GCACGTCTTTCTGA': 1,
#               'TAGAGCACGGCAAG': 404,
#               'TCTGATACAAAAGC': 914,
#               'AACCTTTGCGGTAT': 12,
#               'GCGTGAACTTTCCC': 1,
#               'GTGTCTATTAGTCG': 1,
#               'GACTGCACTTTCCC': 7,
#               'GTGTATATTACTAC': 1,
#               'GTGTATATTCGTAT': 1,
#               'TTGTATATTATTAA': 1,
#               'GTGTATATTAGTCC': 1,
#               'CAGACTGACTATGG': 186,
#               'GACCATGATCAGTG': 2,
#               'GACTGAACTTTCAC': 953,
#               'CACTGAACTTTCAC': 3,
#               'GACTGAAATTTCAC': 1,
#               'GTGTATCTTCGTAG': 467,
#               'GTGTATCTTCGTAT': 4,
#               'GTGTATATTCGTAG': 5,
#               'TGATTCTGTCTTAC': 1112,
#               'GGTACAGAACAATC': 1,
#               'ATGTTGCTGCAGAG': 110,
#               'GAGTGTTGGGGATC': 5,
#               'CGGACCTGAATGCC': 5,
#               'TAACCGGACATTTC': 173,
#               'TAGGTTCTGACGAG': 2066,
#               'TATACAGAGCTACA': 213,
#               'TTATGAGATCCCGT': 1534,
#               'GGGGTGCGCGGGGC': 1,
#               'CGCAAATGCGACGA': 1,
#               'CTTATCGAAACGAA': 998,
#               'TTACCATGCTGCTC': 529,
#               'CGGCCTTGTTGCCG': 1,
#               'TTCATTCGCGTTGC': 3,
#               'GAACGGGATGACCA': 164,
#               'CCTAAACTGAGCAG': 20,
#               'GCCAAAACGTTTCT': 91,
#               'AACTACCTTGCCCT': 241,
#               'TCGAGAAAGTCTTT': 3,
#               'ACCATTTGAGCACT': 812,
#               'CAATAATGTTTCTG': 2,
#               'GCCTGACTAGTCGG': 33,
#               'TGACGCCTCTAATC': 2,
#               'ACTCCTTGGTTTAC': 2,
#               'ATAATAGATGTAGC': 1,
#               'ACGGAATCCACACA': 1,
#               'AGAACGCTTAGCGT': 16,
#               'AGTTGTCTGAAATT': 1,
#               'TTTAGGCTCACTGC': 112,
#               'TGTTAGATTCGCCA': 12,
#               'AGACACACACGGGA': 183,
#               'ATGCGCCTCGATCT': 1,
#               'CGGAAGTGACTCTT': 1,
#               'GAACCTGATAAAGG': 282,
#               'GACGTCGTTTTCGT': 1,
#               'GATTCTACCTGAGT': 17,
#               'AACCTACTGCGACG': 1,
#               'ATACACCTGCTCCT': 118,
#               'CCTCTACTAACTGC': 753,
#               'GCAACTGATCCCGT': 130,
#               'ACGAGTCCCGACAT': 2,
#               'CGGCACGAAGTAGA': 178,
#               'GAGCATACTGCTTT': 66,
#               'TAAGCGTGAGGTTC': 647,
#               'TACGCCCCTGTAGC': 1,
#               'TGACTTACCTCTAT': 229,
#               'TGCGTAGACCTTCG': 166,
#               'TTGCTATGTGCCTC': 23,
#               'CTGAATTGTTCTCC': 1,
#               'ATCACGTGTGCCCT': 3,
#               'CACTATACCTTTAC': 16,
#               'CATTGTACTTGTGG': 368,
#               'CCGATATGGCTGAT': 2,
#               'GCCACCCTCTGTCC': 7,
#               'TATGGTCTTTCCAA': 1,
#               'TATTGCTGGTGCAT': 941,
#               'TGGTTAATGGAGAA': 1,
#               'CCCTAGTGTAGAAG': 765,
#               'CTAGTTTGTGCCTA': 1,
#               'GTTAAAAAGCTGAT': 3,
#               'GGTACTGAACCATG': 37,
#               'CGGTCCGCGCCCCC': 1,
#               'CCCCCAGACGTAAC': 1,
#               'CCCGGGACAAGTGA': 2,
#               'TCGTAGGATCCTAT': 1112,
#               'GCTATTGATTCATG': 1,
#               'ACCCGTTGATTTCC': 508,
#               'CACAGAACAGTACC': 826,
#               'CACTTAACAGGGTG': 362,
#               'TACTACACCGCCTT': 766,
#               'TCGAGAACGTCTTT': 762,
#               'TGCGAAACCGGCGA': 3,
#               'AGACTTCTGCGTAT': 4,
#               'CACTCTCTACCAGT': 308,
#               'ACGATTCTTAAGGT': 1,
#               'CTATCCCTATCGAC': 606,
#               'TCCACGTGCTAGAC': 343,
#               'GACTGTGAGGTAGG': 274,
#               'ACCCCAGAGGTACT': 34,
#               'GATATATGGTCACA': 16,
#               'ATGCGGCTGGATCT': 1,
#               'ATTCTGACAAACGA': 304,
#               'CACTAGTGTAGAAG': 11,
#               'CGACCACTCTGTCC': 54,
#               'CGCCTGCTTGACAC': 2,
#               'CGTAAACTCGCCTT': 1,
#               'GGACCGTGAGTCAC': 275,
#               'GGGCACACGCGGAA': 95,
#               'AAACCGTGCATGGT': 4,
#               'AATTGTGATCACGA': 2,
#               'CCAAGAACTCCGAA': 1247,
#               'CGGACCGAAGCAGT': 22,
#               'CGCTTCAAGTGATC': 1,
#               'CGACCGATTTGCGA': 1,
#               'AAACTTGAGAGGTG': 419,
#               'GCGGCAACCTCAAG': 1673,
#               'GTAAGCTGCAAATG': 1,
#               'GTTATACTAGCAAA': 1,
#               'GACAAAGAACTCGT': 1,
#               'TTCGAGGAAGCCTA': 1350,
#               'TAAATAACTTAAAC': 1,
#               'CTCGAGCTCGTTAG': 126,
#               'CTCGAGCTCGTTCG': 1,
#               'GAAGTAGAGAATGA': 34,
#               'GCACAAACTAACCG': 173,
#               'GGGGGGTGGTTTTG': 3,
#               'GGATAATGACAGTA': 1,
#               'TTGTACACAGCAAA': 1069,
#               'TTTAGAGAATTCAT': 18,
#               'AATCCTACTGTCCC': 366,
#               'ACCACACAGATACC': 1,
#               'ATTATGGAGAGCGC': 80,
#               'CGAGGCTGCTATTC': 993,
#               'CGGGACTGGAGAGC': 4,
#               'CGTACCTGCGAACT': 139,
#               'GGGGGGGGGGGGGT': 406,
#               'GGGGCCCCTATTGC': 1,
#               'CCCCGTACTATCGG': 1,
#               'CGTACCGATCGTGA': 8,
#               'CGTGCACTAGAAGT': 1,
#               'GGCGGACTAGTAGA': 33,
#               'CATCATACCAACTA': 1,
#               'TCGGGGCGGGGCGC': 1,
#               'ACAAGCACGCTGTA': 176,
#               'ACGTCCTGCTTGTT': 541,
#               'AACCTACTGAGACG': 38,
#               'CCCACATGCCTCCA': 1549,
#               'CCCGATCTCCTGAA': 4,
#               'GGTATCGAGCCGGC': 2,
#               'ATACCCCTTTCGTT': 10,
#               'CAGGTTGCTCCGGT': 2,
#               'AAGGCTACCGTGTA': 13,
#               'ACCTGAGAACCTTT': 260,
#               'CAGGTTGATCCCGT': 1496,
#               'CATCTTGCCCTTCG': 3,
#               ...}),
#  defaultdict(int,
#              {'AAACGCACACGCAT': 212,
#               'AAACGGCTTGTCCC': 369,
#               'AACAATACTCTAGG': 30,
#               'AACAGAGACGAGAG': 1320,
#               'AACCAGTGTTTCGT': 169,
#               'AACCTACTCCAACA': 169,
#               'AACGTGTGTTGTCT': 32,
#               'AACGTTCTACAGTC': 1769,
#               'AACTACCTTTATCC': 50,
#               'AACTCGGATAGCCA': 1096,
#               'AAGCAAGAAAGAAC': 1994,
#               'AAGCAAGATGCTAG': 807,
#               'AAGCCAACGGTTAC': 7,
#               'AAGGTGCTTTGGTG': 561,
#               'AATGAGGAATGCCA': 37,
#               'AATGATACCTCAGA': 317,
#               'AATGTAACTATGCG': 1636,
#               'ACACCAGAGGAGCA': 734,
#               'ACACGATGCACCAA': 922,
#               'ACAGGTACAGTCTG': 567,
#               'ACAGTGTGCGTTGA': 18,
#               'ACCATTACTCTCGC': 1060,
#               'ACCCTCGAACGACT': 504,
#               'ACCTATTGCCCTAC': 1744,
#               'ACGAACTGTATGGC': 709,
#               'ACGGATTGCACACA': 438,
#               'ACGTCGCTTCGTAG': 1130,
#               'ACTCAGGATTCGCC': 733,
#               'ACTGGCCTAAGGTA': 883,
#               'ACTTAAGAGTGCTA': 125,
#               'AGAAACGATCCGAA': 21,
#               'AGAGAAACGGATCT': 1069,
#               'AGCACTGATTGAGC': 469,
#               'AGCGGCTGGGGAGT': 194,
#               'AGGATAGAGGTACT': 2459,
#               'AGGATAGAGTCTAG': 676,
#               'AGTAATTGAAGTGA': 341,
#               'AGTACGTGAAAGCA': 190,
#               'AGTGCAACCCATGA': 56,
#               'ATACCACTCGAACT': 34,
#               'ATAGCTCTTGCCTC': 33,
#               'ATAGGCTGTTCGTT': 1338,
#               'ATCCGCACAGCGTT': 1396,
#               'ATGAGCACTGGTTG': 102,
#               'ATGCAGACTTTCGT': 2297,
#               'ATGTACCTCTACCC': 235,
#               'ATTCTTCTTTGACG': 1514,
#               'ATTGAATGTAAGCC': 2247,
#               'ATTTCCGACTCAAG': 1758,
#               'ATTTCGTGGCGGAA': 124,
#               'CAACCAGACGTAAC': 706,
#               'CAACGTGAATGACC': 931,
#               'CACATACTGAAACA': 28,
#               'CACCGTACTATCGG': 22,
#               'CACGGGACAAGTGA': 10,
#               'CACGGGACTTGCGA': 2,
#               'CAGACATGTTAGGC': 12,
#               'CAGCACCTCTAAGC': 1261,
#               'CAGCGTCTACTACG': 399,
#               'CAGCTCACACCTCC': 431,
#               'CAGCTCACTTGACG': 307,
#               'CAGGGCACGTCCTC': 97,
#               'CATACTACAGGCGA': 518,
#               'CATTACACAGTAGA': 3910,
#               'CCACCTGACCATAG': 2353,
#               'CCAGAAACGGACAG': 327,
#               'CCAGTCTGCTTCGC': 1893,
#               'CCATTAACACACTG': 2046,
#               'CCCAGACTAGGCGA': 18,
#               'CCCAGTTGATGTCG': 37,
#               'CCCTAGTGGCCCTT': 1068,
#               'CCGTAAGACTTCGC': 695,
#               'CCTGACTGCATGGT': 485,
#               'CGACGTCTCGACTA': 190,
#               'CGAGATTGTTACCT': 567,
#               'CGATCAGATGCAGT': 237,
#               'CGCAAATGGGACGA': 39,
#               'CGCCATACGACAAA': 2071,
#               'CGGACCGAAGAAGT': 1733,
#               'CGGACCGACTACCC': 68,
#               'CGGAGGCTACGGTT': 78,
#               'CGGAGGCTGAAGGC': 4,
#               'CGGATAACCTTATC': 1426,
#               'CGTAACGAAGTAGA': 33,
#               'CGTACAGATCGTGA': 1889,
#               'CGTCAAGAAATCGC': 386,
#               'CTACGGCTCACTCC': 2,
#               'CTACTCCTGTTGTG': 799,
#               'CTATCCCTTCTATC': 12,
#               'CTCAGAGAGCTTCC': 11,
#               'CTCAGCACAGGTCT': 393,
#               'CTCAGGCTACGCAT': 2511,
#               'CTGACAGAAGTTCG': 333,
#               'CTGACAGAGTTTGG': 1424,
#               'CTGGCACTTAACGC': 62,
#               'CTTTGATGTTCATC': 1663,
#               'GAATGCACAAACAG': 200,
#               'GAATGCTGAGGCGA': 401,
#               'GACCAAACGGGAGT': 250,
#               'GACCCTACACCTAG': 8,
#               'GAGCGGCTTGAGGG': 1531,
#               'GAGGATCTGCTAAC': 82,
#               'GAGGATCTTTCCGC': 1004,
#               'GAGGGAACGTAAAG': 587,
#               'GAGGTTACCAGTCA': 952,
#               'GATATCCTACCTGA': 56,
#               'GATGACACAAGAAC': 1907,
#               'GATGACACTTTACC': 150,
#               'GCACGTCTTGCTGA': 402,
#               'GCAGATACACCCTC': 76,
#               'GCAGGGCTCGACAT': 338,
#               'GCATCAGAGGCGAA': 1365,
#               'GCATGATGGTTCTT': 7,
#               'GCATGTGACCGAAT': 4,
#               'GCCTGACTAGTCGT': 7322,
#               'GGAATGCTTCAGAC': 4,
#               'GGACCTCTGTCACA': 1052,
#               'GGAGGATGATTCGG': 193,
#               'GGAGTTTGTACTCT': 315,
#               'GGATAGCTCGACTA': 65,
#               'GGCCCAGAACTGGT': 891,
#               'GGCTAAACGTAAGA': 1650,
#               'GGGACCACAGTACC': 25,
#               'GGTACATGAGGGTG': 259,
#               'GGTACTGAGTCTTT': 22,
#               'GGTGATACCCAACA': 321,
#               'GTTATGCTTTCACT': 1772,
#               'GTTCAACTCCTTCG': 980,
#               'TAAACAACCCCTTG': 2252,
#               'TAAATGTGCACTCC': 155,
#               'TAACACCTCCTAAG': 2177,
#               'TAAGAACTTGTCCC': 2051,
#               'TAATGATGTCTAGG': 23,
#               'TACGTACTGGATTC': 2002,
#               'TACTGGGACAGGAG': 256,
#               'TAGAATACTAGAAG': 23,
#               'TAGGAGCTCCCAAA': 387,
#               'TATACCACTCATTC': 1276,
#               'TATCCTGATCTTAC': 215,
#               'TATGTGCTTGTTCT': 871,
#               'TCAGTACTTTGTCT': 468,
#               'TCCATCCTAACGAA': 14,
#               'TCCCGAACACGGTT': 9,
#               'TCCGAGCTGCCAAT': 86,
#               'TCGCAAGACAGAGG': 9,
#               'TCGGACCTTGCTCC': 668,
#               'TCGTTATGCAGAGG': 1338,
#               'TGATAAACACGACT': 708,
#               'TGGAACTGGTGAGG': 881,
#               'TGGAGGGACAGAGG': 60,
#               'TGGATCGAATGCTG': 1391,
#               'TGGTAGACGTCCTC': 72,
#               'TGGTCAGAGACACT': 7,
#               'TGTAAAACAGTGCT': 134,
#               'TGTATGCTCCACCT': 1334,
#               'TGTTACACTGAGAA': 1323,
#               'TTACTCGAGGAAAT': 1588,
#               'TTAGTCTGTCGCCT': 1077,
#               'TTGGGAACTGCCTC': 17,
#               'TTGTACACCTATGG': 21,
#               'TTTAGAGAATTCCT': 1870,
#               'TTTAGGCTCACTGA': 4882,
#               'TTTATCCTGGTGTT': 300,
#               'TTTCACGATGTAGC': 585,
#               'AAACGCTGAGTTCG': 21,
#               'AAAGACGATAGAAG': 1651,
#               'AAAGAGACCTCTTA': 402,
#               'AAATCAACTTCCAT': 22,
#               'AAATCATGTCTCAT': 936,
#               'AAATTGACAGTAGA': 52,
#               'AAATTGACTTAGGC': 611,
#               'AACCTACTAAGATG': 27,
#               'AACCTTACAAGTGA': 7,
#               'AACGGTTGTTGTCT': 29,
#               'AACGTGTGTGATGC': 1526,
#               'AACGTTCTAACGTC': 818,
#               'AAGGTCACTACGAC': 81,
#               'AAGTCCGATGCCCT': 1433,
#               'AATAGGGAAACCAC': 107,
#               'AATATCGACTATGG': 1442,
#               'AATCAAACTGCAAC': 322,
#               'AATCCTACCGATAC': 42,
#               'AATCCTTGCTTTAC': 1856,
#               'AATGAGGACTGAGT': 124,
#               'AATGATACTTTCAC': 147,
#               'AATGTAACGAGGAC': 162,
#               'AATTCCTGTCTATC': 271,
#               'ACAAGCACCGTGAT': 1635,
#               'ACAATAACGGTGAG': 205,
#               'ACAGTGTGCTTCCG': 42,
#               'ACCCAGCTAGTCGT': 237,
#               'ACCGCGGAAGTCGT': 7,
#               'ACGAGTACCGACAT': 315,
#               'ACGGAACTAGTACC': 37,
#               'ACGGCTCTTTGGTG': 464,
#               'ACTACGGAACAGTC': 2222,
#               'ACTGTTACTTGCTT': 287,
#               'ACTTCTGATATGGC': 34,
#               'ACTTGTACTAGAGA': 1283,
#               'AGACACACAACGAA': 130,
#               'AGACACACACGGGA': 209,
#               'AGAGAATGTCCTTA': 1384,
#               'AGATTAACGTGCTA': 582,
#               'AGCGCTCTCGGAGA': 7,
#               'AGCTGTGAGTCTGA': 138,
#               'AGGCCTCTACCTGA': 3242,
#               'AGGGAGTGATCACG': 1023,
#               'AGGGCCACTACTTC': 421,
#               'AGTAATACGTTACG': 561,
#               'ATACACCTTTCGTT': 10,
#               'ATACGGACACCCTC': 266,
#               'ATCACGGACACACA': 1565,
#               'ATCATGCTTCTCGC': 27,
#               'ATCGAGTGCTGAAC': 3,
#               'ATCTACACTAGAGA': 437,
#               'ATGATATGGGATCT': 219,
#               'ATGCGCCTGGATCT': 12,
#               'ATGGTGACCCGATA': 111,
#               'ATGTTGCTGTCATG': 290,
#               'ATTATGGAGAGAGC': 2718,
#               'ATTGGGTGTCCCAC': 41,
#               'ATTTGCACCAGATC': 75,
#               'CAAATATGCAGGAG': 13,
#               'CAACTTTGCTCTCG': 264,
#               'CAAGAAGACAACTG': 88,
#               'CACAGAACGAAGGC': 1170,
#               'CACCCATGATCAGC': 328,
#               'CACCGGGAATCACG': 1155,
#               'CACCGTACCTGTCC': 2,
#               'CACCTGACGTACAC': 42,
#               'CACTCCGACTCCCA': 75,
#               'CACTCTCTCATTGG': 386,
#               'CACTTAACAGGGTG': 393,
#               'CAGGGCACAGAACA': 363,
#               'CATAAAACTTCCAT': 733,
#               'CATCATACCCTCGT': 783,
#               'CATTGTACTCCCGT': 579,
#               'CCAGCGGAGGTCAT': 1540,
#               'CCAGCGGATGGTAC': 1469,
#               'CCCTAGTGTAGAAG': 820,
#               'CCCTTACTTCGTTT': 1075,
#               'CCGACTACTCCAGA': 177,
#               'CGACTGCTTGACAC': 26,
#               'CGAGGAGATTGCGA': 1248,
#               'CGCATAGATGGATC': 267,
#               'CGCGAGACTCGCCT': 57,
#               'CGGAATTGTTGCAG': 10,
#               'CGGATAACCCTCGT': 203,
#               'CGGGCATGAGTCGT': 582,
#               'CGTTAACTCGCCTT': 43,
#               'CTACTATGGAGCAG': 95,
#               'CTCAGCACTGTGGT': 16,
#               'CTCAGGCTGCGATT': 132,
#               'CTCGAGCTAGTGTC': 1053,
#               'CTCGAGCTTTATCC': 402,
#               'CTGAACGACCACAA': 513,
#               'CTGAAGACCTCCAC': 58,
#               'CTGAAGTGACTCTT': 13,
#               'CTGAAGTGCCTCGT': 2,
#               'CTGATTTGGGTGGA': 89,
#               'CTGTATACCTTAGG': 1471,
#               'CTTACAACTAGCGT': 68,
#               'CTTGTATGCCTCGT': 1253,
#               'CTTTGATGGTACCA': 1433,
#               'GAAATACTAGAATG': 1125,
#               'GAAGATGACTCGAA': 866,
#               'GAAGTCACACGTGT': 169,
#               'GACAGTACTACTCT': 161,
#               'GACCCTACTCCAGA': 195,
#               'GACGTATGTGACCA': 1467,
#               'GAGGTACTGCCATA': 36,
#               'GAGTACACAAGCAA': 1989,
#               'GAGTGTTGGGTATC': 628,
#               'GATAGCACCTCAGA': 404,
#               'GATATATGCCAAGT': 528,
#               'GCACCTTGAGATGA': 397,
#               'GCACGGACCTATTC': 6,
#               'GCACTGCTCGCCTT': 287,
#               'GGAGACGACGTAAC': 81,
#               'GGAGCGCTTTGCGA': 969,
#               'GGAGTTACTAAGGA': 135,
#               'GGATGTACTACTGG': 2116,
#               'GGGACCTGAATGCC': 1729,
#               'GGGACCTGCTTGTT': 1247,
#               'GGGCAAGAATTGGC': 170,
#               'GGGTAACTGCATCA': 185,
#               'GGTACATGGTTGAC': 1127,
#               'GGTCAAACGATAAG': 780,
#               'GTAAGCTGCCAATG': 101,
#               'GTAAGCTGCTTACT': 523,
#               'GTAGCTGATTAGGC': 364,
#               'GTCAACGAGAAGGC': 998,
#               'GTCAACGATGTGAC': 6,
#               'GTCACAGATTAGGC': 986,
#               'GTCCCATGGAATGA': 295,
#               'GTCGAATGTGGTTG': 359,
#               'GTTAAATGATGTCG': 1320,
#               'GTTATGCTGTCACA': 17,
#               'TAAATCGAAGCGTT': 17,
#               'TAACGTCTGGAGGT': 793,
#               'TAAGAGGATGCCAA': 951,
#               'TAATGCCTCGACTA': 99,
#               'TACACACTAAACGA': 9,
#               'TACGCCACTGTAGC': 28,
#               'TACTAAGATCGCTC': 53,
#               'TACTTGACAGCGTT': 1423,
#               'TAGGTCGAAGTACC': 1031,
#               'TAGGTGTGTCGTGA': 23,
#               'TCAACACTCTATTC': 597,
#               'TCAAGGTGAAAGCA': 8,
#               'TCACAACTCGCATA': 210,
#               'TCATCAACTTGTCT': 629,
#               'TCATCATGACCTTT': 236,
#               'TCCCAGACAAGATG': 1452,
# ...
#   ('CATCCCGACATTTC', 'CATCCCGACTTTTC'),
#   ('-', 'AGTCCCCCTCTTTG'),
#   ('ATACACCTAGCCAT', 'ATACACCTAGCCAC'),
#   ('TCCCAGACGGACGA', 'TCCCAGACGGACGA'),
#   ('-', 'TTTGCCTGCCTCCC'),
#   ('CAATGGACTCACGA', 'CAATGGACTCACGA'),
#   ('-', 'GAGGGTGGCCCCCC'),
#   ('-', 'GACCTCACACCCAC'),
#   ('CTAGGTGACGACTA', 'CTAGGTGACGTCTA'),
#   ('-', 'GCGAAGGCCCCACA'),
#   ('CAGCTCTGACCGAT', 'CAGCTCTGACCGAT'),
#   ('CTCCTACTTCGTAG', 'CTCCTACTTCGTAG'),
#   ('-', 'CCCACCTGCACCGG'),
#   ('ACAGACACACACGT', 'ACAGACACACACGT'),
#   ('TTACGTACGTTAGC', 'TTACGTACGTTAGC'),
#   ('ACTTAGCTCGACTA', 'ACTTAGCTCGACTA'),
#   ('TAGTAATGCGAGTT', 'TAGTAATGCGAGTT'),
#   ('-', 'CTACTAATTGCTTT'),
#   ('-', 'GCCGGGGCCGGTCG'),
#   ('-', 'GAACACAATAGCAG'),
#   ('ACTAGGTGGGGATG', 'ACTAGGTGTGGATG'),
#   ('TTAACCACAAAACG', 'TTACCCACAAAACG'),
#   ('-', 'GCCGACCCCTCGTA'),
#   ('-', 'TTTTATCTATAATG'),
#   ('-', 'TCCAGAGACGGTGT'),
#   ('GTTACGGATAGAGA', 'GTTACGGATAGAGA'),
#   ('GAGCGGCTCGTAGT', 'GAGCGGCTCGTTGT'),
#   ('TATCCTGATGCAAC', 'TATCCTGATTCAAC'),
#   ('TATGGGACGGTCTA', 'TATGGGACGGTCTA'),
#   ('ATCCAGGAGTGTCA', 'ATCCAGGAGTGTCA'),
#   ('AATGAGGAGTAAGA', 'AATGAGGAGTAAGA'),
#   ('-', 'AGCTCTCTGGTTAG'),
#   ('-', 'CTAATACAACCTAT'),
#   ('CTACAACTCAGAAA', 'CTACAACTCAGAAA'),
#   ('-', 'GATTGGTGATTCCA'),
#   ('-', 'CAATAAGAATCTAA'),
#   ('-', 'AGCGCGGCCGGGGG'),
#   ('TAGGACTGATGTGC', 'TAGGACTGATGTGG'),
#   ('CAGCCTACTAAGCC', 'CACCCTACTAAGCC'),
#   ('TACTTGACTCTTTG', 'TACTTGACTCTTTG'),
#   ('-', 'CCACGCGGGCATGC'),
#   ('GCGTAAACACTCAG', 'GCGTAAACACTCAG'),
#   ('-', 'CAGCGCTCTGGTAA'),
#   ('TTCTCAGAGAGACG', 'TTCTCAGAGAGACC'),
#   ('-', 'TGGGCTGTTGCAGG'),
#   ('CCAAGATGCCCACT', 'CCAAGATGCCAACT'),
#   ('-', 'CAGGAACTATATCA'),
#   ('CAGAAGCTTGTTTC', 'GAGAAGCTTGTTTC'),
#   ('CAGCTCTGGATGAA', 'CCGCTCTGGATGAA'),
#   ('-', 'CCGCCCCTAACGCC'),
#   ('GATCGATGAGAATG', 'GATCGATGAGATTG'),
#   ('CGGACCGACTACCC', 'CGGACCGACTCCCC'),
#   ('GTACAGTGCCTGAA', 'GTACAGTGACTGAA'),
#   ('GTTCAGGAACCTGA', 'GTTCAGGAACCTAA'),
#   ('-', 'CAACGATGCTTATT'),
#   ('-', 'CACTTTGAGCCGCG'),
#   ('CGTGTAGACCTACC', 'CGGGTAGACCTACC'),
#   ('GTTAGGTGGAAGGC', 'GTTAGGTGGAAGGC'),
#   ('GTCTAACTCTTTAC', 'GTCTAACTCTTTTC'),
#   ('GGCGACTGGCGAGA', 'GGCGACTGGCGAGA'),
#   ('GATAAGGACCTACC', 'GATAAGGACCTAGC'),
#   ('AGTCAGACAACCGT', 'AGTCAGACAACAGT'),
#   ('-', 'GAGATCGACGTGAT'),
#   ('CTTAGACTAGGTTC', 'CTTAGACTAGGTTC'),
#   ('-', 'TCCTCCCGGCTCCG'),
#   ('CGGCACGAAAACAG', 'CGGCACGAAAACAG'),
#   ('-', 'GGGCCAACCGGGGG'),
#   ('-', 'GCCACCCTATCAAT'),
#   ('-', 'ACTTCAACGTAACA'),
#   ('-', 'GTTATAGATAGCTG'),
#   ('GTAACGTGGCTCCT', 'GTAACGTGGCTCCT'),
#   ('-', 'TGGCAGCTAACGGG'),
#   ('TGGAAGCTCGCATA', 'TGGAAGCTCGCATA'),
#   ('AGGTCTGAGTGTCA', 'AGGGCTGAGTGTCA'),
#   ('CTGATTTGTCCTGC', 'CTGATTTGTCCTGC'),
#   ('ATTGGTCTAGCGTT', 'ATTGGTCTAGCGTT'),
#   ('-', 'CAAATTTTTTTAAA'),
#   ('AATACTGAGGGTGA', 'AATACTGAGGGTCA'),
#   ('AACTCACTGGTAAA', 'AACTCAGTGGTAAA'),
#   ('-', 'ATGCAAGATACCCG'),
#   ('TCAAGGACACGGAG', 'GCAAGGACACGGAG'),
#   ('CGAGGAGATGTTCT', 'CGAGGAGATTTTCT'),
#   ('CAGATGACAAACGA', 'CAGATGCCAAACGA'),
#   ('-', 'GCTCGACCCGGTAG'),
#   ('AGCGGCACATGCCA', 'AGCGGCTCATGCCA'),
#   ('CAGCATGATGCAGT', 'CAGCAGGATGCAGT'),
#   ('ATTCAAGACCCGTT', 'ATTCAAGACCCGCT'),
#   ('CGGAGGCTCCCGTT', 'CGGAGTCTCCCGTT'),
#   ('TGGAAGCTGGCATT', 'TGGAAGCTGGCATT'),
#   ('TGAGACACGAATAG', 'TGAGACACGAATAG'),
#   ('-', 'AAAGAAAATCCAAA'),
#   ('-', 'TTATCACAGAAAAA'),
#   ('AACTCACTCGTACA', 'AACTCACTCGTACC'),
#   ('ACCCAGCTGTTAGC', 'CCCCAGCTGTTAGC'),
#   ('-', 'TGGCTAGGATATCG'),
#   ('CACTTAACCACTAG', 'CACTTAACCACTAC'),
#   ('CGTGAATGCGCCTT', 'CGTGAATGGGCCTT'),
#   ('-', 'ACTTTGGGGCGTAG'),
#   ('-', 'TCGCCGGTAGTAGA'),
#   ('GGTACAACACCACA', 'GGTACACCACCACA'),
#   ('TGCCACTGAACCGT', 'TGCCCCTGAACCGT'),
#   ('-', 'GTATTAGAGTCACC'),
#   ('-', 'CGATCCGCCGCACG'),
#   ('-', 'AACCTGTGTGCCCA'),
#   ('-', 'GGTTACTGCGTGCT'),
#   ('-', 'CTCCAGGGGGGACG'),
#   ('-', 'ATCGGAGAACCTAC'),
#   ('-', 'ACTCGCGAGTCGAG'),
#   ('GATCCGCTGATGAA', 'GATCCCCTGATGAA'),
#   ('-', 'CATAGACAACATCC'),
#   ('ATACGGACTTTGTC', 'CTACGGACTTTGTC'),
#   ('-', 'GATGACACGCGCCA'),
#   ('AGTCGCCTGCATCA', 'AGTCGCCTGCATCA'),
#   ('CCACTGACCTGGTA', 'CCACTGCCCTGGTA'),
#   ('ATATGAACTACGAC', 'ATATGAACTACGAC'),
#   ('-', 'TCCCTCCCGCGGCC'),
#   ('GATTCTACAGCTCA', 'GATTCTACAGCTCA'),
#   ('CGATACGACCTCGT', 'CGATACGACCTAGT'),
#   ('TGCGATGATTCATC', 'TGCGATGATTCATC'),
#   ('-', 'GACAAAAAAGTTAA'),
#   ('TTCGTATGTCGTAG', 'TTCGTATGTCGTAG'),
#   ('AGGGTTTGGTTGGT', 'AGGGTTTGGTTGGT'),
#   ('CGCAAATGCTTACT', 'CGCAAATGCGTACT'),
#   ('ATTCGACTCTGTGA', 'ATTCGCCTCTGTGA'),
#   ('CTCAGAGAGCGAGA', 'CTCAGAGAGCGAGC'),
#   ('-', 'CGAGGCCCGGGCTG'),
#   ('CCAGCTACTCGCAA', 'CCAGCTACTCGCAA'),
#   ('CGAGGAGATGGATC', 'CGAGGAGATGGATC'),
#   ('GACAGTTGTAGAAG', 'GACGGTTGTAGAAG'),
#   ('AGCGGCTGACGGTT', 'AGTGGCTGACGGTT'),
#   ('-', 'CGTCCATGTACCCG'),
#   ('AAAGCAGAAGCATC', 'AAAGCAGAAGCATA'),
#   ('GAAGTCACTCGATG', 'GAAGACACTCGATG'),
#   ('-', 'GCGGGGCCCCCGAC'),
#   ('-', 'AAAACCATAAAGTT'),
#   ('AGCGATACAGCTAC', 'AGCGATACCGCTAC'),
#   ('ATAGATACAAAGCA', 'ATAGATATAAAGCA'),
#   ('AACCCAGAAGCTAC', 'AACCCAGAACCTAC'),
#   ('AGCCGGTGATTCGG', 'AGCCGGTGATTCGG'),
#   ('ACCTGAGATTGCTT', 'CCCTGAGATTGCTT'),
#   ('CGCAGGTGTAACCG', 'CGCAGGTGTAACCG'),
#   ('-', 'AGGCGGGGGGGGTG'),
#   ('-', 'TCACCTCAAGACAG'),
#   ('-', 'ACATTACTGTGACG'),
#   ('-', 'GATGCCCGGCATGC'),
#   ('-', 'AGCCGCCTTTGGTT'),
#   ('TAGCGATGAGAGTA', 'TAGCGATGAGATTA'),
#   ('AATCTCACGCATCA', 'AATCTGACGCATCA'),
#   ('TAGGTGTGTTGACG', 'TAGGTGTGTTTACG'),
#   ('TGAGCTGACTGTAG', 'TGAGATGACTGTAG'),
#   ('GAGGGCCTTCTTCA', 'GAGGGCCATCTTCA'),
#   ('-', 'AATCGGGGGGTCCG'),
#   ('GAGGATCTTTCATC', 'GAGGATCTTTCATC'),
#   ('-', 'AAAAACATAAACTA'),
#   ('TCCCACGACAGAAA', 'TCCCACGACAGAAA'),
#   ('TATAAGTGTGTAGC', 'TATAAGTGTGTAGC'),
#   ('GAAATACTGGTTCA', 'GAAATTCTGGTTCA'),
#   ('-', 'AGAGGAACTCAGAA'),
#   ('GAGGTACTCAGGAG', 'GAGGTACGCAGGAG'),
#   ('GTGATTCTGCTATG', 'GTGATTCTGCTTTG'),
#   ('-', 'AACATAACATTTAA'),
#   ('-', 'AAACTAACACAGCT'),
#   ('GTGTATCTTATCGG', 'GTGTATCGTATCGG'),
#   ('CACCCATGAAGTGA', 'CCCCCATGAAGTGA'),
#   ('-', 'GGGTTGCTTGGGGT'),
#   ('CGGGCATGTCTTTG', 'CGGGCATGTGTTTG'),
#   ('TGTAGTCTCTACCC', 'TGTAGTCTCTACCC'),
#   ('AGGAATGACCCGTT', 'AGGAATGACCCGTT'),
#   ('CACCACTGGGCAAG', 'CACCACTGGGCAAG'),
#   ('AGGGCCTGTCAGTG', 'AGGGCCTGTCAGTG'),
#   ('ATTGAAACACTGTG', 'ATTGAAACACTGTG'),
#   ('GCCCATACCTGTCC', 'GCCCATACCTGTAC'),
#   ('AGAAAGTGCTTGCC', 'AGAAAGTGATTGCC'),
#   ('ACTCAGGAAAAGCA', 'ACACAGGAAAAGCA'),
#   ('-', 'GTTACATAGCATAC'),
#   ('TGCGCACTGGAAGC', 'TGCGGACTGGAAGC'),
#   ('GAGCTCCTCGCCTT', 'GAGCTCCTCGCCGT'),
#   ('CATTGTTGCCATGA', 'CATTGTTGCCATGA'),
#   ('CCTATTGAGGAAGC', 'CCTATTGAGGAAGC'),
#   ('ATTACCACAGATGA', 'ATTACCACAGATGA'),
#   ('-', 'ATTCGACTGGTCCT'),
#   ('-', 'CCCCCCTGCCGGGC'),
#   ('-', 'TAGCGATGATATTA'),
#   ('AATAAGCTATTCTC', 'AATAAGCTATTCTA'),
#   ('GGGCAAGAAGAGTA', 'GGGCAAGAATAGTA'),
#   ('ATTGCTACTACGCA', 'ATTGCTACTACGGA'),
#   ('TGACGATGGATAGA', 'TGACGATGAATAGA'),
#   ('-', 'CATATAACCGCGAA'),
#   ('GTTATAGAAGCTCA', 'GTTATAGAAGCCCA'),
#   ('-', 'CCCAGGACGGTAAC'),
#   ('-', 'AACACTCTCAATAC'),
#   ('-', 'CCACACTGTCTTCA'),
#   ('-', 'TGCCACTGGGATCG'),
#   ('GGATTTCTACTCAG', 'GGATTTATACTCAG'),
#   ('GCACGTCTTCATTC', 'GCACGTCTTCATTC'),
#   ('-', 'ATTGATGATTCGTC'),
#   ('-', 'TCGAGCCTTGTGTA'),
#   ('-', 'ATCCCCCTAGCTCC'),
#   ('-', 'GGGGCGCGCGCGGC'),
#   ('-', 'GCCCGTCTTGCAGG'),
#   ('AATTCCTGCTGTTT', 'AATTCCTGCTGTTT'),
#   ('GTACAGTGCTCCAC', 'GTACAGTGCTCCAC'),
#   ('-', 'CCGGGTTCTTTGGG'),
#   ('-', 'GGAAACCTACATCA'),
#   ('-', 'CGCCACCTATGTCG'),
#   ('GATAAGGATGCAAC', 'GATAAGGATGCACC'),
#   ('-', 'GAGCGATGGGCACC'),
#   ('-', 'GGCGGGGTGGGGCC'),
#   ('-', 'AGCGTGCAATCGCG'),
#   ('-', 'TAGAAATGAAACAT'),
#   ('-', 'AGGTATGACACAAT'),
#   ('-', 'CCCCCGTGCACTCG'),
#   ('-', 'GCGCGCGCCCGGGG'),
#   ('-', 'AGAAATGCCTATTG'),
#   ('-', 'TAATGCCTAGCCTC'),
#   ('-', 'ACCTGGCTCAAAGG'),
#   ('-', 'GGCACGTGTAGCGC'),
#   ('CTTGAACTAGAGTA', 'CTTGAAATAGAGTA'),
#   ('-', 'GCGGGTGGGGCGGG'),
#   ('TAATGATGACAGTC', 'TAATGATGACAGCC'),
#   ('-', 'GCCTACCCCCTGCC'),
#   ('AAGGCTACGTTACG', 'AAGGCTATGTTACG'),
#   ('GGATGTTGGAGCTT', 'GGATTTTGGAGCTT'),
#   ('TAGGCAACTGTGCA', 'TAGGCAACTGTCCA'),
#   ('ACTGAGACGGTTTG', 'ACTGAGCCGGTTTG'),
#   ('-', 'CCTAGGATGTCGTA'),
#   ('GTGTGATGACCTAG', 'GTGTGATGACCAAG'),
#   ('GACAGGGATGAGAA', 'GACAGGGATGACAA'),
#   ('CAAAGCACCTGTAG', 'CAAAGCACCTGGAG'),
#   ('TAAACAACCACTTT', 'TAAACAACCACTTA'),
#   ('TTGCATTGCCTTCG', 'TTGCATTGCCTTCG'),
#   ('ACGGAACTAGTTCG', 'ACGGAACTAGTTCG'),
#   ('-', 'GCTTCGGCCGCGTA'),
#   ('-', 'TCAATAGCCCGCGT'),
#   ('-', 'AACGCGCAGACACT'),
#   ('-', 'CTTGGGCGGGGCGG'),
#   ('CGTACCTGAGAGAT', 'CGTACCTCAGAGAT'),
#   ('CACAGCCTATCGTG', 'CACAGCCTATCGTG'),
#   ('TCGCAAGAAGTCTG', 'TCGCAAGAAGTCTG'),
#   ('CTTAGACTTGCCCT', 'CTTAGACTTGCCCT'),
#   ('ACTACGGATGCATG', 'ACTACGGATGCATG'),
#   ('CAGAGGGACGCCTT', 'CAGAGGGACGCCTT'),
#   ('TCGATTTGGGGCAA', 'ACGATTTGGGGCAA'),
#   ('-', 'CGCCGCGTACGCGT'),
#   ('-', 'TAGAACACTGAAGC'),
#   ('CGATCCACGCTTAG', 'CGATCCACGCTTAG'),
#   ('TTGCTATGGCATAC', 'TTGCTATGGCATAC'),
#   ('-', 'AGAGCCCCTCCGTC'),
#   ('-', 'TTCCGTACTGGTAG'),
#   ('-', 'TAACATGCCCCTCC'),
#   ('-', 'TAGTTAGACCGGGT'),
#   ('GAGCGCTGACGGGA', 'GAGCGCTGACGGGC'),
#   ('-', 'CACAGACCCCAAAA'),
#   ('-', 'TTGGACACCGCAAA'),
#   ('-', 'GGGGAGTGCAAAGA'),
#   ('-', 'CCTCCTGGGTGGCT'),
#   ('-', 'TGTAAAACCCCACA'),
#   ('TAGCCCTGTGAAGA', 'TAGCCCAGTGAAGA'),
#   ('ACGATCGAATCTTC', 'ACGATCCAATCTTC'),
#   ('AGAGTCTGTCTTCA', 'AGAGTCTATCTTCA'),
#   ('CGAGGGCTTGTAGC', 'CGAGGGCATGTAGC'),
#   ('-', 'GTGCGGGTTCTAGC'),
#   ('-', 'AGACCAGAGAAGCC'),
#   ('-', 'GACGAGGCCCTCCG'),
#   ('ACGATGACACTTTC', 'ACGATGACACTTTA'),
#   ('-', 'AACGACAAAAATAA'),
#   ('-', 'GCAAACCACGTGTA'),
#   ('-', 'TCGAGACCGTGTTT'),
#   ('-', 'AAGCGACTAGCATA'),
#   ('CCACCATGAGTCAC', 'CCACAATGAGTCAC'),
#   ('-', 'GGTGGGGGTGGGGG'),
#   ('AGCTTACTAAACAG', 'CGCTTACTAAACAG'),
#   ('GTGTACGACTATTC', 'GTGTACGACCATTC'),
#   ('AGGTTGTGATAAGG', 'AGGTTGTGATAAGC'),
#   ('GACAACACATTCTC', 'GACAACAAATTCTC'),
#   ('TGCATGGACCTCAC', 'TGCATGGACCTCCC'),
#   ('-', 'GTTAACGAACCACA'),
#   ('-', 'AAGCATGAGAACCT'),
#   ('-', 'GCCTAACCTGACTA'),
#   ('CTAATGCTTGATGC', 'CTAATGCTTGATGC'),
#   ('-', 'CCACCCTGCGACGC'),
#   ('AGTTAAACGCTGTA', 'AGTTAAACGCTCTA'),
#   ('AGTGTTCTAGTCTG', 'AGTGTTCTCGTCTG'),
#   ('GCTTGAGAACTCTT', 'GCTTGAGAACACTT'),
#   ('-', 'GCTCCCTGTGCAGG'),
#   ('TATTGCTGTAACCG', 'TATTGCGGTAACCG'),
#   ('-', 'CTAGGCTGCTGACA'),
#   ('TATCCAACCTGTGA', 'TATCCAACCTGTGA'),
#   ('TAACGTCTGGATCT', 'TAACGTCTGGATCT'),
#   ('-', 'CATCCCAATTTGTC'),
#   ('CACGGGTGGTGTAC', 'CACGCGTGGTGTAC'),
#   ('-', 'CCTGCCTGAAGTGC'),
#   ('-', 'AGTCGACTTCTGTA'),
#   ('-', 'TGACCTCTCTATTG'),
#   ('-', 'ATCGCCGCCACGCC'),
#   ('ATGAAGGACCCGTT', 'ATGAAGGACCCGTT'),
#   ('-', 'AAGTAAATCAGCAA'),
#   ('CATCTTGAATTCGG', 'CATCTTGAATTCGG'),
#   ('AGCCTCTGCTTCGC', 'AGCCTCTGCTTCGC'),
#   ('CTATACTGCCTATT', 'CTATACTGCCTAAT'),
#   ('ATCGTTTGGTCGAT', 'ATCGTTTGGTCAAT'),
#   ('GCAATTCTAGAGGC', 'GCAATTCTAGAGGC'),
#   ('TAAATGTGGAAACA', 'AAAATGTGGAAACA'),
#   ('ACCTGAGAACGCAT', 'ACCTGAGAACCCAT'),
#   ('-', 'GGATCGCTACCGTC'),
#   ('GGGTAACTAGAAGT', 'GGGTAACTAGAAGT'),
#   ('ATTCGACTGTAGGG', 'ATTCGACTGTACGG'),
#   ('-', 'AGCACCACCCTCAC'),
#   ('CGTACAGAGCGAGA', 'CGTACACAGCGAGA'),
#   ('GTTGACGAGAATCC', 'GTTGCCGAGAATCC'),
#   ('-', 'TGTAATGAGTCATC'),
#   ('-', 'AAACTCAAGAGACC'),
#   ('-', 'GCGGGGGGGGCTTT'),
#   ('CATTTGACACGGTT', 'CATTTGAAACGGTT'),
#   ('AGGTGTTGTGCTGA', 'CGGTGTTGTGCTGA'),
#   ('TGACGATGACTAGC', 'TGACGATGAGTAGC'),
#   ('AAGCCAACCCGATA', 'AAGCCAACCCTATA'),
#   ('-', 'CGTACCTGGCCGGT'),
#   ('-', 'TTGGACCGCTCTGG'),
#   ('-', 'CGAGCAGATTCAGA'),
#   ('CACCGTACGAGACG', 'CACCGTACGAGACG'),
#   ('CACTAGGAGAGGAC', 'CACTAGGAGAGGAC'),
#   ('GTATCTACTCCTAT', 'ATATCTACTCCTAT'),
#   ('-', 'TCCTTATCCCATTG'),
#   ('GACTGTGACCGTTC', 'GACTGTGACCGTTC'),
#   ('-', 'TAATCCCTCAATAC'),
#   ('-', 'CCAGGGCACTCCCA'),
#   ('-', 'GGGGGCTGGGGGCG'),
#   ('-', 'CGCACTATAATGCC'),
#   ('CTAACTACCATGGT', 'CTAACTACCAAGGT'),
#   ('-', 'ATATCAACAACCTG'),
#   ('-', 'ATTGCCCCTCGGTT'),
#   ('-', 'TAGTAACTTTCACA'),
#   ('GGATTGTGTTCTTG', 'GGATTGTGTTCTTG'),
#   ('ACGACAACCTTCGC', 'ACGACAACCTTCGC'),
#   ('-', 'GGGGGGCGTGGTGG'),
#   ('-', 'ATTTCACACTGAAC'),
#   ('-', 'CGAGCCACTCTCGC'),
#   ('-', 'TGGATTCTTTGGCC'),
#   ('-', 'AGTACTCCTGGTCT'),
#   ('-', 'AAGGTCTGCGGCGC'),
#   ('-', 'TAGGTGGGTCTGTG'),
#   ('-', 'GGTATACTCACTAT'),
#   ('TTCAGTTGTTGCGA', 'TTCAGTTGTTGCCA'),
#   ('CTGAATCTCACAAC', 'CTGAATCTCACAAC'),
#   ('CAAGCTGACACCAA', 'CAAGCTGACCCCAA'),
#   ('-', 'GCCTACCCGGTCTT'),
#   ('-', 'AGATATGACAGATA'),
#   ('GAGGATCTTCCCGT', 'GAGGTTCTTCCCGT'),
#   ('-', 'AAAACACATATGTA'),
#   ('-', 'TGGCGCGTCTGCTG'),
#   ('GTGCTAGAAAGGGC', 'GTGCTAGCAAGGGC'),
#   ('-', 'CCGGTATGGGTGAT'),
#   ('-', 'ATCCCCTCAACCAC'),
#   ('-', 'GTATGGTGCCCGAG'),
#   ('-', 'GGTGCGGCGGGGGG'),
#   ('TTAGACCTGATACC', 'TTAGACGTGATACC'),
#   ('ACTCCTCTAGCCAT', 'ACTCCTCTAGCCAT'),
#   ('-', 'AAACATACCCCCTA'),
#   ('CTGAAGTGTGTGGT', 'CGGAAGTGTGTGGT'),
#   ('TGGAACACTTTGCT', 'TGGAACACTTTGCG'),
#   ('GATCATCTGTTAGC', 'GATAATCTGTTAGC'),
#   ('-', 'GAGGGCGGTGCAGT'),
#   ('-', 'GAGTCGGAAACCTT'),
#   ('AAGCGTACTCCGAA', 'AAGCGTACTCCGTA'),
#   ('GTAGACTGCATGAC', 'ATAGACTGCATGAC'),
#   ('GCACACCTCCAACA', 'GCACCCCTCCAACA'),
#   ('-', 'CAAAGTTATTAGAA'),
#   ('-', 'ACCAACATCACTTT'),
#   ('-', 'CCGTGGGGTGGGGG'),
#   ('-', 'GCATGTGCCTCGAT'),
#   ('-', 'GCCGTGCTGGTCCC'),
#   ('-', 'CAGACACTCAAAGA'),
#   ('TGCACAGAGGAGGT', 'TGCACAGCGGAGGT'),
#   ('-', 'CGAACTACAGCGGA'),
#   ('AATGAGGAACCCAA', 'AATGAGGAACCCAA'),
#   ('CACCGTACCAAGCT', 'CACCGTACCAAGCT'),
#   ('-', 'ATCTTGCCCCGCGC'),
#   ('TACTACACAGACTC', 'TACTTCACAGACTC'),
#   ('TTCACCCTCCTGTC', 'TTCACCCTCCGGTC'),
#   ('-', 'GGGCGCTGGGCGGG'),
#   ('GCCCAGGACCGTAA', 'GCCCAGGACCGTAC'),
#   ('CGTACCACTGTAGC', 'CGTACCACTGTAGC'),
#   ('GGGCAAGATTCGTT', 'GGGCAAGATTCCTT'),
#   ('GCCATCACCATACG', 'GCCATCACAATACG'),
#   ('AGAGAATGACACTG', 'AGAGAATGACCCTG'),
#   ('TGGATCGACGTGTA', 'TGGATCGCCGTGTA'),
#   ('-', 'CCACCCCCCGTATA'),
#   ('-', 'ACGAAACTAAAAGA'),
#   ('AAGATGGACAACCA', 'AAGATGGCCAACCA'),
#   ('ACTGGCCTGCCTTC', 'ACTGGCGTGCCTTC'),
#   ('TACCATTGATGTCG', 'TACGATTGATGTCG'),
#   ('-', 'TCAGGGACCGCCTT'),
#   ('-', 'CACGCTCTTCCTCC'),
#   ('CCTTTAGAAAGTAG', 'CCTTTAGCAAGTAG'),
#   ('-', 'GATCGGTGGCCGTT'),
#   ('AGCATGACTCAGGT', 'AGCGTGACTCAGGT'),
#   ('CCAGGTCTCCTGTC', 'CCAGGTCCCCTGTC'),
#   ('TACGTACTATTCGG', 'TACGTACTATTCGC'),
#   ('ATTAACGATAGAGA', 'ATTAACCATAGAGA'),
#   ('CGGATATGCTCGCT', 'CGCATATGCTCGCT'),
#   ('GAATGGCTGTTGCA', 'GAATGGCTGGTGCA'),
#   ('GACCTAGAACCTGA', 'GACCTAGAACCTGA'),
#   ('-', 'CGACCTTGCTTCAG'),
#   ('-', 'TTGTGATGTATCAT'),
#   ('-', 'TAGTTAAAAATGAA'),
#   ('-', 'CCCTAGGAGGAGCG'),
#   ('-', 'CGAGGAACATTGCG'),
#   ('TCGGACCTGGTAAA', 'TCGGACCTGGTAAA'),
#   ('ATGGGTACTGCAGT', 'ATGGGTACTGCAGA'),
#   ('-', 'TGATATGTCAGACA'),
#   ('AAGTGGCTCCAATG', 'AAGGGGCTCCAATG'),
#   ('-', 'ACCCGTTGGGCGAG'),
#   ('-', 'GGGGCGTGGGCCCC'),
#   ('-', 'TTCGATTGATTCAC'),
#   ('-', 'ACATCACATTAATC'),
#   ('AGTGTTCTGAGGTG', 'AGTGTTCTGCGGTG'),
#   ('-', 'GTAACCTGCAATGG'),
#   ('-', 'CTAATAGATAATAT'),
#   ('AAGCAAGAGTAAGA', 'AAGCAAGCGTAAGA'),
#   ('TAACTCACAACGTC', 'TAACTCAAAACGTC'),
#   ('-', 'GGTACATGCTCTAG'),
#   ('GTCCAAGACTGTCC', 'GTCCAACACTGTCC'),
#   ('TTCACAACCGTGTA', 'TTCACAACAGTGTA'),
#   ('-', 'GTTTTAATGGTAAT'),
#   ('-', 'TCCCCGCTCCGCCG'),
#   ('GTGGTAACTGGTTG', 'GTGGTACCTGGTTG'),
#   ('ATAACAACGAGGGT', 'ATAACACCGAGGGT'),
#   ('-', 'CCCCGATCAGTTCG'),
#   ('-', 'CGCCGCTGGGGTAG'),
#   ('AGTCCAGACACTGA', 'AGTCCAGACACTGA'),
#   ('TAGTCTTGTCCCAC', 'TAGTCTTGTCCCAC'),
#   ('TTTCACGATGATGC', 'TTTCACGATGATGC'),
#   ('-', 'TTCATCACGTACAA'),
#   ('-', 'GGGCGTCGTCGGGT'),
#   ('-', 'ATCATAACACTATA'),
#   ('AACTGTCTGGATCT', 'CACTGTCTGGATCT'),
#   ('-', 'TACAGTACAGACCA'),
#   ('-', 'CACGCAACCCAAAC'),
#   ('AGGCCTCTGCTCCT', 'AGGCCGCTGCTCCT'),
#   ('AGGATGCTCCCTCA', 'CGGATGCTCCCTCA'),
#   ('-', 'CACATGACTCAATC'),
#   ('ACAGTGACGCGAGA', 'AAAGTGACGCGAGA'),
#   ('GCATCAGAGACTAC', 'GCATCAGAGCCTAC'),
#   ('GCCATGCTTTGTCT', 'GCCATGCTTTGTCT'),
#   ('TAATCGCTACACTG', 'TAATCGCTACACTG'),
#   ('CGGTAAACGTGAGG', 'CGGTAAACGTGAGG'),
#   ('GTACTACTCACTTT', 'GTACTAATCACTTT'),
#   ('AACTTGCTGATAGA', 'AACTTGCTGATAGA'),
#   ('TCCTAAACGTGTAC', 'TCCTAAACGTGTAC'),
#   ('CGAGGCTGTGCAGT', 'CGAGGCTGTGCAGT'),
#   ('GAAGGGTGAGCTCA', 'GAAGGGTGAGCTCA'),
#   ('-', 'CCCCCGCACCTTTC'),
#   ('-', 'AAGTATACAGTAGC'),
#   ('-', 'CAAATTTGGTCGGG'),
#   ('-', 'AAAGCCTGCACTCA'),
#   ('-', 'TAGTTCCTGAAAAA'),
#   ('-', 'GGAGCAGACCGCTA'),
#   ('CGCAAATGCGACAT', 'CCCAAATGCGACAT'),
#   ('TTAGACCTCAATCG', 'TTAGACCTCAATAG'),
#   ('-', 'TCGAGGCTGGCTGC'),
#   ('TGTACTTGCTCTCG', 'TGTCCTTGCTCTCG'),
#   ('-', 'ACGATTATACAGAT'),
#   ('-', 'TCTGCCTGTTATGA'),
#   ('-', 'AAACAAGATTAATA'),
#   ('-', 'TGCCCGCTGCCGCG'),
#   ('-', 'CGGCCATAAATGCC'),
#   ('GCGCACGACATGGT', 'GCGCACGACAAGGT'),
#   ('-', 'CCCCTCCATACACA'),
#   ('-', 'GTGAATCCCTTTCC'),
#   ...})

# %%
[CR_read_number,CB_read_number,BC_read_number, barcodes, corrected_barcodes, barcode_pairs] = pickle.load(open(BARCODE_INFO,"rb"))

# %%
len(CB_read_number)
# Out:
# 143877

# %%
len(CR_read_number)
# Out:
# 810680

# %%
print(len(BC_read_number))
BC_read_number
# Out:
# 8
# defaultdict(int,
#             {'AGGGCGTT': 1004988,
#              'GCTCGTCA': 1063341,
#              'TACATAAG': 924429,
#              'CTATACGC': 1037301,
#              'ATCGCCAT': 998068,
#              'CATAAAGG': 1047861,
#              'GGGTTTCC': 1237219,
#              'TCACGGTA': 979680})

# %% [markdown]
# # Similar to the paper:
# For the AML datasets previously generated by 10X Genomics (Zheng et al., 2017b), cells from two patients (AML027 and AML035) were analyzed for mitochondrial genotypes. Aligned and processed .bam files were downloaded from the 10X website (https:// support.10xgenomics.com/single-cell-gene-expression/datasets/) and further processed using custom Python scripts. Cell barco- des associated with at least 200 reads uniquely aligning to the mitochondrial genome were considered for downstream analysis. Barcodes were further filtered by requiring coverage by at least one read at two specific variants at mtDNA positions 3010 and 9698. We note that we did not observe a barcode that contained a read to support both alternate alleles (3010G > A and 9698T > C). We determined that 4 out of 1,077 cells were derived from the recipient (Figure 7M), a higher estimate than in the previously reported analysis performed with nuclear genome variants (reported exactly 0%) (Zheng et al., 2017b), though these four cells were not included in the published analysis as they did not pass the author’s barcode/ transcriptome filters. We did not observe a well-covered set of variants separating the donor/ recipient pair in the AML027 dataset, and did not further analyze it for mutations but only for determining well-covered barcodes (Figures S7G and S7H

# %% [markdown]
# ## Filter for reads with more than 200 bps

# %%
count = 0
CB_filter = set()
for key in CB_read_number:
    if CB_read_number[key] > 200:
        CB_filter.add(key)
        count += 1
print(count)
# Out:
# 7716

# %% [markdown]
# ## Filter for reads with variants at 3010G and 9698T)

# %%
# genome_fa = "/data2/genome/human_GRCh38/cellranger/refdata-cellranger-GRCh38-3.0.0/fasta/genome.fa"

# cmd = f'samtools mpileup -g -f  {genome_fa} {BAM} > {BAM.replace(".bam",".bcf")}'
# print(cmd)
# !{cmd}
# Out:
# samtools mpileup -g -f  /data2/genome/human_GRCh38/cellranger/refdata-cellranger-GRCh38-3.0.0/fasta/genome.fa ../data/test/aml027_post_transplant_possorted_genome_bam.MT.bam > ../data/test/aml027_post_transplant_possorted_genome_bam.MT.bcf
# [mpileup] 1 samples in 1 input files
# <mpileup> Set max per-file depth to 8000

# %% [markdown]
# samtools view -b aml027_post_transplant_possorted_genome_bam.MT.bam MT:3010-3010 | samtools fillmd -e - /data2/genome/human_GRCh38/cellranger/refdata-cellranger-GRCh38-3.0.0/fasta/genome.fa | grep -v "^@"| awk -v pos="3010" 'BEGIN {OFS = FS = "\t" } ; {n=split($10,a,"") ; if(a[(pos-$4)+1] != "=" ) print $0, "V:" a[(pos-$4)+1]}' > 3010_reads.txt

# %% [markdown]
# samtools view -b aml027_post_transplant_possorted_genome_bam.MT.bam MT:9698-9698 | samtools fillmd -e - /data2/genome/human_GRCh38/cellranger/refdata-cellranger-GRCh38-3.0.0/fasta/genome.fa | grep -v "^@"| awk -v pos="9698" 'BEGIN {OFS = FS = "\t" } ; {n=split($10,a,"") ; if(a[(pos-$4)+1] != "=" ) print $0, "V:" a[(pos-$4)+1]}' > 9698_reads.txt

# %%
with open("../data/test/3010_reads.txt", "r") as f:
    lines = list(map(lambda x: x.strip(), f.readlines()))
    
    
lines
ref = "A"
var_3010=defaultdict(int)
for i in lines:
    if "CB:Z:" in i:
        if i[-1] != ref and i[-1] != ":":
            curr_bc = i.split("CB:Z:")[1].split("\t")[0].split("-")[0]
            var_3010[curr_bc] +=1

print(f"Total reads mapping there: {len(lines)}")
print(len(var_3010))
# Out:
# Total reads mapping there: 2395
# 498

# %%
with open("../data/test/9698_reads.txt", "r") as f:
    lines = list(map(lambda x: x.strip(), f.readlines()))
    
    
lines
ref = "C"
var_9698=defaultdict(int)
for i in lines:
    if "CB:Z:" in i:
        if i[-1] != ref and i[-1] != ":":
            curr_bc = i.split("CB:Z:")[1].split("\t")[0].split("-")[0]
            var_9698[curr_bc] +=1
print(f"Total reads mapping there: {len(lines)}")
print(len(var_9698))
# Out:
# Total reads mapping there: 1676
# 589

# %%
overlap_var = set(var_9698.keys()).union(set(var_3010.keys()))
print(f"Number of unique barcodes across both variants: {len(overlap_var)}")
# Out:
# Number of unique barcodes across both variants: 1069

# %%
print(f"Number of unique barcodes across both variants and with more than 200 reads: {len(overlap_var.intersection(CB_filter))}")
# Out:
# Number of unique barcodes across both variants and with more than 200 reads: 661
