# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.simulations.parametersweep import ParameterSweep

default_params_f = 'parameters/test_simple.yaml'
sweep_params_f = 'parameters/test_sweep.yaml'
sweep = ParameterSweep(default_params_f, sweep_params_f)
# Out:
# fig_utils from mplh
# here
# INFO: Pandarallel will run on 32 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# False

# %%
import pickle
import pandas as pd

# %%
sweep.load_results()
sweep.sweep_results
# Out:
# {0: {'prec_scores': [0.017849298081020835,
#    0.019693586576492304,
#    0.016510024786809088,
#    0.017752977018834718,
#    0.018219674720974643,
#    0.018215454656616833,
#    0.016418344111773224,
#    0.019104913515192567,
#    0.019204655925418194,
#    0.02042798143782657],
#   'dropout': [0.5768321513002365,
#    0.6124197002141327,
#    0.617948717948718,
#    0.6240409207161125,
#    0.6204379562043796,
#    0.5858823529411765,
#    0.5910290237467019,
#    0.6196868008948546,
#    0.5509761388286334,
#    0.608786610878661],
#   'rocs': [(array([0.00000000e+00, 5.10803494e-05, 2.04321398e-04, 1.32808908e-03,
#            5.00587424e-03, 1.97170149e-02, 2.61020585e-02, 2.61020585e-02,
#            3.12611738e-02, 3.12611738e-02, 4.03023957e-02, 4.03023957e-02,
#            4.22434489e-02, 4.22434489e-02, 4.38780201e-02, 4.38780201e-02,
#            4.46953057e-02, 4.46953057e-02, 5.04673852e-02, 5.04673852e-02,
# ...

# %%
len(sweep.sweep_results)
# Out:
# 32

# %%
(sweep.sweep_results[0])
# Out:
# {'prec_scores': [0.017849298081020835,
#   0.019693586576492304,
#   0.016510024786809088,
#   0.017752977018834718,
#   0.018219674720974643,
#   0.018215454656616833,
#   0.016418344111773224,
#   0.019104913515192567,
#   0.019204655925418194,
#   0.02042798143782657],
#  'dropout': [0.5768321513002365,
#   0.6124197002141327,
#   0.617948717948718,
#   0.6240409207161125,
#   0.6204379562043796,
#   0.5858823529411765,
#   0.5910290237467019,
#   0.6196868008948546,
#   0.5509761388286334,
#   0.608786610878661],
#  'rocs': [(array([0.00000000e+00, 5.10803494e-05, 2.04321398e-04, 1.32808908e-03,
#           5.00587424e-03, 1.97170149e-02, 2.61020585e-02, 2.61020585e-02,
#           3.12611738e-02, 3.12611738e-02, 4.03023957e-02, 4.03023957e-02,
#           4.22434489e-02, 4.22434489e-02, 4.38780201e-02, 4.38780201e-02,
#           4.46953057e-02, 4.46953057e-02, 5.04673852e-02, 5.04673852e-02,
#           5.28170813e-02, 1.98242836e-01, 1.99519845e-01, 1.99519845e-01,
# ...

# %%
(sweep.sweep_results[0].keys())
# Out:
# dict_keys(['prec_scores', 'dropout', 'rocs', 'b_a_df', 'Dominant Cluster Confusion', 'Cluster F1 scores', 'pred_growth_rates', 'pred_clone_sizes', 'b_a_clust_df'])

# %% [markdown]
# ## Figures

# %%
# %matplotlib inline

# %%
x = sweep.plot_before_after_all_clones()

# %%
x = sweep.plot_before_after_true_growth(to_log=True)
# Out:
# df_full     cov_constant dominant_clone_sizes dominant_growth  dominant_het  \
# 0            5.0                 0.02             0.1          0.02
# 0            5.0                 0.02             0.1          0.02
# 0            5.0                 0.02             0.1          0.02
# 0            5.0                 0.02             0.1          0.02
# 0            5.0                 0.02             0.1          0.02
# ..           ...                  ...             ...           ...
# 31         100.0                  0.2             0.5          0.20
# 31         100.0                  0.2             0.5          0.20
# 31         100.0                  0.2             0.5          0.20
# 31         100.0                  0.2             0.5          0.20
# 31         100.0                  0.2             0.5          0.20
#
#     het_err_rate       A/B             Source
# 0           0.05  1.190722               True
# 0           0.05  1.141553               True
# ...

# %%
x = sweep.plot_sensitivity_and_dropout()  # plots results
# Out:
# /home/isshamie/software/anaconda2/envs/mito_trace/lib/python3.7/site-packages/seaborn/axisgrid.py:715: UserWarning: Using the stripplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
