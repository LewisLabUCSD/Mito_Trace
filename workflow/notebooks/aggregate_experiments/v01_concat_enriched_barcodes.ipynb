# %%
#outdir = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/single_clones/donor0/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/single/"
in_files = {}
outdir = "/data/Mito_Trace/output/aggregate/CHIP_aggr/v04/results/enriched_barcodes"
#cloneID = "0_C6"


# outdir = snakemake.params.outdir
# clone_var_clone_dirs = snakemake.input.clone_var_clone_dirs
# vaf_donor_dirs = snakemake.input.vaf_donor_dirs

# %% [markdown]
# ## Setup input directories

# %%
n_donors = {
    "chip_b1": 2,
    "chip_b2": 2,
    "chip_a1": 5,
    "cd34":4
}

clone_var_donor_dirs = {
    "chip_b1": "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30",
    "chip_b2": "/data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/",
    "chip_a1": "/data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30",
    "cd34": "/data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30"
}

# %%
# VAF and clone combine
method_type = "clonalShift_method_clones/top"

variants = "init"
kparam = 30

cloneMethod = f"cloneMethod_variants_{variants}_knn_resolution_{kparam}"

vaf_donor_dirs = {
    "chip_b1": "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/",
    "chip_b2": "/data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/",
    "chip_a1": "/data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones",
    "cd34": "/data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones"
}

# %%
from os.path import join, exists, dirname
from glob import glob
import pickle
import mplh.cluster_help as ch
import mplh.fig_utils as fu
import numpy as np
import os
import numpy as np
from scipy import sparse
from scipy.io import mmread
import matplotlib.pyplot as plt
from scipy.stats import hypergeom

import pandas as pd
import seaborn as sns
np.set_printoptions(formatter={'float': lambda x: format(x, '.5f')})

from svgutils.compose import *


import svgutils.transform as sg
import sys
# Out:
# fig_utils from mplh

# %%
"""
based on https://neuroscience.telenczuk.pl/?p=331
"""

import svgutils.transform as sg


class Svg(object):
    "svg files with a data object (the svg), width, height and coordinates"

    def __init__(self, data, dim, coords, name, global_scale=0.5):
        self.data = data
        self.width = dim[0]*global_scale
        self.height = dim[1]*global_scale
        self.x = coords[0]
        self.y = coords[1]
        self.global_scale = global_scale
        self.name = name

    def scale_width_to_reference(self, reference_width):
        """Proportionally scale the image to a given width."""
        scalings_factor = reference_width / self.width
        self.data.moveto(0, 0)#, scale=scalings_factor)
        self.width = self.width * scalings_factor
        self.height = self.height * scalings_factor

    def scale_height_to_reference(self, reference_height):
        """Proportionally scale the image to a given height."""
        scalings_factor = reference_height / self.height
        self.data.moveto(0, 0)#, scale=scalings_factor)
        self.width = self.width * scalings_factor
        self.height = self.height * scalings_factor
        
    def scale_by_factor(self, scalings_factor):
        """Proportionally scale image by a scaling factor."""
        self.data.moveto(0, 0, scale=scalings_factor)
        self.width = self.width * scalings_factor
        self.height = self.height * scalings_factor

    def move(self, x, y):
        """Move the coordinates of an image."""
        self.data.moveto(x, y)
        self.x = x
        self.y = y


def get_size(svg_file):
    """Naively parse the svg text file to get the width and height."""
    with open(svg_file) as svg:
        for line in svg:
            if line.startswith('<svg'):
                paramdict = {e.split('="')[0]: e.split('="')[1] for e in line[5:-2].split('" ')}
                break
    print(paramdict["width"])
    print("height")
    print(paramdict["height"])
    return int(np.ceil(float(paramdict["width"].replace('pt', '').replace('"', '')))), int(np.ceil(float(paramdict["height"].replace('pt', '').replace('"', ''))))



def rescale_height(svgs, curr_keys, ref_key):
    """Change the dimensions of the images to the desired combinations."""
    for key in curr_keys:
        svgs[key].scale_height_to_reference(svgs[ref_key].height)
    #assert svgs[ref_key].height == svgs[curr_keys[0]].height == svgs[curr_keys[-1]].height


def rescale_width(svgs, curr_keys, ref_key):
    """Change the dimensions of the images to the desired combinations."""
    for key in curr_keys:
        svgs[key].scale_width_to_reference(svgs[ref_key].width)
    #assert svgs[ref_key].height == svgs[curr_keys[0]].height == svgs[curr_keys[-1]].height


def change_positions(df, svgs, widths, heights):
    """Move the images to the desired positions."""
    for i_row, row in enumerate(df.index):
        for i_col, col in enumerate(df.columns):
            curr = df.loc[row, col].split(".svg")[0]
            svgs[curr].move(sum(widths[:i_col]), sum(heights[:i_row]))
    

def letter_annotations(svgs, df=None, only_grid_titles=True, figure_names=None, transposed=False):
    if only_grid_titles:
        all_texts = []
        if transposed: # make donors the columns and figure_names the rows
            for ind in df.index:
                nm = figure_names[ind]
                value = svgs[df.loc[ind].iloc[0].split(".svg")[0]]
                all_texts.append(sg.TextElement(value.x, value.y-10, nm, size=15, weight="bold")) 
            for col in df.columns:
                value = svgs[df[col].iloc[0].split(".svg")[0]]
                all_texts.append(sg.TextElement(value.x, value.y-10, col, size=15, weight="bold"))
                
        else:
            for ind in df.index:
                value = svgs[df.loc[ind].iloc[0].split(".svg")[0]]
                all_texts.append(sg.TextElement(value.x, value.y, ind, size=15, weight="bold"))
            for col in df.columns:
                nm = figure_names[col]
                value = svgs[df[col].iloc[0].split(".svg")[0]]
                all_texts.append(sg.TextElement(value.x, value.y-10, nm, size=15, weight="bold"))    
        return all_texts
    """Add letters based on the location of the images."""
    return [sg.TextElement(value.x, value.y, value.name, size=15, weight="bold")
            for key, value in svgs.items()]
#     return [sg.TextElement(value.x + 10, value.y + 15, value.name, size=15, weight="bold")
#             for key, value in svgs.items()]


def files_to_svg_dict(df, scale=0.5, verbose=False):
    """Convert a list of images to a dictionary.
    Mapping the image basename to the Svg class instance,
    setting the dimensions based on sizes and coordinates (0,0) by default
    """
    out = {}
    for row in df.index:
        for col in df.columns:
            s = df.loc[row, col]
            key = df.loc[row, col].split(".svg")[0]
            name = f"{row} {col.replace('dendro', '').replace('.svg', '')}"
            if verbose:
                print(s)
            out[key] = Svg(
                data=sg.fromfile(s).getroot().scale(scale),
                dim=get_size(s),
                coords=(0, 0),
                global_scale=scale,
                name=name)
    return out




def main_df(df, out_f, scale=0.25, figure_names=None, to_pdf=False):
    svgs = files_to_svg_dict(df, scale=scale)#df.values().flatten())
    
    for don, val in df.iterrows():
        curr_init_files = []
        curr_ref = val.iloc[0].split('.svg')[0] #svgs[val.iloc[0].split('.svg')[0]]
        curr_keys = [x.split('.svg')[0] for x in val.values] 
        rescale_height(svgs, curr_keys, curr_ref)
    
    col_max_widths = []

    for col in df.columns:
        curr_col_max = 0
        for ind in df.index:
            tmp_width = svgs[df.loc[ind, col].split(".svg")[0]].width
            if tmp_width > curr_col_max:
                curr_col_max = tmp_width
        col_max_widths.append(curr_col_max)

    row_max_heights = [] #should be the same in theory  
    for ind in df.index:
        curr_row_max = 0
        for col in df.columns:
            tmp_height = svgs[df.loc[ind, col].split(".svg")[0]].height
            if tmp_height > curr_row_max:
                curr_row_max = tmp_height
        row_max_heights.append(curr_row_max)
    
    change_positions(df, svgs, col_max_widths, row_max_heights)
    
    full_width = sum(col_max_widths) #[svgs[i].width for i in ['A', 'E']])
    full_height = sum(row_max_heights) #[svgs[i].height for i in ['A', 'B', 'C', 'D']])
    fig = sg.SVGFigure(full_width+20, full_height+20)
    text = letter_annotations(svgs, df=df, figure_names=figure_names)
    fig.append([s.data for s in svgs.values()])
    fig.append(text)
    fig.save(out_f)
 
    cmd = f'inkscape --file={out_f} -d 300 --export-area-drawing --without-gui --export-png={out_f.replace(".svg", ".png")}' # --export-area-drawing --without-gui --export-pdf=output.pdf'
    print(cmd)
    # !{cmd}
    
    if to_pdf:
        cmd = f'inkscape --file={out_f} --export-area-drawing --without-gui --export-pdf={out_f.replace("svg", "pdf")} '
        print(cmd)
        # !{cmd}
    
    

def main_df_transpose(df, out_f, scale=0.25, figure_names=None, to_pdf=False, to_transpose=True):
    svgs = files_to_svg_dict(df, scale=scale)#df.values().flatten())
    
    
    for don, val in df.iterrows():
        curr_init_files = []
        curr_ref = val.iloc[0].split('.svg')[0] #svgs[val.iloc[0].split('.svg')[0]]
        curr_keys = [x.split('.svg')[0] for x in val.values] 
        rescale_width(svgs, curr_keys, curr_ref)
    
    df = df.transpose()
    
    col_max_widths = []
    for col in df.columns:
        curr_col_max = 0
        for ind in df.index:
            tmp_width = svgs[df.loc[ind, col].split(".svg")[0]].width
            if tmp_width > curr_col_max:
                curr_col_max = tmp_width
        col_max_widths.append(curr_col_max)

    row_max_heights = [] #should be the same in theory  
    for ind in df.index:
        curr_row_max = 0
        for col in df.columns:
            tmp_height = svgs[df.loc[ind, col].split(".svg")[0]].height
            if tmp_height > curr_row_max:
                curr_row_max = tmp_height
        row_max_heights.append(curr_row_max)
    
    change_positions(df, svgs, col_max_widths, row_max_heights)
    
    full_width = sum(col_max_widths) #[svgs[i].width for i in ['A', 'E']])
    full_height = sum(row_max_heights) #[svgs[i].height for i in ['A', 'B', 'C', 'D']])
    fig = sg.SVGFigure(full_width+20, full_height+20)
    text = letter_annotations(svgs, df=df, figure_names=figure_names, transposed=True)
    fig.append([s.data for s in svgs.values()])
    fig.append(text)
    fig.save(out_f)
 
    cmd = f'inkscape --file={out_f} -d 300 --export-area-drawing --without-gui --export-png={out_f.replace(".svg", ".png")}' # --export-area-drawing --without-gui --export-pdf=output.pdf'
    print(cmd)
    # !{cmd}
    
    if to_pdf:
        cmd = f'inkscape --file={out_f} --export-area-drawing --without-gui --export-pdf={out_f.replace("svg", "pdf")} '
        print(cmd)
        # !{cmd}

# %%
#"single_clones/donor0/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/"

# %% [markdown]
# # 1. clone_var supplementary

# %% [markdown]
# ## Convert from pdf to svg

# %%
for run in clone_var_donor_dirs:
    for d in np.arange(n_donors[run]):
        curr_pdfs = glob(join(clone_var_donor_dirs[run], f"donor{d}",  "*.pdf"))
        for in_f in curr_pdfs:
        #in_f = join(clone_var_donor_dirs, "best_params.pdf")
            out_f = in_f.replace(".pdf", ".svg")
            if not exists(out_f):
                cmd = f"inkscape -l {out_f} {in_f}" 
                print(cmd)
                # !{cmd}
            else:
                print(f"{out_f} already here")
# Out:
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top10perc_param_group_clusters.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/elbow_multi_obj_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top_param_group_results.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/best_params.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/multi_clusters_nclust_4.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top_param_groups_clone_vars.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/multi_clusters_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top10perc_param_group_clusters.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/elbow_multi_obj_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top_param_group_results.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/best_params.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/multi_clusters_nclust_4.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top_param_groups_clone_vars.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/multi_clusters_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top10perc_param_group_clusters.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/elbow_multi_obj_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top_param_group_results.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/multi_clusters_nclust_5.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/best_params.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top_param_groups_clone_vars.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/multi_clusters_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top10perc_param_group_clusters.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/elbow_multi_obj_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top_param_group_results.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/best_params.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top_param_groups_clone_vars.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/multi_clusters_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/multi_clusters_nclust_3.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top10perc_param_group_clusters.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/elbow_multi_obj_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top_param_group_results.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/best_params.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top_param_groups_clone_vars.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/multi_clusters_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/multi_clusters_nclust_3.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top10perc_param_group_clusters.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/elbow_multi_obj_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top_param_group_results.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/multi_clusters_nclust_5.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/best_params.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/multi_clusters_nclust_2.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top_param_groups_clone_vars.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/multi_clusters_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/top10perc_param_group_clusters.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/elbow_multi_obj_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/top_param_group_results.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/multi_clusters_nclust_8.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/best_params.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/top_param_groups_clone_vars.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/multi_clusters_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/top10perc_param_group_clusters.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/elbow_multi_obj_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/top_param_group_results.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/multi_clusters_nclust_8.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/best_params.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/top_param_groups_clone_vars.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/multi_clusters_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor4/elbow_multi_obj_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor4/best_params.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor4/multi_clusters_nclust_4.svg already here
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor4/multi_clusters_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top10perc_param_group_clusters.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/elbow_multi_obj_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top_param_group_results.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/best_params.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/multi_clusters_nclust_4.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top_param_groups_clone_vars.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/multi_clusters_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top10perc_param_group_clusters.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/elbow_multi_obj_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top_param_group_results.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/multi_clusters_nclust_5.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/best_params.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top_param_groups_clone_vars.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/multi_clusters_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/multi_clusters_nclust_6.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/top10perc_param_group_clusters.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/elbow_multi_obj_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/top_param_group_results.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/multi_clusters_nclust_5.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/best_params.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/top_param_groups_clone_vars.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/multi_clusters_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/top10perc_param_group_clusters.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/elbow_multi_obj_nclust.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/top_param_group_results.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/multi_clusters_nclust_5.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/best_params.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/top_param_groups_clone_vars.svg already here
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/multi_clusters_nclust.svg already here

# %% [markdown]
# ## Loop through and align svgs, with each donor in horizontal

# %%
clonevar_figure_names = {
    "best_params.svg": "Final clone-barcode table",
    "top10perc_param_group_clusters.svg": "Cluster top hyperparameters by multi-objectives",
    "elbow_multi_obj_nclust.svg": "Elbow plot for determining number of objective clusters",
    "multi_clusters_nclust.svg": "multi_obj_clusters" ,
    "top_param_group_results.svg": "top_objective_scores"
    #"top_param_groups_clone_vars.svg": "clone-barcode table of top hyperparameter clusters",
}

#     "multi_clusters_nclust.svg": "Cluster hyperparameter and take highest objective score cluster",
#     "top_param_group_results.svg": "Hyperparameter cluster objective results"
# }

indexes = []
for run in clone_var_donor_dirs:
    for d in np.arange(n_donors[run]):
        indexes.append(join(f"{run}_donor{d}"))
        
don_row_subfig_col_df = pd.DataFrame(index=indexes,columns = list(clonevar_figure_names.keys()))
for run in clone_var_donor_dirs:
    for d in np.arange(n_donors[run]):
        curr_ind = f"{run}_donor{d}"
        
        for f_name in don_row_subfig_col_df.columns:
            curr_f = (join(clone_var_donor_dirs[run], f"donor{d}",  f_name))
            don_row_subfig_col_df.loc[curr_ind, f_name] = curr_f
            
don_row_subfig_col_df
# Out:
#                                                   best_params.svg  \
# chip_b1_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_b1/M...
# chip_b1_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_b1/M...
# chip_b2_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_b2/I...
# chip_b2_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_b2/I...
# chip_a1_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor2  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor3  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor4  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# cd34_donor0     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor1     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor2     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor3     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
#
#                                top10perc_param_group_clusters.svg  \
# chip_b1_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_b1/M...
# chip_b1_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_b1/M...
# chip_b2_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_b2/I...
# chip_b2_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_b2/I...
# chip_a1_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor2  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor3  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor4  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# cd34_donor0     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor1     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor2     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor3     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
#
#                                        elbow_multi_obj_nclust.svg  \
# chip_b1_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_b1/M...
# chip_b1_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_b1/M...
# chip_b2_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_b2/I...
# chip_b2_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_b2/I...
# chip_a1_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor2  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor3  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor4  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# cd34_donor0     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor1     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor2     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor3     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
#
#                                         multi_clusters_nclust.svg  \
# chip_b1_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_b1/M...
# chip_b1_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_b1/M...
# chip_b2_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_b2/I...
# chip_b2_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_b2/I...
# chip_a1_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor2  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor3  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor4  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# cd34_donor0     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor1     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor2     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor3     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
#
#                                       top_param_group_results.svg
# chip_b1_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_b1/M...
# chip_b1_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_b1/M...
# chip_b2_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_b2/I...
# chip_b2_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_b2/I...
# chip_a1_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor2  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor3  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor4  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# cd34_donor0     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor1     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor2     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor3     /data/Mito_Trace/output/pipeline/v04/cd34norm/...

# %%
main_df(don_row_subfig_col_df, join(outdir, "clone_var_supplementary.svg"), 
        scale=0.25, figure_names=clonevar_figure_names)
# Out:
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/best_params.svg
# 893.024687pt
# height
# 908.1445pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top10perc_param_group_clusters.svg
# 1083.40586pt
# height
# 782.65125pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/elbow_multi_obj_nclust.svg
# 460.8pt
# height
# 345.6pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/multi_clusters_nclust.svg
# 582.13512pt
# height
# 463.055158pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top_param_group_results.svg
# 841.998125pt
# height
# 841.784063pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/best_params.svg
# 893.024687pt
# height
# 907.966688pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top10perc_param_group_clusters.svg
# 1066.33927pt
# height
# 782.65125pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/elbow_multi_obj_nclust.svg
# 460.8pt
# height
# 345.6pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/multi_clusters_nclust.svg
# 582.13512pt
# height
# 463.738669pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top_param_group_results.svg
# 841.998125pt
# height
# 841.784063pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/best_params.svg
# 893.024687pt
# height
# 908.1445pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top10perc_param_group_clusters.svg
# 1063.15802pt
# height
# 782.65125pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/elbow_multi_obj_nclust.svg
# 460.8pt
# height
# 345.6pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/multi_clusters_nclust.svg
# 582.22512pt
# height
# 467.373125pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top_param_group_results.svg
# 841.998125pt
# height
# 841.784063pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/best_params.svg
# 893.024687pt
# height
# 908.1445pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top10perc_param_group_clusters.svg
# 1066.33927pt
# height
# 782.65125pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/elbow_multi_obj_nclust.svg
# 460.8pt
# height
# 345.6pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/multi_clusters_nclust.svg
# 582.13512pt
# height
# 464.808902pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top_param_group_results.svg
# 841.998125pt
# height
# 841.784063pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/best_params.svg
# 892.751875pt
# height
# 907.966688pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top10perc_param_group_clusters.svg
# 1063.15802pt
# height
# 782.850469pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/elbow_multi_obj_nclust.svg
# 460.8pt
# height
# 345.6pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/multi_clusters_nclust.svg
# 581.590728pt
# height
# 467.373125pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top_param_group_results.svg
# 841.998125pt
# height
# 841.784063pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/best_params.svg
# 892.979062pt
# height
# 908.1445pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top10perc_param_group_clusters.svg
# 1063.15802pt
# height
# 782.65125pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/elbow_multi_obj_nclust.svg
# 460.8pt
# height
# 345.6pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/multi_clusters_nclust.svg
# 582.22512pt
# height
# 467.373125pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top_param_group_results.svg
# 841.998125pt
# height
# 841.784063pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/best_params.svg
# 893.024687pt
# height
# 908.1445pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/top10perc_param_group_clusters.svg
# 1063.15802pt
# height
# 782.65125pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/elbow_multi_obj_nclust.svg
# 460.8pt
# height
# 345.6pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/multi_clusters_nclust.svg
# 582.22512pt
# height
# 467.373125pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/top_param_group_results.svg
# 841.998125pt
# height
# 841.784063pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/best_params.svg
# 893.024687pt
# height
# 908.1445pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/top10perc_param_group_clusters.svg
# 1063.15802pt
# height
# 782.65125pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/elbow_multi_obj_nclust.svg
# 460.8pt
# height
# 345.6pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/multi_clusters_nclust.svg
# 582.22512pt
# height
# 467.373125pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/top_param_group_results.svg
# 841.998125pt
# height
# 841.784063pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor4/best_params.svg
# 892.979063pt
# height
# 908.1445pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor4/top10perc_param_group_clusters.svg
# 1063.15802pt
# height
# 782.65125pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor4/elbow_multi_obj_nclust.svg
# 460.8pt
# height
# 345.6pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor4/multi_clusters_nclust.svg
# 582.22512pt
# height
# 478.305pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor4/top_param_group_results.svg
# 841.998125pt
# height
# 841.784063pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/best_params.svg
# 893.024687pt
# height
# 907.966688pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top10perc_param_group_clusters.svg
# 1071.51614pt
# height
# 782.65125pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/elbow_multi_obj_nclust.svg
# 460.8pt
# height
# 345.6pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/multi_clusters_nclust.svg
# 577.681577pt
# height
# 467.373125pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor0/top_param_group_results.svg
# 841.998125pt
# height
# 841.784063pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/best_params.svg
# 893.024687pt
# height
# 908.1445pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top10perc_param_group_clusters.svg
# 1083.40586pt
# height
# 782.65125pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/elbow_multi_obj_nclust.svg
# 460.8pt
# height
# 345.6pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/multi_clusters_nclust.svg
# 582.13512pt
# height
# 466.835658pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor1/top_param_group_results.svg
# 841.998125pt
# height
# 841.784063pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/best_params.svg
# 893.024687pt
# height
# 908.1445pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/top10perc_param_group_clusters.svg
# 1066.33927pt
# height
# 782.65125pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/elbow_multi_obj_nclust.svg
# 460.8pt
# height
# 345.6pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/multi_clusters_nclust.svg
# 582.22512pt
# height
# 467.373125pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor2/top_param_group_results.svg
# 841.998125pt
# height
# 841.784063pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/best_params.svg
# 893.024687pt
# height
# 908.1445pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/top10perc_param_group_clusters.svg
# 1063.15802pt
# height
# 782.65125pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/elbow_multi_obj_nclust.svg
# 460.8pt
# height
# 345.6pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/multi_clusters_nclust.svg
# 582.13512pt
# height
# 465.134707pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/donor3/top_param_group_results.svg
# 841.998125pt
# height
# 841.784063pt
# inkscape --file=/data/Mito_Trace/output/aggregate/CHIP_aggr/v04/results/enriched_barcodes/clone_var_supplementary.svg -d 300 --export-area-drawing --without-gui --export-png=/data/Mito_Trace/output/aggregate/CHIP_aggr/v04/results/enriched_barcodes/clone_var_supplementary.png
# DPI: 300
# Background RRGGBBAA: ffffff00
# Area 0:-2853.29:1336.92:121.396 exported to 4178 x 9296 pixels (300 dpi)
# Bitmap saved as: /data/Mito_Trace/output/aggregate/CHIP_aggr/v04/results/enriched_barcodes/clone_var_supplementary.png

# %% [markdown]
# # 2. Dendrograms:

# %%
dendro_figure_names =  {"dendro.NoCondition.max2.AF.svg": "AF (max 0.2)",
             "dendro.NoCondition.max5.AF.svg": "AF (max 0.5)",
             "dendro.NoCondition.DP.svg": "Log2 reads per cell-MT position"}

# %%
dendro_don_subfig_df = pd.DataFrame(index=indexes,columns = ["dendro.NoCondition.max2.AF.svg",
                                                             "dendro.NoCondition.max5.AF.svg",
                                                             "dendro.NoCondition.DP.svg"]
                                   )


for run in clone_var_donor_dirs:
    for d in np.arange(n_donors[run]):
        curr_ind = f"{run}_donor{d}"
        curr_dendro_f = join(clone_var_donor_dirs[run], "barcodes/btwnClones_dendro", f"donor{d}.")
        for f_name in dendro_don_subfig_df.columns:
            curr_f = curr_dendro_f + f_name
            dendro_don_subfig_df.loc[curr_ind, f_name] = curr_f
            assert(exists(curr_f))
dendro_don_subfig_df
# Out:
#                                    dendro.NoCondition.max2.AF.svg  \
# chip_b1_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_b1/M...
# chip_b1_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_b1/M...
# chip_b2_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_b2/I...
# chip_b2_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_b2/I...
# chip_a1_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor2  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor3  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor4  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# cd34_donor0     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor1     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor2     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor3     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
#
#                                    dendro.NoCondition.max5.AF.svg  \
# chip_b1_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_b1/M...
# chip_b1_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_b1/M...
# chip_b2_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_b2/I...
# chip_b2_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_b2/I...
# chip_a1_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor2  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor3  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor4  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# cd34_donor0     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor1     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor2     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor3     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
#
#                                         dendro.NoCondition.DP.svg
# chip_b1_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_b1/M...
# chip_b1_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_b1/M...
# chip_b2_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_b2/I...
# chip_b2_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_b2/I...
# chip_a1_donor0  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor1  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor2  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor3  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# chip_a1_donor4  /data/Mito_Trace/output/pipeline/v04/CHIP_Inpu...
# cd34_donor0     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor1     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor2     /data/Mito_Trace/output/pipeline/v04/cd34norm/...
# cd34_donor3     /data/Mito_Trace/output/pipeline/v04/cd34norm/...

# %%
main_df(dendro_don_subfig_df, join(outdir, "dendrogram_barcodes.svg"), 
        scale=0.25, figure_names=dendro_figure_names)
# Out:
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor0.dendro.NoCondition.max2.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor0.dendro.NoCondition.max5.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor0.dendro.NoCondition.DP.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor1.dendro.NoCondition.max2.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor1.dendro.NoCondition.max5.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor1.dendro.NoCondition.DP.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor0.dendro.NoCondition.max2.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor0.dendro.NoCondition.max5.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor0.dendro.NoCondition.DP.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor1.dendro.NoCondition.max2.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor1.dendro.NoCondition.max5.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor1.dendro.NoCondition.DP.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor0.dendro.NoCondition.max2.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor0.dendro.NoCondition.max5.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor0.dendro.NoCondition.DP.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor1.dendro.NoCondition.max2.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor1.dendro.NoCondition.max5.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor1.dendro.NoCondition.DP.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor2.dendro.NoCondition.max2.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor2.dendro.NoCondition.max5.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor2.dendro.NoCondition.DP.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor3.dendro.NoCondition.max2.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor3.dendro.NoCondition.max5.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor3.dendro.NoCondition.DP.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor4.dendro.NoCondition.max2.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor4.dendro.NoCondition.max5.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor4.dendro.NoCondition.DP.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor0.dendro.NoCondition.max2.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor0.dendro.NoCondition.max5.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor0.dendro.NoCondition.DP.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor1.dendro.NoCondition.max2.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor1.dendro.NoCondition.max5.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor1.dendro.NoCondition.DP.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor2.dendro.NoCondition.max2.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor2.dendro.NoCondition.max5.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor2.dendro.NoCondition.DP.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor3.dendro.NoCondition.max2.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor3.dendro.NoCondition.max5.AF.svg
# 720pt
# height
# 720pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro/donor3.dendro.NoCondition.DP.svg
# 720pt
# height
# 720pt
# inkscape --file=/data/Mito_Trace/output/aggregate/CHIP_aggr/v04/results/enriched_barcodes/dendrogram_barcodes.svg -d 300 --export-area-drawing --without-gui --export-png=/data/Mito_Trace/output/aggregate/CHIP_aggr/v04/results/enriched_barcodes/dendrogram_barcodes.png
# DPI: 300
# Background RRGGBBAA: ffffff00
# Area 0:-2240:625.562:121.396 exported to 1955 x 7379 pixels (300 dpi)
# Bitmap saved as: /data/Mito_Trace/output/aggregate/CHIP_aggr/v04/results/enriched_barcodes/dendrogram_barcodes.png

# %% [markdown]
# # 3. Clone count barplots

# %%
cl_count_figure_names =  {
    "normalized_counts.barplot_conditions.svg": "normalized clone counts",
    "top20_minCell10_clone_counts.barplot_conditions.svg": "top 20 clones",
    "clone_counts.conditionScatter.svg": "scatterplot of ncells across conditions"
}

#    "clone barplot": "clone_counts.barplot_conditions.svg",

# %%
cl_count_subfig_df = pd.DataFrame(index=indexes,columns = list(cl_count_figure_names.keys()))

for run in clone_var_donor_dirs:
    for d in np.arange(n_donors[run]):
        curr_ind = f"{run}_donor{d}"
        curr_dendro_f = join(clone_var_donor_dirs[run], "annotation_clones/clone_counts/", f"donor{d}")
        for f_name in cl_count_subfig_df.columns:
            curr_f = join(curr_dendro_f, f_name)
            cl_count_subfig_df.loc[curr_ind, f_name] = curr_f
            assert(exists(curr_f))
cl_count_subfig_df   


main_df(cl_count_subfig_df, join(outdir, "clone_counts.svg"), 
        scale=0.5, figure_names=cl_count_figure_names)
# Out:
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor0/normalized_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor0/top20_minCell10_clone_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor0/clone_counts.conditionScatter.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor1/normalized_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor1/top20_minCell10_clone_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor1/clone_counts.conditionScatter.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor0/normalized_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor0/top20_minCell10_clone_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor0/clone_counts.conditionScatter.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor1/normalized_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor1/top20_minCell10_clone_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor1/clone_counts.conditionScatter.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor0/normalized_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor0/top20_minCell10_clone_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor0/clone_counts.conditionScatter.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor1/normalized_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor1/top20_minCell10_clone_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor1/clone_counts.conditionScatter.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor2/normalized_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor2/top20_minCell10_clone_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor2/clone_counts.conditionScatter.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor3/normalized_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor3/top20_minCell10_clone_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor3/clone_counts.conditionScatter.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor4/normalized_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor4/top20_minCell10_clone_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor4/clone_counts.conditionScatter.svg
# 1152pt
# height
# 1152pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor0/normalized_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor0/top20_minCell10_clone_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor0/clone_counts.conditionScatter.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor1/normalized_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor1/top20_minCell10_clone_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor1/clone_counts.conditionScatter.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor2/normalized_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor2/top20_minCell10_clone_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor2/clone_counts.conditionScatter.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor3/normalized_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor3/top20_minCell10_clone_counts.barplot_conditions.svg
# 864pt
# height
# 864pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/clones/variants_init/knn/kparam_30/annotation_clones/clone_counts/donor3/clone_counts.conditionScatter.svg
# 864pt
# height
# 864pt
# inkscape --file=/data/Mito_Trace/output/aggregate/CHIP_aggr/v04/results/enriched_barcodes/clone_counts.svg -d 300 --export-area-drawing --without-gui --export-png=/data/Mito_Trace/output/aggregate/CHIP_aggr/v04/results/enriched_barcodes/clone_counts.png
# DPI: 300
# Background RRGGBBAA: ffffff00
# Area 0:-5516:1440:121.396 exported to 4500 x 17617 pixels (300 dpi)
# Bitmap saved as: /data/Mito_Trace/output/aggregate/CHIP_aggr/v04/results/enriched_barcodes/clone_counts.png

# %% [markdown]
# # 4. Variants concat

# %%
# vaf_figure_names =  {
#     "all_variants_af.svg":"vaf",
#     "all_variants_distinct_pct_vs_other.svg": "barcode pct in clone"
# }
vaf_figure_names =  {
    "top_variants_af.svg":"vaf",
    "top_variants_distinct_pct_vs_other.svg": "barcode pct in clone"
}

# fvars_pct = join(outdir, "top_variants_distinct_pct_vs_other.svg")
# fvars_pct_minus = join(outdir, "top_variants_pct_minus_other.svg")
# fvars_vars_af = join(outdir, "top_variants_af.svg")
# fvars_vars_af_box = join(outdir, "top_variants_in_clone_af_boxen.svg") 


vaf_subfig_df = pd.DataFrame(index=indexes,columns = list(vaf_figure_names.keys()))

for run in clone_var_donor_dirs:
    for d in np.arange(n_donors[run]):
        curr_ind = f"{run}_donor{d}"
        curr_vaf_f = join(vaf_donor_dirs[run], f"donor{d}", cloneMethod, method_type)
        for f_name in vaf_subfig_df.columns:
            print('curr_f', curr_f)
            curr_f = join(curr_vaf_f, f_name)
            vaf_subfig_df.loc[curr_ind, f_name] = curr_f
            assert(exists(curr_f))
vaf_subfig_df   


main_df_transpose(vaf_subfig_df, join(outdir, "vaf.svg"), 
        scale=0.5, figure_names=vaf_figure_names)
# Out:
# curr_f /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor3/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor0/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor0/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor1/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor1/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor0/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor0/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor1/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor1/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor0/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor0/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor1/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor1/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor2/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor2/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor3/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor3/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor4/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor4/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor0/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor0/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor1/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor1/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor2/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor2/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# curr_f /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor3/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor0/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# 1657.57328875
# height
# 1501.7203125"
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor0/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# 626.040625pt
# height
# 2998.414062pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor1/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# 1658.47352375
# height
# 1501.7203125"
# /data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor1/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# 626.040625pt
# height
# 2998.414062pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor0/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# 4306.33080375
# height
# 1501.7203125"
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor0/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# 626.040625pt
# height
# 2998.414062pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor1/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# 4306.51864
# height
# 1501.7203125"
# /data/Mito_Trace/output/pipeline/v04/CHIP_b2/InputOnly/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor1/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# 626.040625pt
# height
# 2998.523438pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor0/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# 10480.935945000003
# height
# 1501.7203125"
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor0/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# 626.040625pt
# height
# 2117.243438pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor1/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# 10485.954967500002
# height
# 1501.7203125"
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor1/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# 626.040625pt
# height
# 2998.523438pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor2/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# 10487.064733750001
# height
# 1501.7203125"
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor2/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# 626.040625pt
# height
# 2998.414062pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor3/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# 10489.56200625
# height
# 1501.7203125"
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor3/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# 626.040625pt
# height
# 2998.38125pt
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor4/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# 10487.589296250002
# height
# 1501.7203125"
# /data/Mito_Trace/output/pipeline/v04/CHIP_Input_nameFix_april08_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor4/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# 626.040625pt
# height
# 2998.38125pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor0/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# 13136.131647500004
# height
# 1501.7203125"
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor0/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# 626.040625pt
# height
# 2117.134062pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor1/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# 13141.3934425
# height
# 1501.7203125"
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor1/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# 626.040625pt
# height
# 2998.414062pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor2/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# 13143.410372499999
# height
# 1501.7203125"
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor2/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# 626.040625pt
# height
# 2998.523438pt
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor3/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_af.svg
# 13141.040292500002
# height
# 1501.7203125"
# /data/Mito_Trace/output/pipeline/v04/cd34norm/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/enriched_barcodes/objs_high_cells/single_clones/donor3/cloneMethod_variants_init_knn_resolution_30/clonalShift_method_clones/top/top_variants_distinct_pct_vs_other.svg
# 626.040625pt
# height
# 2998.414062pt
# inkscape --file=/data/Mito_Trace/output/aggregate/CHIP_aggr/v04/results/enriched_barcodes/vaf.svg -d 300 --export-area-drawing --without-gui --export-png=/data/Mito_Trace/output/aggregate/CHIP_aggr/v04/results/enriched_barcodes/vaf.png
# DPI: 300
# Background RRGGBBAA: ffffff00
# Area 0:-2150.26:58464:121.396 exported to 182700 x 7099 pixels (300 dpi)
# Bitmap saved as: /data/Mito_Trace/output/aggregate/CHIP_aggr/v04/results/enriched_barcodes/vaf.png

# %%
# join(clone_var_donor_dirs[run], "annotation_clones/clone_counts/", f"donor{d}")

# f1_umap_clust = join(outdir,'top_umap_clust_col.svg')
# f2_umap_cond = join(outdir,'top_umap_cond_col.svg')
# f3_clone_clust = join(outdir,'top_cluster_condition_ncells.svg')
# f4_hyper = join(outdir,'top10_sig_hypergeo.svg')

# fvars_pct = join(outdir, "top_variants_distinct_pct_vs_other.svg")
# fvars_pct_minus = join(outdir, "top_variants_pct_minus_other.svg")
# fvars_vars_af = join(outdir, "top_variants_af.svg")
# fvars_vars_af_box = join(outdir, "top_variants_in_clone_af_boxen.svg")

# %% [markdown]
# ## Create Figure 2
# (Need select variants)

# %% [markdown]
# ## Create hyperparam clone-var supplementary
