# %%
library(stringi)

# %%
#ids.reversed = TRUE

cells_meta_f = "/data/Mito_Trace/output/aggregate/CHIP_aggr/v04/data/clone_var/variants.prefilterMerge_impute_knnRes.30_objs_standard_constraints_None/aggregate/cells_meta.tsv"
se_f = "/data/Mito_Trace/output/aggregate/CHIP_aggr/v04/data/annotation/gff_A2/mergedSamples/allSamples.integrated.rds"
clone_order_f = "/data/Mito_Trace/output/aggregate/CHIP_aggr/v04/data/clone_var/variants.prefilterMerge_impute_knnRes.30_objs_standard_constraints_None/aggregate/cloneOrder.tsv"

gff_id = "A2_black"
annotations_indir = "/mnt/md0/isshamie/Projects/Mito_Trace/data/processed/annotation_granges/"

save_large_se = FALSE

# Add coverage
# cov_fs = ["/mnt/md0/isshamie/Projects/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/Input/MT/cellr_True/numread_200/Input.coverage.strands.txt",
#            "/mnt/md0/isshamie/Projects/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/Flt3l/MT/cellr_True/numread_200/Flt3l.coverage.strands.txt"]
samples = c("Input", "72h Culture")
cov_fs = c("/mnt/md0/isshamie/Projects/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/Flt3l/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/Flt3l.coverage.tsv",
         "/mnt/md0/isshamie/Projects/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/Input/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/Input.coverage.tsv")

# %%
cov <- sapply(cov_fs,read.table)

# %%
head(cov[[1]])
# Out:
#         AAACGAAAGGAGACTC.1 AAACGAAAGTCACGCC.1 AAACGAACAAGACTAA.1
# 709G>A  8                   7                 10
# 930G>A  7                   6                 13
# 1888G>A 7                   4                 17
# 1949G>A 9                   6                 12
# 2992G>A 4                   9                 10
# 3244G>A 7                  16                 29
#         AAACGAACAAGCGAAC.1 AAACGAACACAGCCAC.1 AAACGAACACAGGTAG.1
# 709G>A  20                 34                 9
# 930G>A  21                 33                 8
# 1888G>A 15                 31                 7
# 1949G>A 23                 37                 5
# 2992G>A  9                 20                 8
# 3244G>A 13                 33                 8
#         AAACGAACACAGTAGG.1 AAACGAACATAGAATG.1 AAACGAACATGTAGAA.1
# 709G>A  13                  9                 30
# 930G>A  13                 13                 24
# 1888G>A 13                  9                 12
# 1949G>A 13                  8                  9
# 2992G>A 21                 14                 31
# 3244G>A  9                 19                 36
#         AAACGAAGTATTCGAC.1 ⋯ TTTGGTTTCGGTAGGA.1 TTTGTGTAGACCTATC.1
# 709G>A  22                 ⋯  9                  8
# 930G>A  30                 ⋯  9                  9
# 1888G>A  6                 ⋯  4                  8
# 1949G>A 20                 ⋯ 17                  4
# 2992G>A 16                 ⋯ 18                 10
# 3244G>A 14                 ⋯ 22                  1
#         TTTGTGTAGTCCCGCA.1 TTTGTGTAGTTAGAGT.1 TTTGTGTGTAATGTAG.1
# 709G>A  35                  5                 21
# 930G>A  10                  9                 28
# 1888G>A 19                  8                 19
# 1949G>A 22                  4                  7
# 2992G>A 19                  5                 24
# 3244G>A 32                 12                 14
#         TTTGTGTGTACGCAAG.1 TTTGTGTGTGCATTCA.1 TTTGTGTTCAGGCGCT.1
# 709G>A   5                 11                 22
# 930G>A   8                  3                 13
# 1888G>A 11                 15                 22
# 1949G>A 15                  9                 24
# 2992G>A  7                  7                 32
# 3244G>A 15                 11                 38
#         TTTGTGTTCAGTGTAC.1 TTTGTGTTCCCGAAGC.1
# 709G>A  22                  1
# 930G>A  18                  6
# 1888G>A 28                  5
# 1949G>A 26                  9
# 2992G>A 20                  5
# 3244G>A 36                 11

# %%
cov_sum <- (sapply(cov, colSums))
sapply(cov_sum, max)
# Out:
# /mnt/md0/isshamie/Projects/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/Flt3l/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/Flt3l.coverage.tsv
#                                                                                                                                                                                                       7373
# /mnt/md0/isshamie/Projects/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/Input/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/Input.coverage.tsv
#                                                                                                                                                                                                      97898

# %%
annotations <- readRDS(file.path(annotations_indir, paste0(gff_id, ".annotationGranges.rds")))

# %%
cells_meta <- as.data.frame(readr::read_tsv(cells_meta_f, )) # %>% tidyr::unite(barcode)
rownames(cells_meta) = cells_meta$cell
# Out:
# Rows: 10776 Columns: 42
# ── Column specification ───────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (12): cell, orig.ident, cell_id, proj, high.tss, nucleosome_group, ID, R...
# dbl (30): nCount_ATAC, nFeature_ATAC, total, duplicate, chimeric, unmapped, ...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# if (ids.reversed){
#     split.names <- stringr::str_split(rownames(cells_meta), "_")
#     rownames(cells_meta) = lapply(split.names, function(x){paste0(x[2], "_", x[1])})
# }
# head(cells_meta)

# %%
se <- readRDS(se_f)
se[[]]
# Out:
# Loading required package: SeuratObject
#
# Warning message:
# “package ‘SeuratObject’ was built under R version 4.1.3”
# Attaching sp
#                                   orig.ident nCount_ATAC nFeature_ATAC total
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 Flt3l       5219        5219         25798
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 Flt3l       2350        2350         18340
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 Flt3l       4322        4322         28417
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 Flt3l       1542        1542         12018
# cd34norm_Flt3l_AAACGAACAACGTACT-1 Flt3l       3251        3251         37690
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 Flt3l       1488        1488          9381
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 Flt3l       3107        3107         30421
# cd34norm_Flt3l_AAACGAACACGATATC-1 Flt3l       2626        2626         15245
# cd34norm_Flt3l_AAACGAACACTTACAG-1 Flt3l      10897       10897         48515
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 Flt3l       1436        1436         10268
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 Flt3l       5980        5980         41458
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 Flt3l       6563        6563         41204
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 Flt3l       6876        6876         38508
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 Flt3l       7385        7385         45914
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 Flt3l       2262        2262         16031
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 Flt3l       3313        3313         25798
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 Flt3l       3137        3137         17648
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 Flt3l       2642        2642         16826
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 Flt3l       8696        8696         35874
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 Flt3l       3773        3773         24528
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 Flt3l       1060        1060          7405
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 Flt3l       1926        1926         16795
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 Flt3l       4093        4093         23385
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 Flt3l       3081        3081         20204
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 Flt3l       3064        3064         15112
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 Flt3l       4528        4528         28161
# cd34norm_Flt3l_AAACTCGCACACACCG-1 Flt3l       6911        6911         33406
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 Flt3l       1146        1146          9279
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 Flt3l       2154        2154         13514
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 Flt3l       4093        4093         25950
# ⋮                                 ⋮          ⋮           ⋮             ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  Input      1310        1310           8488
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  Input      5370        5370          23397
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  Input      7668        7668          31056
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  Input       853         853           8488
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  Input      1352        1352          10739
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  Input      3568        3568          14752
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  Input       265         265           2406
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  Input      6005        6005          27746
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  Input      5733        5733          23398
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  Input      1717        1717          11614
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  Input       449         449          10039
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  Input      2873        2873          13438
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  Input      1263        1263          10202
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  Input       379         379           2731
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  Input      2929        2929          14909
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  Input      2131        2131          10937
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  Input       249         249           3481
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  Input      2180        2180           8178
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  Input      1295        1295          11005
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  Input      1365        1365          12812
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  Input      1491        1491           7761
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  Input      1800        1800          21305
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  Input      2944        2944          16564
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  Input      2677        2677          12037
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  Input      2009        2009           8747
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  Input      6841        6841          35511
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  Input      1877        1877          14217
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  Input      3000        3000          15165
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  Input      8494        8494          48687
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  Input      2891        2891          10251
#                                   duplicate chimeric unmapped lowmapq
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1  3956     111       95      1643
# cd34norm_Flt3l_AAACGAAAGCGATACG-1  2478      78       92       794
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1  4398     132      122      1771
# cd34norm_Flt3l_AAACGAAAGTACAACA-1  1524      60       45       585
# cd34norm_Flt3l_AAACGAACAACGTACT-1  3034      82      125      1680
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1  1416      44       50       547
# cd34norm_Flt3l_AAACGAACACCTGGTG-1  5698     112      157      1762
# cd34norm_Flt3l_AAACGAACACGATATC-1  1960      89       32       737
# cd34norm_Flt3l_AAACGAACACTTACAG-1 10680     240      158      2715
# cd34norm_Flt3l_AAACGAACATTAAGGA-1  1269      49       50       603
# cd34norm_Flt3l_AAACGAAGTACAACGG-1  7961     228      168      3383
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1  6460     170      132      2540
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1  6348     125      165      2050
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1  8078     248      193      2277
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1  2229      48       52       676
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1  3257      85       91      1313
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1  2463     100       61      1086
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1  2588      80       76      1073
# cd34norm_Flt3l_AAACGAATCACTGGTA-1  8433     193      117      2031
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1  4486     113       86      1307
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1   935      34       39       373
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1  1902      67       51       900
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1  4038      95       94      1347
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1  3160      95       72       894
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1  3632      91       67       917
# cd34norm_Flt3l_AAACTCGCAATGCACT-1  5773     115      115      1719
# cd34norm_Flt3l_AAACTCGCACACACCG-1  8691     206      180      1749
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1  1042      50       57       536
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1  2027      61       41       789
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1  4641      90      120      1482
# ⋮                                 ⋮         ⋮        ⋮        ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1   1692      32       23       288
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1   4866     133       76       893
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1   6405     165       99      1001
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1   1306      32       30       304
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1    791      25       60       241
# CHIP_b2_Input_TTTGGCCCATTCACCC-1   4610      84       73       692
# CHIP_b2_Input_TTTGGCCGTACTATGC-1    187      10        2        67
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1   7591     138       90      1399
# CHIP_b2_Input_TTTGGCCGTTACCACA-1   5791      91      120      1065
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1   1128      45       56       287
# CHIP_b2_Input_TTTGGTTAGATCGATA-1    639      18       35       148
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1   2528      63       55       468
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1   1247      42       38       205
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1    419      19       14        83
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1   2715      83       61       506
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1   1626      46       43       361
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1    423      16       19       121
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1   1789      65       34       254
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1   1209      34       41       254
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1    973      35       44       177
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1   1033      39       28       220
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1   2517      80      105       547
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1   2084      77       66       426
# CHIP_b2_Input_TTTGTGTCACACTAGT-1   2038      74       40       432
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1   1284      52       37       278
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1   7946     148      118      1467
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1   2190      42       40       420
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1   2707      67       52       475
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  14365     242      206      2591
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1   2111      68       40       418
#                                   mitochondrial passed_filters ⋯ TSS.percentile
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1  4740         15253          ⋯ 0.46
# cd34norm_Flt3l_AAACGAAAGCGATACG-1  9325          5573          ⋯ 0.62
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 10224         11770          ⋯ 0.30
# cd34norm_Flt3l_AAACGAAAGTACAACA-1  5688          4116          ⋯ 0.06
# cd34norm_Flt3l_AAACGAACAACGTACT-1 24974          7795          ⋯ 0.69
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1  3616          3708          ⋯ 0.22
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 14034          8658          ⋯ 0.63
# cd34norm_Flt3l_AAACGAACACGATATC-1  5330          7097          ⋯ 0.11
# cd34norm_Flt3l_AAACGAACACTTACAG-1 12096         22626          ⋯ 0.36
# cd34norm_Flt3l_AAACGAACATTAAGGA-1  4716          3581          ⋯ 0.10
# cd34norm_Flt3l_AAACGAAGTACAACGG-1  5015         24703          ⋯ 0.02
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 15426         16476          ⋯ 0.77
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 12787         17033          ⋯ 0.81
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 18382         16736          ⋯ 0.62
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1  7460          5566          ⋯ 0.40
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 12598          8454          ⋯ 0.97
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1  6608          7330          ⋯ 0.25
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1  6548          6461          ⋯ 0.63
# cd34norm_Flt3l_AAACGAATCACTGGTA-1  3094         22006          ⋯ 0.44
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1  8654          9882          ⋯ 0.74
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1  3655          2369          ⋯ 0.80
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1  8785          5090          ⋯ 0.51
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1  7749         10062          ⋯ 0.24
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1  8489          7494          ⋯ 0.86
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1  3409          6996          ⋯ 0.07
# cd34norm_Flt3l_AAACTCGCAATGCACT-1  8284         12155          ⋯ 0.09
# cd34norm_Flt3l_AAACTCGCACACACCG-1  6855         15725          ⋯ 0.69
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1  5043          2551          ⋯ 0.76
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1  5050          5546          ⋯ 0.74
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1  9790          9827          ⋯ 0.57
# ⋮                                 ⋮             ⋮              ⋱ ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1   3638          2815          ⋯ 0.84
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1   9193          8236          ⋯ 0.54
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  10400         12986          ⋯ 0.34
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1   4243          2573          ⋯ 0.90
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1   7581          2041          ⋯ 0.13
# CHIP_b2_Input_TTTGGCCCATTCACCC-1   2474          6819          ⋯ 0.74
# CHIP_b2_Input_TTTGGCCGTACTATGC-1   1583           557          ⋯ 0.67
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1   8225         10303          ⋯ 0.51
# CHIP_b2_Input_TTTGGCCGTTACCACA-1   5277         11054          ⋯ 0.05
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1   7535          2563          ⋯ 0.97
# CHIP_b2_Input_TTTGGTTAGATCGATA-1   7971          1228          ⋯ 0.01
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1   6187          4137          ⋯ 0.58
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1   6556          2114          ⋯ 0.67
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1   1378           818          ⋯ 0.97
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1   6339          5205          ⋯ 0.31
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1   5514          3347          ⋯ 0.23
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1   1978           924          ⋯ 0.98
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1   2980          3056          ⋯ 0.61
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1   7037          2430          ⋯ 0.67
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1   9335          2248          ⋯ 0.72
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1   4259          2182          ⋯ 0.88
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  13227          4829          ⋯ 0.09
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1   9590          4321          ⋯ 0.25
# CHIP_b2_Input_TTTGTGTCACACTAGT-1   5266          4187          ⋯ 0.92
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1   4416          2680          ⋯ 0.63
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  14501         11331          ⋯ 0.48
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1   8229          3296          ⋯ 0.56
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1   7195          4669          ⋯ 0.69
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1   7487         23796          ⋯ 0.33
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1   3246          4368          ⋯ 0.90
#                                   pct_reads_in_peaks blacklist_ratio high.tss
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 30.59726           0               High
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 38.07644           0               High
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 32.71878           0               High
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 32.28863           0               High
# cd34norm_Flt3l_AAACGAACAACGTACT-1 37.78063           0               High
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 34.49299           0               High
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 31.17348           0               High
# cd34norm_Flt3l_AAACGAACACGATATC-1 32.04171           0               High
# cd34norm_Flt3l_AAACGAACACTTACAG-1 47.67966           0               High
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 34.57135           0               High
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 20.62907           0               High
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 39.05074           0               High
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 37.79722           0               High
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 42.11879           0               High
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 36.09414           0               High
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 35.30873           0               High
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 38.47203           0               High
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 35.64464           0               High
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 37.08080           0               High
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 34.63874           0               High
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 39.29928           0               High
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 33.28094           0               High
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 37.16955           0               High
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 37.41660           0               High
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 38.66495           0               High
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 33.53353           0               High
# cd34norm_Flt3l_AAACTCGCACACACCG-1 42.04769           0               High
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 39.08271           0               High
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 33.73603           0               High
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 38.33316           0               High
# ⋮                                 ⋮                  ⋮               ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  41.03020           0               High
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  61.59543           0               High
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  56.02957           0               High
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  28.13836           0               High
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  59.33366           0               High
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  53.52691           0               High
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  42.36984           0               High
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  60.65224           0               High
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  43.63126           0               High
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  63.87046           0               High
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  29.64169           0               High
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  66.27991           0               High
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  53.40587           0               High
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  44.62103           0               High
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  48.04995           0               High
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  60.38243           0               High
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  22.07792           0               High
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  64.98691           0               High
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  46.04938           0               High
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  55.91637           0               High
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  67.64436           0               High
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  30.35825           0               High
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  62.34668           0               High
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  60.90279           0               High
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  72.53731           0               High
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  58.76798           0               High
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  51.91141           0               High
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  60.48404           0               High
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  34.64448           0               High
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  68.58974           0               High
#                                   nucleosome_group ATAC_snn_res.0.8
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 NS < 4           5
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 NS < 4           3
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 NS < 4           2
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 NS < 4           5
# cd34norm_Flt3l_AAACGAACAACGTACT-1 NS < 4           1
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 NS < 4           5
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 NS < 4           8
# cd34norm_Flt3l_AAACGAACACGATATC-1 NS < 4           4
# cd34norm_Flt3l_AAACGAACACTTACAG-1 NS < 4           15
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 NS < 4           1
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 NS < 4           11
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 NS < 4           0
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 NS < 4           2
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 NS < 4           15
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 NS < 4           5
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 NS < 4           3
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 NS < 4           9
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 NS < 4           8
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 NS < 4           15
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 NS < 4           6
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 NS < 4           12
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 NS < 4           6
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 NS < 4           2
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 NS < 4           9
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 NS < 4           9
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 NS < 4           5
# cd34norm_Flt3l_AAACTCGCACACACCG-1 NS < 4           9
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 NS < 4           12
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 NS < 4           6
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 NS < 4           2
# ⋮                                 ⋮                ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  NS < 4           16
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  NS < 4           1
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  NS < 4           7
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  NS < 4           6
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  NS < 4           10
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  NS < 4           11
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  NS < 4           10
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  NS < 4           1
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  NS < 4           7
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  NS < 4           10
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  NS < 4           10
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  NS < 4           1
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  NS < 4           1
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  NS < 4           11
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  NS < 4           1
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  NS < 4           10
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  NS < 4           10
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  NS < 4           0
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  NS < 4           13
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  NS < 4           10
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  NS < 4           10
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  NS < 4           8
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  NS < 4           7
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  NS < 4           1
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  NS < 4           10
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  NS < 4           7
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  NS < 4           1
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  NS < 4           1
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  NS < 4           11
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  NS < 4           11
#                                   seurat_clusters nCount_ATAC_log2 nCount_RNA
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 5               12.34983          8908
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 3               11.19906          3006
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 2               12.07782          6521
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 5               10.59152          2356
# cd34norm_Flt3l_AAACGAACAACGTACT-1 1               11.66711          4275
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 5               10.54013          2150
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 8               11.60177          5338
# cd34norm_Flt3l_AAACGAACACGATATC-1 4               11.35920          4225
# cd34norm_Flt3l_AAACGAACACTTACAG-1 15              13.41178         13471
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 1               10.48884          1970
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 11              12.54617         12950
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 0               12.68036          9274
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 2               12.74756          9676
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 15              12.85058          8908
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 5               11.14402          3223
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 3               11.69436          4450
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 9               11.61563          4114
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 8               11.36796          3832
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 15              13.08630         13007
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 6               11.88188          5316
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 12              10.05121          1252
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 6               10.91214          2678
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 2               11.99930          5555
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 9               11.58965          4230
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 9               11.58167          3899
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 5               12.14498          7294
# cd34norm_Flt3l_AAACTCGCACACACCG-1 9               12.75489          8813
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 12              10.16365          1456
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 6               11.07347          3095
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 2               11.99930          5588
# ⋮                                 ⋮               ⋮                ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  16              10.356452         1594
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  1               12.390975         5410
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  7               12.904823         8561
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  6                9.738092         1418
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  10              10.401946         1408
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  11              11.801304         4629
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  10               8.055282          344
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  1               12.552189         7146
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  7               12.485326         7106
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  10              10.746514         1844
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  10               8.813781          680
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  1               11.488844         2786
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  1               10.303781         1281
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  11               8.569856          488
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  1               11.516685         3201
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  10              11.057992         2316
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  10               7.965784          502
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  0               11.090774         2126
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  13              10.339850         1404
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  10              10.415742         1434
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  10              10.543032         1568
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  8               10.814582         2641
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  7               11.524052         2999
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  1               11.386940         2991
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  10              10.972980         1969
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  7               12.740202         8019
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  1               10.874981         1912
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  1               11.551228         3143
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  11              13.052398        13695
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  11              11.497852         3234
#                                   nFeature_RNA
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 5567
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 2472
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 4620
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 1996
# cd34norm_Flt3l_AAACGAACAACGTACT-1 3340
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 1864
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 3881
# cd34norm_Flt3l_AAACGAACACGATATC-1 3237
# cd34norm_Flt3l_AAACGAACACTTACAG-1 7325
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 1738
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 6704
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 5931
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 6014
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 5598
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 2590
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 3350
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 3289
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 3046
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 7521
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 3919
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 1137
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 2274
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 4003
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 3121
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 3125
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 4858
# cd34norm_Flt3l_AAACTCGCACACACCG-1 5544
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 1327
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 2563
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 4093
# ⋮                                 ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  1385
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  3991
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  5385
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  1021
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  1240
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  3552
# CHIP_b2_Input_TTTGGCCGTACTATGC-1   326
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  5085
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  4794
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  1618
# CHIP_b2_Input_TTTGGTTAGATCGATA-1   559
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  2313
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  1152
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1   452
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  2603
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  1985
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1   372
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  1750
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  1256
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  1272
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  1397
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  2201
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  2467
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  2468
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  1714
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  5370
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  1659
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  2556
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  7620
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  2593

# %%
colnames(se[[]])
# Out:
#  [1] "orig.ident"                       "nCount_ATAC"
#  [3] "nFeature_ATAC"                    "total"
#  [5] "duplicate"                        "chimeric"
#  [7] "unmapped"                         "lowmapq"
#  [9] "mitochondrial"                    "passed_filters"
# [11] "cell_id"                          "is__cell_barcode"
# [13] "TSS_fragments"                    "DNase_sensitive_region_fragments"
# [15] "enhancer_region_fragments"        "promoter_region_fragments"
# [17] "on_target_fragments"              "blacklist_region_fragments"
# [19] "peak_region_fragments"            "peak_region_cutsites"
# [21] "proj"                             "expID"
# [23] "nucleosome_signal"                "nucleosome_percentile"
# [25] "TSS.enrichment"                   "TSS.percentile"
# [27] "pct_reads_in_peaks"               "blacklist_ratio"
# [29] "high.tss"                         "nucleosome_group"
# [31] "ATAC_snn_res.0.8"                 "seurat_clusters"
# [33] "nCount_ATAC_log2"                 "nCount_RNA"
# [35] "nFeature_RNA"                     "Row.names"
# [37] "name"                             "run"
# [39] "donor"                            "condition"

# %%
frac_in_peaks <- se$peak_region_fragments/se$passed_filters
print(min(frac_in_peaks))
print(max(frac_in_peaks))
# Out:
# [1] 0.1500705
# [1] 0.8999499

# %% [markdown]
# ## RenameCells to remove the extra names added

# %%
# map_donors = c(("CHIP_a11", "CHIP_a1"), ("CHIP_a12", "CHIP_a1"), 
#                ("CHIP_b11", "CHIP_b1"), ("CHIP_b12", "CHIP_b1"),
#                ("CHIP_b21", "CHIP_b2"), ("CHIP_b22", "CHIP_b2"))
map_donors = list("CHIP_a11"="CHIP_a1", "CHIP_a12"="CHIP_a1",
                  "CHIP_b11" = "CHIP_b1", "CHIP_b12" = "CHIP_b1",
                  "CHIP_b21" = "CHIP_b2", "CHIP_b22" = "CHIP_b2")
map_donors


new.names <- lapply(row.names(se[[]]), function(s) {stri_replace_all_regex(s, names(map_donors), unlist(map_donors, use.names=F), vectorize=F)})
             
head(new.names)
# Out:
# $CHIP_a11
# [1] "CHIP_a1"
#
# $CHIP_a12
# [1] "CHIP_a1"
#
# $CHIP_b11
# [1] "CHIP_b1"
#
# $CHIP_b12
# [1] "CHIP_b1"
#
# $CHIP_b21
# [1] "CHIP_b2"
#
# $CHIP_b22
# [1] "CHIP_b2"
# [[1]]
# [1] "cd34norm_Flt3l_AAACGAAAGAGCTCCC-1"
#
# [[2]]
# [1] "cd34norm_Flt3l_AAACGAAAGCGATACG-1"
#
# [[3]]
# [1] "cd34norm_Flt3l_AAACGAAAGGCTTCGC-1"
#
# [[4]]
# [1] "cd34norm_Flt3l_AAACGAAAGTACAACA-1"
#
# [[5]]
# [1] "cd34norm_Flt3l_AAACGAACAACGTACT-1"
#
# [[6]]
# [1] "cd34norm_Flt3l_AAACGAACAAGCGGTA-1"

# %%
se <- RenameCells(se, 
                  old.names=names(new.names), 
                  new.names=unlist(new.names, use.names=F))
se[[]]
# Out:
# Warning message:
# “The following arguments are not used: old.names”
# Loading required package: Signac
#
# Registered S3 method overwritten by 'spatstat.core':
#   method          from
#   formula.glmmPQL MASS
#                                   orig.ident nCount_ATAC nFeature_ATAC total
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 Flt3l       5219        5219         25798
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 Flt3l       2350        2350         18340
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 Flt3l       4322        4322         28417
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 Flt3l       1542        1542         12018
# cd34norm_Flt3l_AAACGAACAACGTACT-1 Flt3l       3251        3251         37690
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 Flt3l       1488        1488          9381
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 Flt3l       3107        3107         30421
# cd34norm_Flt3l_AAACGAACACGATATC-1 Flt3l       2626        2626         15245
# cd34norm_Flt3l_AAACGAACACTTACAG-1 Flt3l      10897       10897         48515
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 Flt3l       1436        1436         10268
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 Flt3l       5980        5980         41458
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 Flt3l       6563        6563         41204
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 Flt3l       6876        6876         38508
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 Flt3l       7385        7385         45914
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 Flt3l       2262        2262         16031
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 Flt3l       3313        3313         25798
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 Flt3l       3137        3137         17648
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 Flt3l       2642        2642         16826
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 Flt3l       8696        8696         35874
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 Flt3l       3773        3773         24528
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 Flt3l       1060        1060          7405
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 Flt3l       1926        1926         16795
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 Flt3l       4093        4093         23385
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 Flt3l       3081        3081         20204
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 Flt3l       3064        3064         15112
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 Flt3l       4528        4528         28161
# cd34norm_Flt3l_AAACTCGCACACACCG-1 Flt3l       6911        6911         33406
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 Flt3l       1146        1146          9279
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 Flt3l       2154        2154         13514
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 Flt3l       4093        4093         25950
# ⋮                                 ⋮          ⋮           ⋮             ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  Input      1310        1310           8488
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  Input      5370        5370          23397
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  Input      7668        7668          31056
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  Input       853         853           8488
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  Input      1352        1352          10739
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  Input      3568        3568          14752
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  Input       265         265           2406
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  Input      6005        6005          27746
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  Input      5733        5733          23398
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  Input      1717        1717          11614
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  Input       449         449          10039
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  Input      2873        2873          13438
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  Input      1263        1263          10202
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  Input       379         379           2731
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  Input      2929        2929          14909
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  Input      2131        2131          10937
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  Input       249         249           3481
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  Input      2180        2180           8178
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  Input      1295        1295          11005
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  Input      1365        1365          12812
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  Input      1491        1491           7761
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  Input      1800        1800          21305
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  Input      2944        2944          16564
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  Input      2677        2677          12037
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  Input      2009        2009           8747
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  Input      6841        6841          35511
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  Input      1877        1877          14217
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  Input      3000        3000          15165
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  Input      8494        8494          48687
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  Input      2891        2891          10251
#                                   duplicate chimeric unmapped lowmapq
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1  3956     111       95      1643
# cd34norm_Flt3l_AAACGAAAGCGATACG-1  2478      78       92       794
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1  4398     132      122      1771
# cd34norm_Flt3l_AAACGAAAGTACAACA-1  1524      60       45       585
# cd34norm_Flt3l_AAACGAACAACGTACT-1  3034      82      125      1680
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1  1416      44       50       547
# cd34norm_Flt3l_AAACGAACACCTGGTG-1  5698     112      157      1762
# cd34norm_Flt3l_AAACGAACACGATATC-1  1960      89       32       737
# cd34norm_Flt3l_AAACGAACACTTACAG-1 10680     240      158      2715
# cd34norm_Flt3l_AAACGAACATTAAGGA-1  1269      49       50       603
# cd34norm_Flt3l_AAACGAAGTACAACGG-1  7961     228      168      3383
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1  6460     170      132      2540
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1  6348     125      165      2050
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1  8078     248      193      2277
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1  2229      48       52       676
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1  3257      85       91      1313
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1  2463     100       61      1086
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1  2588      80       76      1073
# cd34norm_Flt3l_AAACGAATCACTGGTA-1  8433     193      117      2031
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1  4486     113       86      1307
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1   935      34       39       373
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1  1902      67       51       900
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1  4038      95       94      1347
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1  3160      95       72       894
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1  3632      91       67       917
# cd34norm_Flt3l_AAACTCGCAATGCACT-1  5773     115      115      1719
# cd34norm_Flt3l_AAACTCGCACACACCG-1  8691     206      180      1749
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1  1042      50       57       536
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1  2027      61       41       789
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1  4641      90      120      1482
# ⋮                                 ⋮         ⋮        ⋮        ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1   1692      32       23       288
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1   4866     133       76       893
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1   6405     165       99      1001
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1   1306      32       30       304
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1    791      25       60       241
# CHIP_b2_Input_TTTGGCCCATTCACCC-1   4610      84       73       692
# CHIP_b2_Input_TTTGGCCGTACTATGC-1    187      10        2        67
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1   7591     138       90      1399
# CHIP_b2_Input_TTTGGCCGTTACCACA-1   5791      91      120      1065
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1   1128      45       56       287
# CHIP_b2_Input_TTTGGTTAGATCGATA-1    639      18       35       148
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1   2528      63       55       468
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1   1247      42       38       205
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1    419      19       14        83
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1   2715      83       61       506
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1   1626      46       43       361
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1    423      16       19       121
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1   1789      65       34       254
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1   1209      34       41       254
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1    973      35       44       177
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1   1033      39       28       220
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1   2517      80      105       547
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1   2084      77       66       426
# CHIP_b2_Input_TTTGTGTCACACTAGT-1   2038      74       40       432
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1   1284      52       37       278
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1   7946     148      118      1467
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1   2190      42       40       420
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1   2707      67       52       475
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  14365     242      206      2591
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1   2111      68       40       418
#                                   mitochondrial passed_filters ⋯ TSS.percentile
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1  4740         15253          ⋯ 0.46
# cd34norm_Flt3l_AAACGAAAGCGATACG-1  9325          5573          ⋯ 0.62
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 10224         11770          ⋯ 0.30
# cd34norm_Flt3l_AAACGAAAGTACAACA-1  5688          4116          ⋯ 0.06
# cd34norm_Flt3l_AAACGAACAACGTACT-1 24974          7795          ⋯ 0.69
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1  3616          3708          ⋯ 0.22
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 14034          8658          ⋯ 0.63
# cd34norm_Flt3l_AAACGAACACGATATC-1  5330          7097          ⋯ 0.11
# cd34norm_Flt3l_AAACGAACACTTACAG-1 12096         22626          ⋯ 0.36
# cd34norm_Flt3l_AAACGAACATTAAGGA-1  4716          3581          ⋯ 0.10
# cd34norm_Flt3l_AAACGAAGTACAACGG-1  5015         24703          ⋯ 0.02
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 15426         16476          ⋯ 0.77
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 12787         17033          ⋯ 0.81
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 18382         16736          ⋯ 0.62
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1  7460          5566          ⋯ 0.40
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 12598          8454          ⋯ 0.97
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1  6608          7330          ⋯ 0.25
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1  6548          6461          ⋯ 0.63
# cd34norm_Flt3l_AAACGAATCACTGGTA-1  3094         22006          ⋯ 0.44
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1  8654          9882          ⋯ 0.74
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1  3655          2369          ⋯ 0.80
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1  8785          5090          ⋯ 0.51
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1  7749         10062          ⋯ 0.24
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1  8489          7494          ⋯ 0.86
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1  3409          6996          ⋯ 0.07
# cd34norm_Flt3l_AAACTCGCAATGCACT-1  8284         12155          ⋯ 0.09
# cd34norm_Flt3l_AAACTCGCACACACCG-1  6855         15725          ⋯ 0.69
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1  5043          2551          ⋯ 0.76
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1  5050          5546          ⋯ 0.74
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1  9790          9827          ⋯ 0.57
# ⋮                                 ⋮             ⋮              ⋱ ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1   3638          2815          ⋯ 0.84
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1   9193          8236          ⋯ 0.54
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  10400         12986          ⋯ 0.34
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1   4243          2573          ⋯ 0.90
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1   7581          2041          ⋯ 0.13
# CHIP_b2_Input_TTTGGCCCATTCACCC-1   2474          6819          ⋯ 0.74
# CHIP_b2_Input_TTTGGCCGTACTATGC-1   1583           557          ⋯ 0.67
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1   8225         10303          ⋯ 0.51
# CHIP_b2_Input_TTTGGCCGTTACCACA-1   5277         11054          ⋯ 0.05
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1   7535          2563          ⋯ 0.97
# CHIP_b2_Input_TTTGGTTAGATCGATA-1   7971          1228          ⋯ 0.01
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1   6187          4137          ⋯ 0.58
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1   6556          2114          ⋯ 0.67
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1   1378           818          ⋯ 0.97
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1   6339          5205          ⋯ 0.31
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1   5514          3347          ⋯ 0.23
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1   1978           924          ⋯ 0.98
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1   2980          3056          ⋯ 0.61
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1   7037          2430          ⋯ 0.67
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1   9335          2248          ⋯ 0.72
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1   4259          2182          ⋯ 0.88
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  13227          4829          ⋯ 0.09
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1   9590          4321          ⋯ 0.25
# CHIP_b2_Input_TTTGTGTCACACTAGT-1   5266          4187          ⋯ 0.92
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1   4416          2680          ⋯ 0.63
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  14501         11331          ⋯ 0.48
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1   8229          3296          ⋯ 0.56
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1   7195          4669          ⋯ 0.69
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1   7487         23796          ⋯ 0.33
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1   3246          4368          ⋯ 0.90
#                                   pct_reads_in_peaks blacklist_ratio high.tss
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 30.59726           0               High
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 38.07644           0               High
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 32.71878           0               High
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 32.28863           0               High
# cd34norm_Flt3l_AAACGAACAACGTACT-1 37.78063           0               High
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 34.49299           0               High
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 31.17348           0               High
# cd34norm_Flt3l_AAACGAACACGATATC-1 32.04171           0               High
# cd34norm_Flt3l_AAACGAACACTTACAG-1 47.67966           0               High
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 34.57135           0               High
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 20.62907           0               High
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 39.05074           0               High
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 37.79722           0               High
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 42.11879           0               High
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 36.09414           0               High
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 35.30873           0               High
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 38.47203           0               High
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 35.64464           0               High
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 37.08080           0               High
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 34.63874           0               High
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 39.29928           0               High
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 33.28094           0               High
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 37.16955           0               High
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 37.41660           0               High
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 38.66495           0               High
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 33.53353           0               High
# cd34norm_Flt3l_AAACTCGCACACACCG-1 42.04769           0               High
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 39.08271           0               High
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 33.73603           0               High
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 38.33316           0               High
# ⋮                                 ⋮                  ⋮               ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  41.03020           0               High
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  61.59543           0               High
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  56.02957           0               High
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  28.13836           0               High
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  59.33366           0               High
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  53.52691           0               High
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  42.36984           0               High
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  60.65224           0               High
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  43.63126           0               High
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  63.87046           0               High
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  29.64169           0               High
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  66.27991           0               High
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  53.40587           0               High
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  44.62103           0               High
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  48.04995           0               High
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  60.38243           0               High
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  22.07792           0               High
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  64.98691           0               High
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  46.04938           0               High
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  55.91637           0               High
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  67.64436           0               High
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  30.35825           0               High
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  62.34668           0               High
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  60.90279           0               High
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  72.53731           0               High
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  58.76798           0               High
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  51.91141           0               High
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  60.48404           0               High
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  34.64448           0               High
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  68.58974           0               High
#                                   nucleosome_group ATAC_snn_res.0.8
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 NS < 4           5
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 NS < 4           3
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 NS < 4           2
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 NS < 4           5
# cd34norm_Flt3l_AAACGAACAACGTACT-1 NS < 4           1
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 NS < 4           5
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 NS < 4           8
# cd34norm_Flt3l_AAACGAACACGATATC-1 NS < 4           4
# cd34norm_Flt3l_AAACGAACACTTACAG-1 NS < 4           15
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 NS < 4           1
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 NS < 4           11
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 NS < 4           0
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 NS < 4           2
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 NS < 4           15
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 NS < 4           5
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 NS < 4           3
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 NS < 4           9
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 NS < 4           8
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 NS < 4           15
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 NS < 4           6
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 NS < 4           12
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 NS < 4           6
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 NS < 4           2
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 NS < 4           9
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 NS < 4           9
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 NS < 4           5
# cd34norm_Flt3l_AAACTCGCACACACCG-1 NS < 4           9
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 NS < 4           12
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 NS < 4           6
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 NS < 4           2
# ⋮                                 ⋮                ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  NS < 4           16
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  NS < 4           1
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  NS < 4           7
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  NS < 4           6
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  NS < 4           10
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  NS < 4           11
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  NS < 4           10
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  NS < 4           1
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  NS < 4           7
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  NS < 4           10
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  NS < 4           10
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  NS < 4           1
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  NS < 4           1
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  NS < 4           11
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  NS < 4           1
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  NS < 4           10
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  NS < 4           10
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  NS < 4           0
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  NS < 4           13
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  NS < 4           10
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  NS < 4           10
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  NS < 4           8
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  NS < 4           7
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  NS < 4           1
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  NS < 4           10
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  NS < 4           7
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  NS < 4           1
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  NS < 4           1
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  NS < 4           11
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  NS < 4           11
#                                   seurat_clusters nCount_ATAC_log2 nCount_RNA
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 5               12.34983          8908
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 3               11.19906          3006
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 2               12.07782          6521
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 5               10.59152          2356
# cd34norm_Flt3l_AAACGAACAACGTACT-1 1               11.66711          4275
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 5               10.54013          2150
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 8               11.60177          5338
# cd34norm_Flt3l_AAACGAACACGATATC-1 4               11.35920          4225
# cd34norm_Flt3l_AAACGAACACTTACAG-1 15              13.41178         13471
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 1               10.48884          1970
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 11              12.54617         12950
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 0               12.68036          9274
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 2               12.74756          9676
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 15              12.85058          8908
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 5               11.14402          3223
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 3               11.69436          4450
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 9               11.61563          4114
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 8               11.36796          3832
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 15              13.08630         13007
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 6               11.88188          5316
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 12              10.05121          1252
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 6               10.91214          2678
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 2               11.99930          5555
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 9               11.58965          4230
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 9               11.58167          3899
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 5               12.14498          7294
# cd34norm_Flt3l_AAACTCGCACACACCG-1 9               12.75489          8813
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 12              10.16365          1456
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 6               11.07347          3095
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 2               11.99930          5588
# ⋮                                 ⋮               ⋮                ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  16              10.356452         1594
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  1               12.390975         5410
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  7               12.904823         8561
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  6                9.738092         1418
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  10              10.401946         1408
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  11              11.801304         4629
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  10               8.055282          344
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  1               12.552189         7146
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  7               12.485326         7106
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  10              10.746514         1844
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  10               8.813781          680
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  1               11.488844         2786
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  1               10.303781         1281
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  11               8.569856          488
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  1               11.516685         3201
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  10              11.057992         2316
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  10               7.965784          502
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  0               11.090774         2126
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  13              10.339850         1404
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  10              10.415742         1434
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  10              10.543032         1568
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  8               10.814582         2641
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  7               11.524052         2999
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  1               11.386940         2991
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  10              10.972980         1969
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  7               12.740202         8019
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  1               10.874981         1912
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  1               11.551228         3143
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  11              13.052398        13695
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  11              11.497852         3234
#                                   nFeature_RNA
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 5567
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 2472
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 4620
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 1996
# cd34norm_Flt3l_AAACGAACAACGTACT-1 3340
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 1864
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 3881
# cd34norm_Flt3l_AAACGAACACGATATC-1 3237
# cd34norm_Flt3l_AAACGAACACTTACAG-1 7325
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 1738
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 6704
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 5931
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 6014
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 5598
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 2590
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 3350
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 3289
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 3046
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 7521
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 3919
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 1137
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 2274
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 4003
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 3121
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 3125
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 4858
# cd34norm_Flt3l_AAACTCGCACACACCG-1 5544
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 1327
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 2563
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 4093
# ⋮                                 ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  1385
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  3991
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  5385
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  1021
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  1240
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  3552
# CHIP_b2_Input_TTTGGCCGTACTATGC-1   326
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  5085
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  4794
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  1618
# CHIP_b2_Input_TTTGGTTAGATCGATA-1   559
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  2313
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  1152
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1   452
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  2603
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  1985
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1   372
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  1750
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  1256
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  1272
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  1397
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  2201
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  2467
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  2468
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  1714
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  5370
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  1659
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  2556
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  7620
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  2593

# %% [markdown]
# ## Merge clones and se

# %%
new_cells_meta = merge(cells_meta[c("name", "run", "donor", "condition")],
                       se[[]], by=0, all=TRUE)
rownames(new_cells_meta) <- new_cells_meta$Row.names
sample(new_cells_meta, 10)
# Out:
#                                   TSS.enrichment
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 3.166357
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 3.434863
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 2.927073
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 2.354402
# cd34norm_Flt3l_AAACGAACAACGTACT-1 3.562635
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 2.772228
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 3.447257
# cd34norm_Flt3l_AAACGAACACGATATC-1 2.538445
# cd34norm_Flt3l_AAACGAACACTTACAG-1 3.023408
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 2.513276
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 2.031676
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 3.757317
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 3.871358
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 3.424922
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 3.075994
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 5.269017
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 2.836557
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 3.456245
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 3.143467
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 3.690754
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 3.854969
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 3.251294
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 2.816231
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 4.090028
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 2.416250
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 2.484241
# cd34norm_Flt3l_AAACTCGCACACACCG-1 3.581664
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 3.716284
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 3.684687
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 3.342112
# ⋮                                 ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  5.180005
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  4.266642
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  3.838801
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  5.631868
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  3.289734
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  4.771592
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  4.570430
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  4.204449
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  2.909148
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  6.668332
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  2.209555
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  4.335963
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  4.580035
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  6.526807
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  3.766821
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  3.596404
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  7.059607
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  4.410974
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  4.573205
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  4.715285
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  5.430467
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  3.149578
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  3.632731
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  5.794206
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  4.465904
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  4.125604
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  4.309327
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  4.635365
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  3.805932
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  5.594406
#                                   Row.names                         run
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 NA
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 cd34norm_Flt3l_AAACGAAAGCGATACG-1 NA
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 NA
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 cd34norm_Flt3l_AAACGAAAGTACAACA-1 NA
# cd34norm_Flt3l_AAACGAACAACGTACT-1 cd34norm_Flt3l_AAACGAACAACGTACT-1 cd34norm
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 cd34norm_Flt3l_AAACGAACAAGCGGTA-1 NA
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 cd34norm_Flt3l_AAACGAACACCTGGTG-1 cd34norm
# cd34norm_Flt3l_AAACGAACACGATATC-1 cd34norm_Flt3l_AAACGAACACGATATC-1 cd34norm
# cd34norm_Flt3l_AAACGAACACTTACAG-1 cd34norm_Flt3l_AAACGAACACTTACAG-1 NA
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 cd34norm_Flt3l_AAACGAACATTAAGGA-1 NA
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 cd34norm_Flt3l_AAACGAAGTACAACGG-1 cd34norm
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 cd34norm_Flt3l_AAACGAAGTGGACCAA-1 cd34norm
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 NA
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 NA
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 cd34norm
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 cd34norm_Flt3l_AAACGAAGTTGAATAG-1 NA
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 NA
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 cd34norm_Flt3l_AAACGAATCAAGTTGC-1 NA
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 cd34norm_Flt3l_AAACGAATCACTGGTA-1 NA
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 cd34norm_Flt3l_AAACGAATCCTAAAGC-1 cd34norm
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 cd34norm_Flt3l_AAACGAATCGAGTGTT-1 cd34norm
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 cd34norm_Flt3l_AAACTCGAGCAATAAC-1 NA
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 cd34norm_Flt3l_AAACTCGAGTACAGAT-1 NA
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 cd34norm
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 cd34norm
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 cd34norm_Flt3l_AAACTCGCAATGCACT-1 cd34norm
# cd34norm_Flt3l_AAACTCGCACACACCG-1 cd34norm_Flt3l_AAACTCGCACACACCG-1 cd34norm
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 cd34norm_Flt3l_AAACTCGCAGATTTGC-1 cd34norm
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 cd34norm_Flt3l_AAACTCGCATCCCTCA-1 NA
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 cd34norm_Flt3l_AAACTCGCATGCGTTA-1 NA
# ⋮                                 ⋮                                 ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  CHIP_b2_Input_TTTGGCCAGTAACACA-1  CHIP_b2
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  CHIP_b2
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  CHIP_b2
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  CHIP_b2_Input_TTTGGCCCAGGTAACG-1  CHIP_b2
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  CHIP_b2
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  CHIP_b2_Input_TTTGGCCCATTCACCC-1  NA
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  CHIP_b2_Input_TTTGGCCGTACTATGC-1  NA
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  CHIP_b2_Input_TTTGGCCGTATCTGCA-1  CHIP_b2
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  CHIP_b2_Input_TTTGGCCGTTACCACA-1  NA
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  CHIP_b2_Input_TTTGGCCTCGGACGAA-1  CHIP_b2
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  CHIP_b2_Input_TTTGGTTAGATCGATA-1  CHIP_b2
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  CHIP_b2
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  CHIP_b2_Input_TTTGGTTCACGGTTAT-1  CHIP_b2
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  CHIP_b2_Input_TTTGGTTGTACTTCAG-1  NA
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  CHIP_b2
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  CHIP_b2
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  NA
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  CHIP_b2_Input_TTTGGTTTCAATTGGC-1  NA
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  CHIP_b2_Input_TTTGGTTTCGGCAATT-1  CHIP_b2
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  CHIP_b2_Input_TTTGTGTAGACTAGCG-1  CHIP_b2
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  CHIP_b2_Input_TTTGTGTAGATTCCGT-1  CHIP_b2
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  CHIP_b2_Input_TTTGTGTAGGATTGAT-1  NA
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  CHIP_b2
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  CHIP_b2_Input_TTTGTGTCACACTAGT-1  CHIP_b2
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  CHIP_b2_Input_TTTGTGTCATGGCCTG-1  CHIP_b2
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  CHIP_b2
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  CHIP_b2_Input_TTTGTGTGTGGACAGT-1  CHIP_b2
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  CHIP_b2_Input_TTTGTGTTCAGTACAC-1  CHIP_b2
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  CHIP_b2_Input_TTTGTGTTCTATAGGC-1  CHIP_b2
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  CHIP_b2_Input_TTTGTGTTCTATGAGC-1  NA
#                                   seurat_clusters peak_region_fragments
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 5                4667
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 3                2122
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 2                3851
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 5                1329
# cd34norm_Flt3l_AAACGAACAACGTACT-1 1                2945
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 5                1279
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 8                2699
# cd34norm_Flt3l_AAACGAACACGATATC-1 4                2274
# cd34norm_Flt3l_AAACGAACACTTACAG-1 15              10788
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 1                1238
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 11               5096
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 0                6434
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 2                6438
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 15               7049
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 5                2009
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 3                2985
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 9                2820
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 8                2303
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 15               8160
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 6                3423
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 12                931
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 6                1694
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 2                3740
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 9                2804
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 9                2705
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 5                4076
# cd34norm_Flt3l_AAACTCGCACACACCG-1 9                6612
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 12                997
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 6                1871
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 2                3767
# ⋮                                 ⋮               ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  16              1155
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  1               5073
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  7               7276
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  6                724
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  10              1211
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  11              3650
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  10               236
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  1               6249
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  7               4823
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  10              1637
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  10               364
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  1               2742
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  1               1129
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  11               365
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  1               2501
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  10              2021
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  10               204
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  0               1986
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  13              1119
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  10              1257
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  10              1476
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  8               1466
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  7               2694
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  1               2550
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  10              1944
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  7               6659
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  1               1711
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  1               2824
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  11              8244
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  11              2996
#                                   donor      unmapped high.tss
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 NA          95      High
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 NA          92      High
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 NA         122      High
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 NA          45      High
# cd34norm_Flt3l_AAACGAACAACGTACT-1 cd34norm_2 125      High
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 NA          50      High
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 cd34norm_2 157      High
# cd34norm_Flt3l_AAACGAACACGATATC-1 cd34norm_2  32      High
# cd34norm_Flt3l_AAACGAACACTTACAG-1 NA         158      High
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 NA          50      High
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 cd34norm_3 168      High
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 cd34norm_3 132      High
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 NA         165      High
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 NA         193      High
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 cd34norm_2  52      High
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 NA          91      High
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 NA          61      High
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 NA          76      High
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 NA         117      High
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 cd34norm_2  86      High
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 cd34norm_3  39      High
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 NA          51      High
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 NA          94      High
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 cd34norm_3  72      High
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 cd34norm_1  67      High
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 cd34norm_0 115      High
# cd34norm_Flt3l_AAACTCGCACACACCG-1 cd34norm_0 180      High
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 cd34norm_3  57      High
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 NA          41      High
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 NA         120      High
# ⋮                                 ⋮          ⋮        ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  CHIP_b2_0   23      High
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  CHIP_b2_1   76      High
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  CHIP_b2_0   99      High
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  CHIP_b2_0   30      High
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  CHIP_b2_1   60      High
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  NA          73      High
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  NA           2      High
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  CHIP_b2_1   90      High
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  NA         120      High
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  CHIP_b2_1   56      High
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  CHIP_b2_0   35      High
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  CHIP_b2_1   55      High
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  CHIP_b2_0   38      High
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  NA          14      High
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  CHIP_b2_0   61      High
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  CHIP_b2_1   43      High
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  NA          19      High
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  NA          34      High
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  CHIP_b2_1   41      High
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  CHIP_b2_1   44      High
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  CHIP_b2_1   28      High
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  NA         105      High
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  CHIP_b2_1   66      High
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  CHIP_b2_1   40      High
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  CHIP_b2_1   37      High
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  CHIP_b2_1  118      High
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  CHIP_b2_0   40      High
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  CHIP_b2_1   52      High
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  CHIP_b2_0  206      High
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  NA          40      High
#                                   blacklist_region_fragments TSS_fragments
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 0                          2708
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 0                          1062
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 0                          2145
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 0                           727
# cd34norm_Flt3l_AAACGAACAACGTACT-1 0                          1562
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 0                           705
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 0                          1708
# cd34norm_Flt3l_AAACGAACACGATATC-1 0                          1273
# cd34norm_Flt3l_AAACGAACACTTACAG-1 0                          4793
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 0                           669
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 0                          4684
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 0                          3521
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 0                          3142
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 0                          3024
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 0                          1035
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 0                          1499
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 0                          1419
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 0                          1421
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 0                          5138
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 0                          1844
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 0                           410
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 0                           965
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 0                          1821
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 0                          1411
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 0                          1351
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 0                          2319
# cd34norm_Flt3l_AAACTCGCACACACCG-1 0                          3055
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 0                           507
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 0                          1059
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 0                          1938
# ⋮                                 ⋮                          ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  0                           801
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  0                          2846
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  0                          4516
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  0                           602
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  0                           810
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  0                          2761
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  0                           180
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  0                          4347
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  0                          3104
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  0                          1119
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  0                           280
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  0                          1553
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  0                           677
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  0                           271
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  0                          1505
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  0                          1397
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  0                           215
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  0                          1158
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  0                           699
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  0                           832
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  0                          1060
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  0                          1210
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  0                          1720
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  0                          1702
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  0                          1166
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  0                          4329
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  0                          1086
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  0                          1680
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  0                          6795
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  0                          2053

# %%
unique(new_cells_meta$expID)

new_cells_meta$expID <- unlist(lapply(new_cells_meta$expID, 
                                      function(s) {stri_replace_all_regex(s, names(map_donors), unlist(map_donors, use.names=F), vectorize=F)}), 
                               use.names=F)
# Out:
# [1] "cd34norm_Flt3l" "CHIP_a12_Flt3l" "CHIP_a11_Input" "CHIP_b11_Flt3l"
# [5] "CHIP_b12_Input" "CHIP_b2_Input"

# %%
# se$ID <- apply(stringr::str_split((rownames(se[[]])), "_", simplify=T)[,1:2], 1, function(x) {paste0(x[[1]],  "_", x[[2]])})
# se <- RenameCells(se, new.names=se$ID)

# %%
donor_levels <- levels(factor(new_cells_meta$donor))
donor_levels[length(donor_levels) + 1] <- "None"

# %%
condition_levels <- levels(factor(new_cells_meta$condition))
condition_levels[length(condition_levels) + 1] <- "None"

lineage_levels <- levels(factor(new_cells_meta$lineage))
lineage_levels[length(lineage_levels) + 1] <- "None"

# %%
#new_cells_meta$name <- paste0(new_cells_meta$donor, "_", new_cells_meta$lineage)
name_levels <- levels(factor(new_cells_meta$name))
name_levels[length(name_levels) + 1] <- "None"

# %%
new_cells_meta$donor <- factor(new_cells_meta$donor, levels=donor_levels)
new_cells_meta$condition <- factor(new_cells_meta$condition, levels=condition_levels)
#new_cells_meta$lineage <- factor(new_cells_meta$lineage, levels=lineage_levels)
new_cells_meta$name <- factor(new_cells_meta$name, levels=name_levels)

# %%
#new_cells_meta$name <- paste0(new_cells_meta$donor, "_", new_cells_meta$lineage)
new_cells_meta$donor[is.na(new_cells_meta$donor)] <- "None"
new_cells_meta$condition[is.na(new_cells_meta$condition)] <- "None"
new_cells_meta$name[(is.na(new_cells_meta$name) | grepl("NA", new_cells_meta$name))] <- "None"

#new_cells_meta$lineage[is.na(new_cells_meta$lineage)] <- "None"

# %%
new_cells_meta
# Out:
#                                   Row.names
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 cd34norm_Flt3l_AAACGAAAGAGCTCCC-1
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 cd34norm_Flt3l_AAACGAAAGCGATACG-1
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 cd34norm_Flt3l_AAACGAAAGGCTTCGC-1
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 cd34norm_Flt3l_AAACGAAAGTACAACA-1
# cd34norm_Flt3l_AAACGAACAACGTACT-1 cd34norm_Flt3l_AAACGAACAACGTACT-1
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 cd34norm_Flt3l_AAACGAACAAGCGGTA-1
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 cd34norm_Flt3l_AAACGAACACCTGGTG-1
# cd34norm_Flt3l_AAACGAACACGATATC-1 cd34norm_Flt3l_AAACGAACACGATATC-1
# cd34norm_Flt3l_AAACGAACACTTACAG-1 cd34norm_Flt3l_AAACGAACACTTACAG-1
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 cd34norm_Flt3l_AAACGAACATTAAGGA-1
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 cd34norm_Flt3l_AAACGAAGTACAACGG-1
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 cd34norm_Flt3l_AAACGAAGTGGACCAA-1
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 cd34norm_Flt3l_AAACGAAGTGGCGCTT-1
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 cd34norm_Flt3l_AAACGAAGTGTCCCAG-1
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 cd34norm_Flt3l_AAACGAAGTGTTTCTT-1
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 cd34norm_Flt3l_AAACGAAGTTGAATAG-1
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 cd34norm_Flt3l_AAACGAAGTTGCAGAG-1
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 cd34norm_Flt3l_AAACGAATCAAGTTGC-1
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 cd34norm_Flt3l_AAACGAATCACTGGTA-1
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 cd34norm_Flt3l_AAACGAATCCTAAAGC-1
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 cd34norm_Flt3l_AAACGAATCGAGTGTT-1
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 cd34norm_Flt3l_AAACTCGAGCAATAAC-1
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 cd34norm_Flt3l_AAACTCGAGTACAGAT-1
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 cd34norm_Flt3l_AAACTCGAGTGTGTAA-1
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 cd34norm_Flt3l_AAACTCGCAAGCCCTG-1
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 cd34norm_Flt3l_AAACTCGCAATGCACT-1
# cd34norm_Flt3l_AAACTCGCACACACCG-1 cd34norm_Flt3l_AAACTCGCACACACCG-1
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 cd34norm_Flt3l_AAACTCGCAGATTTGC-1
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 cd34norm_Flt3l_AAACTCGCATCCCTCA-1
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 cd34norm_Flt3l_AAACTCGCATGCGTTA-1
# ⋮                                 ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  CHIP_b2_Input_TTTGGCCAGTAACACA-1
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  CHIP_b2_Input_TTTGGCCAGTCTCGAT-1
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  CHIP_b2_Input_TTTGGCCCAAAGAGAG-1
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  CHIP_b2_Input_TTTGGCCCAGGTAACG-1
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  CHIP_b2_Input_TTTGGCCCAGGTCCTG-1
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  CHIP_b2_Input_TTTGGCCCATTCACCC-1
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  CHIP_b2_Input_TTTGGCCGTACTATGC-1
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  CHIP_b2_Input_TTTGGCCGTATCTGCA-1
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  CHIP_b2_Input_TTTGGCCGTTACCACA-1
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  CHIP_b2_Input_TTTGGCCTCGGACGAA-1
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  CHIP_b2_Input_TTTGGTTAGATCGATA-1
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  CHIP_b2_Input_TTTGGTTAGTTCCCGG-1
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  CHIP_b2_Input_TTTGGTTCACGGTTAT-1
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  CHIP_b2_Input_TTTGGTTGTACTTCAG-1
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  CHIP_b2_Input_TTTGGTTGTCAGGCTC-1
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  CHIP_b2_Input_TTTGGTTGTTCCCGGA-1
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  CHIP_b2_Input_TTTGGTTGTTCTTTGT-1
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  CHIP_b2_Input_TTTGGTTTCAATTGGC-1
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  CHIP_b2_Input_TTTGGTTTCGGCAATT-1
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  CHIP_b2_Input_TTTGTGTAGACTAGCG-1
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  CHIP_b2_Input_TTTGTGTAGATTCCGT-1
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  CHIP_b2_Input_TTTGTGTAGGATTGAT-1
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  CHIP_b2_Input_TTTGTGTCAAGGTTCT-1
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  CHIP_b2_Input_TTTGTGTCACACTAGT-1
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  CHIP_b2_Input_TTTGTGTCATGGCCTG-1
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  CHIP_b2_Input_TTTGTGTGTGGAAAGA-1
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  CHIP_b2_Input_TTTGTGTGTGGACAGT-1
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  CHIP_b2_Input_TTTGTGTTCAGTACAC-1
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  CHIP_b2_Input_TTTGTGTTCTATAGGC-1
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  CHIP_b2_Input_TTTGTGTTCTATGAGC-1
#                                   name          run      donor      condition
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAACAACGTACT-1 cd34norm_2_4  cd34norm cd34norm_2 Flt3l
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 cd34norm_2_8  cd34norm cd34norm_2 Flt3l
# cd34norm_Flt3l_AAACGAACACGATATC-1 cd34norm_2_5  cd34norm cd34norm_2 Flt3l
# cd34norm_Flt3l_AAACGAACACTTACAG-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 cd34norm_3_5  cd34norm cd34norm_3 Flt3l
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 cd34norm_3_4  cd34norm cd34norm_3 Flt3l
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 cd34norm_2_7  cd34norm cd34norm_2 Flt3l
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 cd34norm_2_24 cd34norm cd34norm_2 Flt3l
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 cd34norm_3_27 cd34norm cd34norm_3 Flt3l
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 None          NA       None       None
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 None          NA       None       None
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 cd34norm_3_11 cd34norm cd34norm_3 Flt3l
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 cd34norm_1_11 cd34norm cd34norm_1 Flt3l
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 cd34norm_0_3  cd34norm cd34norm_0 Flt3l
# cd34norm_Flt3l_AAACTCGCACACACCG-1 cd34norm_0_22 cd34norm cd34norm_0 Flt3l
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 cd34norm_3_1  cd34norm cd34norm_3 Flt3l
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 None          NA       None       None
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 None          NA       None       None
# ⋮                                 ⋮             ⋮        ⋮          ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  CHIP_b2_0_22  CHIP_b2  CHIP_b2_0  Input
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  CHIP_b2_1_7   CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  CHIP_b2_0_20  CHIP_b2  CHIP_b2_0  Input
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  CHIP_b2_0_19  CHIP_b2  CHIP_b2_0  Input
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  CHIP_b2_1_12  CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  None          NA       None       None
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  None          NA       None       None
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  CHIP_b2_1_20  CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  None          NA       None       None
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  CHIP_b2_1_19  CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  CHIP_b2_0_22  CHIP_b2  CHIP_b2_0  Input
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  CHIP_b2_1_4   CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  CHIP_b2_0_11  CHIP_b2  CHIP_b2_0  Input
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  None          NA       None       None
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  CHIP_b2_0_17  CHIP_b2  CHIP_b2_0  Input
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  CHIP_b2_1_9   CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  None          NA       None       None
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  None          NA       None       None
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  CHIP_b2_1_9   CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  CHIP_b2_1_25  CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  CHIP_b2_1_18  CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  None          NA       None       None
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  CHIP_b2_1_0   CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  CHIP_b2_1_1   CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  CHIP_b2_1_12  CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  CHIP_b2_1_15  CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  CHIP_b2_0_8   CHIP_b2  CHIP_b2_0  Input
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  CHIP_b2_1_23  CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  CHIP_b2_0_7   CHIP_b2  CHIP_b2_0  Input
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  None          NA       None       None
#                                   orig.ident nCount_ATAC nFeature_ATAC total
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 Flt3l       5219        5219         25798
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 Flt3l       2350        2350         18340
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 Flt3l       4322        4322         28417
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 Flt3l       1542        1542         12018
# cd34norm_Flt3l_AAACGAACAACGTACT-1 Flt3l       3251        3251         37690
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 Flt3l       1488        1488          9381
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 Flt3l       3107        3107         30421
# cd34norm_Flt3l_AAACGAACACGATATC-1 Flt3l       2626        2626         15245
# cd34norm_Flt3l_AAACGAACACTTACAG-1 Flt3l      10897       10897         48515
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 Flt3l       1436        1436         10268
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 Flt3l       5980        5980         41458
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 Flt3l       6563        6563         41204
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 Flt3l       6876        6876         38508
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 Flt3l       7385        7385         45914
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 Flt3l       2262        2262         16031
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 Flt3l       3313        3313         25798
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 Flt3l       3137        3137         17648
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 Flt3l       2642        2642         16826
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 Flt3l       8696        8696         35874
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 Flt3l       3773        3773         24528
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 Flt3l       1060        1060          7405
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 Flt3l       1926        1926         16795
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 Flt3l       4093        4093         23385
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 Flt3l       3081        3081         20204
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 Flt3l       3064        3064         15112
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 Flt3l       4528        4528         28161
# cd34norm_Flt3l_AAACTCGCACACACCG-1 Flt3l       6911        6911         33406
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 Flt3l       1146        1146          9279
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 Flt3l       2154        2154         13514
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 Flt3l       4093        4093         25950
# ⋮                                 ⋮          ⋮           ⋮             ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  Input      1310        1310           8488
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  Input      5370        5370          23397
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  Input      7668        7668          31056
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  Input       853         853           8488
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  Input      1352        1352          10739
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  Input      3568        3568          14752
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  Input       265         265           2406
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  Input      6005        6005          27746
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  Input      5733        5733          23398
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  Input      1717        1717          11614
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  Input       449         449          10039
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  Input      2873        2873          13438
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  Input      1263        1263          10202
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  Input       379         379           2731
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  Input      2929        2929          14909
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  Input      2131        2131          10937
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  Input       249         249           3481
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  Input      2180        2180           8178
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  Input      1295        1295          11005
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  Input      1365        1365          12812
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  Input      1491        1491           7761
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  Input      1800        1800          21305
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  Input      2944        2944          16564
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  Input      2677        2677          12037
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  Input      2009        2009           8747
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  Input      6841        6841          35511
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  Input      1877        1877          14217
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  Input      3000        3000          15165
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  Input      8494        8494          48687
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  Input      2891        2891          10251
#                                   duplicate ⋯ TSS.percentile pct_reads_in_peaks
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1  3956     ⋯ 0.46           30.59726
# cd34norm_Flt3l_AAACGAAAGCGATACG-1  2478     ⋯ 0.62           38.07644
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1  4398     ⋯ 0.30           32.71878
# cd34norm_Flt3l_AAACGAAAGTACAACA-1  1524     ⋯ 0.06           32.28863
# cd34norm_Flt3l_AAACGAACAACGTACT-1  3034     ⋯ 0.69           37.78063
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1  1416     ⋯ 0.22           34.49299
# cd34norm_Flt3l_AAACGAACACCTGGTG-1  5698     ⋯ 0.63           31.17348
# cd34norm_Flt3l_AAACGAACACGATATC-1  1960     ⋯ 0.11           32.04171
# cd34norm_Flt3l_AAACGAACACTTACAG-1 10680     ⋯ 0.36           47.67966
# cd34norm_Flt3l_AAACGAACATTAAGGA-1  1269     ⋯ 0.10           34.57135
# cd34norm_Flt3l_AAACGAAGTACAACGG-1  7961     ⋯ 0.02           20.62907
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1  6460     ⋯ 0.77           39.05074
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1  6348     ⋯ 0.81           37.79722
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1  8078     ⋯ 0.62           42.11879
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1  2229     ⋯ 0.40           36.09414
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1  3257     ⋯ 0.97           35.30873
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1  2463     ⋯ 0.25           38.47203
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1  2588     ⋯ 0.63           35.64464
# cd34norm_Flt3l_AAACGAATCACTGGTA-1  8433     ⋯ 0.44           37.08080
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1  4486     ⋯ 0.74           34.63874
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1   935     ⋯ 0.80           39.29928
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1  1902     ⋯ 0.51           33.28094
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1  4038     ⋯ 0.24           37.16955
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1  3160     ⋯ 0.86           37.41660
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1  3632     ⋯ 0.07           38.66495
# cd34norm_Flt3l_AAACTCGCAATGCACT-1  5773     ⋯ 0.09           33.53353
# cd34norm_Flt3l_AAACTCGCACACACCG-1  8691     ⋯ 0.69           42.04769
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1  1042     ⋯ 0.76           39.08271
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1  2027     ⋯ 0.74           33.73603
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1  4641     ⋯ 0.57           38.33316
# ⋮                                 ⋮         ⋱ ⋮              ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1   1692     ⋯ 0.84           41.03020
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1   4866     ⋯ 0.54           61.59543
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1   6405     ⋯ 0.34           56.02957
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1   1306     ⋯ 0.90           28.13836
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1    791     ⋯ 0.13           59.33366
# CHIP_b2_Input_TTTGGCCCATTCACCC-1   4610     ⋯ 0.74           53.52691
# CHIP_b2_Input_TTTGGCCGTACTATGC-1    187     ⋯ 0.67           42.36984
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1   7591     ⋯ 0.51           60.65224
# CHIP_b2_Input_TTTGGCCGTTACCACA-1   5791     ⋯ 0.05           43.63126
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1   1128     ⋯ 0.97           63.87046
# CHIP_b2_Input_TTTGGTTAGATCGATA-1    639     ⋯ 0.01           29.64169
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1   2528     ⋯ 0.58           66.27991
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1   1247     ⋯ 0.67           53.40587
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1    419     ⋯ 0.97           44.62103
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1   2715     ⋯ 0.31           48.04995
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1   1626     ⋯ 0.23           60.38243
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1    423     ⋯ 0.98           22.07792
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1   1789     ⋯ 0.61           64.98691
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1   1209     ⋯ 0.67           46.04938
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1    973     ⋯ 0.72           55.91637
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1   1033     ⋯ 0.88           67.64436
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1   2517     ⋯ 0.09           30.35825
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1   2084     ⋯ 0.25           62.34668
# CHIP_b2_Input_TTTGTGTCACACTAGT-1   2038     ⋯ 0.92           60.90279
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1   1284     ⋯ 0.63           72.53731
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1   7946     ⋯ 0.48           58.76798
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1   2190     ⋯ 0.56           51.91141
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1   2707     ⋯ 0.69           60.48404
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  14365     ⋯ 0.33           34.64448
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1   2111     ⋯ 0.90           68.58974
#                                   blacklist_ratio high.tss nucleosome_group
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAACAACGTACT-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAACACGATATC-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAACACTTACAG-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 0               High     NS < 4
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 0               High     NS < 4
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 0               High     NS < 4
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 0               High     NS < 4
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 0               High     NS < 4
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 0               High     NS < 4
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 0               High     NS < 4
# cd34norm_Flt3l_AAACTCGCACACACCG-1 0               High     NS < 4
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 0               High     NS < 4
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 0               High     NS < 4
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 0               High     NS < 4
# ⋮                                 ⋮               ⋮        ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  0               High     NS < 4
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  0               High     NS < 4
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  0               High     NS < 4
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  0               High     NS < 4
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  0               High     NS < 4
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  0               High     NS < 4
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  0               High     NS < 4
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  0               High     NS < 4
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  0               High     NS < 4
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  0               High     NS < 4
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  0               High     NS < 4
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  0               High     NS < 4
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  0               High     NS < 4
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  0               High     NS < 4
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  0               High     NS < 4
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  0               High     NS < 4
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  0               High     NS < 4
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  0               High     NS < 4
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  0               High     NS < 4
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  0               High     NS < 4
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  0               High     NS < 4
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  0               High     NS < 4
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  0               High     NS < 4
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  0               High     NS < 4
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  0               High     NS < 4
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  0               High     NS < 4
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  0               High     NS < 4
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  0               High     NS < 4
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  0               High     NS < 4
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  0               High     NS < 4
#                                   ATAC_snn_res.0.8 seurat_clusters
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 5                5
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 3                3
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 2                2
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 5                5
# cd34norm_Flt3l_AAACGAACAACGTACT-1 1                1
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 5                5
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 8                8
# cd34norm_Flt3l_AAACGAACACGATATC-1 4                4
# cd34norm_Flt3l_AAACGAACACTTACAG-1 15               15
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 1                1
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 11               11
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 0                0
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 2                2
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 15               15
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 5                5
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 3                3
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 9                9
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 8                8
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 15               15
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 6                6
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 12               12
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 6                6
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 2                2
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 9                9
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 9                9
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 5                5
# cd34norm_Flt3l_AAACTCGCACACACCG-1 9                9
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 12               12
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 6                6
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 2                2
# ⋮                                 ⋮                ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  16               16
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  1                1
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  7                7
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  6                6
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  10               10
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  11               11
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  10               10
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  1                1
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  7                7
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  10               10
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  10               10
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  1                1
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  1                1
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  11               11
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  1                1
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  10               10
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  10               10
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  0                0
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  13               13
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  10               10
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  10               10
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  8                8
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  7                7
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  1                1
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  10               10
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  7                7
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  1                1
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  1                1
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  11               11
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  11               11
#                                   nCount_ATAC_log2 nCount_RNA nFeature_RNA
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 12.34983          8908      5567
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 11.19906          3006      2472
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 12.07782          6521      4620
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 10.59152          2356      1996
# cd34norm_Flt3l_AAACGAACAACGTACT-1 11.66711          4275      3340
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 10.54013          2150      1864
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 11.60177          5338      3881
# cd34norm_Flt3l_AAACGAACACGATATC-1 11.35920          4225      3237
# cd34norm_Flt3l_AAACGAACACTTACAG-1 13.41178         13471      7325
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 10.48884          1970      1738
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 12.54617         12950      6704
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 12.68036          9274      5931
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 12.74756          9676      6014
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 12.85058          8908      5598
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 11.14402          3223      2590
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 11.69436          4450      3350
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 11.61563          4114      3289
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 11.36796          3832      3046
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 13.08630         13007      7521
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 11.88188          5316      3919
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 10.05121          1252      1137
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 10.91214          2678      2274
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 11.99930          5555      4003
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 11.58965          4230      3121
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 11.58167          3899      3125
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 12.14498          7294      4858
# cd34norm_Flt3l_AAACTCGCACACACCG-1 12.75489          8813      5544
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 10.16365          1456      1327
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 11.07347          3095      2563
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 11.99930          5588      4093
# ⋮                                 ⋮                ⋮          ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  10.356452         1594      1385
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  12.390975         5410      3991
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  12.904823         8561      5385
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1   9.738092         1418      1021
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  10.401946         1408      1240
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  11.801304         4629      3552
# CHIP_b2_Input_TTTGGCCGTACTATGC-1   8.055282          344       326
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  12.552189         7146      5085
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  12.485326         7106      4794
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  10.746514         1844      1618
# CHIP_b2_Input_TTTGGTTAGATCGATA-1   8.813781          680       559
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  11.488844         2786      2313
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  10.303781         1281      1152
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1   8.569856          488       452
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  11.516685         3201      2603
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  11.057992         2316      1985
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1   7.965784          502       372
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  11.090774         2126      1750
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  10.339850         1404      1256
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  10.415742         1434      1272
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  10.543032         1568      1397
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  10.814582         2641      2201
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  11.524052         2999      2467
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  11.386940         2991      2468
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  10.972980         1969      1714
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  12.740202         8019      5370
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  10.874981         1912      1659
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  11.551228         3143      2556
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  13.052398        13695      7620
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  11.497852         3234      2593

# %%
se <- AddMetaData(se, new_cells_meta)
se[[]]
# Out:
#                                   orig.ident nCount_ATAC nFeature_ATAC total
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 Flt3l       5219        5219         25798
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 Flt3l       2350        2350         18340
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 Flt3l       4322        4322         28417
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 Flt3l       1542        1542         12018
# cd34norm_Flt3l_AAACGAACAACGTACT-1 Flt3l       3251        3251         37690
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 Flt3l       1488        1488          9381
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 Flt3l       3107        3107         30421
# cd34norm_Flt3l_AAACGAACACGATATC-1 Flt3l       2626        2626         15245
# cd34norm_Flt3l_AAACGAACACTTACAG-1 Flt3l      10897       10897         48515
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 Flt3l       1436        1436         10268
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 Flt3l       5980        5980         41458
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 Flt3l       6563        6563         41204
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 Flt3l       6876        6876         38508
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 Flt3l       7385        7385         45914
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 Flt3l       2262        2262         16031
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 Flt3l       3313        3313         25798
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 Flt3l       3137        3137         17648
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 Flt3l       2642        2642         16826
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 Flt3l       8696        8696         35874
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 Flt3l       3773        3773         24528
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 Flt3l       1060        1060          7405
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 Flt3l       1926        1926         16795
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 Flt3l       4093        4093         23385
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 Flt3l       3081        3081         20204
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 Flt3l       3064        3064         15112
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 Flt3l       4528        4528         28161
# cd34norm_Flt3l_AAACTCGCACACACCG-1 Flt3l       6911        6911         33406
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 Flt3l       1146        1146          9279
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 Flt3l       2154        2154         13514
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 Flt3l       4093        4093         25950
# ⋮                                 ⋮          ⋮           ⋮             ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  Input      1310        1310           8488
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  Input      5370        5370          23397
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  Input      7668        7668          31056
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  Input       853         853           8488
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  Input      1352        1352          10739
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  Input      3568        3568          14752
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  Input       265         265           2406
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  Input      6005        6005          27746
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  Input      5733        5733          23398
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  Input      1717        1717          11614
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  Input       449         449          10039
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  Input      2873        2873          13438
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  Input      1263        1263          10202
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  Input       379         379           2731
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  Input      2929        2929          14909
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  Input      2131        2131          10937
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  Input       249         249           3481
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  Input      2180        2180           8178
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  Input      1295        1295          11005
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  Input      1365        1365          12812
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  Input      1491        1491           7761
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  Input      1800        1800          21305
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  Input      2944        2944          16564
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  Input      2677        2677          12037
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  Input      2009        2009           8747
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  Input      6841        6841          35511
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  Input      1877        1877          14217
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  Input      3000        3000          15165
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  Input      8494        8494          48687
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  Input      2891        2891          10251
#                                   duplicate chimeric unmapped lowmapq
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1  3956     111       95      1643
# cd34norm_Flt3l_AAACGAAAGCGATACG-1  2478      78       92       794
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1  4398     132      122      1771
# cd34norm_Flt3l_AAACGAAAGTACAACA-1  1524      60       45       585
# cd34norm_Flt3l_AAACGAACAACGTACT-1  3034      82      125      1680
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1  1416      44       50       547
# cd34norm_Flt3l_AAACGAACACCTGGTG-1  5698     112      157      1762
# cd34norm_Flt3l_AAACGAACACGATATC-1  1960      89       32       737
# cd34norm_Flt3l_AAACGAACACTTACAG-1 10680     240      158      2715
# cd34norm_Flt3l_AAACGAACATTAAGGA-1  1269      49       50       603
# cd34norm_Flt3l_AAACGAAGTACAACGG-1  7961     228      168      3383
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1  6460     170      132      2540
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1  6348     125      165      2050
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1  8078     248      193      2277
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1  2229      48       52       676
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1  3257      85       91      1313
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1  2463     100       61      1086
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1  2588      80       76      1073
# cd34norm_Flt3l_AAACGAATCACTGGTA-1  8433     193      117      2031
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1  4486     113       86      1307
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1   935      34       39       373
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1  1902      67       51       900
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1  4038      95       94      1347
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1  3160      95       72       894
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1  3632      91       67       917
# cd34norm_Flt3l_AAACTCGCAATGCACT-1  5773     115      115      1719
# cd34norm_Flt3l_AAACTCGCACACACCG-1  8691     206      180      1749
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1  1042      50       57       536
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1  2027      61       41       789
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1  4641      90      120      1482
# ⋮                                 ⋮         ⋮        ⋮        ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1   1692      32       23       288
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1   4866     133       76       893
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1   6405     165       99      1001
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1   1306      32       30       304
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1    791      25       60       241
# CHIP_b2_Input_TTTGGCCCATTCACCC-1   4610      84       73       692
# CHIP_b2_Input_TTTGGCCGTACTATGC-1    187      10        2        67
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1   7591     138       90      1399
# CHIP_b2_Input_TTTGGCCGTTACCACA-1   5791      91      120      1065
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1   1128      45       56       287
# CHIP_b2_Input_TTTGGTTAGATCGATA-1    639      18       35       148
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1   2528      63       55       468
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1   1247      42       38       205
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1    419      19       14        83
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1   2715      83       61       506
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1   1626      46       43       361
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1    423      16       19       121
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1   1789      65       34       254
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1   1209      34       41       254
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1    973      35       44       177
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1   1033      39       28       220
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1   2517      80      105       547
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1   2084      77       66       426
# CHIP_b2_Input_TTTGTGTCACACTAGT-1   2038      74       40       432
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1   1284      52       37       278
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1   7946     148      118      1467
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1   2190      42       40       420
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1   2707      67       52       475
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  14365     242      206      2591
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1   2111      68       40       418
#                                   mitochondrial passed_filters ⋯
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1  4740         15253          ⋯
# cd34norm_Flt3l_AAACGAAAGCGATACG-1  9325          5573          ⋯
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 10224         11770          ⋯
# cd34norm_Flt3l_AAACGAAAGTACAACA-1  5688          4116          ⋯
# cd34norm_Flt3l_AAACGAACAACGTACT-1 24974          7795          ⋯
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1  3616          3708          ⋯
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 14034          8658          ⋯
# cd34norm_Flt3l_AAACGAACACGATATC-1  5330          7097          ⋯
# cd34norm_Flt3l_AAACGAACACTTACAG-1 12096         22626          ⋯
# cd34norm_Flt3l_AAACGAACATTAAGGA-1  4716          3581          ⋯
# cd34norm_Flt3l_AAACGAAGTACAACGG-1  5015         24703          ⋯
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 15426         16476          ⋯
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 12787         17033          ⋯
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 18382         16736          ⋯
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1  7460          5566          ⋯
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 12598          8454          ⋯
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1  6608          7330          ⋯
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1  6548          6461          ⋯
# cd34norm_Flt3l_AAACGAATCACTGGTA-1  3094         22006          ⋯
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1  8654          9882          ⋯
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1  3655          2369          ⋯
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1  8785          5090          ⋯
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1  7749         10062          ⋯
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1  8489          7494          ⋯
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1  3409          6996          ⋯
# cd34norm_Flt3l_AAACTCGCAATGCACT-1  8284         12155          ⋯
# cd34norm_Flt3l_AAACTCGCACACACCG-1  6855         15725          ⋯
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1  5043          2551          ⋯
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1  5050          5546          ⋯
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1  9790          9827          ⋯
# ⋮                                 ⋮             ⋮              ⋱
# CHIP_b2_Input_TTTGGCCAGTAACACA-1   3638          2815          ⋯
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1   9193          8236          ⋯
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  10400         12986          ⋯
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1   4243          2573          ⋯
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1   7581          2041          ⋯
# CHIP_b2_Input_TTTGGCCCATTCACCC-1   2474          6819          ⋯
# CHIP_b2_Input_TTTGGCCGTACTATGC-1   1583           557          ⋯
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1   8225         10303          ⋯
# CHIP_b2_Input_TTTGGCCGTTACCACA-1   5277         11054          ⋯
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1   7535          2563          ⋯
# CHIP_b2_Input_TTTGGTTAGATCGATA-1   7971          1228          ⋯
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1   6187          4137          ⋯
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1   6556          2114          ⋯
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1   1378           818          ⋯
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1   6339          5205          ⋯
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1   5514          3347          ⋯
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1   1978           924          ⋯
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1   2980          3056          ⋯
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1   7037          2430          ⋯
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1   9335          2248          ⋯
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1   4259          2182          ⋯
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  13227          4829          ⋯
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1   9590          4321          ⋯
# CHIP_b2_Input_TTTGTGTCACACTAGT-1   5266          4187          ⋯
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1   4416          2680          ⋯
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  14501         11331          ⋯
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1   8229          3296          ⋯
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1   7195          4669          ⋯
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1   7487         23796          ⋯
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1   3246          4368          ⋯
#                                   ATAC_snn_res.0.8 seurat_clusters
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 5                5
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 3                3
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 2                2
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 5                5
# cd34norm_Flt3l_AAACGAACAACGTACT-1 1                1
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 5                5
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 8                8
# cd34norm_Flt3l_AAACGAACACGATATC-1 4                4
# cd34norm_Flt3l_AAACGAACACTTACAG-1 15               15
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 1                1
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 11               11
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 0                0
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 2                2
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 15               15
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 5                5
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 3                3
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 9                9
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 8                8
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 15               15
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 6                6
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 12               12
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 6                6
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 2                2
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 9                9
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 9                9
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 5                5
# cd34norm_Flt3l_AAACTCGCACACACCG-1 9                9
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 12               12
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 6                6
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 2                2
# ⋮                                 ⋮                ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  16               16
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  1                1
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  7                7
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  6                6
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  10               10
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  11               11
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  10               10
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  1                1
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  7                7
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  10               10
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  10               10
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  1                1
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  1                1
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  11               11
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  1                1
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  10               10
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  10               10
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  0                0
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  13               13
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  10               10
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  10               10
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  8                8
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  7                7
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  1                1
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  10               10
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  7                7
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  1                1
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  1                1
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  11               11
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  11               11
#                                   nCount_ATAC_log2 nCount_RNA nFeature_RNA
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 12.34983          8908      5567
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 11.19906          3006      2472
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 12.07782          6521      4620
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 10.59152          2356      1996
# cd34norm_Flt3l_AAACGAACAACGTACT-1 11.66711          4275      3340
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 10.54013          2150      1864
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 11.60177          5338      3881
# cd34norm_Flt3l_AAACGAACACGATATC-1 11.35920          4225      3237
# cd34norm_Flt3l_AAACGAACACTTACAG-1 13.41178         13471      7325
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 10.48884          1970      1738
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 12.54617         12950      6704
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 12.68036          9274      5931
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 12.74756          9676      6014
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 12.85058          8908      5598
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 11.14402          3223      2590
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 11.69436          4450      3350
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 11.61563          4114      3289
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 11.36796          3832      3046
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 13.08630         13007      7521
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 11.88188          5316      3919
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 10.05121          1252      1137
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 10.91214          2678      2274
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 11.99930          5555      4003
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 11.58965          4230      3121
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 11.58167          3899      3125
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 12.14498          7294      4858
# cd34norm_Flt3l_AAACTCGCACACACCG-1 12.75489          8813      5544
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 10.16365          1456      1327
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 11.07347          3095      2563
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 11.99930          5588      4093
# ⋮                                 ⋮                ⋮          ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  10.356452         1594      1385
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  12.390975         5410      3991
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  12.904823         8561      5385
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1   9.738092         1418      1021
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  10.401946         1408      1240
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  11.801304         4629      3552
# CHIP_b2_Input_TTTGGCCGTACTATGC-1   8.055282          344       326
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  12.552189         7146      5085
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  12.485326         7106      4794
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  10.746514         1844      1618
# CHIP_b2_Input_TTTGGTTAGATCGATA-1   8.813781          680       559
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  11.488844         2786      2313
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  10.303781         1281      1152
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1   8.569856          488       452
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  11.516685         3201      2603
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  11.057992         2316      1985
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1   7.965784          502       372
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  11.090774         2126      1750
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  10.339850         1404      1256
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  10.415742         1434      1272
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  10.543032         1568      1397
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  10.814582         2641      2201
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  11.524052         2999      2467
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  11.386940         2991      2468
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  10.972980         1969      1714
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  12.740202         8019      5370
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  10.874981         1912      1659
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  11.551228         3143      2556
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  13.052398        13695      7620
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  11.497852         3234      2593
#                                   Row.names
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 cd34norm_Flt3l_AAACGAAAGAGCTCCC-1
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 cd34norm_Flt3l_AAACGAAAGCGATACG-1
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 cd34norm_Flt3l_AAACGAAAGGCTTCGC-1
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 cd34norm_Flt3l_AAACGAAAGTACAACA-1
# cd34norm_Flt3l_AAACGAACAACGTACT-1 cd34norm_Flt3l_AAACGAACAACGTACT-1
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 cd34norm_Flt3l_AAACGAACAAGCGGTA-1
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 cd34norm_Flt3l_AAACGAACACCTGGTG-1
# cd34norm_Flt3l_AAACGAACACGATATC-1 cd34norm_Flt3l_AAACGAACACGATATC-1
# cd34norm_Flt3l_AAACGAACACTTACAG-1 cd34norm_Flt3l_AAACGAACACTTACAG-1
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 cd34norm_Flt3l_AAACGAACATTAAGGA-1
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 cd34norm_Flt3l_AAACGAAGTACAACGG-1
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 cd34norm_Flt3l_AAACGAAGTGGACCAA-1
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 cd34norm_Flt3l_AAACGAAGTGGCGCTT-1
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 cd34norm_Flt3l_AAACGAAGTGTCCCAG-1
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 cd34norm_Flt3l_AAACGAAGTGTTTCTT-1
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 cd34norm_Flt3l_AAACGAAGTTGAATAG-1
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 cd34norm_Flt3l_AAACGAAGTTGCAGAG-1
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 cd34norm_Flt3l_AAACGAATCAAGTTGC-1
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 cd34norm_Flt3l_AAACGAATCACTGGTA-1
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 cd34norm_Flt3l_AAACGAATCCTAAAGC-1
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 cd34norm_Flt3l_AAACGAATCGAGTGTT-1
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 cd34norm_Flt3l_AAACTCGAGCAATAAC-1
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 cd34norm_Flt3l_AAACTCGAGTACAGAT-1
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 cd34norm_Flt3l_AAACTCGAGTGTGTAA-1
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 cd34norm_Flt3l_AAACTCGCAAGCCCTG-1
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 cd34norm_Flt3l_AAACTCGCAATGCACT-1
# cd34norm_Flt3l_AAACTCGCACACACCG-1 cd34norm_Flt3l_AAACTCGCACACACCG-1
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 cd34norm_Flt3l_AAACTCGCAGATTTGC-1
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 cd34norm_Flt3l_AAACTCGCATCCCTCA-1
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 cd34norm_Flt3l_AAACTCGCATGCGTTA-1
# ⋮                                 ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  CHIP_b2_Input_TTTGGCCAGTAACACA-1
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  CHIP_b2_Input_TTTGGCCAGTCTCGAT-1
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  CHIP_b2_Input_TTTGGCCCAAAGAGAG-1
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  CHIP_b2_Input_TTTGGCCCAGGTAACG-1
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  CHIP_b2_Input_TTTGGCCCAGGTCCTG-1
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  CHIP_b2_Input_TTTGGCCCATTCACCC-1
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  CHIP_b2_Input_TTTGGCCGTACTATGC-1
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  CHIP_b2_Input_TTTGGCCGTATCTGCA-1
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  CHIP_b2_Input_TTTGGCCGTTACCACA-1
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  CHIP_b2_Input_TTTGGCCTCGGACGAA-1
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  CHIP_b2_Input_TTTGGTTAGATCGATA-1
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  CHIP_b2_Input_TTTGGTTAGTTCCCGG-1
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  CHIP_b2_Input_TTTGGTTCACGGTTAT-1
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  CHIP_b2_Input_TTTGGTTGTACTTCAG-1
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  CHIP_b2_Input_TTTGGTTGTCAGGCTC-1
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  CHIP_b2_Input_TTTGGTTGTTCCCGGA-1
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  CHIP_b2_Input_TTTGGTTGTTCTTTGT-1
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  CHIP_b2_Input_TTTGGTTTCAATTGGC-1
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  CHIP_b2_Input_TTTGGTTTCGGCAATT-1
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  CHIP_b2_Input_TTTGTGTAGACTAGCG-1
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  CHIP_b2_Input_TTTGTGTAGATTCCGT-1
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  CHIP_b2_Input_TTTGTGTAGGATTGAT-1
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  CHIP_b2_Input_TTTGTGTCAAGGTTCT-1
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  CHIP_b2_Input_TTTGTGTCACACTAGT-1
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  CHIP_b2_Input_TTTGTGTCATGGCCTG-1
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  CHIP_b2_Input_TTTGTGTGTGGAAAGA-1
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  CHIP_b2_Input_TTTGTGTGTGGACAGT-1
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  CHIP_b2_Input_TTTGTGTTCAGTACAC-1
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  CHIP_b2_Input_TTTGTGTTCTATAGGC-1
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  CHIP_b2_Input_TTTGTGTTCTATGAGC-1
#                                   name          run      donor      condition
# cd34norm_Flt3l_AAACGAAAGAGCTCCC-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAAAGCGATACG-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAAAGGCTTCGC-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAAAGTACAACA-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAACAACGTACT-1 cd34norm_2_4  cd34norm cd34norm_2 Flt3l
# cd34norm_Flt3l_AAACGAACAAGCGGTA-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAACACCTGGTG-1 cd34norm_2_8  cd34norm cd34norm_2 Flt3l
# cd34norm_Flt3l_AAACGAACACGATATC-1 cd34norm_2_5  cd34norm cd34norm_2 Flt3l
# cd34norm_Flt3l_AAACGAACACTTACAG-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAACATTAAGGA-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAAGTACAACGG-1 cd34norm_3_5  cd34norm cd34norm_3 Flt3l
# cd34norm_Flt3l_AAACGAAGTGGACCAA-1 cd34norm_3_4  cd34norm cd34norm_3 Flt3l
# cd34norm_Flt3l_AAACGAAGTGGCGCTT-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAAGTGTCCCAG-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAAGTGTTTCTT-1 cd34norm_2_7  cd34norm cd34norm_2 Flt3l
# cd34norm_Flt3l_AAACGAAGTTGAATAG-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAAGTTGCAGAG-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAATCAAGTTGC-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAATCACTGGTA-1 None          NA       None       None
# cd34norm_Flt3l_AAACGAATCCTAAAGC-1 cd34norm_2_24 cd34norm cd34norm_2 Flt3l
# cd34norm_Flt3l_AAACGAATCGAGTGTT-1 cd34norm_3_27 cd34norm cd34norm_3 Flt3l
# cd34norm_Flt3l_AAACTCGAGCAATAAC-1 None          NA       None       None
# cd34norm_Flt3l_AAACTCGAGTACAGAT-1 None          NA       None       None
# cd34norm_Flt3l_AAACTCGAGTGTGTAA-1 cd34norm_3_11 cd34norm cd34norm_3 Flt3l
# cd34norm_Flt3l_AAACTCGCAAGCCCTG-1 cd34norm_1_11 cd34norm cd34norm_1 Flt3l
# cd34norm_Flt3l_AAACTCGCAATGCACT-1 cd34norm_0_3  cd34norm cd34norm_0 Flt3l
# cd34norm_Flt3l_AAACTCGCACACACCG-1 cd34norm_0_22 cd34norm cd34norm_0 Flt3l
# cd34norm_Flt3l_AAACTCGCAGATTTGC-1 cd34norm_3_1  cd34norm cd34norm_3 Flt3l
# cd34norm_Flt3l_AAACTCGCATCCCTCA-1 None          NA       None       None
# cd34norm_Flt3l_AAACTCGCATGCGTTA-1 None          NA       None       None
# ⋮                                 ⋮             ⋮        ⋮          ⋮
# CHIP_b2_Input_TTTGGCCAGTAACACA-1  CHIP_b2_0_22  CHIP_b2  CHIP_b2_0  Input
# CHIP_b2_Input_TTTGGCCAGTCTCGAT-1  CHIP_b2_1_7   CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGGCCCAAAGAGAG-1  CHIP_b2_0_20  CHIP_b2  CHIP_b2_0  Input
# CHIP_b2_Input_TTTGGCCCAGGTAACG-1  CHIP_b2_0_19  CHIP_b2  CHIP_b2_0  Input
# CHIP_b2_Input_TTTGGCCCAGGTCCTG-1  CHIP_b2_1_12  CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGGCCCATTCACCC-1  None          NA       None       None
# CHIP_b2_Input_TTTGGCCGTACTATGC-1  None          NA       None       None
# CHIP_b2_Input_TTTGGCCGTATCTGCA-1  CHIP_b2_1_20  CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGGCCGTTACCACA-1  None          NA       None       None
# CHIP_b2_Input_TTTGGCCTCGGACGAA-1  CHIP_b2_1_19  CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGGTTAGATCGATA-1  CHIP_b2_0_22  CHIP_b2  CHIP_b2_0  Input
# CHIP_b2_Input_TTTGGTTAGTTCCCGG-1  CHIP_b2_1_4   CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGGTTCACGGTTAT-1  CHIP_b2_0_11  CHIP_b2  CHIP_b2_0  Input
# CHIP_b2_Input_TTTGGTTGTACTTCAG-1  None          NA       None       None
# CHIP_b2_Input_TTTGGTTGTCAGGCTC-1  CHIP_b2_0_17  CHIP_b2  CHIP_b2_0  Input
# CHIP_b2_Input_TTTGGTTGTTCCCGGA-1  CHIP_b2_1_9   CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGGTTGTTCTTTGT-1  None          NA       None       None
# CHIP_b2_Input_TTTGGTTTCAATTGGC-1  None          NA       None       None
# CHIP_b2_Input_TTTGGTTTCGGCAATT-1  CHIP_b2_1_9   CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGTGTAGACTAGCG-1  CHIP_b2_1_25  CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGTGTAGATTCCGT-1  CHIP_b2_1_18  CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGTGTAGGATTGAT-1  None          NA       None       None
# CHIP_b2_Input_TTTGTGTCAAGGTTCT-1  CHIP_b2_1_0   CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGTGTCACACTAGT-1  CHIP_b2_1_1   CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGTGTCATGGCCTG-1  CHIP_b2_1_12  CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGTGTGTGGAAAGA-1  CHIP_b2_1_15  CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGTGTGTGGACAGT-1  CHIP_b2_0_8   CHIP_b2  CHIP_b2_0  Input
# CHIP_b2_Input_TTTGTGTTCAGTACAC-1  CHIP_b2_1_23  CHIP_b2  CHIP_b2_1  Input
# CHIP_b2_Input_TTTGTGTTCTATAGGC-1  CHIP_b2_0_7   CHIP_b2  CHIP_b2_0  Input
# CHIP_b2_Input_TTTGTGTTCTATGAGC-1  None          NA       None       None

# %%
se
# Out:
# An object of class Seurat
# 240401 features across 35931 samples within 2 assays
# Active assay: RNA (19039 features, 0 variable features)
#  1 other assay present: ATAC
#  2 dimensional reductions calculated: integrated_lsi, umap

# %%
se <- subset(x = se, subset = (name != "None") & (donor != "None") & (condition != "None"))

# %% [markdown]
# ## Save

# %%
write.table(se[[]],file=file.path(outdir, "se_cells_meta.tsv"), sep = "\t", quote=FALSE)

# %% [markdown]
# ## Plot by donor and condition

# %%
library("Seurat")
#library("Seurat")
library(magrittr)
library(cowplot)
library(ggplot2)
library(Signac)
library(patchwork)
set.seed(1234)
library(magrittr)
library(cowplot)
library(metap)
library(dplyr)
library(future)

# %%
# Idents(t.cells) <- "orig.ident"
DimPlot(object = se, label = FALSE, group.by = c('condition')) 
ggsave(file.path(outdir, paste0("donor_condition.pdf")), width=16, height=16)

# %%
# plot top clones:
clone_order <- as.data.frame(readr::read_csv(clone_order_f,col_names=F))$X1
#clone_order

top.clones <- clone_order #clone_order[1:ntop.clones]
#top.clones

ntop.clones <- length(top.clones)

top.se <- subset(x = se, subset = name %in% top.clones)
top.se$name <- factor(x = top.se$name, levels =top.clones)

coord = max(max(Embeddings(top.se[["umap"]])), abs(min(Embeddings(top.se[["umap"]]))))

for (i in levels(droplevels(se$donor))){   
    tryCatch({
        don.top.se <- subset(x = top.se, subset = donor == i)
        curr.ntop.clones <- length(unique(don.top.se$name))
        don.top.se$name <- factor(x = don.top.se$name, levels = top.clones)
        #DimPlot(cd8, split.by = "orig.ident")
        d <- DimPlot(object = don.top.se, label = FALSE, split.by="name", ncol=1, 
                     combine=T,
                     group.by=c("seurat_clusters"), shape.by=c("condition"), pt.size=(curr.ntop.clones)) +
            xlim(-1*coord-0.01,coord+0.01) +
            ylim(-1*coord-0.01,coord+0.01) + 
            theme(text = element_text(size = 2*curr.ntop.clones)) +
            theme(axis.text = element_text(size = 2*curr.ntop.clones))
        ggsave(file.path(outdir, paste(i,"top_umap_clust_col.svg")), width=2*curr.ntop.clones, height=8*curr.ntop.clones, device='svg', units="in", limitsize = FALSE)
        ggsave(file.path(outdir, paste(i,"top_umap_clust_col.pdf")), width=2*curr.ntop.clones, height=8*curr.ntop.clones, units="in", limitsize = FALSE)
    },
    error=function(cond){
        message("donor missing")
        message(cond)}
    )
}

# %%
d <- DimPlot(object = top.se, label = FALSE, split.by="donor", combine=T, ncol=3, pt.size=(ntop.clones/4)) +
    xlim(-1*coord-0.01,coord+0.01) +
    ylim(-1*coord-0.01,coord+0.01) + 
    theme(text = element_text(size = 2*ntop.clones)) +
    theme(axis.text = element_text(size = 2*ntop.clones))

ggsave(file.path(outdir, paste("donor_umap.svg")), width=2*ntop.clones, 
       height=8*ntop.clones, device='svg', units="in", limitsize = FALSE)
ggsave(file.path(outdir, paste("donor_umap.pdf")), width=2*ntop.clones, 
       height=8*ntop.clones, units="in", limitsize = FALSE)

#d

# %%
outdir

# %%
# donors <- levels(se.filt$donor)
# donors <-  donors[donors != "None"]
# donors

# barplot.df <- se.filt[[]] %>% group_by(name,donor) %>% summarize(size=n())# %>% mutate(donor=donor)
# barplot.df

# g <- ggplot(barplot.df[!(barplot.df$name == "None" | is.na(barplot.df$name)), ], aes(x=reorder(name, size), y=size, fill=donor)) + 
#             geom_bar(stat='identity')

# g 
# ggsave(file.path(outdir, paste0("clone_count.pdf")))

# DimPlot(object = se.filt, label = FALSE, split.by="donor", group.by = 'condition')
# ggsave(file.path(outdir, paste0("donor_split_umap.pdf")), width=16, height=16)


# grobs <- lapply(g, as_grob)
# plot_widths <- lapply(grobs, function(x) {x$widths})
# # Aligning the left margins of all g
# aligned_widths <- align_margin(plot_widths, "first")
# # Aligning the right margins of all g as well
# aligned_widths <- align_margin(aligned_widths, "last")
# # Setting the dimensions of g to the aligned dimensions
# for (i in seq_along(g)) {
#   grobs[[i]]$widths <- aligned_widths[[i]]
# }
# # Draw aligned g
# p <- plot_grid(plotlist = grobs, ncol = 1, 'vh')
# pdf(file.path(outdir, "clone_count.donor.pdf"), height = 11, width = 8.5, paper = "letter")
# p
# dev.off()
# # ggsave(file.path(outdir, paste0("clone_count.donor.pdf")), g)

# %% [markdown]
# ## Rerun UMAP for just those cells in clones

# %%
# create a new UMAP using the se.reduce embeddings
se.reduce <- se
DefaultAssay(se.reduce) <- "ATAC"
se.reduce

# %%
reduce_outdir <- file.path(outdir, "umap_rerun")
dir.create(reduce_outdir)

se.reduce <- RunUMAP(se, reduction = "integrated_lsi", dims = 2:30)
p2 <- DimPlot(se.reduce, group.by = "expID")
ggsave(file.path(reduce_outdir,"se_clonevar.batch.png"), dpi=300)
p2

pDepthCorr <- DepthCor(se.reduce, reduction='integrated_lsi')
ggsave(file.path(reduce_outdir,"se_clonevar.depthCor.png"), plot=pDepthCorr, dpi=300)

pDepthCorr



se.reduce

DefaultAssay(se.reduce) <- "ATAC"

se.reduce <- FindNeighbors(object = se.reduce, reduction = 'integrated_lsi', dims = 2:30)


se.reduce <- FindClusters(object = se.reduce, verbose = FALSE, algorithm = 3)
pclust <- DimPlot(object = se.reduce, label = TRUE) + NoLegend()
ggsave(file.path(reduce_outdir, "se_clonevar.lsi.clusters.png"), pclust)
pclust

se.reduce$nCount_ATAC_log2 = log2(se.reduce$nCount_ATAC+1)
FeaturePlot(se.reduce, features = "nCount_ATAC_log2")

# %%
Annotation(se.reduce) <- annotations
gene.activities <- GeneActivity(se.reduce)
mt_genes <- annotations[seqnames(annotations) == "chrM"]
dim(mt_genes)
gene.activities <- gene.activities[!(rownames(gene.activities) %in% mt_genes$gene_name),]
# add the gene activity matrix to the Seurat object as a new assay and normalize it
se.reduce[['RNA']] <- CreateAssayObject(counts = gene.activities)
se.reduce <- NormalizeData(
  object = se.reduce,
  assay = 'RNA',
  normalization.method = 'LogNormalize',
  scale.factor = median(se.reduce$nCount_RNA)
)

# add the gene information to the object
DefaultAssay(se.reduce) <- 'RNA'

# %%
# plot top clones:
ntop.clones <- length(top.clones)

top.se <- subset(x = se.reduce, subset = name %in% top.clones)
top.se$name <- factor(x = top.se$name, levels =top.clones)

coord = max(max(Embeddings(top.se[["umap"]])), abs(min(Embeddings(top.se[["umap"]]))))

reduce_outdir <- file.path(outdir, "umap_rerun")
dir.create(reduce_outdir)
for (i in levels(droplevels(top.se$donor))){   
    don.top.se <- subset(x = top.se, subset = donor == i)
    curr.ntop.clones <- length(unique(don.top.se$name))
    don.top.se$name <- factor(x = don.top.se$name, levels = top.clones)
    #DimPlot(cd8, split.by = "orig.ident")
    d <- DimPlot(object = don.top.se, label = FALSE, split.by="name", ncol=1, 
                 combine=T,
                 group.by=c("seurat_clusters"), shape.by=c("condition"), pt.size=(curr.ntop.clones/4)) +
        xlim(-1*coord-0.01,coord+0.01) +
        ylim(-1*coord-0.01,coord+0.01) + 
        theme(text = element_text(size = 2*curr.ntop.clones)) +
        theme(axis.text = element_text(size = 2*curr.ntop.clones))
    ggsave(file.path(reduce_outdir, paste(i,"top_umap_clust_col.svg")), width=2*curr.ntop.clones, height=8*curr.ntop.clones, device='svg', units="in", limitsize = FALSE)
    ggsave(file.path(reduce_outdir, paste(i,"top_umap_clust_col.pdf")), width=2*curr.ntop.clones, height=8*curr.ntop.clones, units="in", limitsize = FALSE)
}

# %%
reduce_outdir

# %%
write.table(se.reduce[[]],file=file.path(reduce_outdir, "se.reduce_clonevar_cells_meta.tsv"), sep = "\t", quote=FALSE)
saveRDS(obj=se.reduce, file=file.path(reduce_outdir, "se.reduce_clonevar.rds"))

# %%
#write.table(se[[]],file=file.path(outdir, "se_clonevar_cells_meta.tsv"), sep = "\t", quote=FALSE)
if(save_large_se){saveRDS(obj=se, file=file.path(outdir, "SE_clonevar.rds"))}

# %%
#saveRDS(obj=se, file=file.path(outdir, "SE.rds"))
