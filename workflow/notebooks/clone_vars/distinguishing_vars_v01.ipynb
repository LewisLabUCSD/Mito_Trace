# %% [markdown]
# ## Finding specific variants in each cluster
# Using the clones, we want to find variants in each clone that are specific to them.
# To define specificity, we will use two parameters: VAF frequency cutoff, and different %of population to have that variant.
# These parameters will be used to compare each clone's variants to the population

# %%
pwd
# Out:
# '/mnt/md0/isshamie/Projects/Mito_Trace/workflow/notebooks/clone_vars'

# %%
INDIR = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_30/"
OUTDIR = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_30/distinct_variants/donor0"
DONOR = 0

pct_thresh = [0.01, 0.5, 0.75, 0.95]
other_pct_thresh = [0.01, 0.1, 0.25,]
af_thresh = [0, 0.01, 0.1, 0.4]

# %%
from os.path import join, exists, dirname
from glob import glob
import pickle
import mplh.cluster_help as ch
import mplh.fig_utils as fu

import os
import vireoSNP
import numpy as np
from scipy import sparse
from scipy.io import mmread
import matplotlib.pyplot as plt
from scipy.stats import hypergeom
print(vireoSNP.__version__)

import pandas as pd
import seaborn as sns
from mplh import cluster_help as ch
from vireoSNP import Vireo
np.set_printoptions(formatter={'float': lambda x: format(x, '.5f')})
# Out:
# fig_utils from mplh
# 0.5.6

# %%
if not exists(OUTDIR):
    os.mkdir(OUTDIR)

# %% [markdown]
# ## Load cluster results

# %%
af_indir = join(INDIR, "sc_af", f"donor{DONOR}")

AF_df = pd.read_csv(join(af_indir, "af.tsv"), index_col=0, sep="\t")
DP_df = pd.read_csv(join(af_indir, "dp.tsv"), index_col=0, sep="\t")

print(AF_df.shape)
print(DP_df.shape)
print("Depth")
print(DP_df.head())
AF_df.head()
# Out:
# (68, 9023)
# (68, 9023)
# Depth
#          AAACGAAAGAATCAAC-1_Control  AAACGAAAGCGAGAAA-1_Control  \
# Variant
# 10397G                          2.0                        16.0
# 10463C                         11.0                        16.0
# 10559G                         15.0                        26.0
# 10589A                         17.0                        21.0
# 11251G                         13.0                        25.0
#
#          AAACGAAAGTACAGAT-1_Control  AAACGAAAGTTAGCAA-1_Control  \
# Variant
# 10397G                          1.0                         5.0
# 10463C                          3.0                         9.0
# 10559G                          5.0                         5.0
# 10589A                          6.0                         7.0
# 11251G                          5.0                         7.0
#
#          AAACGAACACTCGCAG-1_Control  AAACGAATCAGGCGCT-1_Control  \
# Variant
# 10397G                         14.0                        58.0
# 10463C                          6.0                        48.0
# 10559G                         10.0                        66.0
# 10589A                          9.0                        67.0
# 11251G                         12.0                        91.0
#
#          AAACGAATCCATCGAA-1_Control  AAACGAATCTCGTAGA-1_Control  \
# Variant
# 10397G                         39.0                        12.0
# 10463C                         30.0                         3.0
# 10559G                         16.0                         5.0
# 10589A                         24.0                        12.0
# 11251G                         37.0                        16.0
#
#          AAACTCGAGTGAAGGA-1_Control  AAACTCGCATGCACTA-1_Control  ...  \
# Variant                                                          ...
# 10397G                         15.0                        59.0  ...
# 10463C                          8.0                        39.0  ...
# 10559G                         21.0                        59.0  ...
# 10589A                         18.0                        48.0  ...
# 11251G                         26.0                        75.0  ...
#
#          TTTGGTTTCTGATCCC-1_Input  TTTGTGTAGTTCGTTG-1_Input  \
# Variant
# 10397G                       99.0                      92.0
# 10463C                       78.0                      99.0
# 10559G                       86.0                      80.0
# 10589A                       88.0                      66.0
# 11251G                       78.0                      83.0
#
#          TTTGTGTCACACATTG-1_Input  TTTGTGTGTAAGCCGA-1_Input  \
# Variant
# 10397G                      116.0                      39.0
# 10463C                      156.0                      22.0
# 10559G                      138.0                      32.0
# 10589A                      135.0                      34.0
# 11251G                      133.0                      45.0
#
#          TTTGTGTGTAGATTAG-1_Input  TTTGTGTGTAGGGTCA-1_Input  \
# Variant
# 10397G                       38.0                      69.0
# 10463C                       14.0                      77.0
# 10559G                       13.0                      60.0
# 10589A                       19.0                      59.0
# 11251G                       30.0                      81.0
#
#          TTTGTGTGTTTCTTAC-1_Input  TTTGTGTTCCTGAAAC-1_Input  \
# Variant
# 10397G                       72.0                      93.0
# 10463C                       58.0                      89.0
# 10559G                       48.0                      77.0
# 10589A                       55.0                      99.0
# 11251G                       90.0                     139.0
#
#          TTTGTGTTCGGGAAAC-1_Input  TTTGTGTTCTGGCACG-1_Input
# Variant
# 10397G                       71.0                      67.0
# 10463C                       49.0                      91.0
# 10559G                       64.0                      87.0
# 10589A                       71.0                      80.0
# 11251G                       80.0                      86.0
#
# [5 rows x 9023 columns]
#          AAACGAAAGAATCAAC-1_Control  AAACGAAAGCGAGAAA-1_Control  \
# Variant
# 10397G                     1.000000                         1.0
# 10463C                     0.000000                         0.0
# 10559G                     0.000000                         0.0
# 10589A                     0.882353                         1.0
# 11251G                     0.153846                         0.0
#
#          AAACGAAAGTACAGAT-1_Control  AAACGAAAGTTAGCAA-1_Control  \
# Variant
# 10397G                          0.0                         0.8
# 10463C                          0.0                         0.0
# 10559G                          0.0                         0.0
# 10589A                          1.0                         1.0
# 11251G                          0.0                         0.0
#
#          AAACGAACACTCGCAG-1_Control  AAACGAATCAGGCGCT-1_Control  \
# Variant
# 10397G                          1.0                         1.0
# 10463C                          0.0                         0.0
# 10559G                          0.0                         0.0
# 10589A                          1.0                         1.0
# 11251G                          0.0                         0.0
#
#          AAACGAATCCATCGAA-1_Control  AAACGAATCTCGTAGA-1_Control  \
# Variant
# 10397G                          1.0                         1.0
# 10463C                          0.0                         0.0
# 10559G                          0.0                         0.0
# 10589A                          1.0                         1.0
# 11251G                          0.0                         0.0
#
#          AAACTCGAGTGAAGGA-1_Control  AAACTCGCATGCACTA-1_Control  ...  \
# Variant                                                          ...
# 10397G                     1.000000                         1.0  ...
# 10463C                     0.000000                         0.0  ...
# 10559G                     0.000000                         0.0  ...
# 10589A                     1.000000                         1.0  ...
# 11251G                     0.076923                         0.0  ...
#
#          TTTGGTTTCTGATCCC-1_Input  TTTGTGTAGTTCGTTG-1_Input  \
# Variant
# 10397G                   0.979798                  1.000000
# 10463C                   0.000000                  0.000000
# 10559G                   0.000000                  0.000000
# 10589A                   1.000000                  0.984848
# 11251G                   0.000000                  0.036145
#
#          TTTGTGTCACACATTG-1_Input  TTTGTGTGTAAGCCGA-1_Input  \
# Variant
# 10397G                        1.0                  1.000000
# 10463C                        0.0                  0.000000
# 10559G                        0.0                  0.062500
# 10589A                        1.0                  0.970588
# 11251G                        0.0                  0.000000
#
#          TTTGTGTGTAGATTAG-1_Input  TTTGTGTGTAGGGTCA-1_Input  \
# Variant
# 10397G                   1.000000                  1.000000
# 10463C                   0.000000                  0.000000
# 10559G                   0.000000                  0.000000
# 10589A                   0.736842                  0.966102
# 11251G                   0.000000                  0.000000
#
#          TTTGTGTGTTTCTTAC-1_Input  TTTGTGTTCCTGAAAC-1_Input  \
# Variant
# 10397G                        1.0                  0.978495
# 10463C                        0.0                  0.000000
# 10559G                        0.0                  0.000000
# 10589A                        1.0                  1.000000
# 11251G                        0.0                  0.000000
#
#          TTTGTGTTCGGGAAAC-1_Input  TTTGTGTTCTGGCACG-1_Input
# Variant
# 10397G                        1.0                  1.000000
# 10463C                        0.0                  0.000000
# 10559G                        0.0                  0.000000
# 10589A                        1.0                  1.000000
# 11251G                        0.0                  0.023256
#
# [5 rows x 9023 columns]

# %%
cells_meta = pd.read_csv(join(INDIR, "cells_meta.tsv"), sep='\t', index_col="ID")#.sort_values(["donor", "lineage"])
cells_meta["name"] = cells_meta["donor"].astype(str)+"_"+cells_meta["lineage"].astype(str)
# if "donor_index" in cells_meta.columns and "lineage_index" in cells_meta.columns:
#     cells_meta = cells_meta.sort_values(["donor_index", "lineage_index"])
#AD_df = pd.merge(AD_df, vcf[["#CHROM", "POS", "ALT"]], how="inner", left_index=True,right_index=True).set_index(["#CHROM", "POS", "ALT"])
curr_labels = cells_meta[cells_meta["donor"]==DONOR]
curr_labels
# Out:
#                             lineage  donor condition  name
# ID
# AAACGAAAGAATCAAC-1_Control        0      0   Control   0_0
# AAATGAGAGAGACTCG-1_Control        0      0   Control   0_0
# AACAAAGTCAAGTTGC-1_Control        0      0   Control   0_0
# AACAAAGTCACATCCC-1_Control        0      0   Control   0_0
# AACCAACGTTCATTTC-1_Control        0      0   Control   0_0
# ...                             ...    ...       ...   ...
# TGATCAGAGAGCACTG-1_Input         33      0     Input  0_33
# TGCACCTCAAGCAATA-1_Input         33      0     Input  0_33
# TGCTATTTCGCGTTCT-1_Input         33      0     Input  0_33
# TTGCTTATCCACACCT-1_Input         33      0     Input  0_33
# TTGTTGTTCTTAAGCG-1_Input         33      0     Input  0_33
#
# [9023 rows x 4 columns]

# %%
conditions = curr_labels["condition"].unique()
conditions
# Out:
# array(['Control', 'Flt3l', 'Input'], dtype=object)

# %%
def rm_high(df, thresh, pct_thresh):
    return df.loc[~(((df>thresh).sum(axis=1)>pct_thresh*df.shape[0]))]

def rm_low(df, thresh, pct_thresh):
    return df.loc[~((df<thresh).sum(axis=1)>(pct_thresh*df.shape[1]))]

    #return df.loc[~(((df<=thresh).sum(axis=1)>pct_thresh*df.shape[0]))]
#df[(df<0.01).sum(axis=1)]

# %% [markdown]
# ## Get donor inds

# %%
donor_inds = AF_df.index[((AF_df>0.9).sum(axis=1)>(0.9*AF_df.shape[1]))]
donor_inds
# Out:
# Index(['10397G', '10589A', '11761T', '13188T', '1438G', '146C', '14766T',
#        '15326G', '16126C', '16355T', '16362C', '196C', '204C', '2442C', '263G',
#        '2706G', '3847C', '4769G', '58C', '64T', '7028T', '73G', '750G',
#        '7598A', '827G', '8292A', '8461T', '8860G'],
#       dtype='object', name='Variant')

# %%
# median_af = curr_labels.groupby(["lineage", "condition"]).apply(calc_median, af=AF_df)
# anno = median_af.reset_index()[["lineage", "condition"]]

# #median_dp = curr_labels.groupby(["lineage", "condition"]).apply(calc_median, af=nlog2(DP_df))
# median_dp = curr_labels.groupby(["lineage", "condition"]).apply(calc_median, af=np.log2(DP_df+1))
# anno_dp = median_dp.reset_index()[["lineage", "condition"]]
# median_dp = median_dp.reset_index(drop=True)

# na_cells = curr_labels.loc[curr_labels["lineage"].isnull()]
# na_median_af = na_cells.groupby("condition").apply(calc_median, af=AF_df)

# if not (na_median_af.shape[0] == 0):
#     print('na shape', na_median_af.shape)
#     na_anno = pd.concat((anno,pd.DataFrame({"lineage":["None"]*len(na_median_af.index), "condition":na_median_af.index})), 
#                         ignore_index=True)
#     na_concat = pd.concat((median_af.reset_index(drop=True), na_median_af.reset_index(drop=True)), ignore_index=True)
#     na_median_dp = na_cells.groupby("condition").apply(calc_median, af=np.log2(DP_df+1))
#     na_dp_concat = pd.concat((median_dp, na_median_dp.reset_index(drop=True)), ignore_index=True)
# else:
#     na_anno = anno
#     na_concat = median_af.reset_index(drop=True)
#     na_dp_concat = median_dp

# %% [markdown]
# ## Plot all cells in each clone

# %%
from icecream import ic

# %%
def get_unique_variants(cln_af, other_af, pct_thresh, af_thresh, other_pct_thresh):
    n_thresh = pct_thresh*cln_af.shape[1]
    n_oth_thresh = other_pct_thresh*other_af.shape[1]
    #ic(n_thresh)
    #ic(n_oth_thresh)
    bin_cln = cln_af>af_thresh
    bin_other = other_af>af_thresh
    #ic(bin_cln.head())
    cells_above = bin_cln.sum(axis=1)
    pct_cells_above = cells_above/bin_cln.shape[1]
    #ic(cells_above.head())
    up_vars = bin_cln.loc[cells_above > n_thresh].index
    #ic(up_vars)
    cells_other_above = bin_other.sum(axis=1)
    pct_cells_other_above = cells_other_above/bin_other.shape[1]
    #print('bin_other', bin_other.head())
    #print('pct cells other', pct_cells_other_above.head())
    up_oth_vars = bin_other.loc[cells_other_above > n_oth_thresh].index
    uniq_vars = list(set(up_vars) - set(up_oth_vars))
    #ic(uniq_vars)
    #ic(cells_above.loc[uniq_vars])
    #ic(list(cells_above.loc[uniq_vars].values))
    out = pd.DataFrame(index=uniq_vars, data={"n_cells":cells_above.loc[uniq_vars].values, 
                                              "n_other_cells": cells_other_above.loc[uniq_vars].values,
                                              "pct_above": pct_cells_above,
                                              "pct_other_above": pct_cells_other_above})
    out["pct_thresh"] = pct_thresh
    out["af_thresh"] = af_thresh
    out["other_pct_thresh"] = other_pct_thresh
    return out

# %%
all_unique_df = []
for cln, val in curr_labels.groupby("name"):
    print(cln)
    cln_af = AF_df.loc[:, val.index]
    other_af = AF_df.loc[:, curr_labels.drop(val.index).index]
    curr_dp = DP_df.loc[:, val.index]
    curr_labs = curr_labels[curr_labels.index.isin(cln_af.columns)]
    print(cln_af.shape)
    #curr_anno = pd.DataFrame(curr_af.apply(lambda x: x.name.split("_")[-1], axis=0)).rename({0:"condition"},axis=1)
    for pct_thr in pct_thresh:
        for af_thr in af_thresh:
            for other_pct_thr in other_pct_thresh:
                unique_df = get_unique_variants(cln_af, other_af, pct_thr, af_thr, other_pct_thr)
                unique_df["clone"] = cln
                unique_df["id"] = unique_df["clone"] + "_" + unique_df["pct_thresh"].astype(str)+ "_" + unique_df["af_thresh"].astype(str)+ "_" + unique_df["other_pct_thresh"].astype(str)
                unique_df["variant"] = unique_df.index
                unique_df = unique_df.set_index("id")
                all_unique_df.append(unique_df)
# Out:
# 0_0
# (68, 957)
# cells other Variant
# 10397G    7836
# 10463C     332
# 10559G     418
# 10589A    7830
# 11251G     549
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     332
# 10559G     418
# 10589A    7830
# 11251G     549
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     332
# 10559G     418
# 10589A    7830
# 11251G     549
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     330
# 10559G     418
# 10589A    7830
# 11251G     546
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     330
# 10559G     418
# 10589A    7830
# 11251G     546
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     330
# 10559G     418
# 10589A    7830
# 11251G     546
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     144
# 10559G     163
# 10589A    7830
# 11251G     165
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     144
# 10559G     163
# 10589A    7830
# 11251G     165
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     144
# 10559G     163
# 10589A    7830
# 11251G     165
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C      15
# 10559G      20
# 10589A    7828
# 11251G      15
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C      15
# 10559G      20
# 10589A    7828
# 11251G      15
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C      15
# 10559G      20
# 10589A    7828
# 11251G      15
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     332
# 10559G     418
# 10589A    7830
# 11251G     549
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     332
# 10559G     418
# 10589A    7830
# 11251G     549
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     332
# 10559G     418
# 10589A    7830
# 11251G     549
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     330
# 10559G     418
# 10589A    7830
# 11251G     546
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     330
# 10559G     418
# 10589A    7830
# 11251G     546
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     330
# 10559G     418
# 10589A    7830
# 11251G     546
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     144
# 10559G     163
# 10589A    7830
# 11251G     165
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     144
# 10559G     163
# 10589A    7830
# 11251G     165
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     144
# 10559G     163
# 10589A    7830
# 11251G     165
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C      15
# 10559G      20
# 10589A    7828
# 11251G      15
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C      15
# 10559G      20
# 10589A    7828
# 11251G      15
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C      15
# 10559G      20
# 10589A    7828
# 11251G      15
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     332
# 10559G     418
# 10589A    7830
# 11251G     549
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     332
# 10559G     418
# 10589A    7830
# 11251G     549
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     332
# 10559G     418
# 10589A    7830
# 11251G     549
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     330
# 10559G     418
# 10589A    7830
# 11251G     546
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     330
# 10559G     418
# 10589A    7830
# 11251G     546
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     330
# 10559G     418
# 10589A    7830
# 11251G     546
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     144
# 10559G     163
# 10589A    7830
# 11251G     165
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     144
# 10559G     163
# 10589A    7830
# 11251G     165
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     144
# 10559G     163
# 10589A    7830
# 11251G     165
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C      15
# 10559G      20
# 10589A    7828
# 11251G      15
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C      15
# 10559G      20
# 10589A    7828
# 11251G      15
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C      15
# 10559G      20
# 10589A    7828
# 11251G      15
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C     332
# 10559G     418
# 10589A    7830
# 11251G     549
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    7836
# 10463C
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     415
# 10559G     533
# 10589A    8556
# 11251G     660
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     413
# 10559G     533
# 10589A    8556
# 11251G     657
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     413
# 10559G     533
# 10589A    8556
# 11251G     657
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     413
# 10559G     533
# 10589A    8556
# 11251G     657
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     186
# 10559G     213
# 10589A    8556
# 11251G     198
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     186
# 10559G     213
# 10589A    8556
# 11251G     198
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     186
# 10559G     213
# 10589A    8556
# 11251G     198
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C      16
# 10559G      22
# 10589A    8554
# 11251G      16
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C      16
# 10559G      22
# 10589A    8554
# 11251G      16
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C      16
# 10559G      22
# 10589A    8554
# 11251G      16
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     415
# 10559G     533
# 10589A    8556
# 11251G     660
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     415
# 10559G     533
# 10589A    8556
# 11251G     660
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     415
# 10559G     533
# 10589A    8556
# 11251G     660
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     413
# 10559G     533
# 10589A    8556
# 11251G     657
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     413
# 10559G     533
# 10589A    8556
# 11251G     657
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     413
# 10559G     533
# 10589A    8556
# 11251G     657
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     186
# 10559G     213
# 10589A    8556
# 11251G     198
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     186
# 10559G     213
# 10589A    8556
# 11251G     198
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     186
# 10559G     213
# 10589A    8556
# 11251G     198
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C      16
# 10559G      22
# 10589A    8554
# 11251G      16
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C      16
# 10559G      22
# 10589A    8554
# 11251G      16
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C      16
# 10559G      22
# 10589A    8554
# 11251G      16
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     415
# 10559G     533
# 10589A    8556
# 11251G     660
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     415
# 10559G     533
# 10589A    8556
# 11251G     660
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     415
# 10559G     533
# 10589A    8556
# 11251G     660
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     413
# 10559G     533
# 10589A    8556
# 11251G     657
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     413
# 10559G     533
# 10589A    8556
# 11251G     657
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     413
# 10559G     533
# 10589A    8556
# 11251G     657
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     186
# 10559G     213
# 10589A    8556
# 11251G     198
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     186
# 10559G     213
# 10589A    8556
# 11251G     198
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C     186
# 10559G     213
# 10589A    8556
# 11251G     198
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C      16
# 10559G      22
# 10589A    8554
# 11251G      16
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C      16
# 10559G      22
# 10589A    8554
# 11251G      16
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8560
# 10463C      16
# 10559G      22
# 10589A    8554
# 11251G      16
# dtype: int64
# cells other shape (68,)
# 0_15
# (68, 232)
# cells other Variant
# 10397G    8561
# 10463C     412
# 10559G     528
# 10589A    8554
# 11251G     663
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8561
# 10463C     412
# 10559G     528
# 10589A    8554
# 11251G     663
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8561
# 10463C     412
# 10559G     528
# 10589A    8554
# 11251G     663
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8561
# 10463C     410
# 10559G     528
# 10589A    8554
# 11251G     661
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8561
# 10463C     410
# 10559G     528
# 10589A    8554
# 11251G     661
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8561
# 10463C     410
# 10559G     528
# 10589A    8554
# 11251G     661
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8561
# 10463C     190
# 10559G     220
# 10589A    8554
# 11251G     209
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8561
# 10463C     190
# 10559G     220
# 10589A    8554
# 11251G     209
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8561
# 10463C     190
# 10559G     220
# 10589A    8554
# 11251G     209
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8561
# 10463C      18
# 10559G      23
# 10589A    8552
# 11251G      18
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8561
# 10463C      18
# 10559G      23
# 10589A    8552
# 11251G      18
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8561
# 10463C      18
# 10559G      23
# 10589A    8552
# 11251G      18
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8561
# 10463C     412
# 10559G     528
# 10589A    8554
# 11251G     663
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8561
# 10463C     412
# 10559G     528
# 10589A    8554
# 11251G     663
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8561
# 10463C     412
# 10559G     528
# 10589A    8554
# 11251G     663
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    
# 11251G      18
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8461
# 10463C     414
# 10559G     537
# 10589A    8453
# 11251G     671
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8461
# 10463C     414
# 10559G     537
# 10589A    8453
# 11251G     671
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8461
# 10463C     414
# 10559G     537
# 10589A    8453
# 11251G     671
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8461
# 10463C     412
# 10559G     537
# 10589A    8453
# 11251G     668
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8461
# 10463C     412
# 10559G     537
# 10589A    8453
# 11251G     668
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8461
# 10463C     412
# 10559G     537
# 10589A    8453
# 11251G     668
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8461
# 10463C     189
# 10559G     221
# 10589A    8453
# 11251G     209
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8461
# 10463C     189
# 10559G     221
# 10589A    8453
# 11251G     209
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8461
# 10463C     189
# 10559G     221
# 10589A    8453
# 11251G     209
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8461
# 10463C      18
# 10559G      23
# 10589A    8451
# 11251G      18
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8461
# 10463C      18
# 10559G      23
# 10589A    8451
# 11251G      18
# dtype: int64
# cells other shape (68,)
# cells other Variant
# 10397G    8461
# 10463C      18
# 10559G      23
# 10589A    8451
# 11251G      18
# dtype: int64
# cells other shape (68,)

# %%
all_df = pd.concat(all_unique_df)
all_df
# Out:
#                     n_cells  n_other_cells  pct_above  pct_other_above  \
# id
# 0_0_0.01_0_0.01          16             76   0.016719         0.009422
# 0_0_0.01_0_0.1           50            687   0.052247         0.085172
# 0_0_0.01_0_0.1          164            597   0.171369         0.074014
# 0_0_0.01_0_0.1           97            496   0.101358         0.061493
# 0_0_0.01_0_0.1          101            491   0.105538         0.060873
# ...                     ...            ...        ...              ...
# 0_9_0.01_0.01_0.25        4             79   0.011834         0.009096
# 0_9_0.01_0.01_0.25        4            668   0.011834         0.076914
# 0_9_0.01_0.01_0.25        6            193   0.017751         0.022222
# 0_9_0.01_0.1_0.1          4            120   0.011834         0.013817
# 0_9_0.01_0.1_0.25         4            120   0.011834         0.013817
#
#                     pct_thresh  af_thresh  other_pct_thresh clone variant
# id
# 0_0_0.01_0_0.01           0.01       0.00              0.01   0_0  16129A
# 0_0_0.01_0_0.1            0.01       0.00              0.10   0_0   1888A
# 0_0_0.01_0_0.1            0.01       0.00              0.10   0_0  14905A
# 0_0_0.01_0_0.1            0.01       0.00              0.10   0_0  13368A
# 0_0_0.01_0_0.1            0.01       0.00              0.10   0_0   4917G
# ...                        ...        ...               ...   ...     ...
# 0_9_0.01_0.01_0.25        0.01       0.01              0.25   0_9   8743A
# 0_9_0.01_0.01_0.25        0.01       0.01              0.25   0_9  11251G
# 0_9_0.01_0.01_0.25        0.01       0.01              0.25   0_9    150T
# 0_9_0.01_0.1_0.1          0.01       0.10              0.10   0_9    150T
# 0_9_0.01_0.1_0.25         0.01       0.10              0.25   0_9    150T
#
# [5553 rows x 9 columns]

# %%
import seaborn as sns
sns.countplot([x.shape[0] for x in all_unique_df])
plt.title("Number of variants in each cluster")
plt.xlabel("Variants in a clone")
# Out:
# /home/isaac/miniconda3/envs/mttrace/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'Variants in a clone')

# %%
def plot_ncells_in_variant(curr_df, outdir, ind):
    
    curr_var_counts = curr_df.groupby("variant").sum()["n_cells"]
    #print(curr_var_counts.head())
    #all_var_counts[("pct_thresh", "af_thresh", "other_pct_thresh")] = curr_var_counts
    f=plt.figure()
    curr_var_counts.plot.bar()
    #sns.countplot(x=curr_var_counts)
    plt.title(ind)
    plt.xticks(rotation=90)
    plt.ylabel("Number of cells with the variant in clones with that variant")
    plt.tight_layout()
    plt.savefig(join(outdir, f"pct_thresh_{ind[0]}_af_thresh_{ind[1]}_other_pct_thresh_{ind[2]}__num_cells_inClones_per_var.png"))
    return

# %%
all_var_counts = {}
count = 0
for ind, curr_df in all_df.groupby(["pct_thresh", "af_thresh", "other_pct_thresh"]):
    curr_var_counts = curr_df.groupby("variant").size()
    all_var_counts[("pct_thresh", "af_thresh", "other_pct_thresh")] = curr_var_counts
    f=plt.figure()
    sns.countplot(x=curr_df["variant"])
    plt.title(ind)
    plt.xticks(rotation=90)
    plt.ylabel("Number of clones variant is seen in")
    plt.tight_layout()
    plt.savefig(join(OUTDIR, f"pct_thresh_{ind[0]}_af_thresh_{ind[1]}_other_pct_thresh_{ind[2]}__num_clones_per_var.png"))
    
    if count > 10:
        plt.close()
    #curr_df.groupby("variant").sum()["n_cells"]
    plot_ncells_in_variant(curr_df, OUTDIR, ind)
    
    f=plt.figure()
    sns.countplot(x=curr_df.groupby("clone").size())
    plt.title("Number of variants in each cluster")
    plt.xlabel("Variants in a clone")
    plt.ylabel("Number of clones")
    plt.tight_layout()
    plt.savefig(join(OUTDIR, f"pct_thresh_{ind[0]}_af_thresh_{ind[1]}_other_pct_thresh_{ind[2]}__num_vars_in_clone.png"))
    
    count+=1
    if count > 10:
        plt.close()
# Out:
# variant
# 15297C    11
# 152C      71
# 16129A    20
# 5442C      9
# 8743A     61
# Name: n_cells, dtype: int64
# variant
# 10463C    421
# 10559G    541
# 11251G    675
# 11453A    237
# 11719A    773
# Name: n_cells, dtype: int64
# variant
# 10463C    421
# 10559G    541
# 11251G    675
# 11453A    237
# 11719A    773
# Name: n_cells, dtype: int64
# variant
# 15297C     7
# 152C      71
# 16129A    20
# 5442C      9
# 8743A     61
# Name: n_cells, dtype: int64
# variant
# 10463C    419
# 10559G    541
# 11251G    672
# 11453A    236
# 11719A    751
# Name: n_cells, dtype: int64
# variant
# 10463C    419
# 10559G    541
# 11251G    672
# 11453A    236
# 11719A    751
# Name: n_cells, dtype: int64
# variant
# 11453A    154
# 14674C     45
# 152C       74
# 16129A     36
# 2623G      25
# Name: n_cells, dtype: int64
# /home/isaac/miniconda3/envs/mttrace/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# variant
# 10463C    174
# 10559G    211
# 11251G    201
# 11453A    197
# 11719A    195
# Name: n_cells, dtype: int64
# variant
# 10463C    174
# 10559G    211
# 11251G    201
# 11453A    197
# 11719A    195
# Name: n_cells, dtype: int64
# variant
# 10463C      5
# 10559G     19
# 11251G      8
# 11453A    142
# 11719A      4
# Name: n_cells, dtype: int64
# variant
# 10463C      5
# 10559G     19
# 11251G      8
# 11453A    151
# 11719A      4
# Name: n_cells, dtype: int64
# variant
# 10463C      5
# 10559G     19
# 11251G      8
# 11453A    151
# 11719A      4
# Name: n_cells, dtype: int64
# variant
# 152C    71
# Name: n_cells, dtype: int64
# variant
# 11251G    177
# 11453A    154
# 11812G    232
# 13368A    114
# 14233G    130
# Name: n_cells, dtype: int64
# variant
# 11251G    177
# 11453A    154
# 11812G    232
# 13368A    114
# 14233G    130
# Name: n_cells, dtype: int64
# variant
# 152C    71
# Name: n_cells, dtype: int64
# variant
# 11251G    177
# 11453A    154
# 11812G    232
# 13368A    114
# 14233G    130
# Name: n_cells, dtype: int64
# variant
# 11251G    177
# 11453A    154
# 11812G    232
# 13368A    114
# 14233G    130
# Name: n_cells, dtype: int64
# variant
# 11453A    154
# 152C       71
# Name: n_cells, dtype: int64
# variant
# 11453A    154
# 13368A     58
# 152C       71
# 1949A     278
# Name: n_cells, dtype: int64
# variant
# 11453A    154
# 13368A     58
# 152C       71
# 1949A     278
# Name: n_cells, dtype: int64
# variant
# 11453A    142
# 152C       63
# 1949A     172
# Name: n_cells, dtype: int64
# variant
# 11453A    142
# 152C       63
# 1949A     172
# Name: n_cells, dtype: int64
# variant
# 11453A    142
# 152C       63
# 1949A     172
# Name: n_cells, dtype: int64
# variant
# 152C    71
# Name: n_cells, dtype: int64
# variant
# 11251G    177
# 11453A    154
# 13368A    114
# 14233G    130
# 14905A    100
# Name: n_cells, dtype: int64
# variant
# 11251G    177
# 11453A    154
# 13368A    114
# 14233G    130
# 14905A    100
# Name: n_cells, dtype: int64
# variant
# 152C    71
# Name: n_cells, dtype: int64
# variant
# 11251G    177
# 11453A    154
# 13368A    114
# 14233G    130
# 14905A    100
# Name: n_cells, dtype: int64
# variant
# 11251G    177
# 11453A    154
# 13368A    114
# 14233G    130
# 14905A    100
# Name: n_cells, dtype: int64
# variant
# 11453A    154
# 152C       71
# Name: n_cells, dtype: int64
# variant
# 11453A    154
# 152C       71
# 1949A     278
# Name: n_cells, dtype: int64
# variant
# 11453A    154
# 152C       71
# 1949A     278
# Name: n_cells, dtype: int64
# variant
# 11453A    142
# 152C       63
# 1949A     172
# Name: n_cells, dtype: int64
# variant
# 11453A    142
# 152C       63
# 1949A     172
# Name: n_cells, dtype: int64
# variant
# 11453A    142
# 152C       63
# 1949A     172
# Name: n_cells, dtype: int64
# variant
# 152C    71
# Name: n_cells, dtype: int64
# variant
# 11251G    177
# 11453A    154
# 13368A    114
# 14233G    130
# 14905A    100
# Name: n_cells, dtype: int64
# variant
# 11251G    177
# 11453A    154
# 13368A    114
# 14233G    130
# 14905A    100
# Name: n_cells, dtype: int64
# variant
# 152C    71
# Name: n_cells, dtype: int64
# variant
# 11251G    177
# 11453A    154
# 13368A    114
# 14233G    130
# 14905A    100
# Name: n_cells, dtype: int64
# variant
# 11251G    177
# 11453A    154
# 13368A    114
# 14233G    130
# 14905A    100
# Name: n_cells, dtype: int64
# variant
# 11453A    154
# 152C       71
# Name: n_cells, dtype: int64
# variant
# 11453A    154
# 152C       71
# 1949A     194
# Name: n_cells, dtype: int64
# variant
# 11453A    154
# 152C       71
# 1949A     194
# Name: n_cells, dtype: int64

# %%
curr_var_counts = curr_df.groupby("variant").size()
curr_var_counts
# Out:
# variant
# 11453A    1
# 152C      1
# 1949A     1
# dtype: int64

# %% [markdown]
# ## Get dict of variants and how many clones its in

# %%
# for pct_thr in pct_thresh:
#     for af_thr in af_thresh:
#         for other_pct_thr in other_pct_thresh:
