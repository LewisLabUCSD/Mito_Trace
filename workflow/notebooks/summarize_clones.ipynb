# %%
# Clone dir
clone_dir = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_simpleUnion/knn/kparam_3/"

## Clone specific
annClo_dir = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/gff_A2_black/annotation_clones/"

## Nuclear clustering 
anno_dir = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/annotation/gff_A2_black/mergedSamples"
## Clone-cluster shift
hypergeom = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/gff_A2_black/annotation_clones/hypergeom_clone_clust/mincl.10_bothConds.False_p0.1"
## clean enrichment, sizes, and dominant clone
aggreg_dir = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/gff_A2_black/clones_change/filt_None__shuffle_True__padj_True__pthresh_0.01_minC_1__bothMinC__0/merge_enrich_and_lineage/"

btwnClones = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/barcodes/btwnClones/"
#enrichment_dir = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_simpleUnion/knn/kparam_3/enrichment/"
#umap_clones = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/gff_A2_black/annotation_clones/umap_clones_overlay"
#inClones = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_simpleUnion/knn/kparam_3/barcodes/inClones/"
# Cells 
#cells_meta_f = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_simpleUnion/knn/kparam_3/cells_meta.tsv"


outdir = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/results/clones_summary/feb23_2022/"

#params = {""}
params_f = ""

# %% [markdown]
# ### Setup input directories

# %%
cells_meta_f = join(clone_dir, "cells_meta_f.tsv")
umap_clones = join(annClo_dir, "umap_clones_overlay")
inClones = join(clone_dir, "barcodes/inClones/")
enrichment_dir = join(clone_dir, "enrichment")

# %%
from os.path import join, exists, dirname
from glob import glob
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
#np.set_printoptions(formatter={'float': lambda x: format(x, '.5f')})
from glob import glob

# %%
if not exists(join(outdir, "suppl")):
    os.mkdir(join(outdir, "suppl"))

# %%
cells_meta = pd.read_csv(cells_meta_f, sep="\t", index_col=0)
cells_meta["name"] = cells_meta["donor"].astype(str) + "_" + cells_meta["lineage"].astype(str)

# %% [markdown]
# ## Setup clones_summary_df and clones_summary_files_dict

# %%
clones = cells_meta["name"].unique()

# %%
from collections import defaultdict
clones_summary_files_dict = defaultdict(dict)

# general_files = {"hypergeom_input", "hypergeom", "btwnClones", "lineage_clusters", "volcano", 
#                  "aggregate"}

# %%
conditions = cells_meta["condition"].unique()
conds_size_cols = {c:f"ncells_in_{c}" for c in conditions}
columns = ["ID", "donor", "ncells", "clone_nuclearClust_hypergeom_sig_clusters_inputOnly", "hypergeom_sig_clusters",
           "enrichment_fold", "enrichment_sig",
           "enrichment_log10p", "enrichment_shuffle_sig",
           "top_vars", "dominant_clone", "dominant_clone_ncells", 
           "clone_cluster_embed"]

clones_summary_df = pd.DataFrame(index=clones, columns=columns)
clones_summary_df["donor"] = [x.split("_")[0] for x in clones_summary_df.index]
clones_summary_df["lineage"] = [x.split("_")[1] for x in clones_summary_df.index]
clones_summary_df["ID"] = clones_summary_df.index
clones_summary_df
# Out:
#         ID donor ncells clone_nuclearClust_hypergeom_sig_clusters_inputOnly  \
# 0_0    0_0     0    NaN                                                NaN
# 0_1    0_1     0    NaN                                                NaN
# 0_2    0_2     0    NaN                                                NaN
# 0_3    0_3     0    NaN                                                NaN
# 0_4    0_4     0    NaN                                                NaN
# ...    ...   ...    ...                                                ...
# 1_33  1_33     1    NaN                                                NaN
# 1_34  1_34     1    NaN                                                NaN
# 1_35  1_35     1    NaN                                                NaN
# 1_36  1_36     1    NaN                                                NaN
# 1_37  1_37     1    NaN                                                NaN
#
# ...

# %% [markdown]
# # General Files dictionary

# %%
summary_files_dict = {}
summary_files_dict["volcano_enrichment.png"] = join(enrichment_dir, "volcano_Fisher_foldNorm.png")
summary_files_dict["umap_clusters.png"] = join(anno_dir, "integrated.lsi.clusters.png")
summary_files_dict["umap_conditions_batch.png"] = join(anno_dir, "integrated.batch.png")
#summary_files_dict["umap_clusters"] = join(annC, "lsi.clusters.png")

# %%
for new_f in summary_files_dict:
    cmd = f"cp {summary_files_dict[new_f]} {join(outdir,new_f)}"
    print(cmd)
    # !{cmd}
# Out:
# cp /data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_simpleUnion/knn/kparam_3/enrichment/volcano_Fisher_foldNorm.png /data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/results/clones_summary/feb23_2022/volcano_enrichment.png
# cp /data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/annotation/gff_A2_black/mergedSamples/integrated.lsi.clusters.png /data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/results/clones_summary/feb23_2022/umap_clusters.png
# cp /data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/annotation/gff_A2_black/mergedSamples/integrated.batch.png /data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/results/clones_summary/feb23_2022/umap_conditions_batch.png

# %% [markdown]
# # Files dictionary

# %% [markdown]
# ## i. inClone

# %%
for cln in cells_meta["name"].unique():
    print(cln)
    donor = clones_summary_df.loc[cln,"donor"]
    print(glob(inClones+f"/*donor{donor}_{cln}_*png"))
    clones_summary_files_dict[cln]["suppl/barcode_cell_depth.png"] = join(inClones,f"donor{donor}_{cln}_cell_dp.png")
    clones_summary_files_dict[cln]["suppl/barcode_cell_allele_freq.png"] = join(inClones,f"donor{donor}_{cln}_cell_af_0.5.png")
    clones_summary_files_dict[cln]["suppl/barcode_cell_mean_allele.png"] = join(inClones,f"donor{donor}_{cln}_mean.png")
    clones_summary_files_dict[cln]["suppl/barcode_cell_median_allele.png"] = join(inClones,f"donor{donor}_{cln}_median.png")
# Out:
# 0_0
# ...

# %% [markdown]
# ## ii. annClo

# %%
for cln in cells_meta["name"].unique():
    print(cln)
    clones_summary_files_dict[cln]["umap_overlay_color_by_cluster.png"] = join(umap_clones,f"clone_{cln}clust_color.png")
    clones_summary_files_dict[cln]["umap_overlay_color_by_condition.png"] = join(umap_clones,f"clone_{cln}cond_color.png")
    #curr_fs = glob(umap_clones+f"/clone_{cln}clust*png")+glob(umap_clones+f"/clone_{cln}cond*png")
    #print(curr_fs)
# Out:
# 0_0
# 0_1
# 0_2
# 0_3
# 0_4
# 0_5
# 0_6
# 0_7
# 0_8
# 0_9
# 0_10
# 0_11
# 0_12
# 0_13
# 0_14
# 0_15
# 0_16
# 0_17
# 0_18
# 0_19
# 0_20
# 0_21
# 0_22
# 0_23
# 0_24
# 0_25
# 0_26
# 0_27
# 0_28
# 0_29
# 0_30
# 0_31
# 0_32
# 0_33
# 0_34
# 0_35
# 0_36
# 0_37
# 0_38
# 0_39
# 0_40
# 0_41
# 0_42
# 0_43
# 0_44
# 0_45
# 0_46
# 0_47
# 0_48
# 0_49
# 0_50
# 1_0
# 1_1
# 1_2
# 1_3
# 1_4
# 1_5
# 1_6
# 1_7
# 1_8
# 1_9
# 1_10
# 1_11
# 1_12
# 1_13
# 1_14
# 1_15
# 1_16
# 1_17
# 1_18
# 1_19
# 1_20
# 1_21
# 1_22
# 1_23
# 1_24
# 1_25
# 1_26
# 1_27
# 1_28
# 1_29
# 1_30
# 1_31
# 1_32
# 1_33
# 1_34
# 1_35
# 1_36
# 1_37

# %% [markdown]
# ### Save

# %%
for cln in cells_meta["name"].unique():
    print(cln)
    curr_outdir = join(outdir, cln)
    if not exists(curr_outdir):
        os.mkdir(curr_outdir)
    for new_f in clones_summary_files_dict[cln]:
        cmd = f"cp {clones_summary_files_dict[cln][new_f]} {join(curr_outdir,new_f)}"
        print(cmd)
        # !{cmd}
# Out:
# 0_0
# cp /data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_simpleUnion/knn/kparam_3/barcodes/inClones/donor0_0_0_cell_dp.png /data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/results/clones_summary/feb23_2022/0_0/suppl/barcode_cell_depth.png
# cp: cannot create regular file '/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/results/clones_summary/feb23_2022/0_0/suppl/barcode_cell_depth.png': No such file or directory
# cp /data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_simpleUnion/knn/kparam_3/barcodes/inClones/donor0_0_0_cell_af_0.5.png /data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/results/clones_summary/feb23_2022/0_0/suppl/barcode_cell_allele_freq.png
# ...

# %% [markdown]
# # Clone csv file

# %%
in_aggr = pd.read_csv(join(aggreg_dir, "inputDominant_clones_meta.csv"),index_col=0)
all_aggr = pd.read_csv(join(aggreg_dir, "clones_meta.csv"), index_col=0)
in_aggr
# Out:
#      dominant_cluster  dominant_cluster_size  total_size   entropy  donor  \
# name
# 1_29                2                   19.0        67.0  2.102523      1
# 1_12                2                   53.0       174.0  2.058730      1
# 0_26                3                   24.0        91.0  2.046727      0
# 0_9                 3                   44.0       120.0  2.032120      0
# 0_27                3                   14.0        49.0  2.016626      0
# ...               ...                    ...         ...       ...    ...
# 1_36               12                    3.0         7.0  1.078992      1
# 1_10                2                    4.0         9.0  1.060857      1
# 1_25              2;3                    5.0        12.0  1.028184      1
# 0_50                3                    2.0         2.0  0.000000      0
# 1_33                2                    2.0         2.0  0.000000      1
#
#       clone name.1 condition         p_adj    sig     change  \
# name
# ...

# %% [markdown]
# ## i. enrichment

# %%
enrichment_df = pd.read_csv(join(enrichment_dir, 'enrichmentNorm.csv'))
enrichment_df.head()
conds_size_enrich_cols = {c:f"# {c} Cells in Cluster" for c in conditions}
#enrichment_df[conds_size_enrich_cols.values()]
enrichment_df["ID"] = enrichment_df["Donor"].astype(str) + "_" + enrichment_df["lineage"].astype(str)
enrichment_df = enrichment_df.set_index("ID")
enrichment_df

shuffle_stats_df = pd.read_csv(enrichment_dir+"/shuffle_stats/shuffle_stats.csv", index_col=0)
shuffle_stats_df

clones_summary_df["enrichment_shuffle_sig"] = shuffle_stats_df.loc[clones_summary_df.index,
                                                                   "shuffle_sig_max"]
clones_summary_df.loc[enrichment_df.index, "enrichment_fold"] = enrichment_df.loc[:,enrichment_df.columns.str.contains("fold enrichment norm")].values

# %% [markdown]
# ## ii. cluster-clone size shift hypergeometric input

# %%
cluster_clone_hyper_input = pd.read_csv(join(hypergeom, "input_hypergeom.csv"), index_col=0)
cluster_clone_hyper_input

clones_summary_df.loc[cluster_clone_hyper_input.index, "clone_nuclearClust_hypergeom_sig_clusters_inputOnly"] = cluster_clone_hyper_input["significant clusters"]
clones_summary_df.loc[cluster_clone_hyper_input.index, "clone_nuclearClust_hypergeom_min_pval_inputOnly"] = cluster_clone_hyper_input["min_significance"]
clones_summary_df.loc[cluster_clone_hyper_input.index, "size"] = cluster_clone_hyper_input["size"]

# %%
cmd = f"cp {params_f} {join(outdir, 'params.yaml')}"
print(cmd)
# !{cmd}

# %% [markdown]
# ## Make or recreate figures just for that clone?
