# %%
#DE.out.path = "/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/annotation_clones/de_clone_btwncond_RNA/minPct0.01_logfc0.1/btwnConds_inClone_sepDonrs/"
DE.out.path = '/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/'

export.path = "/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb"
gsea_dir = "/mnt/md0/isshamie/Projects/Mito_Trace/software/Bioinformatics_Tools/"

pthresh = 0.1 
gsea_pthresh = 0.1 
prefilter = FALSE 
stat_col = "log2FoldChange"
padjmethod = "BH"

pct_thresh = 0.1

pattern = "clone_.*counts.*"

#is_dir = TRUE

# %%
if ((prefilter=="TRUE") | (prefilter==TRUE)){
    prefilter=TRUE
}else{
    prefilter=FALSE
}

# %%
# if ((is_dir=="TRUE") | (is_dir==TRUE)){
#     is_dir=TRUE
# }else{
#     is_dir=FALSE
# }
# print(is_dir)

# %%
source(paste0(gsea_dir,'R/Gsea.R'))
# Out:
# Loading required package: clusterProfiler
#
#
#
# clusterProfiler v4.2.2  For help: https://yulab-smu.top/biomedical-knowledge-mining-book/
#
# If you use clusterProfiler in published research, please cite:
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal enrichment tool for interpreting omics data. The Innovation. 2021, 2(3):100141
#
#
# Attaching package: ‘clusterProfiler’
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
# [1] "package already installed:clusterProfiler"
# [1] "package already installed:clusterProfiler"
# Loading required package: GSEABase
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: annotate
#
# Loading required package: AnnotationDbi
#
# Loading required package: stats4
#
# Loading required package: IRanges
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
#
# Attaching package: ‘IRanges’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
#
# Attaching package: ‘AnnotationDbi’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
# Loading required package: XML
#
# Loading required package: graph
#
#
# Attaching package: ‘graph’
#
#
# The following object is masked from ‘package:XML’:
#
#     addNode
# [1] "package already installed:GSEABase"
# [1] "package already installed:GSEABase"
# Loading required package: biomaRt
# [1] "package already installed:biomaRt"
# [1] "package already installed:biomaRt"
# Loading required package: org.Hs.eg.db
# [1] "package already installed:org.Hs.eg.db"
# [1] "package already installed:org.Hs.eg.db"
# Loading required package: DOSE
#
# DOSE v3.20.1  For help: https://yulab-smu.top/biomedical-knowledge-mining-book/
#
# If you use DOSE in published research, please cite:
# Guangchuang Yu, Li-Gen Wang, Guang-Rong Yan, Qing-Yu He. DOSE: an R/Bioconductor package for Disease Ontology Semantic and Enrichment analysis. Bioinformatics 2015, 31(4):608-609
# [1] "package already installed:DOSE"
# [1] "package already installed:DOSE"
# Loading required package: gdata
#
# gdata: read.xls support for 'XLS' (Excel 97-2004) files ENABLED.
#
#
#
# gdata: Unable to load perl libaries needed by read.xls()
# gdata: to support 'XLSX' (Excel 2007+) files.
#
#
#
# gdata: Run the function 'installXLSXsupport()'
# gdata: to automatically download and install the perl
# gdata: libaries needed to support Excel XLS and XLSX formats.
#
#
# Attaching package: ‘gdata’
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     startsWith, trim
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, first<-
#
#
# The following object is masked from ‘package:stats4’:
#
#     nobs
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     combine
#
#
# The following object is masked from ‘package:stats’:
#
#     nobs
#
#
# The following object is masked from ‘package:utils’:
#
#     object.size
#
#
# The following object is masked from ‘package:base’:
#
#     startsWith
#
#
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:gdata’:
#
#     first, last
#
#
# The following object is masked from ‘package:IRanges’:
#
#     shift
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, second
#
#
# Loading required package: openxlsx
#
# Loading required package: dplyr
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:gdata’:
#
#     combine, first, last
#
#
# The following object is masked from ‘package:biomaRt’:
#
#     select
#
#
# The following objects are masked from ‘package:GSEABase’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:graph’:
#
#     union
#
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘stringr’
#
#
# The following object is masked from ‘package:graph’:
#
#     boundary

# %%
dir.create(export.path)
export.path.prep <- gsub("//", "/", file.path(export.path, "prep"))
dir.create(export.path.prep)

# %%
cols.prior <- c("Gene","baseMean","log2FoldChange","lfcSE","stat","pvalue","padj")
cols.needed <- c("Gene","log2FoldChange")
cols.curr <- c("X","p_val","avg_log2FC","pct.1","pct.2","p_val_adj_BH") #first col is empty in csv

# %% [markdown]
# ## Prep files

# %%
files <- list.files(path = DE.out.path,pattern="*_DE.csv", full.names=TRUE)
for (f in files){
    curr <- read.csv(f)
    if (!(nrow(curr)==0)){
        colnames(curr) <- c("Gene","pvalue","log2FoldChange","pct.1","pct.2","padj_bonf", "padj")
        curr$ensg <- mapIds(org.Hs.eg.db,
                    keys=curr$Gene, 
                    column="ENSEMBL",
                    keytype="SYMBOL",
                    multiVals="first")
        write.table(curr, file.path(export.path.prep, paste0(strsplit(basename(f), ".csv")[[1]], ".tsv")),quote = FALSE,
                    row.names=FALSE, sep='\t')
    }

}
# Out:
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:1 mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns
#
# 'select()' returned 1:many mapping between keys and columns

# %%
# #for f in list.files(DE.path, pattern="*.csv"){
# if is_dir{
#     files <- list.files(path=DE.out.path,pattern = pattern, full.names = T, recursive = FALSE, include.dirs = TRUE)
#     DE_dirs <- files[file.info(files)$isdir ]
#     #DE_dirs

#     for(d in DE_dirs){
#         f <- list.files(path=d, pattern="*.csv", full.names=T)
#         if (length(f)>1){
#             print("more than one file! check")
#             print(f)
#         }
#         f = f[[1]]
#         print(f)
#         curr <- read.csv(f)

#         if (!(nrow(curr)==0)){
#             colnames(curr) <- c("Gene","pvalue","log2FoldChange","pct.1","pct.2","padj_bonf", "padj")
#             curr$ensg <- mapIds(org.Hs.eg.db,
#                         keys=curr$Gene, 
#                         column="ENSEMBL",
#                         keytype="SYMBOL",
#                         multiVals="first")
#             write.table(curr, file.path(export.path.prep, paste0(strsplit(basename(f), ".csv")[[1]], ".tsv")),quote = FALSE,
#                         row.names=FALSE, sep='\t')
#         }

#     }
# }else{
#     files <- list.files(path = DE.out.path,pattern="*DE.csv", full.names=TRUE)
#     for (f in files){
#         curr <- read.csv(f)
#         if (!(nrow(curr)==0)){
#             colnames(curr) <- c("Gene","pvalue","log2FoldChange","pct.1","pct.2","padj_bonf", "padj")
#             curr$ensg <- mapIds(org.Hs.eg.db,
#                         keys=curr$Gene, 
#                         column="ENSEMBL",
#                         keytype="SYMBOL",
#                         multiVals="first")
#             write.table(curr, file.path(export.path.prep, paste0(strsplit(basename(f), ".csv")[[1]], ".tsv")),quote = FALSE,
#                         row.names=FALSE, sep='\t')
#         }

#     }
# }

# %%
export.path
# Out:
# [1] "/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb"

# %%
#rm(list=ls())

########################################################################################
##  gsea_ex1
#---------------------------------------------------------------------------------------
#' @description This example is designed to demonstrate how to run gsea analysis on the 
#'              input files (DESeq2 results) put in the same directory
#' @details All the parameter definitions is in the below section of "Setting Parameter"
#' @return out a list that summarizes the GSEA enrichment analysis
#' 
#' @export exportExcel_fp an excel file of the 'out' can be exported
#' @export exportPDF_fp an figure of the GSEA enrichment analysis
#' --------------------------------------------------------------------------------------------------
#' @author Austin W.T. Chiang
#' @note   v1.4 -- 2017.02.15 Add description of ex1, ex2, and idmapping file
#' @note   v1.3 -- 2017.02.08 Add function of displaying topN pathways and optimze code
#' @note   v1.2 -- 2017.02.06 Add zebrafish2 human id mapping
#' @note   v1.1 -- 2017.01.19 Midified for BEN
#' @note   v1.0 -- 2016.12.15 File created
#' --------------------------------------------------------------------------------------------------
########################################################################################
gsea_ex1 <- function(DE_out_path = NULL, export_path = NULL,
                     IDmappingfile = NULL, convert = FALSE,
                     gene_name = TRUE, stat.col="log2FoldChange", GSEA_set = c('c0', 'c2', 'c3'),
                     minGSSize = 30, pAdjustMethod = "none",
                     pvalueCutoff = 0.01, export = "BOTH",
                     ShowTop = TRUE, TopN = 5, gene_sets_dir=NULL){
  DE_out_files <- list.files(path = DE_out_path,pattern="*.tsv", full.names = TRUE)
  for(f in DE_out_files){
    print(paste0("Here we go .... :", f))
    #f <- "res_geno_dobs_removed_C57BL6_J__M.tsv"
    ## Input the DESeq result file
    myClass <- read.csv(f, row.names = 1,sep="\t")
    if(convert == TRUE){
      geneMapTable <- read.csv(IDmappingfile, sep = "\t")
      myClass <- useIDmappingFile(myClass=myClass,
                                  geneMapTable=geneMapTable) #,
                                  #Original_attribute=Original_attribute,
                                 # Convert_attribute=Co nvert_attribute)
    }
    
    #DEGTable <- subset(myClass, abs(log2FoldChange) >= .58 & (padj < 0.05) )
    if (prefilter){
        DEGTable <- subset(myClass, (padj < pthresh) )
        }
      
    print("Myclass")
    print(dim(myClass))
    DEGTable <- subset(myClass, (pct.1 > pct_thresh & pct.2 > pct_thresh) )
    print(dim(DEGTable))

    print(colnames(DEGTable))
    print(head(DEGTable))
    if(gene_name==TRUE){
      DEGTable$Gene <- DEGTable$gene_name
    }else{
      DEGTable$Gene <- row.names(DEGTable)
    }
    
    DEGTable <- DEGTable[with(DEGTable, order(-log2FoldChange)), ] #order
    DEGTable <- DEGTable[,c("Gene",stat.col)]
    if (stat.col=="padj"){
        DEGTable[,stat.col] <- -log10(DEGTable[,stat.col])
        DEGTable <- DEGTable[with(DEGTable, order(-padj)), ] #order
    }
    
    

    #DEGTable <- DEGTable[order(stat.col, ), ]
      
    ## do the GSEA analysis
    f1 <- gsub(".csv", "", basename(f))
    exportExcel_fp = paste0(export_path,f1,"_gsea.xlsx")
    exportPDF_fp = paste0(export_path,f1,"_gsea.pdf")
    exportDOT_fp = file.path(export_path,paste0(f1,"_gsea.dot"))
    GSEA_res <-  AnnotDEG_byGSEA(DEGTable = DEGTable, GSEA_set = GSEA_set,
                                 export = export, ShowTop = ShowTop, TopN = TopN,
                                 exportExcel_fp = exportExcel_fp,
                                 exportPDF_fp = exportPDF_fp,
                                 minGSSize = minGSSize, exportDOT_fp=exportDOT_fp,
                                 pAdjustMethod = pAdjustMethod, stat.col=stat.col,
                                 pvalueCutoff = pvalueCutoff, gene_sets_dir = gene_sets_dir)
    
    #dotplot(GSEA_res)  
    #ggsave(file.path(export_path, paste0(f1, "_gsea.dot.pdf")))
    
  }
    return
}


########################################################################################
##  Setting Parameter
########################################################################################
#' @param DE_out_path the path of the DESeq2 output files 
#' @param export_path the path that user want to export the GSEA results
#' @param convert 'TRUE': need to do id converion; 'FALSE': no id conversion needed  
#' @param IDmappingfile the idmapping file show that user's id to human gene name
#' @param gene_name 'TRUE': there is a columan "gene_name" in the input files (i.e. DESeq2 output files)
#' @param GSEA_set = c('c0', 'c2', 'c3')
#'                 co - hallmark gene sets;       c1 - positional gene sets; 
#'                 c2 - curated gene sets;        c3 - motif gene sets;
#'                 c4 - computational gene sets;  c5 - GO gene sets;
#'                 c6 - oncogenic signatures;     c7 - immunologic signatures. 
#'                 (http://software.broadinstitute.org/gsea/msigdb/collections.jsp#C2)
#' @param minGSSize minimum size of genes for a specific GSEA gene set
#' @param pAdjustMethod one of "holm", "hochberg", "hommel", "bonferroni", "BH", "BY", "fdr", "none"
#' @param pvalueCutoff cutoff of pvalue in the GSEA enrichment analysis 
#' @param export option for exporting GSEA result: "EXCEL", "PDF", or "BOTH"
#' @param ShowTop 'TRUE': the visualization will display only the top and bottom N gene sets; 
#'                'FALSE': all of the significant gsea gene sets will be displayed 
#'                        --> Note that: it is usually results in too many gene sets, which are not easy to see anything    
#' @param TopN this parameter indicate how many gene sets need to be displayed in the plots
########################################################################################

# DE_out_path <- DE.out.path
# export_path <- 
#IDmappingfile <- "" #"mouse2human.txt" #"Data/zebrafish2human_idmapping.txt"
convert = FALSE
gene_name = FALSE 
GSEA_set = c('c0', 'c2', 'c5', 'c7')
minGSSize = 10 #20 #30
pAdjustMethod = "BH"
pvalueCutoff = pthresh
export = "BOTH"
ShowTop = TRUE 
TopN = 10


########################################################################################
##  RUN gsea_ex1
########################################################################################
out = gsea_ex1(DE_out_path = export.path.prep, export_path = export.path, gene_name = gene_name,
         convert = convert, GSEA_set = GSEA_set, minGSSize = minGSSize,
         pAdjustMethod = padjmethod,  pvalueCutoff = gsea_pthresh,
         export = export, ShowTop = ShowTop,  stat.col=stat_col ,
         TopN = TopN, gene_sets_dir=gsea_dir)
# Out:
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/0_expand_vs_0_no_change_cluster_0_DE.tsv"
# [1] "Myclass"
# [1] 51  7
# [1] 46  7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#                      pvalue log2FoldChange pct.1 pct.2 padj_bonf         padj
# NPHP3          3.814486e-05     -0.1143273 0.207 0.336 0.7466856 0.0009726939
# ARHGEF12       6.941920e-05      0.1164970 0.187 0.110 1.0000000 0.0011801264
# ANKRD12        2.891411e-04     -0.1482339 0.456 0.568 1.0000000 0.0036865492
# INTS6L         4.060072e-04     -0.1127478 0.357 0.475 1.0000000 0.0041412737
# EEF1AKMT4-ECE2 6.601838e-04     -0.1001085 0.230 0.339 1.0000000 0.0049977358
# RPS29          6.859637e-04      0.1080969 0.479 0.406 1.0000000 0.0049977358
#                           ensg
# NPHP3          ENSG00000113971
# ARHGEF12       ENSG00000196914
# ANKRD12        ENSG00000101745
# INTS6L         ENSG00000165359
# EEF1AKMT4-ECE2 ENSG00000284917
# RPS29          ENSG00000213741
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/0_regress_vs_0_expand_cluster_0_DE.tsv"
# [1] "Myclass"
# [1] 254   7
# [1] 243   7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#              pvalue log2FoldChange pct.1 pct.2   padj_bonf         padj
# TNS4   2.582586e-07      0.1531943 0.403 0.190 0.005055411 3.279884e-05
# NPHP3  3.841336e-06      0.1376940 0.397 0.207 0.075194159 2.862311e-04
# TSEN54 7.569778e-06      0.1057618 0.336 0.164 0.148178409 2.980397e-04
# RANBP2 1.944413e-05      0.1137990 0.346 0.177 0.380618793 6.173510e-04
# ZHX2   4.182312e-05      0.1977689 0.736 0.551 0.818687570 1.180341e-03
# ZBTB45 8.187307e-05      0.1115000 0.397 0.223 1.000000000 2.079576e-03
#                   ensg
# TNS4   ENSG00000131746
# NPHP3  ENSG00000113971
# TSEN54 ENSG00000182173
# RANBP2 ENSG00000153201
# ZHX2   ENSG00000178764
# ZBTB45 ENSG00000119574
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.41% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.41% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.41% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.41% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/0_regress_vs_0_no_change_cluster_0_DE.tsv"
# [1] "Myclass"
# [1] 39  7
# [1] 37  7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#               pvalue log2FoldChange pct.1 pct.2 padj_bonf       padj
# ZFYVE1  2.940231e-05      0.1047936 0.349 0.230 0.5755502 0.00114669
# STK40   8.602932e-04      0.1156610 0.634 0.520 1.0000000 0.01513462
# CCDC88C 1.217751e-03      0.1184004 0.820 0.751 1.0000000 0.01513462
# SRFBP1  1.603011e-03     -0.1090771 0.169 0.248 1.0000000 0.01513462
# FBXL4   1.940336e-03     -0.1135702 0.190 0.270 1.0000000 0.01513462
# DPP4    3.800757e-03     -0.1179961 0.437 0.516 1.0000000 0.02470492
#                    ensg
# ZFYVE1  ENSG00000165861
# STK40   ENSG00000196182
# CCDC88C ENSG00000015133
# SRFBP1  ENSG00000151304
# FBXL4   ENSG00000112234
# DPP4    ENSG00000197635
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/1_expand_vs_1_regress_cluster_1_DE.tsv"
# [1] "Myclass"
# [1] 1214    7
# [1] 1023    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#             pvalue log2FoldChange pct.1 pct.2  padj_bonf        padj
# TTF2  3.546618e-06     -0.2824055 0.236 0.442 0.06942504 0.001276589
# APBB1 2.163189e-05     -0.2615362 0.182 0.346 0.42344423 0.004512726
# NAA35 3.595024e-05     -0.1755568 0.186 0.358 0.70372590 0.005277525
# SMIM4 3.861944e-05     -0.1847557 0.157 0.312 0.75597548 0.005277525
# ITPR1 3.912498e-05     -0.2516346 0.456 0.642 0.76587151 0.005277525
# RGS10 4.859566e-05     -0.2479798 0.217 0.383 0.95126014 0.005899514
#                  ensg
# TTF2  ENSG00000116830
# APBB1 ENSG00000166313
# NAA35 ENSG00000135040
# SMIM4 ENSG00000168273
# ITPR1 ENSG00000150995
# RGS10 ENSG00000148908
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.39% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.39% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.39% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.39% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/1_no_change_vs_1_expand_cluster_1_DE.tsv"
# [1] "Myclass"
# [1] 546   7
# [1] 490   7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#               pvalue log2FoldChange pct.1 pct.2 padj_bonf       padj
# APEH    2.597942e-05      0.1708482 0.241 0.129 0.5085472 0.01418476
# KIF5C   5.607606e-05      0.1325371 0.275 0.157 1.0000000 0.01530877
# EIF2AK3 2.554707e-04      0.1721919 0.351 0.236 1.0000000 0.02289358
# CREM    3.225131e-04      0.2040457 0.507 0.390 1.0000000 0.02289358
# AIP     3.290710e-04      0.1318100 0.202 0.113 1.0000000 0.02289358
# HK1     3.354371e-04      0.1817705 0.311 0.204 1.0000000 0.02289358
#                    ensg
# APEH    ENSG00000164062
# KIF5C   ENSG00000168280
# EIF2AK3 ENSG00000172071
# CREM    ENSG00000095794
# AIP     ENSG00000110711
# HK1     ENSG00000156515
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/1_no_change_vs_1_regress_cluster_1_DE.tsv"
# [1] "Myclass"
# [1] 548   7
# [1] 501   7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#                pvalue log2FoldChange pct.1 pct.2  padj_bonf         padj
# HIST1H3J 1.547341e-06     -0.1764127 0.178 0.317 0.03028919 0.0004239713
# KIAA1524 4.401333e-06     -0.1251298 0.179 0.317 0.08615610 0.0006621021
# TXK      6.298142e-06     -0.1510079 0.162 0.292 0.12328613 0.0006621021
# ING5     7.511489e-06     -0.1821331 0.272 0.425 0.14703739 0.0006621021
# NAA35    8.384224e-06     -0.1522602 0.210 0.358 0.16412118 0.0006621021
# SMIM4    9.161323e-06     -0.1586724 0.180 0.312 0.17933289 0.0006621021
#                     ensg
# HIST1H3J            <NA>
# KIAA1524            <NA>
# TXK      ENSG00000074966
# ING5     ENSG00000168395
# NAA35    ENSG00000135040
# SMIM4    ENSG00000168273
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/10_no_change_vs_10_expand_cluster_10_DE.tsv"
# [1] "Myclass"
# [1] 2275    7
# [1] 1760    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#                pvalue log2FoldChange pct.1 pct.2 padj_bonf      padj
# SYNE2    0.0001814174      0.2622883 0.400 0.194         1 0.1031812
# DNPEP    0.0003340216      0.2852664 0.366 0.185         1 0.1089287
# ZFYVE28  0.0006911937      0.2190786 0.299 0.130         1 0.1089287
# ATP6V0D2 0.0008186186     -0.2740788 0.192 0.333         1 0.1089287
# LYN      0.0009678118     -0.2788252 0.175 0.315         1 0.1089287
# SNX13    0.0010529701      0.2325670 0.310 0.148         1 0.1089287
#                     ensg
# SYNE2    ENSG00000054654
# DNPEP    ENSG00000123992
# ZFYVE28  ENSG00000159733
# ATP6V0D2 ENSG00000147614
# LYN      ENSG00000254087
# SNX13    ENSG00000071189
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.06% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.06% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.06% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.06% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/10_no_change_vs_10_regress_cluster_10_DE.tsv"
# [1] "Myclass"
# [1] 3370    7
# [1] 2477    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#             pvalue log2FoldChange pct.1 pct.2 padj_bonf      padj
# GFRAL 0.0003137584     -0.2911248 0.155 0.351         1 0.1120227
# MGLL  0.0005965857     -0.4748391 0.118 0.281         1 0.1546534
# MDFIC 0.0008747328      0.4683252 0.462 0.246         1 0.1997096
# CDH23 0.0009481762      0.4886459 0.510 0.263         1 0.1997096
# ETS1  0.0013112825      0.3619180 0.572 0.351         1 0.2325801
# DOK5  0.0015644096     -0.2471637 0.113 0.263         1 0.2391320
#                  ensg
# GFRAL ENSG00000187871
# MGLL  ENSG00000074416
# MDFIC ENSG00000135272
# CDH23 ENSG00000107736
# ETS1  ENSG00000134954
# DOK5  ENSG00000101134
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.08% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.08% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.08% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.08% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/10_regress_vs_10_expand_cluster_10_DE.tsv"
# [1] "Myclass"
# [1] 4246    7
# [1] 2723    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#                pvalue log2FoldChange pct.1 pct.2 padj_bonf      padj
# NDUFA2   0.0005689781      0.3689989 0.333 0.120         1 0.1783912
# TMEM8B   0.0009239678      0.4234337 0.351 0.139         1 0.1854595
# SETD3    0.0010423022      0.4299212 0.316 0.111         1 0.1854595
# NIPA2    0.0010671486      0.4134349 0.333 0.120         1 0.1854595
# FAM160A2 0.0011590002     -0.4678272 0.140 0.370         1 0.1854595
# SERTAD2  0.0013316399      0.2938444 0.632 0.333         1 0.1854595
#                     ensg
# NDUFA2   ENSG00000131495
# TMEM8B   ENSG00000137103
# SETD3    ENSG00000183576
# NIPA2    ENSG00000140157
# FAM160A2            <NA>
# SERTAD2  ENSG00000179833
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.18% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.18% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.18% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.18% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/11_expand_vs_11_regress_cluster_11_DE.tsv"
# [1] "Myclass"
# [1] 2632    7
# [1] 2366    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#                pvalue log2FoldChange pct.1 pct.2 padj_bonf        padj
# DFNB31   1.580961e-06     -0.3969014 0.125 0.465 0.0309473 0.004161088
# AK7      5.211060e-05     -0.3009493 0.216 0.521 1.0000000 0.068577551
# BAP1     1.145262e-04     -0.2660990 0.170 0.451 1.0000000 0.100477686
# KIZ      2.369185e-04     -0.2882821 0.170 0.437 1.0000000 0.129194491
# MBOAT4   2.859257e-04      0.3414530 0.409 0.169 1.0000000 0.129194491
# ARHGAP31 3.436024e-04     -0.3342230 0.273 0.563 1.0000000 0.129194491
#                     ensg
# DFNB31              <NA>
# AK7      ENSG00000140057
# BAP1     ENSG00000163930
# KIZ      ENSG00000088970
# MBOAT4   ENSG00000177669
# ARHGAP31 ENSG00000031081
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.17% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.17% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.17% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.17% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/11_no_change_vs_11_expand_cluster_11_DE.tsv"
# [1] "Myclass"
# [1] 1636    7
# [1] 1544    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#                pvalue log2FoldChange pct.1 pct.2 padj_bonf      padj
# DPP4     0.0002787930     -0.3321227 0.251 0.455         1 0.1479229
# NSUN6    0.0004368234      0.2311816 0.559 0.341         1 0.1479229
# ASF1B    0.0005224768     -0.2832180 0.437 0.614         1 0.1479229
# SLC25A28 0.0006337742      0.2685536 0.607 0.420         1 0.1479229
# TBL3     0.0007352280     -0.2127154 0.154 0.307         1 0.1479229
# EDARADD  0.0012685253      0.1604761 0.287 0.114         1 0.1479229
#                     ensg
# DPP4     ENSG00000197635
# NSUN6    ENSG00000241058
# ASF1B    ENSG00000105011
# SLC25A28 ENSG00000155287
# TBL3     ENSG00000183751
# EDARADD  ENSG00000186197
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.13% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.13% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.13% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.13% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/11_no_change_vs_11_regress_cluster_11_DE.tsv"
# [1] "Myclass"
# [1] 1631    7
# [1] 1543    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#                    pvalue log2FoldChange pct.1 pct.2  padj_bonf        padj
# DFNB31       1.143386e-06     -0.3213176 0.194 0.465 0.02238178 0.001047483
# VPS9D1       3.882901e-05     -0.2695916 0.239 0.479 0.76007789 0.020424614
# CEP250       6.261378e-05     -0.2224630 0.231 0.479 1.00000000 0.020424614
# NUDT16L1     1.075644e-04     -0.2031721 0.182 0.394 1.00000000 0.026943241
# BORCS8-MEF2B 1.227033e-04     -0.1727699 0.263 0.507 1.00000000 0.026943241
# ZBTB8OS      1.321557e-04     -0.2318291 0.381 0.606 1.00000000 0.026943241
#                         ensg
# DFNB31                  <NA>
# VPS9D1       ENSG00000075399
# CEP250       ENSG00000126001
# NUDT16L1     ENSG00000168101
# BORCS8-MEF2B ENSG00000213999
# ZBTB8OS      ENSG00000176261
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.26% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.26% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.26% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.26% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/12_no_change_vs_12_expand_cluster_12_DE.tsv"
# [1] "Myclass"
# [1] 3882    7
# [1] 2784    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#              pvalue log2FoldChange pct.1 pct.2 padj_bonf      padj
# MBNL3  0.0001814614     -0.3378922 0.254 0.548         1 0.1888025
# LRRC31 0.0002919813     -0.2999438 0.148 0.405         1 0.1888025
# WDR48  0.0003454478     -0.3820458 0.162 0.405         1 0.1888025
# KLHL28 0.0006049637      0.3128589 0.486 0.143         1 0.2047563
# KHSRP  0.0008799094     -0.3958693 0.254 0.476         1 0.2277206
# MFSD2B 0.0010651180     -0.3422885 0.190 0.429         1 0.2584242
#                   ensg
# MBNL3  ENSG00000076770
# LRRC31 ENSG00000114248
# WDR48  ENSG00000114742
# KLHL28 ENSG00000179454
# KHSRP  ENSG00000088247
# MFSD2B ENSG00000205639
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.43% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.43% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.43% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.43% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/12_no_change_vs_12_regress_cluster_12_DE.tsv"
# [1] "Myclass"
# [1] 4193    7
# [1] 2936    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#              pvalue log2FoldChange pct.1 pct.2 padj_bonf       padj
# GATB   9.062468e-06     -0.4060367 0.218 0.613 0.1773978 0.03417334
# MEGF11 1.510209e-04     -0.3651534 0.197 0.516 1.0000000 0.09624897
# DGKG   5.377414e-04     -0.5160384 0.542 0.839 1.0000000 0.16105356
# PLSCR2 6.465551e-04     -0.3217540 0.162 0.452 1.0000000 0.16487409
# BLVRB  7.359423e-04     -0.2758478 0.155 0.419 1.0000000 0.16487409
# DHRSX  7.796654e-04     -0.3736797 0.239 0.581 1.0000000 0.16487409
#                   ensg
# GATB   ENSG00000059691
# MEGF11 ENSG00000157890
# DGKG   ENSG00000058866
# PLSCR2 ENSG00000163746
# BLVRB  ENSG00000090013
# DHRSX  ENSG00000169084
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.48% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.48% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.48% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.48% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/12_regress_vs_12_expand_cluster_12_DE.tsv"
# [1] "Myclass"
# [1] 5361    7
# ...
# “There are ties in the preranked stats (0.21% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.21% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.21% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.21% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/8_regress_vs_8_expand_cluster_8_DE.tsv"
# [1] "Myclass"
# [1] 702   7
# [1] 689   7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#               pvalue log2FoldChange pct.1 pct.2   padj_bonf         padj
# FDFT1   4.462848e-07      0.2855082 0.515 0.244 0.008736025 0.0003132919
# FAM105A 4.026829e-06      0.2348923 0.435 0.189 0.078825186 0.0014134171
# MAFF    4.516319e-05      0.1547380 0.335 0.126 0.884069508 0.0105681872
# CMTM8   1.515458e-04      0.1550350 0.388 0.189 1.000000000 0.0229711621
# ZNF276  2.427793e-04      0.1788036 0.531 0.299 1.000000000 0.0229711621
# KDM4A   2.992433e-04      0.1639164 0.462 0.252 1.000000000 0.0229711621
#                    ensg
# FDFT1   ENSG00000079459
# FAM105A            <NA>
# MAFF    ENSG00000185022
# CMTM8   ENSG00000170293
# ZNF276  ENSG00000158805
# KDM4A   ENSG00000066135
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/8_regress_vs_8_no_change_cluster_8_DE.tsv"
# [1] "Myclass"
# [1] 56  7
# [1] 54  7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#                   pvalue log2FoldChange pct.1 pct.2 padj_bonf         padj
# PYCRL       6.570061e-06      0.1148935 0.385 0.234 0.1286090 0.0003679234
# ZNF37A      1.896980e-05      0.1083963 0.354 0.219 0.3713338 0.0005311544
# PALM2-AKAP2 6.586411e-05      0.1144530 0.450 0.297 1.0000000 0.0011841087
# CLDN12      8.457920e-05      0.1036481 0.412 0.263 1.0000000 0.0011841087
# UBE4B       1.582696e-04      0.1163936 0.400 0.272 1.0000000 0.0015727336
# ITPKB       1.897275e-04      0.1576912 0.904 0.853 1.0000000 0.0015727336
#                        ensg
# PYCRL                  <NA>
# ZNF37A      ENSG00000075407
# PALM2-AKAP2            <NA>
# CLDN12      ENSG00000157224
# UBE4B       ENSG00000130939
# ITPKB       ENSG00000143772
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/9_no_change_vs_9_expand_cluster_9_DE.tsv"
# [1] "Myclass"
# [1] 561   7
# [1] 519   7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#              pvalue log2FoldChange pct.1 pct.2 padj_bonf        padj
# SKP2   1.161531e-05      0.1727885 0.277 0.129 0.2273696 0.006516187
# LMBRD2 3.561997e-05      0.1380119 0.275 0.133 0.6972609 0.008083405
# KRI1   6.604659e-05      0.1550859 0.267 0.137 1.0000000 0.008083405
# MAEA   7.204461e-05      0.2027157 0.435 0.281 1.0000000 0.008083405
# FBXL3  1.202930e-04      0.1672602 0.311 0.177 1.0000000 0.008363521
# ATP8B2 1.682689e-04      0.1400599 0.295 0.165 1.0000000 0.008363521
#                   ensg
# SKP2   ENSG00000145604
# LMBRD2 ENSG00000164187
# KRI1   ENSG00000129347
# MAEA   ENSG00000090316
# FBXL3  ENSG00000005812
# ATP8B2 ENSG00000143515
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/9_regress_vs_9_expand_cluster_9_DE.tsv"
# [1] "Myclass"
# [1] 1157    7
# [1] 1050    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#                      pvalue log2FoldChange pct.1 pct.2  padj_bonf         padj
# ATP8B2         2.319629e-06      0.2309398 0.379 0.165 0.04540674 0.0005010705
# DIS3           2.598464e-06      0.2078044 0.411 0.189 0.05086494 0.0005010705
# DAZAP1         3.231756e-06      0.1672759 0.332 0.133 0.06326162 0.0005341630
# C2orf15        6.157362e-06      0.1646726 0.353 0.145 0.12053037 0.0008304663
# TMEM256-PLSCR3 6.459980e-06      0.1712964 0.389 0.173 0.12645410 0.0008304663
# TMEM187        9.965773e-06      0.2499631 0.426 0.217 0.19508001 0.0010759326
#                           ensg
# ATP8B2         ENSG00000143515
# DIS3           ENSG00000083520
# DAZAP1         ENSG00000071626
# C2orf15        ENSG00000273045
# TMEM256-PLSCR3            <NA>
# TMEM187        ENSG00000177854
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in selectChildren(jobs, timeout):
# “error 'No child processes' in select”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb/prep/9_regress_vs_9_no_change_cluster_9_DE.tsv"
# [1] "Myclass"
# [1] 511   7
# [1] 498   7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#              pvalue log2FoldChange pct.1 pct.2  padj_bonf        padj
# NDEL1  3.613295e-06      0.1626587 0.368 0.191 0.07073026 0.000923197
# TMEM52 8.046755e-05      0.1003936 0.337 0.186 1.00000000 0.005601853
# ANP32E 8.253606e-05      0.1607819 0.453 0.283 1.00000000 0.005601853
# ITSN1  9.258599e-05      0.2030581 0.632 0.440 1.00000000 0.005601853
# DNMT1  1.001294e-04      0.1242866 0.337 0.191 1.00000000 0.005601853
# NBEAL2 1.027687e-04      0.1619477 0.405 0.254 1.00000000 0.005601853
#                   ensg
# NDEL1  ENSG00000166579
# TMEM52 ENSG00000178821
# ANP32E ENSG00000143401
# ITSN1  ENSG00000205726
# DNMT1  ENSG00000130816
# NBEAL2 ENSG00000160796
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"

# %%
# require(DOSE)
# dotplot(gse, showCategory=10, split=".sign") + facet_grid(.~.sign)

# %%
export.path
# Out:
# [1] "/data/Mito_Trace/output/pipeline/TcellDupi_may17_2021/MTblacklist/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_hg38_1_2/clones_change/filt_fisher__shuffle_False__padj_True__pthresh_0.01_minC_1__bothMinC__0/de/btwnChange_inClust/minPct_0.01__logfc0.1_pthresh_0.01/allDonors/GSEA_pthresh.0.1_pref.FALSE_stat.log2FoldChange_padj.BH/GSEA.ipynb"

# %%
sessionInfo()
# Out:
# R version 4.1.1 (2021-08-10)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.4 LTS
#
# Matrix products: default
# BLAS/LAPACK: /home/isaac/miniconda3/envs/mttrace/lib/libopenblasp-r0.3.18.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats4    stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] stringr_1.4.0         ggplot2_3.3.5         dplyr_1.0.8
#  [4] openxlsx_4.2.4        data.table_1.14.2     gdata_2.18.0
#  [7] DOSE_3.20.1           org.Hs.eg.db_3.14.0   biomaRt_2.50.0
# [10] GSEABase_1.56.0       graph_1.72.0          annotate_1.72.0
# [13] XML_3.99-0.8          AnnotationDbi_1.56.1  IRanges_2.28.0
# [16] S4Vectors_0.32.0      Biobase_2.54.0        BiocGenerics_0.40.0
# [19] clusterProfiler_4.2.2
#
# loaded via a namespace (and not attached):
#   [1] fgsea_1.20.0           colorspace_2.0-2       ggtree_3.2.1
#   [4] ellipsis_0.3.2         IRdisplay_1.0          qvalue_2.26.0
#   [7] XVector_0.34.0         base64enc_0.1-3        aplot_0.1.2
#  [10] farver_2.1.0           graphlayouts_0.8.0     ggrepel_0.9.1
#  [13] bit64_4.0.5            fansi_1.0.2            scatterpie_0.1.7
#  [16] xml2_1.3.2             splines_4.1.1          cachem_1.0.6
#  [19] GOSemSim_2.20.0        polyclip_1.10-0        IRkernel_1.2
#  [22] jsonlite_1.7.3         dbplyr_2.1.1           GO.db_3.14.0
#  [25] png_0.1-7              ggforce_0.3.3          BiocManager_1.30.16
#  [28] compiler_4.1.1         httr_1.4.2             assertthat_0.2.1
#  [31] Matrix_1.3-4           fastmap_1.1.0          lazyeval_0.2.2
#  [34] cli_3.2.0              tweenr_1.0.2           prettyunits_1.1.1
#  [37] htmltools_0.5.2        tools_4.1.1            igraph_1.2.11
#  [40] gtable_0.3.0           glue_1.6.1             GenomeInfoDbData_1.2.7
#  [43] reshape2_1.4.4         DO.db_2.9              rappdirs_0.3.3
#  [46] fastmatch_1.1-3        Rcpp_1.0.8             enrichplot_1.14.1
#  [49] vctrs_0.3.8            Biostrings_2.62.0      ape_5.6-1
#  [52] nlme_3.1-153           ggraph_2.0.5           lifecycle_1.0.1
#  [55] gtools_3.9.2           zlibbioc_1.40.0        MASS_7.3-54
#  [58] scales_1.1.1           tidygraph_1.2.0        hms_1.1.1
#  [61] parallel_4.1.1         RColorBrewer_1.1-2     curl_4.3.2
#  [64] memoise_2.0.1          gridExtra_2.3          downloader_0.4
#  [67] ggfun_0.0.5            yulab.utils_0.0.4      stringi_1.7.6
#  [70] RSQLite_2.2.8          tidytree_0.3.7         filelock_1.0.2
#  [73] zip_2.2.0              BiocParallel_1.28.0    repr_1.1.3
#  [76] GenomeInfoDb_1.30.0    rlang_1.0.1            pkgconfig_2.0.3
#  [79] bitops_1.0-7           evaluate_0.14          lattice_0.20-45
#  [82] purrr_0.3.4            labeling_0.4.2         treeio_1.18.1
#  [85] patchwork_1.1.1        shadowtext_0.1.1       bit_4.0.4
#  [88] tidyselect_1.1.1       plyr_1.8.6             magrittr_2.0.2
#  [91] R6_2.5.1               generics_0.1.2         pbdZMQ_0.3-6
#  [94] DBI_1.1.1              withr_2.4.3            pillar_1.7.0
#  [97] KEGGREST_1.34.0        RCurl_1.98-1.5         tibble_3.1.6
# [100] crayon_1.5.0           uuid_1.0-3             utf8_1.2.2
# [103] BiocFileCache_2.2.0    progress_1.2.2         viridis_0.6.2
# [106] grid_4.1.1             blob_1.2.2             digest_0.6.29
# [109] xtable_1.8-4           tidyr_1.2.0            gridGraphics_0.5-1
# [112] munsell_0.5.0          viridisLite_0.4.0      ggplotify_0.1.0

# %% [markdown]
# ###
