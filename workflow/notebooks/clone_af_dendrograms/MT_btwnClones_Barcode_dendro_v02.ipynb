# %%
pwd
# Out:
# '/mnt/md0/isshamie/Projects/Mito_Trace/workflow/notebooks/clone_af_dendrograms'

# %%
# INDIR = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/"
# OUTDIR = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/barcodes/btwnClones_dendro_dt_0.6/"
# DONOR = 0
# dendroThresh=0.6

#clones_meta = '/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/results/clones_summary/feb23_2022/clones_summary.csv'
#clones_indir = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/"
#clone_sizes_in_f = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/gff_A2_black/annotation_clones/clone_counts/minCellConds_1/clone_sizes.csv"
# INDIR = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2//data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_30/"
# OUTDIR = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro_dt_dynamic"
# DONOR = 0

INDIR = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30"
OUTDIR = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/barcodes/btwnClones_dendro_dt_dynamic_v02"
DONOR = 0

dendroThresh = "dynamic"

# INDIR = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_30"
# OUTDIR = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_30/barcodes/btwnClones_dendro_dt_0.6"
# DONOR = 1
#dendroThresh = "dynamic" #0.6

verbose=False

mt_ref="/data/Mito_Trace/data/processed/genomes/mtMasked/GRCh38_MT_blacklist_A2_2020/chrM.fasta"

# %%
import src.utils.variant_utils as vu
import src.utils.dendro_clust as dc

import mplh.cluster_help as ch
import mplh.fig_utils as fu

from os.path import join, exists, dirname
from glob import glob
import pickle
import os
import vireoSNP
import numpy as np
from scipy import sparse
from scipy.io import mmread
import matplotlib.pyplot as plt
from scipy.stats import hypergeom
print(vireoSNP.__version__)
import pandas as pd
import seaborn as sns
from vireoSNP import Vireo
np.set_printoptions(formatter={'float': lambda x: format(x, '.5f')})
import scipy
from itertools import combinations
#from src.utils import utils  as ut
# Out:
# fig_utils from mplh
# 0.5.6

# %%
# %load_ext autoreload
# %autoreload 2

# %%
out_f = join(OUTDIR, f"donor{DONOR}")

# %% [markdown]
# ### Load cells_meta
# ### Create clones_meta - get number of cells in a clone and donor

# %%
cells_meta = pd.read_csv(join(INDIR, "cells_meta.tsv"), sep="\t")
cells_meta["lineage"] = cells_meta.apply(lambda x: f'{x["donor"]}_{x["lineage"]}', axis=1)
cells_meta
# Out:
#                             ID lineage  donor condition
# 0     AAACTGCAGACTTCCA-1_Input     0_0      0     Input
# 1     AAACTGCTCCAACGCG-1_Input     0_0      0     Input
# 2     AAAGGATCAGATAAGT-1_Input     0_0      0     Input
# 3     AAAGGATTCCTGACCT-1_Input     0_0      0     Input
# 4     AAAGGGCTCGTTACAG-1_Input     0_0      0     Input
# ...                        ...     ...    ...       ...
# 6604  TAGGTGTGTACGTAAA-1_Input    1_25      1     Input
# 6605  TCCCACAGTTCAGAAA-1_Input    1_25      1     Input
# 6606  TCTCAGCCAGCAATGG-1_Input    1_25      1     Input
# 6607  TGGGTGCAGCGCCTAC-1_Input    1_25      1     Input
# 6608  TTACGGACAAGGGAGG-1_Flt3l    1_25      1     Flt3l
#
# [6609 rows x 4 columns]

# %%
clones_meta_df = pd.DataFrame(cells_meta.groupby("lineage").size(), columns=["size"]) #, index=["size"])
clones_meta_df["donor"] = [x.split("_")[0] for x in clones_meta_df.index]
clones_meta_df["donor"] = clones_meta_df["donor"].astype(int)
clones_meta_df
# Out:
#          size  donor
# lineage
# 0_0       447      0
# 0_1       279      0
# 0_10      106      0
# 0_11      105      0
# 0_12      104      0
# ...       ...    ...
# 1_5       165      1
# 1_6       159      1
# 1_7       142      1
# 1_8       138      1
# 1_9       128      1
#
# [62 rows x 2 columns]

# %%
curr_clones = clones_meta_df[clones_meta_df["donor"]==DONOR]
# cells_meta = pd.read_csv(join(INDIR, "cells_meta.tsv"), sep='\t')#.sort_values(["donor", "lineage"])
curr_labels = cells_meta[cells_meta["donor"]==DONOR]

# %%
# curr_clones = clones_meta_df[clones_meta_df["donor"]==DONOR].set_index("lineage")
# curr_clones

# %% [markdown]
# ## Load AF and DP

# %%
af_indir = join(INDIR, "sc_af", f"donor{DONOR}")
AF_df = pd.read_csv(join(af_indir, "af.tsv"), index_col=0, sep="\t")
DP_df = pd.read_csv(join(af_indir, "dp.tsv"), index_col=0, sep="\t")

# %% [markdown]
# ### Functions to get mean and median

# %%
def calc_mean(cells, af, min_cov=2):
    #print(cells.head())
    return af.loc[:,cells["ID"].values].mean(axis=1)

def calc_median(cells, af):
    #print(cells.head())
    return af.loc[:,cells["ID"].values].median(axis=1)


def calc_mean_with_coverage(cells, af, cov, min_cov=200):
    keep_inds = cov.loc[:, cells["ID"].values]
    print(keep_inds.head())
    keep_inds = keep_inds[keep_inds >= min_cov].columns
    
    print('keep_inds', len(cells["ID"].values)- len(keep_inds))
    return af.loc[:,keep_inds].mean(axis=1)

# %% [markdown]
# ### Calculate clone-barcode mean

# %%
mean_af = curr_labels.groupby(["lineage"]).apply(calc_mean, af=AF_df)

mean_nocov_af = curr_labels.groupby(["lineage"]).apply(calc_mean_with_coverage, af=AF_df, cov=DP_df)
# Out:
#          AAACTGCAGACTTCCA-1_Input  AAACTGCTCCAACGCG-1_Input  \
# Variant
# 146A                           35                        78
# 709A                           33                       111
# 930A                           51                       164
# 1413A                          62                       172
# 1888A                          37                       135
#
#          AAAGGATCAGATAAGT-1_Input  AAAGGATTCCTGACCT-1_Input  \
# Variant
# 146A                           81                        60
# 709A                          147                       107
# 930A                          197                       115
# 1413A                         183                       141
# 1888A                         184                       132
#
#          AAAGGGCTCGTTACAG-1_Input  AAATGAGGTTGTGAGG-1_Input  \
# Variant
# 146A                           72                        77
# 709A                          202                       152
# 930A                          227                       122
# 1413A                         198                        93
# 1888A                         208                       142
#
#          AAATGCCTCTAGTCGA-1_Input  AACAAAGGTCGTAATC-1_Input  \
# Variant
# 146A                           30                        21
# 709A                           33                        57
# 930A                           29                        84
# 1413A                          45                       144
# 1888A                          35                       139
#
#          AACAAAGGTCGTCGCA-1_Input  AACAAAGTCGTCTAGA-1_Input  ...  \
# Variant                                                      ...
# 146A                           42                        61  ...
# 709A                          119                       211  ...
# 930A                          100                       133  ...
# 1413A                         168                       148  ...
# 1888A                         125                       178  ...
#
#          TTGTCTATCTGACTTT-1_Input  TTGTTCAAGTAGGTCG-1_Input  \
# Variant
# 146A                           29                        39
# 709A                           40                        66
# 930A                           52                        71
# 1413A                          83                        64
# 1888A                          91                        89
#
#          TTGTTGTCATGGCCGT-1_Input  TTTGGCCAGGTTCGTT-1_Input  \
# Variant
# 146A                           22                        48
# 709A                           51                       151
# 930A                           62                       171
# 1413A                          52                       179
# 1888A                          89                       146
#
#          TTTGGCCGTAAGTCTC-1_Input  TTTGGCCTCCGGCTGA-1_Input  \
# Variant
# 146A                           49                        45
# 709A                           84                        81
# 930A                           75                        53
# 1413A                          84                        86
# 1888A                          65                        35
#
#          TTTGGTTAGCCAGAAC-1_Input  TTTGGTTTCATCATGG-1_Input  \
# Variant
# 146A                           88                        40
# 709A                           91                        78
# 930A                           77                        73
# 1413A                          66                       136
# 1888A                         116                       110
#
#          TTTGGTTTCGAGGTCC-1_Input  TTTGTGTGTAGATTAG-1_Input
# Variant
# 146A                           58                        22
# 709A                          109                        47
# 930A                           93                        34
# 1413A                         135                        26
# 1888A                          94                        50
#
# [5 rows x 447 columns]
# keep_inds 0
#          AAAGATGGTAGATGAT-1_Input  AAAGATGTCATCATGG-1_Input  \
# Variant
# 146A                           39                        55
# 709A                          111                       135
# 930A                           69                        82
# 1413A                         140                       170
# 1888A                          88                       123
#
#          AAAGGATAGCTGAGGT-1_Input  AAAGGATAGTCCTTCC-1_Input  \
# Variant
# 146A                           63                        12
# 709A                          130                        26
# 930A                          125                        36
# 1413A                         193                        29
# 1888A                         111                        39
#
#          AAAGGATAGTTCTCCC-1_Input  AAAGGATGTGGTAGAC-1_Input  \
# Variant
# 146A                           41                        82
# 709A                          101                        68
# 930A                           86                       100
# 1413A                          98                        95
# 1888A                          60                       137
#
#          AAAGGGCCAATCATCG-1_Input  AAAGGGCTCTCGACCT-1_Input  \
# Variant
# 146A                           66                        20
# 709A                          109                        38
# 930A                          151                        32
# 1413A                         195                        39
# 1888A                         128                        57
#
#          AACAAAGGTGCGACCT-1_Flt3l  AACAAAGTCTGGTACA-1_Input  ...  \
# Variant                                                      ...
# 146A                           14                        33  ...
# 709A                           39                        45  ...
# 930A                           24                        33  ...
# 1413A                          49                        45  ...
# 1888A                          27                        24  ...
#
#          TTCTGTAAGCCTTTGA-1_Input  TTGAGCAGTACGTAAA-1_Input  \
# Variant
# 146A                           53                        37
# 709A                           87                        97
# 930A                           75                       111
# 1413A                          85                       112
# 1888A                          40                       135
#
#          TTGAGTGCAGCGTACC-1_Input  TTGAGTGCAGGACCTC-1_Input  \
# Variant
# 146A                           23                        38
# 709A                           64                       115
# 930A                           57                       109
# 1413A                          84                       120
# 1888A                          68                        87
#
#          TTGCAGACATCCCAAA-1_Flt3l  TTGCGGGTCGCAAGCC-1_Input  \
# Variant
# 146A                           19                        25
# 709A                           35                        25
# 930A                           23                        60
# 1413A                          24                        59
# 1888A                          36                        49
#
#          TTGCTATGTTTCCGGG-1_Input  TTGTCTAGTTAGAGAT-1_Input  \
# Variant
# 146A                           11                        32
# 709A                           37                       125
# 930A                           46                        79
# 1413A                          60                       106
# 1888A                          36                        80
#
#          TTGTTCACAACGAGGT-1_Input  TTTGTGTGTTTCTTAC-1_Input
# Variant
# 146A                           56                        66
# 709A                           91                        99
# 930A                           70                        67
# 1413A                         107                       107
# 1888A                         107                        89
#
# [5 rows x 279 columns]
# keep_inds 0
#          AAACTGCGTGTGAGGT-1_Input  AAATGAGAGAGAGTAG-1_Input  \
# Variant
# 146A                           73                        69
# 709A                          150                       201
# 930A                          183                       166
# 1413A                         167                       207
# 1888A                         124                       172
#
#          AACCTGACATGCGACC-1_Input  AACTTGGCACCTGAAT-1_Input  \
# Variant
# 146A                           41                        45
# 709A                           75                       137
# 930A                           86                        85
# 1413A                         112                        99
# 1888A                         113                       106
#
#          AATGTCGTCGATAGGG-1_Input  ACAAAGATCTGGACAT-1_Input  \
# Variant
# 146A                           35                        61
# 709A                          114                       105
# 930A                           92                       105
# 1413A                         114                       149
# 1888A                          54                       155
#
#          ACAAGCTCAGGCACAA-1_Input  ACAAGCTTCCAGGTAT-1_Flt3l  \
# Variant
# 146A                           48                        19
# 709A                          192                        35
# 930A                          105                        34
# 1413A                         181                        28
# 1888A                         169                        51
#
#          ACAGAAAAGCTACGCC-1_Input  ACAGAAATCAGTGTGT-1_Input  ...  \
# Variant                                                      ...
# 146A                           32                       136  ...
# 709A                           78                       210  ...
# 930A                           88                       133  ...
# 1413A                          70                       228  ...
# 1888A                          69                       172  ...
#
#          TGTAGCAAGTACCCAT-1_Input  TTATGTCGTCCAGACC-1_Input  \
# Variant
# 146A                           57                        92
# 709A                           92                       127
# 930A                           65                       118
# 1413A                          74                       176
# 1888A                          77                       145
#
#          TTCATTGGTCCGGTAC-1_Input  TTCGGTCGTTGTATCG-1_Flt3l  \
# Variant
# 146A                           57                        22
# 709A                          172                        50
# 930A                          123                        21
# 1413A                         186                        37
# 1888A                         168                        32
#
#          TTCTAACGTCCTTCAC-1_Input  TTCTAACGTGCCCGAT-1_Input  \
# Variant
# 146A                           50                        71
# 709A                          137                        95
# 930A                          122                        93
# 1413A                         165                        93
# 1888A                         132                        93
#
#          TTGCTTAAGCTGAATA-1_Input  TTGGTCCAGTGCTAGG-1_Input  \
# Variant
# 146A                           47                        59
# 709A                           98                        82
# 930A                           45                        78
# 1413A                         102                       110
# 1888A                          78                        95
#
#          TTGTCTACATCAACTG-1_Input  TTTGCGCTCAGTTGAC-1_Input
# Variant
# 146A                           64                        61
# 709A                          153                       196
# 930A                          176                       157
# 1413A                         163                       162
# 1888A                         133                       140
#
# [5 rows x 106 columns]
# keep_inds 0
#          AAAGATGTCCGGCGAT-1_Input  AAATGCCTCACAGGGA-1_Input  \
# Variant
# 146A                          121                        30
# 709A                          188                        93
# 930A                          121                        65
# 1413A                         269                        48
# 1888A                         165                        69
#
#          AACAGTCCAAGGAACC-1_Input  AACCGATGTTGGCTAT-1_Input  \
# Variant
# 146A                           45                        38
# 709A                           96                        88
# 930A                           86                       128
# 1413A                          95                       103
# 1888A                          74                       105
#
#          AACCGATGTTTCTACT-1_Input  AACGGGAAGGATCCTT-1_Input  \
# Variant
# 146A                           24                        58
# 709A                           65                       107
# 930A                           57                       112
# 1413A                          55                        92
# 1888A                          69                       105
#
#          AACGTACTCGAGAAGC-1_Input  AATGGCTGTACGCCCA-1_Flt3l  \
# Variant
# 146A                           52                        22
# 709A                          125                        25
# 930A                           89                        35
# 1413A                         105                        29
# 1888A                          95                        38
#
#          ACAAAGAAGTGGTGTG-1_Input  ACAAGCTTCGCTATTT-1_Input  ...  \
# Variant                                                      ...
# 146A                           43                        58  ...
# 709A                           69                       105  ...
# 930A                           91                       143  ...
# 1413A                          81                       138  ...
# 1888A                          86                       107  ...
#
#          TTAACGGGTTTCGTTT-1_Input  TTACCGCAGTCTGTGT-1_Input  \
# Variant
# 146A                           40                        46
# 709A                          136                       136
# 930A                           88                       102
# 1413A                         138                       163
# 1888A                         122                       139
#
#          TTCGGTCTCACTACCC-1_Input  TTCTAACTCAAACCCA-1_Input  \
# Variant
# 146A                           45                        40
# 709A                          133                        44
# 930A                           95                        50
# 1413A                         223                        45
# 1888A                         134                        44
#
#          TTGAGCACACACATGT-1_Input  TTGAGTGGTATCAGCT-1_Input  \
# Variant
# 146A                           22                       134
# 709A                           87                       194
# 930A                           93                       171
# 1413A                         148                       189
# 1888A                         122                       250
#
#          TTGCAGAAGACACAAT-1_Input  TTTACGTTCCAACCTC-1_Input  \
# Variant
# 146A                           35                        77
# 709A                           82                        99
# 930A                           69                       127
# 1413A                          87                       125
# 1888A                          85                       142
#
#          TTTGAGGGTGCTGTCG-1_Input  TTTGGTTCAGGTGGTA-1_Flt3l
# Variant
# 146A                           25                        24
# 709A                           67                        47
# 930A                           39                        43
# 1413A                          63                        41
# 1888A                          47                        44
#
# [5 rows x 105 columns]
# keep_inds 0
#          AAACGAAGTACCAAGG-1_Input  AAATGCCCAGCGTAGA-1_Input  \
# Variant
# 146A                           63                        57
# 709A                          102                       117
# 930A                          103                        88
# 1413A                         130                       132
# 1888A                          51                       149
#
#          AACAGTCGTTCCGGCA-1_Input  AACCTGAGTTGGCTTA-1_Input  \
# Variant
# 146A                           67                        41
# 709A                          125                        59
# 930A                          119                        98
# 1413A                          97                        86
# 1888A                          90                        86
#
#          AACTGTGAGGCGTCCT-1_Input  AAGGAGCTCGTCGCAG-1_Input  \
# Variant
# 146A                           42                        63
# 709A                          116                       142
# 930A                           86                       121
# 1413A                          88                       148
# 1888A                          87                       144
#
#          AATGCCAGTGACAAGC-1_Input  ACATGCACACAGAAGC-1_Flt3l  \
# Variant
# 146A                           38                         9
# 709A                           95                        40
# 930A                          103                        28
# 1413A                          96                        37
# 1888A                          74                        37
#
#          ACGTTAGGTTTCCTAT-1_Input  AGATAGATCCACGGCA-1_Input  ...  \
# Variant                                                      ...
# 146A                           18                        48  ...
# 709A                           72                        99  ...
# 930A                           72                       132  ...
# 1413A                          81                       110  ...
# 1888A                          55                        81  ...
#
#          TGCTTCGTCTGGCCAG-1_Input  TGTGTCCGTCAAACAA-1_Input  \
# Variant
# 146A                           39                        34
# 709A                           90                        48
# 930A                           60                        52
# 1413A                          51                        53
# 1888A                          94                        72
#
#          TTACCCGTCTCATCCG-1_Input  TTACGTTTCCCTAAAG-1_Input  \
# Variant
# 146A                           18                        54
# 709A                           27                        81
# 930A                           31                        86
# 1413A                          36                        76
# 1888A                          48                        83
#
#          TTAGGTGCAGAACTTC-1_Input  TTCAACTCAAAGGTCG-1_Input  \
# Variant
# 146A                           71                        63
# 709A                          177                       177
# 930A                           98                       116
# 1413A                         128                       153
# 1888A                          73                       132
#
#          TTGCGGGTCGTTGTTT-1_Flt3l  TTGCTATAGGATATCA-1_Input  \
# Variant
# 146A                           21                        71
# 709A                           40                       171
# 930A                           32                       133
# 1413A                          50                       199
# 1888A                          47                       134
#
#          TTGCTATAGTGATATG-1_Input  TTGTTCATCCGTACGG-1_Input
# Variant
# 146A                           68                        68
# 709A                          141                        96
# 930A                          116                       110
# 1413A                         156                       116
# 1888A                         166                       129
#
# [5 rows x 104 columns]
# keep_inds 0
#          AAACTCGGTGAGGGTT-1_Input  AAACTGCAGTTACACC-1_Input  \
# Variant
# 146A                           34                        41
# 709A                          118                       134
# 930A                           77                        58
# 1413A                         143                       140
# 1888A                         103                        95
#
#          AAAGATGGTTACGAAA-1_Input  AAAGGGCAGACTTCCA-1_Flt3l  \
# Variant
# 146A                           88                        13
# 709A                          201                        34
# 930A                          117                        42
# 1413A                         215                        49
# 1888A                         134                        50
#
#          AACTTGGAGTCATACC-1_Input  AAGGTTCTCTGTGTGA-1_Input  \
# Variant
# 146A                          104                        45
# 709A                          174                        78
# 930A                          140                        79
# 1413A                         189                       122
# 1888A                         131                        62
#
#          ACAAGCTAGGTCTTTG-1_Input  ACAGAAACAATTGTGC-1_Input  \
# Variant
# 146A                           30                        52
# 709A                           82                       124
# 930A                           58                       159
# 1413A                          89                       159
# 1888A                          83                       114
#
#          ACAGCGCCATCCGTAA-1_Flt3l  ACCGAATGTGTGAGGT-1_Input  ...  \
# Variant                                                      ...
# 146A                           15                        32  ...
# 709A                           34                        75  ...
# 930A                           36                        74  ...
# 1413A                          32                       105  ...
# 1888A                          32                        39  ...
#
#          TGATTTCTCTTCCACG-1_Input  TGCTATTGTTCAGTAC-1_Input  \
# Variant
# 146A                           21                        35
# 709A                           91                        77
# 930A                           79                        94
# 1413A                         136                        95
# 1888A                          89                       157
#
#          TGCTCGTAGCTTTCCC-1_Input  TGGCCTTGTCAATCCA-1_Input  \
# Variant
# 146A                           28                        84
# 709A                           49                       183
# 930A                           45                       102
# 1413A                          44                       132
# 1888A                          72                       137
#
#          TGTAAGCCAAGAAACT-1_Input  TTGAGCATCCACTAGA-1_Flt3l  \
# Variant
# 146A                           25                        19
# 709A                           63                        20
# 930A                           56                        37
# 1413A                          47                        54
# 1888A                          71                        27
#
#          TTGCAGAGTTGGAGGT-1_Input  TTGCAGATCGCGGCAT-1_Input  \
# Variant
# 146A                           17                        37
# 709A                           42                        79
# 930A                           33                        74
# 1413A                          45                        63
# 1888A                          27                       103
#
#          TTGTTGTTCCCGTAGG-1_Flt3l  TTTGGCCTCTAGCAAC-1_Input
# Variant
# 146A                           15                        33
# 709A                           56                        96
# 930A                           36                       101
# 1413A                          40                        96
# 1888A                          56                        95
#
# [5 rows x 100 columns]
# keep_inds 0
#          AAACGAAGTTTGACCA-1_Input  AAAGATGTCACAAGCT-1_Input  \
# Variant
# 146A                           36                        53
# 709A                          154                        78
# 930A                           77                        91
# 1413A                          99                        73
# 1888A                          68                        73
#
#          AAAGGATCACCTGGTG-1_Input  AAAGGGCTCCAGGCCA-1_Input  \
# Variant
# 146A                           53                        14
# 709A                           80                        32
# 930A                           91                        44
# 1413A                         136                        70
# 1888A                          86                        53
#
#          AACCTGAGTATGGTTC-1_Input  AACGGGATCCGGCGAT-1_Input  \
# Variant
# 146A                           86                        91
# 709A                          127                       163
# 930A                          152                       121
# 1413A                         136                       178
# 1888A                         108                       173
#
#          AATACGCCACAAACAA-1_Input  AATACGCGTACAAGCG-1_Input  \
# Variant
# 146A                           91                        57
# 709A                          177                        69
# 930A                          132                        97
# 1413A                         205                        86
# 1888A                         171                       102
#
#          AATGTCGAGGCTAAAT-1_Input  ACAAAGAAGAATCAAC-1_Input  ...  \
# Variant                                                      ...
# 146A                           72                        52  ...
# 709A                          133                       146  ...
# 930A                          155                       131  ...
# 1413A                         181                       159  ...
# 1888A                         142                       110  ...
#
#          TTAACGGGTCATCGTA-1_Input  TTACGTTGTAGCGAGT-1_Input  \
# Variant
# 146A                           71                        32
# 709A                          196                       120
# 930A                          153                        87
# 1413A                         260                        93
# 1888A                         175                       117
#
#          TTACTCAGTGAATCGG-1_Input  TTAGCGATCTTCCACG-1_Input  \
# Variant
# 146A                           34                        39
# 709A                           57                        71
# 930A                           64                        99
# 1413A                          57                       111
# 1888A                          49                       100
#
#          TTAGCGATCTTGCGCT-1_Input  TTCAACTTCGAGGCTC-1_Input  \
# Variant
# 146A                           19                        47
# 709A                           79                        58
# 930A                           74                        94
# 1413A                          85                        50
# 1888A                          43                        91
#
#          TTGAGTGTCCAATAGC-1_Input  TTGCTATTCGGGCTCA-1_Input  \
# Variant
# 146A                           38                        88
# 709A                           93                       113
# 930A                          122                       125
# 1413A                          90                       174
# 1888A                         127                       180
#
#          TTTGTGTAGTTCGTTG-1_Input  TTTGTGTCACACATTG-1_Input
# Variant
# 146A                           80                        60
# 709A                          109                       192
# 930A                          116                       165
# 1413A                         143                       178
# 1888A                         107                       154
#
# [5 rows x 98 columns]
# keep_inds 0
#          AAAGGGCTCCTTACGC-1_Input  AAATGCCGTCTGGGAA-1_Input  \
# Variant
# 146A                           56                        15
# 709A                          114                        57
# 930A                          136                        24
# 1413A                         159                        74
# 1888A                         140                        26
#
#          AACCAACTCCCTATTA-1_Input  AACTGGTAGTACAGTA-1_Input  \
# Variant
# 146A                           57                        29
# 709A                          127                       136
# 930A                          130                        80
# 1413A                         100                       115
# 1888A                         127                        77
#
#          AACTGTGAGAACCATA-1_Input  AACTTGGAGCGTTGCC-1_Input  \
# Variant
# 146A                           27                        28
# 709A                           60                        64
# 930A                           73                        78
# 1413A                         107                        77
# 1888A                          63                        45
#
#          AAGGAGCGTCACCCGA-1_Input  AATACGCAGCTAACAA-1_Input  \
# Variant
# 146A                           93                        54
# 709A                          110                       116
# 930A                          110                       104
# 1413A                         150                       137
# 1888A                         201                       140
#
#          AATGGAACATCCCGGA-1_Input  ACAAAGACACGACGAA-1_Input  ...  \
# Variant                                                      ...
# 146A                           44                        47  ...
# 709A                          121                        65  ...
# 930A                           95                        65  ...
# 1413A                          84                        76  ...
# 1888A                         123                        72  ...
#
#          TTACGTTGTCTCTGCT-1_Input  TTAGGTGGTGCAAAGC-1_Input  \
# Variant
# 146A                           33                       109
# 709A                           96                       219
# 930A                           74                       153
# 1413A                          78                       179
# 1888A                          85                       157
#
#          TTAGGTGTCTCGTAGA-1_Input  TTCATTGAGAGCTCCC-1_Input  \
# Variant
# 146A                           37                        52
# 709A                           46                        81
# 930A                           34                        54
# 1413A                          72                       106
# 1888A                          47                       104
#
#          TTCTAACCAACTAGAA-1_Input  TTCTGTAAGATGGCAC-1_Input  \
# Variant
# 146A                           88                        52
# 709A                           93                       139
# 930A                          106                       106
# 1413A                         123                       143
# 1888A                         135                       110
#
#          TTGACGATCTGCGTCT-1_Input  TTGCACCTCCATCGAA-1_Input  \
# Variant
# 146A                           49                        74
# 709A                           81                       125
# 930A                           93                       119
# 1413A                          79                       113
# 1888A                         101                        99
#
#          TTGCGGGGTGAATCGG-1_Input  TTGCGGGTCGCGTGAC-1_Input
# Variant
# 146A                           53                        70
# 709A                           91                       110
# 930A                           77                       104
# 1413A                          88                        92
# 1888A                          62                       138
#
# [5 rows x 96 columns]
# keep_inds 0
#          AAACTCGGTATTCGAC-1_Input  AAAGGATCAACTCCCT-1_Input  \
# Variant
# 146A                           41                        56
# 709A                          118                        95
# 930A                          134                       103
# 1413A                         156                       121
# 1888A                         110                       180
#
#          AAGGTTCTCCGAGAGA-1_Input  AATGTCGAGCAGAGCT-1_Input  \
# Variant
# 146A                           39                        34
# 709A                           82                       117
# 930A                           78                       100
# 1413A                         127                       141
# 1888A                          77                       113
#
#          ACAGAAAAGGAGTAGA-1_Input  ACATGCAAGCAGAGCT-1_Input  \
# Variant
# 146A                           30                        46
# 709A                           89                       109
# 930A                           62                       110
# 1413A                          57                       101
# 1888A                          87                        99
#
#          ACATGCAGTCTGTGTA-1_Input  ACCCAAATCGTTACAG-1_Input  \
# Variant
# 146A                           62                        35
# 709A                           90                        58
# 930A                          101                        87
# 1413A                         148                       129
# 1888A                         142                        87
#
#          ACCGCAGAGGTTGTGG-1_Input  ACCTGCTCATCGACCG-1_Input  ...  \
# Variant                                                      ...
# 146A                           51                        32  ...
# 709A                           77                        96  ...
# 930A                           63                       106  ...
# 1413A                          68                        68  ...
# 1888A                          56                        51  ...
#
#          TTAGCTTAGGCAAGGG-1_Input  TTCATCACATCCCAAA-1_Input  \
# Variant
# 146A                           86                        69
# 709A                           77                       122
# 930A                           55                        82
# 1413A                         115                       106
# 1888A                         105                        99
#
#          TTCGCGTAGACTCGGA-1_Input  TTCGGTCGTCACAGGA-1_Input  \
# Variant
# 146A                           14                        83
# 709A                           82                       135
# 930A                           61                       123
# 1413A                          78                       108
# 1888A                          57                       101
#
#          TTCTAACTCCAACGCG-1_Input  TTCTGTATCCAGTTAG-1_Input  \
# Variant
# 146A                           49                        44
# 709A                           58                       108
# 930A                           74                       130
# 1413A                          72                       204
# 1888A                          38                       105
#
#          TTGAGCATCATCGCAA-1_Input  TTGCGGGGTGATTCCA-1_Input  \
# Variant
# 146A                           64                        29
# 709A                          106                       119
# 930A                           75                        81
# 1413A                         133                        88
# 1888A                         117                        84
#
#          TTGCGGGGTGCAGACA-1_Input  TTTGAGGAGTTACCAC-1_Input
# Variant
# 146A                           20                        97
# 709A                           44                       127
# 930A                           31                       138
# 1413A                          48                       138
# 1888A                          40                       105
#
# [5 rows x 91 columns]
# keep_inds 0
#          AAATGAGAGGATTAAC-1_Input  AACAAAGCATCCCTCA-1_Input  \
# Variant
# 146A                           34                        23
# 709A                           62                        30
# 930A                           47                        58
# 1413A                         102                        51
# 1888A                          66                        64
#
#          AACCTGATCCAGGGAA-1_Input  AACCTTTCAGTAAGAT-1_Input  \
# Variant
# 146A                           39                        51
# 709A                           96                        56
# 930A                          101                        62
# 1413A                         145                        46
# 1888A                         103                        47
#
#          AACGGGACAGCAACAG-1_Flt3l  AACGGGATCCAAGTCA-1_Input  \
# Variant
# 146A                           34                        27
# 709A                           42                        64
# 930A                           42                        63
# 1413A                          46                        95
# 1888A                          36                        39
#
#          AAGGAGCGTATCATGC-1_Input  AATGCCACAGTGCGAA-1_Input  \
# Variant
# 146A                          125                        24
# 709A                          213                        99
# 930A                          151                        86
# 1413A                         251                        69
# 1888A                         243                        73
#
#          ACAAACCAGCTAGCAG-1_Input  ACAAACCCATGCCCTT-1_Input  ...  \
# Variant                                                      ...
# 146A                          138                        50  ...
# 709A                          271                        75  ...
# 930A                          193                        64  ...
# 1413A                         292                       101  ...
# 1888A                         244                        80  ...
#
#          TCTCTGGTCTGGCCAG-1_Input  TGAGTCAGTGCGCTCA-1_Input  \
# Variant
# 146A                           52                        62
# 709A                          127                        92
# 930A                          132                        92
# 1413A                         159                       108
# 1888A                         106                       121
#
#          TGATGCACATGACTGT-1_Input  TGATTTCTCGTGGAAG-1_Input  \
# Variant
# 146A                           85                        99
# 709A                          153                       206
# 930A                          235                       181
# 1413A                         171                       171
# 1888A                         183                       234
#
#          TGGAAGGAGTCGATAA-1_Input  TGTACGAAGGGTATCG-1_Input  \
# Variant
# 146A                           22                        35
# 709A                           55                       139
# 930A                           51                       124
# 1413A                          48                       181
# 1888A                          79                       123
#
#          TGTAGCAGTGCTGGCT-1_Input  TTACGTTCAACTTGGT-1_Input  \
# Variant
# 146A                           75                        34
# 709A                          113                        70
# 930A                           77                        52
# 1413A                          91                        59
# 1888A                         116                        32
#
#          TTCATTGTCCCTACCA-1_Input  TTGAGTGGTAAACGGC-1_Input
# Variant
# 146A                           76                        34
# 709A                           84                        87
# 930A                           79                        93
# 1413A                         152                        95
# 1888A                          97                        69
#
# [5 rows x 84 columns]
# keep_inds 0
#          AAATGAGGTATCCTTT-1_Flt3l  AACCAACTCCAATAGC-1_Input  \
# Variant
# 146A                           19                        41
# 709A                           26                       126
# 930A                           31                       114
# 1413A                          41                       111
# 1888A                          38                       108
#
#          AAGGAGCCAATGGCAG-1_Flt3l  AAGGAGCGTCATCGTA-1_Flt3l  \
# Variant
# 146A                           20                        28
# 709A                           28                        38
# 930A                           50                        47
# 1413A                          38                        45
# 1888A                          57                        31
#
#          AATGGAAAGCCTGTAT-1_Input  AATGGAACATTCTTTG-1_Input  \
# Variant
# 146A                           67                        39
# 709A                          141                       112
# 930A                          155                        71
# 1413A                         193                        82
# 1888A                         145                        66
#
#          ACAAGCTGTGTCCCAG-1_Input  ACTAACGAGGGCATTG-1_Input  \
# Variant
# 146A                           52                        49
# 709A                          134                        96
# 930A                          104                       105
# 1413A                         123                       112
# 1888A                         147                       123
#
#          ACTGCAATCGTGTGCG-1_Input  ACTGCGGCATTGATGC-1_Input  ...  \
# Variant                                                      ...
# 146A                           64                        43  ...
# 709A                          106                        85  ...
# 930A                           92                       112  ...
# 1413A                          72                        90  ...
# 1888A                          93                        78  ...
#
#          TGATCAGCAGATACAA-1_Input  TGCATGAAGTTCAGGG-1_Input  \
# Variant
# 146A                           45                        47
# 709A                           74                        63
# 930A                           59                        57
# 1413A                         123                       141
# 1888A                          85                        57
#
#          TGCATTTAGTAATCAG-1_Input  TGGTCCTGTGGACAGT-1_Input  \
# Variant
# 146A                           36                        33
# 709A                           46                        50
# 930A                           81                        60
# 1413A                          65                        59
# 1888A                          63                        74
#
# ...
# 709A                           67                        96  ...
# 930A                           46                        60  ...
# 1413A                          87                       117  ...
# 1888A                         100                       122  ...
#
#          TTCTGTAGTTGCTTGA-1_Input  TTCTGTATCGGTCTAA-1_Flt3l  \
# Variant
# 146A                           38                        16
# 709A                           61                        41
# 930A                          111                        32
# 1413A                          92                        33
# 1888A                          75                        41
#
#          TTCTGTATCTCGTGAA-1_Flt3l  TTCTGTATCTTCATAC-1_Input  \
# Variant
# 146A                           34                        47
# 709A                           46                       102
# 930A                           52                       101
# 1413A                          52                       120
# 1888A                          71                        85
#
#          TTGACGAGTCGATTAC-1_Flt3l  TTGAGTGAGCAATGTA-1_Input  \
# Variant
# 146A                           37                        80
# 709A                           36                       120
# 930A                           45                       134
# 1413A                          57                       118
# 1888A                          41                       146
#
#          TTGCAGAAGGATTGCG-1_Input  TTGCGGGCACCTGAAT-1_Input  \
# Variant
# 146A                           48                        61
# 709A                           72                        59
# 930A                          122                        58
# 1413A                         132                        53
# 1888A                         107                        36
#
#          TTTGAGGTCTTATCAC-1_Input  TTTGGCCAGTATACGA-1_Input
# Variant
# 146A                           65                        53
# 709A                          133                        60
# 930A                           95                        67
# 1413A                         149                        67
# 1888A                          96                        58
#
# [5 rows x 147 columns]
# keep_inds 0
#          AAACTCGGTCAAACAA-1_Input  AAACTGCAGCTAGCAG-1_Input  \
# Variant
# 146A                          202                        47
# 709A                          394                        86
# 930A                          406                        67
# 1413A                         568                       126
# 1888A                         373                        87
#
#          AAAGATGCACCGTTGG-1_Input  AAATGAGAGTCGACCC-1_Input  \
# Variant
# 146A                           76                        32
# 709A                          137                       116
# 930A                          120                        89
# 1413A                         141                        93
# 1888A                         166                       120
#
#          AAATGCCTCCTGACCT-1_Input  AAATGCCTCGTCAACA-1_Input  \
# Variant
# 146A                           39                        50
# 709A                          102                       141
# 930A                           91                       109
# 1413A                         131                       134
# 1888A                         105                       106
#
#          AACAAAGTCCCTACCA-1_Input  AACAGTCAGAAAGCAG-1_Flt3l  \
# Variant
# 146A                           60                        29
# 709A                          136                        30
# 930A                          130                        44
# 1413A                         139                        40
# 1888A                         167                        29
#
#          AACAGTCAGGTAAGTT-1_Input  AACAGTCGTTCAGAAA-1_Input  ...  \
# Variant                                                      ...
# 146A                           75                        30  ...
# 709A                          217                       100  ...
# 930A                          168                        58  ...
# 1413A                         226                       108  ...
# 1888A                         191                        65  ...
#
#          TTCAACTTCGCTATTT-1_Input  TTCGCGTAGAGACTCG-1_Input  \
# Variant
# 146A                           52                        43
# 709A                           61                        91
# 930A                           78                       151
# 1413A                          60                       130
# 1888A                          89                       168
#
#          TTCGTTAGTACAAATG-1_Flt3l  TTGAGTGCACGCGATC-1_Input  \
# Variant
# 146A                           17                        29
# 709A                           32                        40
# 930A                           34                        36
# 1413A                          29                        45
# 1888A                          46                        61
#
#          TTGCAGATCCGTGCGA-1_Input  TTGCGAATCCCGGGTA-1_Input  \
# Variant
# 146A                           21                        33
# 709A                          117                       105
# 930A                           83                        69
# 1413A                         137                       128
# 1888A                          67                        92
#
#          TTGCGGGCATCCCGGA-1_Input  TTGGTCCGTCTCTAAG-1_Input  \
# Variant
# 146A                           36                        70
# 709A                           93                       128
# 930A                           57                       122
# 1413A                          61                       197
# 1888A                          69                       102
#
#          TTTGAGGTCGGAAAGC-1_Input  TTTGGTTTCTGATCCC-1_Input
# Variant
# 146A                           57                        61
# 709A                           44                       129
# 930A                           48                       101
# 1413A                          92                       110
# 1888A                          43                       115
#
# [5 rows x 144 columns]
# keep_inds 0
#          AACAAAGCACAGATGG-1_Input  AACCAACCATTGAACC-1_Input  \
# Variant
# 146A                           24                        34
# 709A                          133                       124
# 930A                          133                       124
# 1413A                         108                       157
# 1888A                          96                       117
#
#          AACCTTTCAGCTGATT-1_Input  AACGAGGGTGGATTCT-1_Input  \
# Variant
# 146A                           53                        31
# 709A                          140                        91
# 930A                          132                       141
# 1413A                         108                       121
# 1888A                         104                       101
#
#          AAGGAGCTCAGTGGTT-1_Input  AATGCCAAGTATACCC-1_Input  \
# Variant
# 146A                           43                        82
# 709A                           27                       144
# 930A                           25                       104
# 1413A                          35                       110
# 1888A                          29                        98
#
#          ACAAACCGTCTAAGAA-1_Input  ACAAAGATCCTAAAGC-1_Input  \
# Variant
# 146A                           40                        46
# 709A                           87                        95
# 930A                           81                        75
# 1413A                          93                       115
# 1888A                          47                       102
#
#          ACAGACTTCTTGCGCT-1_Input  ACCCAAAGTGGATTCT-1_Input  ...  \
# Variant                                                      ...
# 146A                           63                        24  ...
# 709A                          117                        65  ...
# 930A                           91                        70  ...
# 1413A                         141                        70  ...
# 1888A                         129                        74  ...
#
#          TGAGTCATCGGCTATA-1_Input  TGGGTGCCATGATCGT-1_Input  \
# Variant
# 146A                           28                        47
# 709A                           30                        93
# 930A                           29                        98
# 1413A                          64                        93
# 1888A                          38                        94
#
#          TGGTCAACAAATTCCG-1_Input  TGTGACATCTCTGCGT-1_Input  \
# Variant
# 146A                           49                        74
# 709A                           96                       117
# 930A                           86                       113
# 1413A                         122                       148
# 1888A                          72                       111
#
#          TGTGGCGGTCACAGGA-1_Input  TTACTTGTCTGAGTCA-1_Input  \
# Variant
# 146A                           28                        85
# 709A                           64                        92
# 930A                           80                       109
# 1413A                          56                        85
# 1888A                          56                       105
#
#          TTCGGTCGTTCTTAGG-1_Input  TTGACGATCGCACAAT-1_Flt3l  \
# Variant
# 146A                           44                        14
# 709A                           86                        40
# 930A                           89                        20
# 1413A                         138                        48
# 1888A                          67                        39
#
#          TTGGTCCCAAGTCTGT-1_Input  TTTGGTTTCCAGCACG-1_Input
# Variant
# 146A                           31                        96
# 709A                          124                       166
# 930A                           91                       135
# 1413A                         153                       208
# 1888A                         144                       169
#
# [5 rows x 110 columns]
# keep_inds 0
#          AAACGAAAGACGCCAA-1_Input  AAAGGATTCCGCTCTA-1_Input  \
# Variant
# 146A                           44                        93
# 709A                          124                       173
# 930A                           92                       130
# 1413A                         127                       185
# 1888A                         113                       172
#
#          AACAGTCAGAGTTTGA-1_Input  AACCAACCAAAGCTGG-1_Input  \
# Variant
# 146A                           38                        45
# 709A                          130                       111
# 930A                          108                        99
# 1413A                          94                       101
# 1888A                         101                       116
#
#          AACCTTTTCCAGTACA-1_Input  AACGAGGCAGTAACTC-1_Input  \
# Variant
# 146A                           87                        72
# 709A                           84                       133
# 930A                           95                       114
# 1413A                         152                       129
# 1888A                         160                       100
#
#          AACGAGGTCGCTCGGA-1_Input  AACTTGGAGGGTCCCT-1_Input  \
# Variant
# 146A                           75                        71
# 709A                          120                       138
# 930A                           99                       122
# 1413A                         202                       167
# 1888A                         140                       141
#
#          AACTTGGCATGTCCCT-1_Input  AATGTCGAGAAGGGCG-1_Flt3l  ...  \
# Variant                                                      ...
# 146A                           73                        32  ...
# 709A                          154                        39  ...
# 930A                          136                        36  ...
# 1413A                         140                        45  ...
# 1888A                         123                        28  ...
#
#          TTAACGGGTTTGCATG-1_Input  TTACCCGTCAGGTCTA-1_Input  \
# Variant
# 146A                           29                        52
# 709A                          101                       128
# 930A                           64                        98
# 1413A                          60                       115
# 1888A                          89                       134
#
#          TTACCGCTCCTCCAGT-1_Input  TTACTCAGTAGTCTGT-1_Input  \
# Variant
# 146A                           42                        43
# 709A                          111                        75
# 930A                           68                       124
# 1413A                          94                       128
# 1888A                         105                        85
#
#          TTCTAACAGGAAGAAC-1_Input  TTCTAACTCTACCCGT-1_Input  \
# Variant
# 146A                           28                        63
# 709A                          168                       144
# 930A                          134                       179
# 1413A                         163                       165
# 1888A                         170                       152
#
#          TTGCCCAAGATCTAAG-1_Input  TTGTTGTGTTTAAGGA-1_Input  \
# Variant
# 146A                           56                        62
# 709A                           87                        96
# 930A                           59                       113
# 1413A                         131                       152
# 1888A                         112                        85
#
#          TTTGGTTCATGGCCCA-1_Input  TTTGGTTTCACTCGGG-1_Input
# Variant
# 146A                           46                        98
# 709A                          121                       194
# 930A                          144                       163
# 1413A                         135                       229
# 1888A                         119                       190
#
# [5 rows x 110 columns]
# keep_inds 0

# %%
anno = mean_af.reset_index()[["lineage"]]

# Remove clones that have all 0
# print('mean_af shape', mean_af.shape)
# mean_af = mean_af.loc[~((mean_af==0).all(axis=1))]
# curr_clones = curr_clones.loc[mean_af.index]
# print('mean_af shape after rm 0', mean_af.shape)

mean_dp = curr_labels.groupby(["lineage"]).apply(calc_mean, af=np.log2(DP_df+1))
mean_dp = mean_dp.loc[mean_af.index, mean_af.columns]

#mean_dp = mean_dp.reset_index(drop=True)
anno_dp = mean_dp.reset_index()[["lineage"]]
na_cells = curr_labels.loc[curr_labels["lineage"].isnull()]
na_mean_af = na_cells.groupby("condition").apply(calc_mean, af=AF_df)

if not (na_mean_af.shape[0] == 0):
    print('na shape', na_mean_af.shape)
    na_anno = pd.concat((anno,pd.DataFrame({"lineage":["None"]*len(na_mean_af.index)})), ignore_index=True)
    na_concat = pd.concat((mean_af.reset_index(drop=True), na_mean_af.reset_index(drop=True)), ignore_index=True)
    na_mean_dp = na_cells.groupby("condition").apply(calc_mean, af=np.log2(DP_df+1))
    na_dp_concat = pd.concat((mean_dp, na_mean_dp.reset_index(drop=True)), ignore_index=True)
else:
    na_anno = anno
    na_concat = mean_af.reset_index(drop=True)
    na_dp_concat = mean_dp
    
print((mean_af<0.01).all(axis=0).sum())

print((mean_af<0.01).all(axis=1).sum())
mean_af = mean_af.loc[:,~(mean_af<0.01).all(axis=0)]
mean_af
# Out:
# 30
# 0
# Variant     1888A     1949A     2514A     3242A     3244A     3820A     4837A  \
# lineage
# 0_0      0.004577  0.000618  0.004234  0.005276  0.000487  0.000470  0.003391
# 0_1      0.000148  0.000472  0.000000  0.000082  0.000340  0.000551  0.000053
# 0_10     0.001198  0.002033  0.001163  0.000074  0.008205  0.001005  0.002065
# 0_11     0.000220  0.002717  0.000858  0.000102  0.000140  0.003621  0.001126
# 0_12     0.003174  0.279984  0.001624  0.000000  0.000125  0.001263  0.002045
# 0_13     0.001755  0.001019  0.001379  0.000000  0.000000  0.004623  0.001401
# 0_14     0.000962  0.001489  0.000734  0.000638  0.000000  0.001068  0.002681
# 0_15     0.000580  0.017700  0.000872  0.010217  0.000440  0.001827  0.014508
# 0_16     0.003232  0.002667  0.000970  0.006349  0.006848  0.001497  0.000988
# 0_17     0.001105  0.808135  0.002142  0.000298  0.000236  0.002985  0.002123
# 0_18     0.001386  0.001257  0.000388  0.001270  0.060184  0.002278  0.000721
# 0_19     0.000768  0.002140  0.001650  0.000129  0.000681  0.001587  0.001535
# 0_2      0.001622  0.001169  0.001922  0.004366  0.000894  0.001474  0.001689
# 0_20     0.002063  0.001541  0.001941  0.001045  0.000488  0.005306  0.001523
# 0_21     0.002394  0.001509  0.002281  0.000000  0.000000  0.000710  0.001839
# 0_22     0.002126  0.000917  0.002690  0.000718  0.005757  0.001227  0.001619
# 0_23     0.008103  0.002074  0.002953  0.003218  0.102953  0.002348  0.005284
# 0_24     0.000378  0.001759  0.001219  0.000000  0.000141  0.035085  0.002389
# 0_25     0.002421  0.002014  0.000841  0.000000  0.000810  0.001072  0.003603
# 0_26     0.000958  0.002316  0.000529  0.000525  0.011559  0.001730  0.002081
# 0_27     0.000744  0.002620  0.001186  0.000282  0.000118  0.001003  0.003142
# 0_28     0.003287  0.001015  0.001020  0.000000  0.000209  0.000650  0.002387
# 0_29     0.002047  0.000388  0.002568  0.000000  0.007287  0.004888  0.003650
# 0_3      0.001234  0.001246  0.000545  0.000187  0.000072  0.000309  0.001169
# 0_30     0.006376  0.000710  0.003260  0.000000  0.003312  0.001690  0.001574
# 0_31     0.005000  0.002022  0.001077  0.000000  0.000440  0.001673  0.001690
# 0_32     0.000336  0.002858  0.001423  0.000000  0.000000  0.002138  0.005057
# 0_33     0.001102  0.001063  0.003881  0.000978  0.014029  0.001732  0.001748
# 0_34     0.005562  0.002500  0.000576  0.000000  0.000000  0.002632  0.000936
# 0_35     0.002425  0.000000  0.003786  0.000000  0.000000  0.003666  0.000529
# 0_4      0.000694  0.000233  0.000749  0.000504  0.000296  0.000108  0.000556
# 0_5      0.001355  0.002421  0.002729  0.000000  0.000080  0.001680  0.002579
# 0_6      0.001112  0.001870  0.000435  0.000000  0.000505  0.004455  0.001061
# 0_7      0.001495  0.003795  0.001970  0.000000  0.000647  0.001687  0.002226
# 0_8      0.025097  0.000186  0.000590  0.008630  0.000000  0.002437  0.003254
# 0_9      0.001735  0.002063  0.022987  0.000197  0.000000  0.002732  0.001245
#
# Variant     5147A     7775A     8697A  ...     5581G    10559G    13676G  \
# lineage                                ...
# 0_0      0.001214  0.003618  0.006483  ...  0.932052  0.008033  0.000068
# 0_1      0.000395  0.000080  0.000745  ...  0.000238  0.000087  0.001816
# 0_10     0.000462  0.000611  0.001098  ...  0.667069  0.002181  0.000396
# 0_11     0.002192  0.000511  0.000810  ...  0.000756  0.000405  0.000340
# 0_12     0.003324  0.002186  0.003014  ...  0.773325  0.003887  0.005409
# 0_13     0.003119  0.000659  0.034076  ...  0.002653  0.001601  0.000147
# 0_14     0.001900  0.002835  0.001596  ...  0.939894  0.000604  0.001308
# 0_15     0.002494  0.000165  0.001475  ...  0.001722  0.000862  0.000624
# 0_16     0.003136  0.000323  0.002251  ...  0.000850  0.001266  0.000301
# 0_17     0.001488  0.002775  0.003876  ...  0.003966  0.004541  0.012700
# 0_18     0.002085  0.002243  0.001804  ...  0.001500  0.000642  0.000000
# 0_19     0.004038  0.000551  0.001740  ...  0.000437  0.000000  0.001855
# 0_2      0.001428  0.002474  0.001414  ...  0.410807  0.001394  0.000122
# 0_20     0.003066  0.002170  0.001184  ...  0.006175  0.001882  0.000129
# 0_21     0.001013  0.003602  0.000942  ...  0.001244  0.066036  0.000236
# 0_22     0.058571  0.002444  0.003675  ...  0.931456  0.002259  0.001722
# 0_23     0.007655  0.003096  0.005786  ...  0.854792  0.006408  0.000000
# 0_24     0.001006  0.000406  0.001866  ...  0.949638  0.002158  0.000566
# 0_25     0.001056  0.000796  0.001235  ...  0.000787  0.002343  0.000000
# 0_26     0.002242  0.030893  0.000353  ...  0.001189  0.000643  0.004307
# 0_27     0.002445  0.002004  0.000648  ...  0.000623  0.001315  0.000464
# 0_28     0.002010  0.002666  0.004009  ...  0.942111  0.002657  0.015964
# 0_29     0.001029  0.001839  0.000721  ...  0.000000  0.001408  0.000000
# 0_3      0.000549  0.000824  0.000708  ...  0.970629  0.000500  0.000074
# 0_30     0.000832  0.002349  0.003866  ...  0.932034  0.000628  0.000000
# 0_31     0.005041  0.001724  0.004555  ...  0.002634  0.004281  0.000000
# 0_32     0.000629  0.001484  0.003386  ...  0.000000  0.003059  0.000000
# 0_33     0.000000  0.001994  0.002920  ...  0.830535  0.001550  0.000000
# 0_34     0.000661  0.003564  0.000000  ...  0.004558  0.000000  0.000000
# 0_35     0.001120  0.004937  0.002005  ...  0.000000  0.005952  0.000916
# 0_4      0.000000  0.000834  0.001228  ...  0.995061  0.000502  0.001206
# 0_5      0.003536  0.001146  0.001142  ...  0.001312  0.001462  0.000969
# 0_6      0.018674  0.001106  0.001928  ...  0.000810  0.000416  0.008814
# 0_7      0.003671  0.002799  0.003320  ...  0.134572  0.004870  0.000756
# 0_8      0.001454  0.001210  0.002133  ...  0.002244  0.001311  0.000638
# 0_9      0.001854  0.001700  0.001613  ...  0.000825  0.000520  0.000141
#
# Variant    14233G    15244G     3735T     7361T    12283T    16294T    16296T
# lineage
# 0_0      0.000965  0.004759  0.003447  0.003110  0.002216  0.000995  0.000324
# 0_1      0.000401  0.000600  0.000172  0.000129  0.000500  0.000234  0.000181
# 0_10     0.000448  0.004586  0.001137  0.002125  0.000818  0.000000  0.000248
# 0_11     0.001718  0.000984  0.000984  0.001027  0.013708  0.000235  0.000235
# 0_12     0.002015  0.000000  0.002539  0.002412  0.002388  0.001872  0.002180
# 0_13     0.000703  0.001944  0.000538  0.002017  0.001781  0.000250  0.000253
# 0_14     0.002470  0.000000  0.000816  0.001745  0.001789  0.000592  0.000615
# 0_15     0.002716  0.000193  0.000208  0.001172  0.001018  0.000210  0.000213
# 0_16     0.002499  0.000638  0.001715  0.001258  0.001022  0.000000  0.000000
# 0_17     0.002682  0.000000  0.002710  0.001175  0.001739  0.002276  0.002231
# 0_18     0.026185  0.002162  0.000838  0.018379  0.000776  0.000781  0.000310
# 0_19     0.002585  0.000000  0.001353  0.001412  0.002017  0.000000  0.000000
# 0_2      0.001093  0.000313  0.001844  0.002509  0.001226  0.000993  0.001060
# 0_20     0.003884  0.000000  0.002555  0.001828  0.002081  0.004580  0.004726
# 0_21     0.001406  0.000527  0.001079  0.002838  0.000166  0.002121  0.002288
# 0_22     0.001624  0.013889  0.001786  0.001455  0.000590  0.000521  0.000323
# 0_23     0.004769  0.000000  0.001148  0.000000  0.003336  0.061330  0.044004
# 0_24     0.001391  0.000000  0.002924  0.001295  0.002155  0.000501  0.000512
# 0_25     0.000000  0.001181  0.001145  0.001913  0.001347  0.000000  0.000000
# 0_26     0.001829  0.000737  0.000000  0.002354  0.000454  0.000000  0.000512
# 0_27     0.001125  0.000353  0.000924  0.000907  0.001068  0.000706  0.001076
# 0_28     0.002222  0.000000  0.001511  0.001506  0.003773  0.000734  0.000550
# 0_29     0.000406  0.000503  0.035395  0.002209  0.001759  0.002170  0.000000
# 0_3      0.000543  0.000429  0.000943  0.000605  0.000901  0.000082  0.000258
# 0_30     0.066028  0.000842  0.002012  0.000772  0.001993  0.000000  0.000588
# 0_31     0.015385  0.000712  0.002972  0.000981  0.000986  0.077665  0.064421
# 0_32     0.002418  0.000000  0.002835  0.000756  0.001737  0.000000  0.000000
# 0_33     0.002257  0.000000  0.000878  0.000470  0.003922  0.002245  0.002245
# 0_34     0.000000  0.001375  0.001929  0.002994  0.002813  0.001905  0.001951
# 0_35     0.000000  0.000000  0.000000  0.000000  0.000000  0.006728  0.005591
# 0_4      0.000557  0.000967  0.000471  0.001004  0.001635  0.000296  0.000452
# 0_5      0.003450  0.000626  0.002185  0.000999  0.001634  0.000544  0.000484
# 0_6      0.002039  0.001287  0.000795  0.000819  0.001048  0.000831  0.000801
# 0_7      0.002104  0.000129  0.001556  0.001681  0.000833  0.001435  0.000920
# 0_8      0.002786  0.001239  0.001415  0.000000  0.000664  0.002190  0.001427
# 0_9      0.002255  0.000140  0.001209  0.001969  0.000781  0.000807  0.000549
#
# [36 rows x 46 columns]

# %%
# Get variant types
variants_df = vu.add_ref_to_variants(variants=mean_af.columns.values,
                                     mt_df=vu.load_mt_ref(mt_ref))

variants_df = vu.type_of_variants(variants_df, to_preproc=False)

# %%
# mean_af.to_csv(out_f+".initInds.mean.csv")

# curr_clones[["donor","size", "log2_fold","-log10(fold p_adj)", "shuffle_sig", 
#              "ncells"]+ list(curr_labels["condition"].unique())].to_csv(out_f+".initInds.indsMeta.csv")

# %% [markdown]
# ### Cluster to get dendro results

# %%
if mean_af.shape[0] == 1 or  mean_af.shape[1] == 1 :
    print('no clustering needed only one var')
else:
    g = sns.clustermap(mean_af, row_cluster=True, col_cluster=True, vmax=0.2, vmin=0)
    inds = g.dendrogram_row.dendrogram["leaves"]
    cols = g.dendrogram_col.dendrogram["leaves"]
    curr_clones = curr_clones.iloc[inds]
    plt.close(g.fig)

# %% [markdown]
# ### Cluster and calculate proper size

# %%
# %matplotlib inline
if not (mean_af.shape[0] == 1 or  mean_af.shape[1] == 1 ):
    
    if dendroThresh == "dynamic":
        clusters, link = dc.run_dynamic_hyper(np.sqrt(mean_af))
        #clusters, link = dc.run_dynamic(mean_af, metric='euclidean', method="average", minClusterSize=1)
        curr_clones["den_clust"] = curr_clones.apply(lambda x: f'C{clusters.loc[x.name, "labels"]}', axis=1)
    else:
        den = dc.dendro_cluster(mean_af, g, d_thresh=dendroThresh)

        if verbose:
            print('icoord and color list')
            print(len(den["icoord"]))
            print(len(den["color_list"]))
            print('leaves leaves color and mean_af shape')
            print(len(den["leaves"]))
            print(len(den["leaves_color_list"]))
            print(mean_af.shape)
        # cluster_classes = dc.get_cluster_classes(den)
        curr_clones = dc.add_cluster_labels(den,curr_clones)
        curr_clones

    size_pvals = dc.cluster_stats(curr_clones, out_f= out_f )

    curr_clones["donor"]= [x.split("_")[0] for x in curr_clones.index]
    curr_clones = curr_clones.loc[mean_af.index]

    # with open(out_f + ".dendrogram_pvals.txt", "w") as f:
    #     #for l in size_pvals:
    #     f.write("\n".join(size_pvals))
else:
    with open(out_f+".dendrogram_pvals.txt", "w") as f:
        f.write("no cells")
# Out:
# distances
# [0.29642 0.01671 0.28330 0.07523 0.26741 0.01651 0.27607 0.27916 0.43225
#  0.30371 0.28951 0.02523 0.39250 0.28410 0.02000 0.06405 0.01949 0.28643
#  0.28016 0.28477 0.02156 0.30286 0.01436 0.02085 0.30617 0.30430 0.17552
#  0.41787 0.43906 0.01452 0.27059 0.28180 0.09171 0.26600 0.27408 0.23704
#  0.03166 0.30710 0.05225 0.29859 0.03872 0.04592 0.26993 0.09258 0.02597
#  0.17031 0.27758 0.06911 0.30099 0.35067 0.29426 0.04013 0.02982 0.03221
#  0.30108 0.03372 0.28551 0.29913 0.12513 0.04756 0.38992 0.26436 0.21648
#  0.30722 0.03770 0.03318 0.08470 0.04268 0.02553 0.23248 0.07217 0.23710
#  0.01973 0.23125 0.23725 0.39041 0.25985 0.23710 0.02065 0.41367 0.24280
#  0.02610 0.07479 0.01962 0.24621 0.22857 0.24125 0.02659 0.25320 0.01410
#  0.02593 0.29572 0.26351 0.17809 0.40825 0.40888 0.01508 0.23105 0.23863
#  0.07461 0.23228 0.23440 0.29187 0.05511 0.29243 0.04798 0.05050 0.24734
#  0.09727 0.03207 0.17156 0.26358 0.06699 0.29469 0.33384 0.28981 0.05445
#  0.04923 0.04035 0.29579 0.04698 0.29275 0.29110 0.11752 0.06229 0.39207
#  0.27671 0.23810 0.31333 0.04383 0.04021 0.08024 0.04755 0.03575 0.28677
#  0.07506 0.25798 0.29367 0.21257 0.32807 0.29332 0.08058 0.43738 0.29397
#  0.08448 0.12239 0.07438 0.29451 0.28728 0.29215 0.07943 0.31795 0.07556
#  0.08568 0.31915 0.31699 0.20775 0.43848 0.44779 0.08064 0.27744 0.28268
#  0.12123 0.29632 0.28087 0.29074 0.06975 0.04805 0.26832 0.08909 0.06027
#  0.16565 0.27098 0.07917 0.26988 0.31963 0.28032 0.05182 0.06498 0.05463
#  0.26549 0.05708 0.28774 0.27911 0.11190 0.06528 0.38299 0.28697 0.23993
#  0.30759 0.04220 0.04006 0.07429 0.05444 0.03769 0.28963 0.30208 0.43768
#  0.33198 0.28000 0.03477 0.42594 0.31198 0.02448 0.07312 0.01490 0.29904
#  0.28676 0.29198 0.02169 0.31582 0.01086 0.02400 0.32647 0.31684 0.17449
#  0.44226 0.44819 0.01368 0.28419 0.29127 0.10555 0.28223 0.28613 0.05479
#  0.20658 0.09374 0.03423 0.15777 0.28998 0.06540 0.29006 0.33256 0.28497
#  0.05492 0.04305 0.04280 0.29508 0.04980 0.28490 0.28742 0.13066 0.05659
#  0.35703 0.26588 0.23872 0.30458 0.04846 0.05018 0.08539 0.05114 0.03759
#  0.24975 0.06788 0.04660 0.17010 0.28811 0.08147 0.28673 0.32314 0.29462
#  0.05216 0.05302 0.05132 0.30153 0.05147 0.29771 0.28776 0.12129 0.06038
#  0.37356 0.27847 0.25156 0.31751 0.03847 0.04796 0.08117 0.04826 0.04107
#  0.29765 0.25190 0.34775 0.43860 0.26288 0.44115 0.45467 0.43354 0.26167
#  0.25289 0.25397 0.43111 0.27763 0.44184 0.44035 0.29890 0.26293 0.51899
#  0.43851 0.41929 0.46140 0.24580 0.25172 0.25958 0.27850 0.24842 0.08907
#  0.19351 0.29805 0.10413 0.31512 0.31193 0.33137 0.09573 0.06793 0.09687
#  0.31146 0.08385 0.32675 0.29538 0.15037 0.10559 0.40840 0.32194 0.28037
#  0.34161 0.07619 0.09285 0.11244 0.09754 0.09352 0.16806 0.27373 0.06626
#  0.29318 0.34538 0.29308 0.04694 0.03204 0.03087 0.29884 0.03439 0.29328
#  0.29329 0.12593 0.04242 0.38301 0.27316 0.23440 0.31441 0.03753 0.03533
#  0.08130 0.04713 0.02716 0.32335 0.18083 0.04186 0.08557 0.03571 0.17580
#  0.16287 0.16994 0.04037 0.18287 0.02885 0.03974 0.21244 0.19670 0.17684
#  0.30758 0.33306 0.03490 0.15969 0.16861 0.03434 0.16148 0.15995 0.30595
#  0.43006 0.42861 0.44213 0.29343 0.26195 0.28029 0.42626 0.28630 0.43175
#  0.42720 0.24542 0.29719 0.47559 0.40733 0.42443 0.45709 0.28529 0.26870
#  0.24275 0.28436 0.25899 0.30835 0.33566 0.31044 0.07549 0.06230 0.06544
#  0.29900 0.06468 0.31026 0.30360 0.11987 0.07577 0.40768 0.30323 0.23719
#  0.32329 0.06257 0.06802 0.08929 0.07215 0.06030 0.06591 0.02799 0.29724
#  0.28384 0.29262 0.03113 0.30851 0.02578 0.03140 0.31523 0.31609 0.18662
#  0.43052 0.45002 0.02934 0.27442 0.26853 0.10651 0.27996 0.28183 0.07624
#  0.33607 0.31616 0.33384 0.07296 0.34121 0.07906 0.06823 0.25178 0.36320
#  0.19988 0.46823 0.46332 0.08022 0.32192 0.32011 0.14334 0.30362 0.32467
#  0.29530 0.29197 0.29355 0.02496 0.30633 0.01163 0.02451 0.32920 0.31641
#  0.16883 0.43249 0.43897 0.01378 0.28310 0.28693 0.10673 0.28308 0.28112
#  0.04615 0.04705 0.29766 0.04606 0.29596 0.29813 0.13067 0.05921 0.38035
#  0.27588 0.24705 0.31688 0.04082 0.04443 0.08073 0.05186 0.03409 0.03618
#  0.28557 0.03998 0.28699 0.28408 0.12653 0.05380 0.36961 0.27553 0.22587
#  0.30654 0.04111 0.03649 0.07704 0.04899 0.03599 0.29729 0.03658 0.29022
#  0.29167 0.10773 0.04526 0.37980 0.27694 0.22492 0.31574 0.03768 0.03916
#  0.08480 0.03894 0.03167 0.31811 0.02154 0.02861 0.32289 0.31928 0.18799
#  0.44659 0.44492 0.02035 0.28172 0.28515 0.10233 0.28090 0.28969 0.31109
#  0.30955 0.11772 0.05178 0.40522 0.27572 0.23974 0.33409 0.04305 0.04234
#  0.09562 0.05063 0.03052 0.02208 0.33708 0.31886 0.17588 0.41069 0.44953
#  0.00252 0.28526 0.29501 0.10576 0.28233 0.28416 0.30877 0.30958 0.18406
#  0.43612 0.43999 0.02319 0.27971 0.28474 0.10611 0.27191 0.28052 0.12499
#  0.40562 0.31510 0.25976 0.35842 0.10684 0.09779 0.12328 0.09584 0.09781
#  0.41072 0.28040 0.24288 0.34331 0.05031 0.05841 0.09923 0.05605 0.04250
#  0.52011 0.50968 0.17977 0.38535 0.36894 0.23839 0.38355 0.36550 0.40420
#  0.42679 0.25639 0.27899 0.28126 0.27196 0.26871 0.46327 0.21406 0.21489
#  0.24749 0.21713 0.21697 0.30619 0.31577 0.11867 0.30371 0.30606 0.03334
#  0.06631 0.04147 0.02762 0.07742 0.04144 0.02825 0.08188 0.06938 0.03747]
# link
# [[23.00000 30.00000 0.00252 2.00000]
#  [6.00000 36.00000 0.01368 3.00000]
#  [17.00000 37.00000 0.01490 4.00000]
#  [0.00000 2.00000 0.01671 2.00000]
#  [38.00000 39.00000 0.01973 6.00000]
#  [1.00000 35.00000 0.02553 2.00000]
#  [24.00000 40.00000 0.02593 7.00000]
#  [11.00000 41.00000 0.02716 3.00000]
#  [21.00000 42.00000 0.02861 8.00000]
#  [15.00000 44.00000 0.03140 9.00000]
#  [20.00000 43.00000 0.03221 4.00000]
#  [31.00000 32.00000 0.03334 2.00000]
#  [12.00000 33.00000 0.03434 2.00000]
#  [19.00000 46.00000 0.03618 5.00000]
#  [22.00000 49.00000 0.03998 6.00000]
#  [34.00000 47.00000 0.04147 3.00000]
#  [18.00000 50.00000 0.04705 7.00000]
#  [3.00000 51.00000 0.04755 4.00000]
#  [5.00000 8.00000 0.04805 2.00000]
#  [7.00000 53.00000 0.05114 5.00000]
#  [52.00000 55.00000 0.05492 12.00000]
#  [26.00000 56.00000 0.06229 13.00000]
#  [54.00000 57.00000 0.06975 15.00000]
#  [16.00000 45.00000 0.08022 10.00000]
#  [14.00000 58.00000 0.08147 16.00000]
#  [10.00000 60.00000 0.10559 17.00000]
#  [4.00000 48.00000 0.12123 3.00000]
#  [59.00000 62.00000 0.14334 13.00000]
#  [25.00000 61.00000 0.15037 18.00000]
#  [27.00000 63.00000 0.23839 14.00000]
#  [29.00000 64.00000 0.28037 19.00000]
#  [28.00000 66.00000 0.40420 20.00000]
#  [13.00000 67.00000 0.42443 21.00000]
#  [9.00000 68.00000 0.43860 22.00000]
#  [65.00000 69.00000 0.52011 36.00000]]
# deepsplit 4
# ..cutHeight not given, setting it to 0.5150452349089991  ===>  99% of the (truncated) height range in dendro.
# ..done.
# clusters [2 1 2 1 3 1 2 1 1 1 1 1 3 1 1 2 2 2 1 1 1 2 1 2 2 1 1 2 1 1 2 1 1 3 1 1]
# min cluster size: 3
# ('C2', 'C3')
# ('C2', 'C1')
# ('C3', 'C1')

# %% [markdown]
# ## Group clones using dendrogram and run stats on size differences in the groups

# %% [markdown]
# ### Run ranksums on clone size btwn debdrogram clusters

# %%
# size_pvals = []
# for pair in combinations(curr_clones["den_clust"].unique(),2):
#     print(pair)
#     stat, p_val = scipy.stats.ranksums(curr_clones.loc[curr_clones["den_clust"]==pair[0], "size"].values, 
#                          y=curr_clones.loc[curr_clones["den_clust"]==pair[1], "size"].values, 
#                          alternative='two-sided')

#     size_pvals.append(f"{pair[0]}, {pair[1]}, {str(p_val)}")

# %% [markdown]
# ## Plot with dendro clusters

# %%
conditions = cells_meta["condition"].unique()

# %%
if not (mean_af.shape[0] == 1 or  mean_af.shape[1] == 1 ):
    g = ch.plot_cluster(mean_af,row_meta=curr_clones, to_row_clust=True, to_col_clust=True,
                        col_meta=variants_df[["variant type", "variant change"]], col_clr_schemes="categorical",
                        row_clr_schemes={"size":"sequential","donor":"categorical","den_clust":"categorical"}, 
                        vmax=0.2, vmin=0, 
                        row_linkage=link)
    plt.suptitle("Donor sqrt allele-frequency heatmap with clone and condition labels (max AF=0.2)")
    #fu.helper_save(out_f+"withEnrichmentFoldChange.NoCondition.clust.max2.AF.png",to_pdf=False)
    fu.helper_save(out_f+".dendro.NoCondition.max2.AF.png",to_pdf=False, to_svg=True)

    inds = g.dendrogram_row.dendrogram["leaves"]
    cols = g.dendrogram_col.dendrogram["leaves"]

    g1d = ch.plot_cluster(mean_dp.iloc[inds, cols], row_meta=curr_clones, to_row_clust=False, to_col_clust=False,
                          row_clr_schemes={"size":"sequential","donor":"categorical","den_clust":"categorical"}, 
                          col_meta=variants_df[["variant type", "variant change"]], col_clr_schemes="categorical",
                         )
    g1d.ax_cbar.set_title("log2(reads+1)")
    fu.helper_save(out_f+".dendro.NoCondition.DP.png",to_pdf=False, to_svg=True)#, f=g1d.figure)


    mean_af = mean_af.iloc[inds,cols]
    curr_clones = curr_clones.loc[mean_af.index]

    ch.plot_cluster(mean_af,row_meta=curr_clones, to_row_clust=False, to_col_clust=False,
                    col_meta=variants_df[["variant type", "variant change"]], col_clr_schemes="categorical",
                    row_clr_schemes={"size":"sequential","donor":"categorical","den_clust":"categorical"}, 
                    vmax=0.5, vmin=0)
    plt.suptitle("Donor sqrt allele-frequency heatmap with clone and condition labels (max AF=0.5)")
    #fu.helper_save(out_f+"withEnrichmentFoldChange.NoCondition.clust.max5.AF.png",to_pdf=False)
    fu.helper_save(out_f+".dendro.NoCondition.max5.AF.png",to_pdf=False, to_svg=True)

else:
    f = plt.figure()
    plt.title("no cells")
    f.savefig(out_f+".dendro.NoCondition.max2.AF.png")

# %%
# ## Get top3 variants for each clone and plot af

# def get_max_diff(clone, af):
#     print(clone.name)
#     return (af.loc[clone.name]-af).sum()

# max_diffs = mean_af.apply(get_max_diff, args=(mean_af,),axis=1)
# max_diffs

# %% [markdown]
# ### Save mean_af and curr_clonnes

# %%
mean_af.to_csv(out_f+".mean.csv")
curr_clones.to_csv(out_f+".clones_dendro.csv")
