# %%
DE.out.path = "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust"
export.path = "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/GSEA_pthresh_0.1/"
gsea_dir = "/mnt/md0/isshamie/Projects/Mito_Trace/software/Bioinformatics_Tools/"
#pthresh = 0.1


gsea_pthresh = 0.1 
prefilter = FALSE 
stat_col = "log2FoldChange"
padjmethod = "BH"

pct_thresh = 0.1

# %%
export.path.prep <- file.path(export.path, "prep")
dir.create(export.path.prep)

# %%
# library("AnnotationDbi")
#library("org.Hs.eg.db")
# library(TxDb.Hsapiens.UCSC.hg38.knownGene)
source(paste0(gsea_dir,'R/Gsea.R'))
# Out:
# Loading required package: clusterProfiler
#
#
#
# clusterProfiler v4.2.2  For help: https://yulab-smu.top/biomedical-knowledge-mining-book/
#
# If you use clusterProfiler in published research, please cite:
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal enrichment tool for interpreting omics data. The Innovation. 2021, 2(3):100141
#
#
# Attaching package: ‘clusterProfiler’
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
# [1] "package already installed:clusterProfiler"
# [1] "package already installed:clusterProfiler"
# Loading required package: GSEABase
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: annotate
#
# Loading required package: AnnotationDbi
#
# Loading required package: stats4
#
# Loading required package: IRanges
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
#
# Attaching package: ‘IRanges’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
#
# Attaching package: ‘AnnotationDbi’
#
#
# The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
# Loading required package: XML
#
# Loading required package: graph
#
#
# Attaching package: ‘graph’
#
#
# The following object is masked from ‘package:XML’:
#
#     addNode
# [1] "package already installed:GSEABase"
# [1] "package already installed:GSEABase"
# Loading required package: biomaRt
# [1] "package already installed:biomaRt"
# [1] "package already installed:biomaRt"
# Loading required package: org.Hs.eg.db
# [1] "package already installed:org.Hs.eg.db"
# [1] "package already installed:org.Hs.eg.db"
# Loading required package: DOSE
#
# DOSE v3.20.1  For help: https://yulab-smu.top/biomedical-knowledge-mining-book/
#
# If you use DOSE in published research, please cite:
# Guangchuang Yu, Li-Gen Wang, Guang-Rong Yan, Qing-Yu He. DOSE: an R/Bioconductor package for Disease Ontology Semantic and Enrichment analysis. Bioinformatics 2015, 31(4):608-609
# [1] "package already installed:DOSE"
# [1] "package already installed:DOSE"
# Loading required package: gdata
#
# gdata: read.xls support for 'XLS' (Excel 97-2004) files ENABLED.
#
#
#
# gdata: Unable to load perl libaries needed by read.xls()
# gdata: to support 'XLSX' (Excel 2007+) files.
#
#
#
# gdata: Run the function 'installXLSXsupport()'
# gdata: to automatically download and install the perl
# gdata: libaries needed to support Excel XLS and XLSX formats.
#
#
# Attaching package: ‘gdata’
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     startsWith, trim
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, first<-
#
#
# The following object is masked from ‘package:stats4’:
#
#     nobs
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     combine
#
#
# The following object is masked from ‘package:stats’:
#
#     nobs
#
#
# The following object is masked from ‘package:utils’:
#
#     object.size
#
#
# The following object is masked from ‘package:base’:
#
#     startsWith
#
#
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:gdata’:
#
#     first, last
#
#
# The following object is masked from ‘package:IRanges’:
#
#     shift
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, second
#
#
# Loading required package: openxlsx
#
# Loading required package: dplyr
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:gdata’:
#
#     combine, first, last
#
#
# The following object is masked from ‘package:biomaRt’:
#
#     select
#
#
# The following objects are masked from ‘package:GSEABase’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:graph’:
#
#     union
#
#
# The following object is masked from ‘package:AnnotationDbi’:
#
#     select
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘stringr’
#
#
# The following object is masked from ‘package:graph’:
#
#     boundary

# %%
cols.prior <- c("Gene","baseMean","log2FoldChange","lfcSE","stat","pvalue","padj")
cols.needed <- c("Gene","log2FoldChange")
cols.curr <- c("X","p_val","avg_log2FC","pct.1","pct.2","p_val_adj_BH") #first col is empty in csv

# %% [markdown]
# ## Prep files

# %%
#for f in list.files(DE.path, pattern="*.csv"){

DE_files <- list.files(path = DE.out.path,pattern="*.csv", full.names=TRUE)
for(f in DE_files){
    print(f)
    curr <- read.csv(f)
    
    if (!(nrow(curr)==0)){
        colnames(curr) <- c("Gene","pvalue","log2FoldChange","pct.1","pct.2","padj_bonf", "padj")
        curr$ensg <- mapIds(org.Hs.eg.db,
                    keys=curr$Gene, 
                    column="ENSEMBL",
                    keytype="SYMBOL",
                    multiVals="first")
        write.table(curr, file.path(export.path.prep, paste0(strsplit(basename(f), ".csv")[[1]], ".tsv")),quote = FALSE,
                    row.names=FALSE, sep='\t')
    }
    
}
# Out:
# [1] "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/cluster0.DE.csv"
# 'select()' returned 1:many mapping between keys and columns
# [1] "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/cluster1.DE.csv"
# 'select()' returned 1:many mapping between keys and columns
# [1] "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/cluster10.DE.csv"
# 'select()' returned 1:many mapping between keys and columns
# [1] "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/cluster11.DE.csv"
# 'select()' returned 1:many mapping between keys and columns
# [1] "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/cluster12.DE.csv"
# 'select()' returned 1:many mapping between keys and columns
# [1] "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/cluster13.DE.csv"
# 'select()' returned 1:many mapping between keys and columns
# [1] "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/cluster14.DE.csv"
# 'select()' returned 1:many mapping between keys and columns
# [1] "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/cluster2.DE.csv"
# 'select()' returned 1:many mapping between keys and columns
# [1] "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/cluster3.DE.csv"
# 'select()' returned 1:many mapping between keys and columns
# [1] "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/cluster4.DE.csv"
# 'select()' returned 1:many mapping between keys and columns
# [1] "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/cluster5.DE.csv"
# 'select()' returned 1:many mapping between keys and columns
# [1] "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/cluster6.DE.csv"
# 'select()' returned 1:many mapping between keys and columns
# [1] "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/cluster7.DE.csv"
# 'select()' returned 1:many mapping between keys and columns
# [1] "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/cluster8.DE.csv"
# 'select()' returned 1:many mapping between keys and columns
# [1] "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/cluster9.DE.csv"
# 'select()' returned 1:many mapping between keys and columns

# %%
# #rm(list=ls())

# ########################################################################################
# ##  gsea_ex1
# #---------------------------------------------------------------------------------------
# #' @description This example is designed to demonstrate how to run gsea analysis on the 
# #'              input files (DESeq2 results) put in the same directory
# #' @details All the parameter definitions is in the below section of "Setting Parameter"
# #' @return out a list that summarizes the GSEA enrichment analysis
# #' 
# #' @export exportExcel_fp an excel file of the 'out' can be exported
# #' @export exportPDF_fp an figure of the GSEA enrichment analysis
# #' --------------------------------------------------------------------------------------------------
# #' @author Austin W.T. Chiang
# #' @note   v1.4 -- 2017.02.15 Add description of ex1, ex2, and idmapping file
# #' @note   v1.3 -- 2017.02.08 Add function of displaying topN pathways and optimze code
# #' @note   v1.2 -- 2017.02.06 Add zebrafish2 human id mapping
# #' @note   v1.1 -- 2017.01.19 Midified for BEN
# #' @note   v1.0 -- 2016.12.15 File created
# #' --------------------------------------------------------------------------------------------------
# ########################################################################################
# gsea_ex1 <- function(DE_out_path = NULL, export_path = NULL,
#                      IDmappingfile = NULL, convert = FALSE,
#                      gene_name = TRUE, GSEA_set = c('c0', 'c2', 'c3'),
#                      minGSSize = 30, pAdjustMethod = "none",
#                      pvalueCutoff = 0.01, export = "BOTH",
#                      ShowTop = TRUE, TopN = 5, gene_sets_dir=NULL){
#   DE_out_files <- list.files(path = DE_out_path,pattern="*.tsv", full.names = TRUE)
#   for(f in DE_out_files){
#     print(paste0("Here we go .... :", f))
#     #f <- "res_geno_dobs_removed_C57BL6_J__M.tsv"
#     ## Input the DESeq result file
#     myClass <- read.csv(f, row.names = 1,sep="\t")
#     if(convert == TRUE){
#       geneMapTable <- read.csv(IDmappingfile, sep = "\t")
#       myClass <- useIDmappingFile(myClass=myClass,
#                                   geneMapTable=geneMapTable) #,
#                                   #Original_attribute=Original_attribute,
#                                  # Convert_attribute=Co nvert_attribute)
#     }
    
#     #DEGTable <- subset(myClass, abs(log2FoldChange) >= .58 & (padj < 0.05) )
#     #DEGTable <- subset(myClass, (padj < 0.1) )
#     print("Myclass")
#     print(dim(myClass))
#     DEGTable <- subset(myClass, (pct.1 > 0 & pct.2 > 0) )
#     print(dim(DEGTable))

#     DEGTable <- DEGTable[with(DEGTable, order(-log2FoldChange)), ]
#     print(colnames(DEGTable))
#     if(gene_name==TRUE){
#       DEGTable$Gene <- DEGTable$gene_name
#     }else{
#       print('here')
#       DEGTable$Gene <- row.names(DEGTable)
#     }

#     DEGTable <- DEGTable[,c("Gene","log2FoldChange")]
    
#     ## do the GSEA analysis
#     f1 <- gsub(".csv", "", basename(f))
#     exportExcel_fp = paste0(export_path,f1,"_gsea.xlsx")
#     exportPDF_fp = paste0(export_path,f1,"_gsea.pdf")
#     GSEA_res <-  AnnotDEG_byGSEA(DEGTable = DEGTable, GSEA_set = GSEA_set,
#                                  export = export, ShowTop = ShowTop, TopN = TopN,
#                                  exportExcel_fp = exportExcel_fp,
#                                  exportPDF_fp = exportPDF_fp,
#                                  minGSSize = minGSSize, 
#                                  pAdjustMethod = pAdjustMethod, 
#                                  pvalueCutoff = pvalueCutoff, gene_sets_dir = gene_sets_dir)
    
#   }
# }


# ########################################################################################
# ##  Setting Parameter
# ########################################################################################
# #' @param DE_out_path the path of the DESeq2 output files 
# #' @param export_path the path that user want to export the GSEA results
# #' @param convert 'TRUE': need to do id converion; 'FALSE': no id conversion needed  
# #' @param IDmappingfile the idmapping file show that user's id to human gene name
# #' @param gene_name 'TRUE': there is a columan "gene_name" in the input files (i.e. DESeq2 output files)
# #' @param GSEA_set = c('c0', 'c2', 'c3')
# #'                 co - hallmark gene sets;       c1 - positional gene sets; 
# #'                 c2 - curated gene sets;        c3 - motif gene sets;
# #'                 c4 - computational gene sets;  c5 - GO gene sets;
# #'                 c6 - oncogenic signatures;     c7 - immunologic signatures. 
# #'                 (http://software.broadinstitute.org/gsea/msigdb/collections.jsp#C2)
# #' @param minGSSize minimum size of genes for a specific GSEA gene set
# #' @param pAdjustMethod one of "holm", "hochberg", "hommel", "bonferroni", "BH", "BY", "fdr", "none"
# #' @param pvalueCutoff cutoff of pvalue in the GSEA enrichment analysis 
# #' @param export option for exporting GSEA result: "EXCEL", "PDF", or "BOTH"
# #' @param ShowTop 'TRUE': the visualization will display only the top and bottom N gene sets; 
# #'                'FALSE': all of the significant gsea gene sets will be displayed 
# #'                        --> Note that: it is usually results in too many gene sets, which are not easy to see anything    
# #' @param TopN this parameter indicate how many gene sets need to be displayed in the plots
# ########################################################################################

# # DE_out_path <- DE.out.path
# # export_path <- 
# #IDmappingfile <- "" #"mouse2human.txt" #"Data/zebrafish2human_idmapping.txt"
# convert = FALSE
# gene_name = FALSE 
# GSEA_set = c('c0', 'c2', 'c5', 'c7')
# minGSSize = 10 #20 #30
# pAdjustMethod = "BH"
# pvalueCutoff = gsea_pthresh
# export = "BOTH"
# ShowTop = TRUE 
# TopN = 10


# ########################################################################################
# ##  RUN gsea_ex1
# ########################################################################################
# gsea_ex1(DE_out_path = export.path.prep, export_path = export.path, gene_name = gene_name,
#          convert = convert, GSEA_set = GSEA_set, minGSSize = minGSSize,
#          pAdjustMethod = pAdjustMethod,  pvalueCutoff = pvalueCutoff,
#          export = export, ShowTop = ShowTop,   
#          TopN = TopN, gene_sets_dir=gsea_dir)

# %%
#rm(list=ls())

########################################################################################
##  gsea_ex1
#---------------------------------------------------------------------------------------
#' @description This example is designed to demonstrate how to run gsea analysis on the 
#'              input files (DESeq2 results) put in the same directory
#' @details All the parameter definitions is in the below section of "Setting Parameter"
#' @return out a list that summarizes the GSEA enrichment analysis
#' 
#' @export exportExcel_fp an excel file of the 'out' can be exported
#' @export exportPDF_fp an figure of the GSEA enrichment analysis
#' --------------------------------------------------------------------------------------------------
#' @author Austin W.T. Chiang
#' @note   v1.4 -- 2017.02.15 Add description of ex1, ex2, and idmapping file
#' @note   v1.3 -- 2017.02.08 Add function of displaying topN pathways and optimze code
#' @note   v1.2 -- 2017.02.06 Add zebrafish2 human id mapping
#' @note   v1.1 -- 2017.01.19 Midified for BEN
#' @note   v1.0 -- 2016.12.15 File created
#' --------------------------------------------------------------------------------------------------
########################################################################################
gsea_ex1 <- function(DE_out_path = NULL, export_path = NULL,
                     IDmappingfile = NULL, convert = FALSE,
                     gene_name = TRUE, stat.col="log2FoldChange", GSEA_set = c('c0', 'c2', 'c3'),
                     minGSSize = 30, pAdjustMethod = "none",
                     pvalueCutoff = 0.01, export = "BOTH",
                     ShowTop = TRUE, TopN = 5, gene_sets_dir=NULL){
  DE_out_files <- list.files(path = DE_out_path,pattern="*.tsv", full.names = TRUE)
  for(f in DE_out_files){
    print(paste0("Here we go .... :", f))
    #f <- "res_geno_dobs_removed_C57BL6_J__M.tsv"
    ## Input the DESeq result file
    myClass <- read.csv(f, row.names = 1,sep="\t")
    if(convert == TRUE){
      geneMapTable <- read.csv(IDmappingfile, sep = "\t")
      myClass <- useIDmappingFile(myClass=myClass,
                                  geneMapTable=geneMapTable) #,
                                  #Original_attribute=Original_attribute,
                                 # Convert_attribute=Co nvert_attribute)
    }
    
    #DEGTable <- subset(myClass, abs(log2FoldChange) >= .58 & (padj < 0.05) )
    if (prefilter){
        DEGTable <- subset(myClass, (padj < pthresh) )
        }
      
    print("Myclass")
    print(dim(myClass))
    DEGTable <- subset(myClass, (pct.1 > pct_thresh & pct.2 > pct_thresh) )
    print(dim(DEGTable))

    print(colnames(DEGTable))
    print(head(DEGTable))
    if(gene_name==TRUE){
      DEGTable$Gene <- DEGTable$gene_name
    }else{
      print('here')
      DEGTable$Gene <- row.names(DEGTable)
    }
    
    DEGTable <- DEGTable[with(DEGTable, order(-log2FoldChange)), ] #order
    DEGTable <- DEGTable[,c("Gene",stat.col)]
    if (stat.col=="padj"){
        DEGTable[,stat.col] <- -log10(DEGTable[,stat.col])
        DEGTable <- DEGTable[with(DEGTable, order(-padj)), ] #order
    }
    
    

    #DEGTable <- DEGTable[order(stat.col, ), ]
      
    print(head(DEGTable))
    ## do the GSEA analysis
    f1 <- gsub(".csv", "", basename(f))
    exportExcel_fp = paste0(export_path,f1,"_gsea.xlsx")
    exportPDF_fp = paste0(export_path,f1,"_gsea.pdf")
    exportDOT_fp = file.path(export_path,paste0(f1,"_gsea.dot"))
    GSEA_res <-  AnnotDEG_byGSEA(DEGTable = DEGTable, GSEA_set = GSEA_set,
                                 export = export, ShowTop = ShowTop, TopN = TopN,
                                 exportExcel_fp = exportExcel_fp,
                                 exportPDF_fp = exportPDF_fp,
                                 minGSSize = minGSSize, exportDOT_fp=exportDOT_fp,
                                 pAdjustMethod = pAdjustMethod, stat.col=stat.col,
                                 pvalueCutoff = pvalueCutoff, gene_sets_dir = gene_sets_dir)
    
    #dotplot(GSEA_res)  
    #ggsave(file.path(export_path, paste0(f1, "_gsea.dot.pdf")))
    
  }
    return
}


########################################################################################
##  Setting Parameter
########################################################################################
#' @param DE_out_path the path of the DESeq2 output files 
#' @param export_path the path that user want to export the GSEA results
#' @param convert 'TRUE': need to do id converion; 'FALSE': no id conversion needed  
#' @param IDmappingfile the idmapping file show that user's id to human gene name
#' @param gene_name 'TRUE': there is a columan "gene_name" in the input files (i.e. DESeq2 output files)
#' @param GSEA_set = c('c0', 'c2', 'c3')
#'                 co - hallmark gene sets;       c1 - positional gene sets; 
#'                 c2 - curated gene sets;        c3 - motif gene sets;
#'                 c4 - computational gene sets;  c5 - GO gene sets;
#'                 c6 - oncogenic signatures;     c7 - immunologic signatures. 
#'                 (http://software.broadinstitute.org/gsea/msigdb/collections.jsp#C2)
#' @param minGSSize minimum size of genes for a specific GSEA gene set
#' @param pAdjustMethod one of "holm", "hochberg", "hommel", "bonferroni", "BH", "BY", "fdr", "none"
#' @param pvalueCutoff cutoff of pvalue in the GSEA enrichment analysis 
#' @param export option for exporting GSEA result: "EXCEL", "PDF", or "BOTH"
#' @param ShowTop 'TRUE': the visualization will display only the top and bottom N gene sets; 
#'                'FALSE': all of the significant gsea gene sets will be displayed 
#'                        --> Note that: it is usually results in too many gene sets, which are not easy to see anything    
#' @param TopN this parameter indicate how many gene sets need to be displayed in the plots
########################################################################################

# DE_out_path <- DE.out.path
# export_path <- 
#IDmappingfile <- "" #"mouse2human.txt" #"Data/zebrafish2human_idmapping.txt"
convert = FALSE
gene_name = FALSE 
GSEA_set = c('c0', 'c2', 'c5', 'c7')
minGSSize = 10 #20 #30
pAdjustMethod = "BH"
#pvalueCutoff = pthresh
export = "BOTH"
ShowTop = TRUE 
TopN = 10


########################################################################################
##  RUN gsea_ex1
########################################################################################
gsea_ex1(DE_out_path = export.path.prep, export_path = export.path, gene_name = gene_name,
         convert = convert, GSEA_set = GSEA_set, minGSSize = minGSSize,
         pAdjustMethod = padjmethod,  pvalueCutoff = gsea_pthresh,
         export = export, ShowTop = ShowTop,  stat.col=stat_col ,
         TopN = TopN, gene_sets_dir=gsea_dir)
# Out:
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/GSEA_pthresh_0.1//prep/cluster0.DE.tsv"
# [1] "Myclass"
# [1] 2748    7
# [1] 2655    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#               pvalue log2FoldChange pct.1 pct.2    padj_bonf         padj
# SHC3    1.300202e-11      0.3594911 0.694 0.290 2.475455e-07 1.190985e-08
# GPR88   1.007255e-10      0.1921534 0.408 0.112 1.917713e-06 6.919842e-08
# RBM47   6.770215e-10      0.6175955 0.878 0.593 1.288981e-05 3.100759e-07
# SFT2D2  8.738095e-10      0.2699131 0.592 0.221 1.663646e-05 3.430326e-07
# FAM107B 1.604936e-09      0.5684002 0.898 0.646 3.055637e-05 5.512954e-07
# STX18   4.715542e-09      0.2808526 0.796 0.354 8.977920e-05 1.295831e-06
#                    ensg
# SHC3    ENSG00000148082
# GPR88   ENSG00000181656
# RBM47   ENSG00000163694
# SFT2D2  ENSG00000213064
# FAM107B ENSG00000065809
# STX18   ENSG00000168818
# [1] "here"
#            Gene log2FoldChange
# RBM47     RBM47      0.6175955
# EDNRB     EDNRB      0.6110585
# FAM107B FAM107B      0.5684002
# FNDC3B   FNDC3B      0.5559874
# UBAC2     UBAC2      0.5320749
# LRRC8C   LRRC8C      0.5090904
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in fgseaMultilevel(...):
# “For some pathways, in reality P-values are less than 1e-10. You can set the `eps` argument to zero for better estimation.”
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/GSEA_pthresh_0.1//prep/cluster1.DE.tsv"
# [1] "Myclass"
# [1] 1922    7
# [1] 1860    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#              pvalue log2FoldChange pct.1 pct.2    padj_bonf         padj
# TREM1  1.692755e-09      0.1967330 0.461 0.199 3.222837e-05 1.445301e-06
# CDA    2.255932e-09      0.2286145 0.303 0.109 4.295069e-05 1.445301e-06
# SRPK1  1.218518e-08      0.2297985 0.449 0.209 2.319937e-04 5.805216e-06
# ZNF274 3.027105e-08      0.1400484 0.348 0.138 5.763305e-04 9.687150e-06
# FNDC3B 4.032113e-08      0.3919171 0.843 0.812 7.676739e-04 9.687150e-06
# FCER1G 1.101348e-07      0.1546290 0.281 0.106 2.096856e-03 2.351989e-05
#                   ensg
# TREM1  ENSG00000124731
# CDA    ENSG00000158825
# SRPK1  ENSG00000096063
# ZNF274 ENSG00000171606
# FNDC3B ENSG00000075420
# FCER1G ENSG00000158869
# [1] "here"
#          Gene log2FoldChange
# SPIDR   SPIDR      0.4351778
# TAOK3   TAOK3      0.4262597
# FNDC3B FNDC3B      0.3919171
# SYNPO2 SYNPO2      0.3803389
# RAB27A RAB27A      0.3639749
# MYO9B   MYO9B      0.3568084
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.05% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.05% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.05% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.05% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/GSEA_pthresh_0.1//prep/cluster10.DE.tsv"
# [1] "Myclass"
# [1] 2729    7
# [1] 2578    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#              pvalue log2FoldChange pct.1 pct.2    padj_bonf         padj
# DUSP22 3.755870e-14      0.6074315 0.895 0.553 7.150801e-10 3.416590e-11
# P2RY6  1.180151e-13      0.4248014 0.579 0.217 2.246890e-09 6.441266e-11
# SAMHD1 3.746000e-12      0.4266320 0.614 0.259 7.132010e-08 1.703806e-09
# SULF2  8.657784e-12      0.4876427 0.807 0.417 1.648355e-07 2.953387e-09
# FGD2   4.239535e-11      0.3159547 0.544 0.213 8.071651e-07 1.285521e-08
# ZNF366 3.031251e-10      0.2811687 0.596 0.243 5.771199e-06 7.204697e-08
#                   ensg
# DUSP22 ENSG00000112679
# P2RY6  ENSG00000171631
# SAMHD1 ENSG00000101347
# SULF2  ENSG00000196562
# FGD2   ENSG00000146192
# ZNF366 ENSG00000178175
# [1] "here"
#            Gene log2FoldChange
# DUSP22   DUSP22      0.6074315
# UBAC2     UBAC2      0.5910751
# XYLT1     XYLT1      0.5183923
# SULF2     SULF2      0.4876427
# FAM53B   FAM53B      0.4748454
# RAPGEF4 RAPGEF4      0.4666756
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.04% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.04% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in fgseaMultilevel(...):
# “For some pathways, in reality P-values are less than 1e-10. You can set the `eps` argument to zero for better estimation.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.04% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.04% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/GSEA_pthresh_0.1//prep/cluster11.DE.tsv"
# [1] "Myclass"
# [1] 1773    7
# [1] 1713    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#                pvalue log2FoldChange pct.1 pct.2    padj_bonf         padj
# CXADR    5.893781e-93      0.4315471 0.621 0.274 1.122117e-88 2.612419e-90
# GAS7     2.739031e-92     -0.6763486 0.384 0.728 5.214841e-88 9.712603e-90
# KIAA1211 3.511034e-89      0.5242064 0.817 0.532 6.684657e-85 7.914606e-87
# ABCC4    3.571170e-89      0.5722032 0.915 0.692 6.799151e-85 7.914606e-87
# PHTF1    1.340226e-84      0.5338288 0.705 0.400 2.551657e-80 2.640246e-82
# NBAS     4.790408e-72      0.4916605 0.816 0.572 9.120457e-68 6.533379e-70
#                     ensg
# CXADR    ENSG00000154639
# GAS7     ENSG00000007237
# KIAA1211            <NA>
# ABCC4    ENSG00000125257
# PHTF1    ENSG00000116793
# NBAS     ENSG00000151779
# [1] "here"
#              Gene log2FoldChange
# ABCC4       ABCC4      0.5722032
# PHTF1       PHTF1      0.5338288
# KIAA1211 KIAA1211      0.5242064
# NBAS         NBAS      0.4916605
# DNAJC6     DNAJC6      0.4724268
# SGMS1       SGMS1      0.4722091
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in fgseaMultilevel(...):
# “For some pathways, in reality P-values are less than 1e-10. You can set the `eps` argument to zero for better estimation.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/GSEA_pthresh_0.1//prep/cluster12.DE.tsv"
# [1] "Myclass"
# [1] 1804    7
# [1] 1758    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#                pvalue log2FoldChange pct.1 pct.2    padj_bonf         padj
# PDZRN3   1.754121e-52      0.5426902 0.711 0.368 3.339670e-48 6.328867e-50
# FAM160A1 4.643906e-52      0.5162730 0.797 0.455 8.841532e-48 1.396268e-49
# GABRR3   1.867852e-51      0.2983251 0.447 0.141 3.556204e-47 4.813722e-49
# PALD1    4.164597e-51      0.5882127 0.810 0.507 7.928976e-47 9.391166e-49
# VASH2    9.521400e-48      0.3465417 0.550 0.219 1.812779e-43 1.908512e-45
# ADGRD1   1.242133e-46      0.4606054 0.682 0.344 2.364897e-42 2.240808e-44
#                     ensg
# PDZRN3   ENSG00000121440
# FAM160A1            <NA>
# GABRR3   ENSG00000183185
# PALD1    ENSG00000107719
# VASH2    ENSG00000143494
# ADGRD1   ENSG00000111452
# [1] "here"
#              Gene log2FoldChange
# PALD1       PALD1      0.5882127
# DUSP22     DUSP22      0.5842464
# PDZRN3     PDZRN3      0.5426902
# FAM160A1 FAM160A1      0.5162730
# ESR2         ESR2      0.5105183
# SH3RF3     SH3RF3      0.5003210
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in fgseaMultilevel(...):
# “For some pathways, in reality P-values are less than 1e-10. You can set the `eps` argument to zero for better estimation.”
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/GSEA_pthresh_0.1//prep/cluster13.DE.tsv"
# [1] "Myclass"
# [1] 2349    7
# [1] 2243    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#                pvalue log2FoldChange pct.1 pct.2     padj_bonf          padj
# ADPRHL1 1.476829e-114      0.5112066 0.512 0.101 2.811735e-110 3.469071e-111
# CD81    3.418258e-105      0.6129103 0.573 0.139 6.508021e-101 2.676496e-102
# GSDME    1.228116e-97      0.6343366 0.698 0.225  2.338209e-93  7.212109e-95
# IQSEC1   6.828346e-89      1.0754666 0.963 0.839  1.300049e-84  2.673298e-86
# SH2D4B   1.807914e-85      0.7044860 0.725 0.282  3.442087e-81  6.066842e-83
# POU2AF1  5.857634e-69      0.7229606 0.797 0.416  1.115235e-64  1.528843e-66
#                    ensg
# ADPRHL1 ENSG00000153531
# CD81    ENSG00000110651
# GSDME   ENSG00000105928
# IQSEC1  ENSG00000144711
# SH2D4B  ENSG00000178217
# POU2AF1 ENSG00000110777
# [1] "here"
#            Gene log2FoldChange
# IQSEC1   IQSEC1      1.0754666
# POU2AF1 POU2AF1      0.7229606
# STK32B   STK32B      0.7164427
# EBF1       EBF1      0.7151201
# SH2D4B   SH2D4B      0.7044860
# HS6ST1   HS6ST1      0.6650850
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in fgseaMultilevel(...):
# “For some pathways, in reality P-values are less than 1e-10. You can set the `eps` argument to zero for better estimation.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in fgseaMultilevel(...):
# “For some pathways, in reality P-values are less than 1e-10. You can set the `eps` argument to zero for better estimation.”
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/GSEA_pthresh_0.1//prep/cluster14.DE.tsv"
# [1] "Myclass"
# [1] 4421    7
# [1] 4066    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#                pvalue log2FoldChange pct.1 pct.2    padj_bonf         padj
# SH3RF3   2.015704e-11     -0.6023952 0.284 0.728 3.837700e-07 8.911429e-08
# PLCB4    2.850679e-10     -0.5207638 0.254 0.658 5.427408e-06 6.301427e-07
# TTC7A    6.256168e-10     -0.5413430 0.403 0.790 1.191112e-05 9.219507e-07
# TG       1.333314e-09     -0.5328141 0.448 0.829 2.538496e-05 1.473645e-06
# ARHGAP26 2.180425e-09     -0.5474291 0.642 0.921 4.151312e-05 1.698968e-06
# CAMK1D   2.305770e-09     -0.5142398 0.373 0.736 4.389955e-05 1.698968e-06
#                     ensg
# SH3RF3   ENSG00000172985
# PLCB4    ENSG00000101333
# TTC7A    ENSG00000068724
# TG       ENSG00000042832
# ARHGAP26 ENSG00000145819
# CAMK1D   ENSG00000183049
# [1] "here"
#              Gene log2FoldChange
# PNKP         PNKP      0.5200417
# AKT1S1     AKT1S1      0.5035193
# ARL6IP6   ARL6IP6      0.4979031
# TTC9C       TTC9C      0.4796567
# BRD2         BRD2      0.4667659
# HNRNPUL2 HNRNPUL2      0.4542660
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.02% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.02% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in fgseaMultilevel(...):
# “For some pathways, in reality P-values are less than 1e-10. You can set the `eps` argument to zero for better estimation.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.02% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.02% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/GSEA_pthresh_0.1//prep/cluster2.DE.tsv"
# [1] "Myclass"
# [1] 536   7
# [1] 534   7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#              pvalue log2FoldChange pct.1 pct.2    padj_bonf         padj
# STXBP4 1.444796e-70      0.3234813 0.524 0.336 2.750747e-66 7.744106e-68
# GBP5   5.771940e-62      0.2345411 0.371 0.197 1.098920e-57 1.546880e-59
# CDH7   6.296195e-61      0.2826013 0.443 0.269 1.198733e-56 1.124920e-58
# PRKCD  3.637440e-57     -0.2061194 0.194 0.397 6.925321e-53 4.874169e-55
# FNDC3B 3.422179e-56     -0.3336139 0.752 0.840 6.515486e-52 3.668576e-54
# PAG1   9.640002e-54     -0.2507497 0.473 0.669 1.835360e-49 8.611735e-52
#                   ensg
# STXBP4 ENSG00000166263
# GBP5   ENSG00000154451
# CDH7   ENSG00000081138
# PRKCD  ENSG00000163932
# FNDC3B ENSG00000075420
# PAG1   ENSG00000076641
# [1] "here"
#          Gene log2FoldChange
# STXBP4 STXBP4      0.3234813
# IDS       IDS      0.2945213
# PREX2   PREX2      0.2847497
# CDH7     CDH7      0.2826013
# RBPMS   RBPMS      0.2622928
# LIMCH1 LIMCH1      0.2609779
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/GSEA_pthresh_0.1//prep/cluster3.DE.tsv"
# [1] "Myclass"
# [1] 515   7
# [1] 514   7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#                 pvalue log2FoldChange pct.1 pct.2     padj_bonf          padj
# FNDC3B   2.681228e-116      0.4199917 0.910 0.768 5.104790e-112 1.380832e-113
# HRH2     3.277582e-115      0.2490083 0.541 0.239 6.240189e-111 8.439774e-113
# ARHGAP26  2.370965e-82      0.3295712 0.953 0.902  4.514079e-78  3.052617e-80
# PLEK      4.039935e-80      0.2124438 0.578 0.316  7.691633e-76  4.161134e-78
# NEDD9     7.789418e-78      0.2771485 0.769 0.544  1.483027e-73  6.685917e-76
# TLR4      7.395997e-77      0.1381588 0.350 0.138  1.408124e-72  5.441341e-75
#                     ensg
# FNDC3B   ENSG00000075420
# HRH2     ENSG00000113749
# ARHGAP26 ENSG00000145819
# PLEK     ENSG00000115956
# NEDD9    ENSG00000111859
# TLR4     ENSG00000136869
# [1] "here"
#              Gene log2FoldChange
# FNDC3B     FNDC3B      0.4199917
# ARHGAP26 ARHGAP26      0.3295712
# SPIDR       SPIDR      0.2910866
# NEDD9       NEDD9      0.2771485
# CRYBG1     CRYBG1      0.2726461
# NIBAN1     NIBAN1      0.2636502
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/GSEA_pthresh_0.1//prep/cluster4.DE.tsv"
# [1] "Myclass"
# [1] 3723    7
# [1] 3300    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#              pvalue log2FoldChange pct.1 pct.2    padj_bonf         padj
# PAPPA  2.175191e-19      0.6933287 0.726 0.285 4.141345e-15 2.699412e-16
# DNAJC6 1.873663e-14      0.8099137 0.758 0.438 3.567267e-10 1.003790e-11
# GAS7   1.990829e-14     -0.8079114 0.210 0.697 3.790340e-10 1.003790e-11
# HBS1L  2.297521e-14      0.7968706 0.839 0.569 4.374251e-10 1.003790e-11
# RSRC1  2.723428e-14      0.7346708 0.887 0.645 5.185135e-10 1.013932e-11
# NBAS   3.030861e-12      0.7378054 0.806 0.595 5.770457e-08 7.052435e-10
#                   ensg
# PAPPA  ENSG00000182752
# DNAJC6 ENSG00000116675
# GAS7   ENSG00000007237
# HBS1L  ENSG00000112339
# RSRC1  ENSG00000174891
# NBAS   ENSG00000151779
# [1] "here"
#          Gene log2FoldChange
# DNAJC6 DNAJC6      0.8099137
# HBS1L   HBS1L      0.7968706
# NBAS     NBAS      0.7378054
# RSRC1   RSRC1      0.7346708
# PAPPA   PAPPA      0.6933287
# KDM4C   KDM4C      0.6622285
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.03% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.03% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in fgseaMultilevel(...):
# “For some pathways, in reality P-values are less than 1e-10. You can set the `eps` argument to zero for better estimation.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.03% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.03% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/GSEA_pthresh_0.1//prep/cluster5.DE.tsv"
# [1] "Myclass"
# [1] 1490    7
# [1] 1456    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#                pvalue log2FoldChange pct.1 pct.2    padj_bonf         padj
# ABCC4    1.179951e-16      0.4494771 0.911 0.712 2.246509e-12 1.758127e-13
# ARHGAP26 1.057611e-13     -0.4951176 0.887 0.919 2.013586e-09 5.252803e-11
# STAU2    1.083234e-11      0.3605069 0.806 0.595 2.062369e-07 3.228036e-09
# TRPC6    1.506367e-11      0.3791280 0.677 0.448 2.867973e-07 3.740812e-09
# FBN1     8.073139e-11      0.4046036 0.589 0.362 1.537045e-06 1.503622e-08
# STAB2    1.061231e-10      0.2646638 0.484 0.249 2.020477e-06 1.756926e-08
#                     ensg
# ABCC4    ENSG00000125257
# ARHGAP26 ENSG00000145819
# STAU2    ENSG00000040341
# TRPC6    ENSG00000137672
# FBN1     ENSG00000166147
# STAB2    ENSG00000136011
# [1] "here"
#          Gene log2FoldChange
# ABCC4   ABCC4      0.4494771
# FBN1     FBN1      0.4046036
# TRPC6   TRPC6      0.3791280
# ZBTB16 ZBTB16      0.3628065
# STAU2   STAU2      0.3605069
# ACKR2   ACKR2      0.3179753
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in fgseaMultilevel(...):
# “For some pathways, in reality P-values are less than 1e-10. You can set the `eps` argument to zero for better estimation.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/GSEA_pthresh_0.1//prep/cluster6.DE.tsv"
# [1] "Myclass"
# [1] 2059    7
# [1] 1945    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#              pvalue log2FoldChange pct.1 pct.2    padj_bonf         padj
# IL1RL1 2.595089e-17      0.3893434 0.397 0.146 4.940789e-13 5.343287e-14
# NIBAN1 1.612850e-12      0.5372001 0.836 0.680 3.070704e-08 1.106952e-09
# FNDC3B 3.622886e-12      0.4667811 0.914 0.811 6.897613e-08 1.864881e-09
# MTCL1  8.060460e-11      0.4374754 0.638 0.437 1.534631e-06 3.319298e-08
# HDC    1.239793e-10      0.3880010 0.491 0.277 2.360442e-06 3.926606e-08
# IL21R  1.334932e-10     -0.3109422 0.121 0.443 2.541576e-06 3.926606e-08
#                   ensg
# IL1RL1 ENSG00000115602
# NIBAN1 ENSG00000135842
# FNDC3B ENSG00000075420
# MTCL1  ENSG00000168502
# HDC    ENSG00000140287
# IL21R  ENSG00000103522
# [1] "here"
#            Gene log2FoldChange
# NIBAN1   NIBAN1      0.5372001
# FAM107B FAM107B      0.4699492
# FNDC3B   FNDC3B      0.4667811
# MTCL1     MTCL1      0.4374754
# CACNA1D CACNA1D      0.4155360
# MRPS22   MRPS22      0.4047123
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/GSEA_pthresh_0.1//prep/cluster7.DE.tsv"
# [1] "Myclass"
# [1] 295   7
# [1] 295   7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#              pvalue log2FoldChange pct.1 pct.2    padj_bonf         padj
# KIFAP3 7.601911e-12     -0.1814480 0.294 0.499 1.447328e-07 1.639523e-09
# PTPN14 1.111541e-11      0.2697832 0.638 0.567 2.116262e-07 1.639523e-09
# PDE6A  9.907833e-11     -0.1033735 0.121 0.274 1.886352e-06 8.704012e-09
# CTDP1  1.428232e-10     -0.1279875 0.297 0.495 2.719211e-06 8.704012e-09
# MICU1  1.475256e-10     -0.1266285 0.217 0.392 2.808740e-06 8.704012e-09
# VAV2   4.180937e-10     -0.1268003 0.222 0.396 7.960086e-06 2.055627e-08
#                   ensg
# KIFAP3 ENSG00000075945
# PTPN14 ENSG00000152104
# PDE6A  ENSG00000132915
# CTDP1  ENSG00000060069
# MICU1  ENSG00000107745
# VAV2   ENSG00000160293
# [1] "here"
#          Gene log2FoldChange
# PTPN14 PTPN14      0.2697832
# TGFBR2 TGFBR2      0.2519881
# XYLT1   XYLT1      0.2387782
# GSAP     GSAP      0.2272137
# SPIDR   SPIDR      0.2270040
# KCNIP1 KCNIP1      0.2186043
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/GSEA_pthresh_0.1//prep/cluster8.DE.tsv"
# [1] "Myclass"
# [1] 1648    7
# [1] 1642    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#               pvalue log2FoldChange pct.1 pct.2    padj_bonf         padj
# OR9Q1   1.082304e-08      0.1610702 0.327 0.132 0.0002060599 1.783637e-05
# XKR4    2.882887e-08      0.2648601 0.673 0.426 0.0005488728 2.166714e-05
# CACNA1E 3.944262e-08      0.3045096 0.663 0.429 0.0007509480 2.166714e-05
# DSCAML1 6.347643e-08      0.2996004 0.894 0.656 0.0012085278 2.615229e-05
# NOS1    8.083100e-08      0.2095611 0.433 0.214 0.0015389414 2.664190e-05
# PPP3CA  1.476629e-07     -0.3848197 0.721 0.776 0.0028113547 3.477235e-05
#                    ensg
# OR9Q1   ENSG00000186509
# XKR4    ENSG00000206579
# CACNA1E ENSG00000198216
# DSCAML1 ENSG00000177103
# NOS1    ENSG00000089250
# PPP3CA  ENSG00000138814
# [1] "here"
#              Gene log2FoldChange
# NCOR2       NCOR2      0.3289826
# FNDC3B     FNDC3B      0.3053310
# CACNA1E   CACNA1E      0.3045096
# ARHGAP26 ARHGAP26      0.3031086
# DSCAML1   DSCAML1      0.2996004
# SH3PXD2A SH3PXD2A      0.2779532
# preparing geneSet collections...
#
# GSEA analysis...
#
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in fgseaMultilevel(...):
# “For some pathways, in reality P-values are less than 1e-10. You can set the `eps` argument to zero for better estimation.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# leading edge analysis...
#
# done...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# [1] "Here we go .... :/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/GSEA_pthresh_0.1//prep/cluster9.DE.tsv"
# [1] "Myclass"
# [1] 10172     7
# [1] 3524    7
# [1] "pvalue"         "log2FoldChange" "pct.1"          "pct.2"
# [5] "padj_bonf"      "padj"           "ensg"
#               pvalue log2FoldChange pct.1 pct.2   padj_bonf        padj
# ANKRD44 3.511464e-07     -0.9269130 0.118 0.885 0.006685477 0.001190620
# CDH23   1.994185e-06     -0.9767119 0.176 0.847 0.037967292 0.001970732
# KDM4C   2.131150e-06     -0.7285555 0.118 0.808 0.040574962 0.001970732
# ZBTB16  6.818995e-06     -0.8635996 0.176 0.833 0.129826840 0.003009636
# OSBPL3  1.071772e-05     -0.7372069 0.118 0.755 0.204054608 0.003692687
# GAB2    1.122044e-05     -0.6473667 0.118 0.761 0.213625881 0.003692687
#                    ensg
# ANKRD44 ENSG00000065413
# CDH23   ENSG00000107736
# KDM4C   ENSG00000107077
# ZBTB16  ENSG00000109906
# OSBPL3  ENSG00000070882
# GAB2    ENSG00000033327
# [1] "here"
#            Gene log2FoldChange
# PLD5       PLD5       1.606308
# CDCP1     CDCP1       1.350161
# EXOC5     EXOC5       1.326394
# RASGRP3 RASGRP3       1.285011
# ARL6       ARL6       1.252783
# ALDH5A1 ALDH5A1       1.187421
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.03% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.03% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in fgseaMultilevel(...):
# “There were 12 pathways for which P-values were not calculated properly due to unbalanced (positive and negative) gene-level statistic values. For such pathways pval, padj, NES, log2err are set to NA. You can try to increase the value of the argument nPermSimple (for example set it nPermSimple = 10000)”
# Warning message in fgseaMultilevel(...):
# “For some of the pathways the P-values were likely overestimated. For such pathways log2err is set to NA.”
# leading edge analysis...
#
# done...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.03% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# no term enriched under specific pvalueCutoff...
#
# preparing geneSet collections...
#
# GSEA analysis...
#
# Warning message in preparePathwaysAndStats(pathways, stats, minSize, maxSize, gseaParam, :
# “There are ties in the preranked stats (0.03% of the list).
# The order of those tied genes will be arbitrary, which may produce unexpected results.”
# Warning message in fgseaMultilevel(...):
# “For some of the pathways the P-values were likely overestimated. For such pathways log2err is set to NA.”
# no term enriched under specific pvalueCutoff...
#
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# Warning message in is.na(egmt[[c]]):
# “is.na() applied to non-(list or vector) of type 'S4'”
# Warning message in summary(egmt[[c]]):
# “summary method to convert the object to data.frame is deprecated, please use as.data.frame instead.”
# [1] "preExcel writing"
# [1] "postExcel writing"
# .Primitive("return")

# %%
export.path
# Out:
# [1] "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/input_cond/DE_minPct_00_pval0.1/btwnClust/GSEA_pthresh_0.1/"

# %%
sessionInfo()
# Out:
# R version 4.1.1 (2021-08-10)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.3 LTS
#
# Matrix products: default
# BLAS/LAPACK: /home/isaac/miniconda3/envs/mttrace/lib/libopenblasp-r0.3.18.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats4    stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] stringr_1.4.0         ggplot2_3.3.5         dplyr_1.0.7
#  [4] openxlsx_4.2.4        data.table_1.14.2     gdata_2.18.0
#  [7] DOSE_3.20.1           org.Hs.eg.db_3.14.0   biomaRt_2.50.0
# [10] GSEABase_1.56.0       graph_1.72.0          annotate_1.72.0
# [13] XML_3.99-0.8          AnnotationDbi_1.56.1  IRanges_2.28.0
# [16] S4Vectors_0.32.0      Biobase_2.54.0        BiocGenerics_0.40.0
# [19] clusterProfiler_4.2.2
#
# loaded via a namespace (and not attached):
#   [1] fgsea_1.20.0           colorspace_2.0-2       ggtree_3.2.1
#   [4] ellipsis_0.3.2         IRdisplay_1.0          qvalue_2.26.0
#   [7] XVector_0.34.0         base64enc_0.1-3        aplot_0.1.2
#  [10] farver_2.1.0           graphlayouts_0.8.0     ggrepel_0.9.1
#  [13] bit64_4.0.5            fansi_0.4.2            scatterpie_0.1.7
#  [16] xml2_1.3.2             splines_4.1.1          cachem_1.0.6
#  [19] GOSemSim_2.20.0        polyclip_1.10-0        IRkernel_1.2
#  [22] jsonlite_1.7.2         dbplyr_2.1.1           GO.db_3.14.0
#  [25] png_0.1-7              ggforce_0.3.3          BiocManager_1.30.16
#  [28] compiler_4.1.1         httr_1.4.2             assertthat_0.2.1
#  [31] Matrix_1.3-4           fastmap_1.1.0          lazyeval_0.2.2
#  [34] tweenr_1.0.2           prettyunits_1.1.1      htmltools_0.5.2
#  [37] tools_4.1.1            igraph_1.2.9           gtable_0.3.0
#  [40] glue_1.5.1             GenomeInfoDbData_1.2.7 reshape2_1.4.4
#  [43] DO.db_2.9              rappdirs_0.3.3         fastmatch_1.1-3
#  [46] Rcpp_1.0.7             enrichplot_1.14.1      vctrs_0.3.8
#  [49] Biostrings_2.62.0      ape_5.6-1              nlme_3.1-153
#  [52] ggraph_2.0.5           lifecycle_1.0.1        gtools_3.9.2
#  [55] zlibbioc_1.40.0        MASS_7.3-54            scales_1.1.1
#  [58] tidygraph_1.2.0        hms_1.1.1              parallel_4.1.1
#  [61] RColorBrewer_1.1-2     curl_4.3.2             memoise_2.0.1
#  [64] gridExtra_2.3          downloader_0.4         ggfun_0.0.5
#  [67] yulab.utils_0.0.4      stringi_1.7.6          RSQLite_2.2.8
#  [70] tidytree_0.3.7         filelock_1.0.2         zip_2.2.0
#  [73] BiocParallel_1.28.0    repr_1.1.3             GenomeInfoDb_1.30.0
#  [76] rlang_0.4.12           pkgconfig_2.0.3        bitops_1.0-7
#  [79] evaluate_0.14          lattice_0.20-45        purrr_0.3.4
#  [82] labeling_0.4.2         treeio_1.18.1          patchwork_1.1.1
#  [85] shadowtext_0.1.1       bit_4.0.4              tidyselect_1.1.1
#  [88] plyr_1.8.6             magrittr_2.0.1         R6_2.5.1
#  [91] generics_0.1.1         pbdZMQ_0.3-6           DBI_1.1.1
#  [94] withr_2.4.2            pillar_1.6.4           KEGGREST_1.34.0
#  [97] RCurl_1.98-1.5         tibble_3.1.6           crayon_1.4.2
# [100] uuid_1.0-3             utf8_1.2.2             BiocFileCache_2.2.0
# [103] progress_1.2.2         viridis_0.6.2          grid_4.1.1
# [106] blob_1.2.2             digest_0.6.28          xtable_1.8-4
# [109] tidyr_1.1.4            gridGraphics_0.5-1     munsell_0.5.0
# [112] viridisLite_0.4.0      ggplotify_0.1.0

# %% [markdown]
# ###
