# %% [markdown]
# ## Plot markers umap embeddings
# Does this over each donor and separate

# %%
# Input info
se_f = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/SE.rds"
#sample_names = "preB,postB"
outdir = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap"


# Parallel processing
cores = 4

# R utils script
utils_script = "/data/Mito_Trace/R_scripts/seurat_utils.R"
markers_f = "/data/Mito_Trace/data/processed/cd34_markers_v02.txt"

# %%
library("Nebulosa")
# Out:
# Loading required package: ggplot2
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.1.3”
# Loading required package: patchwork
#
# Registered S3 method overwritten by 'spatstat.core':
#   method          from
#   formula.glmmPQL MASS

# %%
source(utils_script)
#outdir = outdir
dir.create(outdir, showWarnings = FALSE)
# Out:
# Attaching SeuratObject
#
# Attaching sp
#
# Warning message:
# “package ‘dplyr’ was built under R version 4.1.3”
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# sample_names <- unlist(strsplit(sample_names, ",")[[1]])
# sample_names

# %%
library(GenomicRanges)
library(Seurat)
library(Signac)
library(GenomeInfoDb)
library(EnsDb.Hsapiens.v75)
library(ggplot2)
library(patchwork)
set.seed(1234)
library(data.table)
library(magrittr)
library(cowplot)
library(metap)
library("RColorBrewer")

library(future)
plan()

plan("multiprocess", workers = cores)
#options(future.globals.maxSize = 50000 * 1024^2) # for 50 Gb RAM
options(future.globals.maxSize = 8000 * 1024^2)

library(dplyr)
# Out:
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
# Warning message:
# “package ‘S4Vectors’ was built under R version 4.1.2”
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Warning message:
# “package ‘IRanges’ was built under R version 4.1.2”
#
# Attaching package: ‘IRanges’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# The following object is masked from ‘package:sp’:
#
#     %over%
#
#
# Loading required package: GenomeInfoDb
#
# Loading required package: ensembldb
#
# Loading required package: GenomicFeatures
#
# Loading required package: AnnotationDbi
#
# Loading required package: Biobase
#
# Warning message:
# “package ‘Biobase’ was built under R version 4.1.2”
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘AnnotationDbi’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
#
# Loading required package: AnnotationFilter
#
#
# Attaching package: 'ensembldb'
#
#
# The following object is masked from 'package:dplyr':
#
#     filter
#
#
# The following object is masked from 'package:stats':
#
#     filter
#
#
#
# Attaching package: 'data.table'
#
#
# The following object is masked from 'package:GenomicRanges':
#
#     shift
#
#
# The following object is masked from 'package:IRanges':
#
#     shift
#
#
# The following objects are masked from 'package:S4Vectors':
#
#     first, second
#
#
# The following objects are masked from 'package:dplyr':
#
#     between, first, last
#
#
# Warning message:
# "package 'magrittr' was built under R version 4.1.3"
#
# Attaching package: 'magrittr'
#
#
# The following object is masked from 'package:AnnotationFilter':
#
#     not
#
#
#
# Attaching package: 'cowplot'
#
#
# The following object is masked from 'package:patchwork':
#
#     align_plots
#
#
# Warning message:
# "package 'RColorBrewer' was built under R version 4.1.3"
# Warning message:
# "package 'future' was built under R version 4.1.3"
#
# Attaching package: 'future'
#
#
# The following object is masked from 'package:AnnotationFilter':
#
#     value
#
#
# The following object is masked from 'package:GenomicRanges':
#
#     values
#
#
# The following object is masked from 'package:S4Vectors':
#
#     values
# sequential:
# - args: function (..., envir = parent.frame())
# - tweaked: FALSE
# - call: NULL
# Warning message:
# "Strategy 'multiprocess' is deprecated in future (>= 1.20.0). Instead, explicitly specify either 'multisession' or 'multicore'. In the current R session, 'multiprocess' equals 'multicore'."

# %%
se <- readRDS(se_f)#file.path(indir, paste0("allSamples.integrated.rds")))
se

DefaultAssay(se) <- "RNA"
# Out:
# An object of class Seurat
# 212927 features across 13593 samples within 2 assays
# Active assay: RNA (19039 features, 0 variable features)
#  1 other assay present: ATAC
#  2 dimensional reductions calculated: integrated_lsi, umap

# %%
markers <- read.csv(markers_f, header=F)[[1]]

# %%
markers
# Out:
#  [1] "HLF"     "CD34"    "CD38"    "PTPRC"   "THY1"    "ITGA6"   "PF4"
#  [8] "CA1"     "HBA2"    "LY86"    "LYZ"     "GSTM1"   "FCN1"    "LTF"
# [15] "TPSAB1"  "PRG2"    "CD74"    "Siglec9" "VPREB1"  "MYL4"    "FCRLA"
# [22] "KIT"     "ADGRG1"  "DNTT"    "FLT3"    "LY6D"    "CD7"     "ITGB7"
# [29] "NAAA"    "CSF1R"   "F13A1"   "ELANE"   "IRF8"    "CEPBA"   "SPI1"
# [36] "SATB1"   "CD33"    "CD14"    "CD4"     "CD19"

# %% [markdown]
# ## Plot marker embeddings

# %%
# featplot <- function(name.sig, se, curr.outdir, feat.names=NULL){
#   if (!is.null(feat.names)){
#     name <- feat.names[name.sig,]
#   }else{
#     name <- name.sig
#   }
#   if (name.sig %in% rownames(se)){
#     feat <- FeaturePlot(se,  features=name.sig) + ggtitle(name)
#     ggsave(plot=feat,
#            file=file.path(curr.outdir, paste0(name.sig,".embedFeat.top.png")))
#   }else{
#     print(paste0("Feature no in object: ", name.sig))
#   }

# %%
featplot <- function(name.sig, se, curr.outdir, use.density){
    if (name.sig %in% rownames(se)){
        if(!file.exists(file.path(curr.outdir, paste0(name.sig,".embedFeat.top.png")))){
            feat <- FeaturePlot(se,  features=name.sig)
            ggsave(plot=feat,
                   file=file.path(curr.outdir, paste0(name.sig,".embedFeat.top.png")))
            ggsave(plot=feat,
                   file=file.path(curr.outdir, paste0(name.sig,".embedFeat.top.svg")))

            if(use.density){
                print("plot density")
                f <- plot_density(se, name.sig) + ggtitle(name.sig)
                ggsave(plot=f,
                   file=file.path(curr.outdir, paste0("density.", name.sig,".embedFeat.top.png")))
                ggsave(plot=f,
                   file=file.path(curr.outdir, paste0("density.", name.sig,".embedFeat.top.svg")))
            }
        }else{print("file already here. not overwriting. Please delete first")}
    }
}


sapply(markers, FUN=featplot, se=se, curr.outdir=outdir, use.density=TRUE)
# Out:
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# [1] "plot density"
# Saving 6.67 x 6.67 in image
#
# Saving 6.67 x 6.67 in image
# $HLF
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.HLF.embedFeat.top.svg"
#
# $CD34
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.CD34.embedFeat.top.svg"
#
# $CD38
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.CD38.embedFeat.top.svg"
#
# $PTPRC
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.PTPRC.embedFeat.top.svg"
#
# $THY1
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.THY1.embedFeat.top.svg"
#
# $ITGA6
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.ITGA6.embedFeat.top.svg"
#
# $PF4
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.PF4.embedFeat.top.svg"
#
# $CA1
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.CA1.embedFeat.top.svg"
#
# $HBA2
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.HBA2.embedFeat.top.svg"
#
# $LY86
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.LY86.embedFeat.top.svg"
#
# $LYZ
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.LYZ.embedFeat.top.svg"
#
# $GSTM1
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.GSTM1.embedFeat.top.svg"
#
# $FCN1
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.FCN1.embedFeat.top.svg"
#
# $LTF
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.LTF.embedFeat.top.svg"
#
# $TPSAB1
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.TPSAB1.embedFeat.top.svg"
#
# $PRG2
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.PRG2.embedFeat.top.svg"
#
# $CD74
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.CD74.embedFeat.top.svg"
#
# $Siglec9
# NULL
#
# $VPREB1
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.VPREB1.embedFeat.top.svg"
#
# $MYL4
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.MYL4.embedFeat.top.svg"
#
# $FCRLA
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.FCRLA.embedFeat.top.svg"
#
# $KIT
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.KIT.embedFeat.top.svg"
#
# $ADGRG1
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.ADGRG1.embedFeat.top.svg"
#
# $DNTT
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.DNTT.embedFeat.top.svg"
#
# $FLT3
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.FLT3.embedFeat.top.svg"
#
# $LY6D
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.LY6D.embedFeat.top.svg"
#
# $CD7
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.CD7.embedFeat.top.svg"
#
# $ITGB7
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.ITGB7.embedFeat.top.svg"
#
# $NAAA
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.NAAA.embedFeat.top.svg"
#
# $CSF1R
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.CSF1R.embedFeat.top.svg"
#
# $F13A1
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.F13A1.embedFeat.top.svg"
#
# $ELANE
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.ELANE.embedFeat.top.svg"
#
# $IRF8
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.IRF8.embedFeat.top.svg"
#
# $CEPBA
# NULL
#
# $SPI1
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.SPI1.embedFeat.top.svg"
#
# $SATB1
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.SATB1.embedFeat.top.svg"
#
# $CD33
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.CD33.embedFeat.top.svg"
#
# $CD14
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.CD14.embedFeat.top.svg"
#
# $CD4
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.CD4.embedFeat.top.svg"
#
# $CD19
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.CD19.embedFeat.top.svg"

# %% [markdown]
# ## Plot marker embeddings with peaks

# %%
DefaultAssay(se) <- "ATAC"
feature.names <- ClosestFeature(se, rownames(se))

# %%
featplot <- function(name.sig, se, curr.outdir, feat.names=NULL, use.density=TRUE){
    if (!is.null(feat.names)){
        name <- feat.names[name.sig,]
    }else{
        name <- name.sig
    }
    if (name.sig %in% rownames(se)){
        feat <- FeaturePlot(se,  features=name.sig) + ggtitle(name)
        ggsave(plot=feat,
               file=file.path(curr.outdir, paste0(name.sig,".embedFeat.top.png")))  
        ggsave(plot=feat,
               file=file.path(curr.outdir, paste0(name.sig,".embedFeat.top.svg")))  
        if(use.density){
            f <- plot_density(se, name.sig) + ggtitle(name)
            ggsave(plot=f,
                   file=file.path(curr.outdir, paste0("density.", name.sig,".embedFeat.top.png")))
            ggsave(plot=f,
                   file=file.path(curr.outdir, paste0("density.", name.sig,".embedFeat.top.svg")))
        }
    }
}

# %%
marker.feature.names <- feature.names %>% dplyr::filter(gene_name %in% markers)
rownames(marker.feature.names) <- marker.feature.names[,"query_region"]
marker.feature.names

marker.feature.names$name <- paste0(marker.feature.names$gene_name, "_", marker.feature.names$type)



sapply(rownames(marker.feature.names), 
       FUN=featplot, se=se, curr.outdir=outdir, feat.names=marker.feature.names["name"])
data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr1-207901271-207901463.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                           chr2-172440778-172441148
#  "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr2-172440778-172441148.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                             chr3-18363381-18363433
#    "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr3-18363381-18363433.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                             chr3-18405355-18405467
#    "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr3-18405355-18405467.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                             chr3-18418987-18419439
#    "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr3-18418987-18419439.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                             chr4-15785030-15785373
#    "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr4-15785030-15785373.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                             chr4-15804435-15804654
#    "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr4-15804435-15804654.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                             chr4-15891340-15891831
#    "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr4-15891340-15891831.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                             chr4-54640551-54640619
#    "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr4-54640551-54640619.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                             chr4-54653263-54653676
#    "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr4-54653263-54653676.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                             chr4-54674282-54674443
#    "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr4-54674282-54674443.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                           chr5-150092095-150092592
#  "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr5-150092095-150092592.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                           chr5-150110091-150110152
#  "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr5-150110091-150110152.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                               chr6-6251905-6252289
#      "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr6-6251905-6252289.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                               chr6-6594083-6594242
#      "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr6-6594083-6594242.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                               chr6-6616624-6617179
#      "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr6-6616624-6617179.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                           chr9-134909900-134910185
#  "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr9-134909900-134910185.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                            chr10-96313517-96313611
#   "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr10-96313517-96313611.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                            chr13-28071674-28071819
#   "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr13-28071674-28071819.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                            chr13-28108475-28108676
#   "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr13-28108475-28108676.embedFeat.top.svg"
#                                                                                                                                                                                                                                                                                                            chr17-55267173-55267235
#   "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_prefilterMerge_impute/knn/kparam_30/gff_A2_black/annotation_clones/markers/scrap/density.chr17-55267173-55267235.embedFeat.top.svg"

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
sessionInfo()
# Out:
# R version 4.1.1 (2021-08-10)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.4 LTS
#
# Matrix products: default
# BLAS/LAPACK: /home/isaac/miniconda3/envs/mttrace/lib/libopenblasp-r0.3.20.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats4    stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] future_1.25.0             RColorBrewer_1.1-3
#  [3] metap_1.1                 cowplot_1.1.1
#  [5] magrittr_2.0.3            data.table_1.14.2
#  [7] EnsDb.Hsapiens.v75_2.99.0 ensembldb_2.18.1
#  [9] AnnotationFilter_1.18.0   GenomicFeatures_1.46.1
# [11] AnnotationDbi_1.56.1      Biobase_2.54.0
# [13] GenomicRanges_1.46.1      GenomeInfoDb_1.30.1
# [15] IRanges_2.28.0            S4Vectors_0.32.3
# [17] BiocGenerics_0.40.0       dplyr_1.0.9
# [19] sp_1.4-7                  SeuratObject_4.1.0
# [21] Seurat_4.1.0              Signac_1.4.0
# [23] Nebulosa_1.4.0            patchwork_1.1.1
# [25] ggplot2_3.3.6
#
# loaded via a namespace (and not attached):
#   [1] utf8_1.2.2                  reticulate_1.24
#   [3] ks_1.13.5                   tidyselect_1.1.2
#   [5] RSQLite_2.2.8               htmlwidgets_1.5.4
#   [7] grid_4.1.1                  docopt_0.7.1
#   [9] BiocParallel_1.28.3         Rtsne_0.16
#  [11] munsell_0.5.0               codetools_0.2-18
#  [13] ica_1.0-2                   pbdZMQ_0.3-7
#  [15] miniUI_0.1.1.1              withr_2.5.0
#  [17] spatstat.random_2.2-0       colorspace_2.0-3
#  [19] progressr_0.10.0            filelock_1.0.2
#  [21] uuid_1.1-0                  SingleCellExperiment_1.16.0
#  [23] ROCR_1.0-11                 tensor_1.5
#  [25] listenv_0.8.0               labeling_0.4.2
#  [27] Rdpack_2.3                  MatrixGenerics_1.6.0
#  [29] slam_0.1-50                 repr_1.1.4
#  [31] GenomeInfoDbData_1.2.7      polyclip_1.10-0
#  [33] bit64_4.0.5                 farver_2.1.0
#  [35] parallelly_1.31.1           vctrs_0.4.1
#  [37] generics_0.1.2              BiocFileCache_2.2.0
#  [39] lsa_0.73.2                  ggseqlogo_0.1
#  [41] R6_2.5.1                    bitops_1.0-7
#  [43] spatstat.utils_2.3-0        cachem_1.0.6
#  [45] DelayedArray_0.20.0         assertthat_0.2.1
#  [47] BiocIO_1.4.0                promises_1.2.0.1
#  [49] scales_1.2.0                rgeos_0.5-9
#  [51] gtable_0.3.0                globals_0.14.0
#  [53] goftest_1.2-3               rlang_1.0.2
#  [55] systemfonts_1.0.3           RcppRoll_0.3.0
#  [57] splines_4.1.1               rtracklayer_1.54.0
#  [59] lazyeval_0.2.2              spatstat.geom_2.4-0
#  [61] yaml_2.3.5                  reshape2_1.4.4
#  [63] abind_1.4-5                 httpuv_1.6.5
#  [65] tools_4.1.1                 ellipsis_0.3.2
#  [67] spatstat.core_2.4-2         ggridges_0.5.3
#  [69] Rcpp_1.0.8.3                plyr_1.8.7
#  [71] base64enc_0.1-3             progress_1.2.2
#  [73] zlibbioc_1.40.0             purrr_0.3.4
#  [75] RCurl_1.98-1.6              prettyunits_1.1.1
#  [77] rpart_4.1.16                deldir_1.0-6
#  [79] pbapply_1.5-0               zoo_1.8-10
#  [81] SummarizedExperiment_1.24.0 ggrepel_0.9.1
#  [83] cluster_2.1.3               scattermore_0.8
#  [85] lmtest_0.9-40               RANN_2.6.1
#  [87] mvtnorm_1.1-3               SnowballC_0.7.0
#  [89] ProtGenerics_1.26.0         fitdistrplus_1.1-8
#  [91] matrixStats_0.62.0          hms_1.1.1
#  [93] mime_0.12                   evaluate_0.15
#  [95] xtable_1.8-4                XML_3.99-0.9
#  [97] mclust_5.4.10               sparsesvd_0.2
#  [99] gridExtra_2.3               compiler_4.1.1
# [101] biomaRt_2.50.0              tibble_3.1.7
# [103] KernSmooth_2.23-20          crayon_1.5.1
# [105] htmltools_0.5.2             mgcv_1.8-40
# [107] later_1.3.0                 tidyr_1.2.0
# [109] DBI_1.1.2                   tweenr_1.0.2
# [111] dbplyr_2.1.1                rappdirs_0.3.3
# [113] MASS_7.3-57                 Matrix_1.4-1
# [115] cli_3.3.0                   rbibutils_2.2.8
# [117] parallel_4.1.1              igraph_1.3.1
# [119] pkgconfig_2.0.3             GenomicAlignments_1.30.0
# [121] IRdisplay_1.1               plotly_4.10.0
# [123] spatstat.sparse_2.1-1       xml2_1.3.3
# [125] svglite_2.1.0               XVector_0.34.0
# [127] stringr_1.4.0               digest_0.6.29
# [129] sctransform_0.3.3           RcppAnnoy_0.0.19
# [131] pracma_2.3.8                spatstat.data_2.2-0
# [133] Biostrings_2.62.0           leiden_0.3.10
# [135] fastmatch_1.1-3             uwot_0.1.11
# [137] restfulr_0.0.13             curl_4.3.2
# [139] shiny_1.7.1                 Rsamtools_2.10.0
# [141] rjson_0.2.21                lifecycle_1.0.1
# [143] nlme_3.1-157                jsonlite_1.8.0
# [145] viridisLite_0.4.0           fansi_1.0.3
# [147] pillar_1.7.0                lattice_0.20-45
# [149] KEGGREST_1.34.0             fastmap_1.1.0
# [151] httr_1.4.3                  survival_3.3-1
# [153] glue_1.6.2                  qlcMatrix_0.9.7
# [155] png_0.1-7                   bit_4.0.4
# [157] ggforce_0.3.3               stringi_1.7.6
# [159] blob_1.2.3                  memoise_2.0.1
# [161] IRkernel_1.2                irlba_2.3.5
# [163] future.apply_1.9.0
