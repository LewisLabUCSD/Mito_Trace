# %%
ids.reversed = TRUE


#cells_meta_f = "/data/Mito_Trace/output/pipeline/DUPI_april08_2021/MTblacklist_mtasnucl_Bonly/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/cells_meta.tsv" 
se_f = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/annotation/gff_A2_black/mergedSamples/allSamples.integrated.rds" 
outdir = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/annotation/gff_A2_black/mergedSamples"


cluster_labels_f = "/mnt/md0/isshamie/Projects/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/results/chip_b1_lineage_markers.txt"

# %%
se <- readRDS(se_f)
se[[]]
# Out:
# Loading required package: SeuratObject
#
# Warning message:
# “package ‘SeuratObject’ was built under R version 4.1.3”
# Attaching sp
#                          orig.ident nCount_ATAC nFeature_ATAC total duplicate
# Flt3l_AAACGAAAGGAGACTC-1 Flt3l       531         531           2286  298
# Flt3l_AAACGAAAGTCACGCC-1 Flt3l      1222        1222           4711  555
# Flt3l_AAACGAACAAGACTAA-1 Flt3l      2225        2225           9178 1509
# Flt3l_AAACGAACAAGCGAAC-1 Flt3l      2271        2271           8825 1544
# Flt3l_AAACGAACACAGCCAC-1 Flt3l      2854        2854          10589 1294
# Flt3l_AAACGAACACAGGTAG-1 Flt3l       615         615           2384  240
# Flt3l_AAACGAACACAGTAGG-1 Flt3l      2545        2545          10019 1869
# Flt3l_AAACGAACATAGAATG-1 Flt3l       985         985           3395  433
# Flt3l_AAACGAACATGTAGAA-1 Flt3l      1020        1020           5086  708
# Flt3l_AAACGAAGTATTCGAC-1 Flt3l       894         894           4999  553
# ...

# %%
meta <- se[[]]

# %%
clusters <- read.csv(cluster_labels_f, header = FALSE)
row.names(clusters) = clusters$V1
meta$cluster_labels <- sapply(meta$seurat_clusters, function(x) (clusters[as.character(x), "V2"]) )

se <- AddMetaData(se, meta["cluster_labels"])
se[[]]
# Out:
# Loading required package: Signac
#
# Registered S3 method overwritten by 'spatstat.core':
#   method          from
#   formula.glmmPQL MASS
#                          orig.ident nCount_ATAC nFeature_ATAC total duplicate
# Flt3l_AAACGAAAGGAGACTC-1 Flt3l       531         531           2286  298
# Flt3l_AAACGAAAGTCACGCC-1 Flt3l      1222        1222           4711  555
# Flt3l_AAACGAACAAGACTAA-1 Flt3l      2225        2225           9178 1509
# Flt3l_AAACGAACAAGCGAAC-1 Flt3l      2271        2271           8825 1544
# Flt3l_AAACGAACACAGCCAC-1 Flt3l      2854        2854          10589 1294
# Flt3l_AAACGAACACAGGTAG-1 Flt3l       615         615           2384  240
# Flt3l_AAACGAACACAGTAGG-1 Flt3l      2545        2545          10019 1869
# Flt3l_AAACGAACATAGAATG-1 Flt3l       985         985           3395  433
# Flt3l_AAACGAACATGTAGAA-1 Flt3l      1020        1020           5086  708
# Flt3l_AAACGAAGTATTCGAC-1 Flt3l       894         894           4999  553
# ...

# %%
# if ((cluster_labels_f != "") & (cluster_labels_f != "FALSE") & (cluster_labels_f != "None" )){
#     print("Adding label information")
#     row.names(clusters) = clusters$V1
#     meta$cluster_labels <- sapply(meta$seurat_clusters, function(x) (clusters[as.character(x), "V2"]) )
# }else{
#     meta$cluster_labels <- meta$seurat_clusters
# }
# meta

# %%
# #library("Seurat")
# library(magrittr)
# library(cowplot)
# library(Signac)
# library(patchwork)
# set.seed(1234)
# library(magrittr)
# library(cowplot)
# library(metap)
# library(dplyr)
# library(future)


library("Seurat")
library(ggplot2)
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 4.1.3”

# %%
Idents(se) <- "orig.ident"
DimPlot(object = se, label = FALSE, split.by = c('orig.ident'),) 
ggsave(file.path(outdir, paste0("condition_umap.pdf")))
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %%
Idents(se) <- "orig.ident"
DimPlot(object = se, label = FALSE, group.by = c('orig.ident'),) 
ggsave(file.path(outdir, paste0("conditionOverlap_umap.pdf")))
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %%
Idents(se) <- "cluster_labels"

# Idents(t.cells) <- "orig.ident"
#DimPlot(object = se, label = FALSE, group.by = c('orig.ident')) 
DimPlot(object = se, label = FALSE, split.by = c('orig.ident'), ncol=1)
ggsave(file.path(outdir, paste0("cluster_condition_umap.pdf")), width=8, heigh=8)

#ggsave(file.path(outdir, paste0("donor_umap.pdf")))
# Out:
# plot without title

# %%
Idents(se) <- "cluster_labels"

DimPlot(object = se, label = FALSE, split.by = c('orig.ident')) 
ggsave(file.path(outdir, paste0("cluster_condition_umap.pdf")))

#ggsave(file.path(outdir, paste0("donor_umap.pdf")))
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %%
DimPlot(object = se, label = FALSE) 
ggsave(file.path(outdir, paste0("cluster_umap.pdf")))
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %%
Idents(se) <- "seurat_clusters"

# Idents(t.cells) <- "orig.ident"
#DimPlot(object = se, label = FALSE, group.by = c('orig.ident')) 
DimPlot(object = se, label = FALSE, split.by = c('orig.ident')) 
ggsave(file.path(outdir, paste0("cluster_condition_umap_noLabels.pdf")))

#ggsave(file.path(outdir, paste0("donor_umap.pdf")))
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %%
sessionInfo()
# Out:
# R version 4.1.1 (2021-08-10)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.4 LTS
#
# Matrix products: default
# BLAS/LAPACK: /home/isaac/miniconda3/envs/mttrace/lib/libopenblasp-r0.3.20.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] ggplot2_3.3.6      Seurat_4.1.0       Signac_1.4.0       sp_1.4-7
# [5] SeuratObject_4.1.0
#
# loaded via a namespace (and not attached):
#   [1] uuid_1.1-0             fastmatch_1.1-3        plyr_1.8.7
#   [4] igraph_1.3.1           repr_1.1.4             lazyeval_0.2.2
# ...
