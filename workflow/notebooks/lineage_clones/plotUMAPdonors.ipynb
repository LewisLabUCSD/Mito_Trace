# %%
cells_meta_f = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_30/cells_meta.tsv" 
#se_f = "/data/Mito_Trace/output/pipeline/DUPI_april08_2021/MTblacklist_mtasnucl_Bonly/data/annotation/gff_hg38_1_2/mergedSamples/allSamples.integrated.rds" 
ids.reversed = TRUE

outdir = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_30/gff_A2_black/annotation_clones"
#save_rds = FALSE

# %%
library("Seurat")
library(ggplot2)
# Out:
# Registered S3 method overwritten by 'spatstat.core':
#   method          from
#   formula.glmmPQL MASS
#
# Attaching SeuratObject
#
# Attaching sp
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.1.3”

# %%
se = readRDS(file.path(outdir, "SE.rds"))
se[[]]
# Out:
#                          orig.ident nCount_ATAC nFeature_ATAC total duplicate
# Flt3l_AAACGAAAGGAGACTC-1 Flt3l       531         531           2286  298
# Flt3l_AAACGAAAGTCACGCC-1 Flt3l      1222        1222           4711  555
# Flt3l_AAACGAACAAGACTAA-1 Flt3l      2225        2225           9178 1509
# Flt3l_AAACGAACAAGCGAAC-1 Flt3l      2271        2271           8825 1544
# Flt3l_AAACGAACACAGCCAC-1 Flt3l      2854        2854          10589 1294
# Flt3l_AAACGAACACAGGTAG-1 Flt3l       615         615           2384  240
# Flt3l_AAACGAACACAGTAGG-1 Flt3l      2545        2545          10019 1869
# Flt3l_AAACGAACATAGAATG-1 Flt3l       985         985           3395  433
# Flt3l_AAACGAACATGTAGAA-1 Flt3l      1020        1020           5086  708
# Flt3l_AAACGAAGTATTCGAC-1 Flt3l       894         894           4999  553
# Flt3l_AAACGAAGTCTGATTG-1 Flt3l      4239        4239          15047 1940
# Flt3l_AAACGAATCGCTGATA-1 Flt3l      1521        1521           6172 1092
# ...

# %%
# cells_meta <- as.data.frame(readr::read_tsv(cells_meta_f)) # %>% tidyr::unite(barcode)
# rownames(cells_meta) = cells_meta$ID

# if (ids.reversed){
#     split.names <- stringr::str_split(rownames(cells_meta), "_")
#     rownames(cells_meta) = lapply(split.names, function(x){paste0(x[2], "_", x[1])})
# }
# head(cells_meta)

# new_cells_meta = merge(cells_meta, se[[]], by=0, all=TRUE)
# rownames(new_cells_meta) <- new_cells_meta$Row.names
# head(new_cells_meta)



# se$ID <- apply(stringr::str_split((rownames(se[[]])), "_", simplify=T)[,1:2], 1, function(x) {paste0(x[[1]],  "_", x[[2]])})
# se <- RenameCells(se, new.names=se$ID)

# %%
pclust <- DimPlot(object = se, label = TRUE) + NoLegend() + ggtitle("labels")
pclust
ggsave(plot = pclust, filename =  file.path(outdir,"umap.clusters.svg"), width = 16, height = 16)
# Out:
# Loading required package: Signac
# plot without title

# %%
p1 <- DimPlot(se, group.by = "proj") + 
              ggtitle("condition")

ggsave(filename = file.path(outdir,"umap.conditions.svg"), plot = p1, height=16, width=16)

p1
# Out:
# plot without title

# %%
pd <- DimPlot(se, group.by = "proj") + 
              ggtitle("donor")

#ggsave(filename = file.path(outdir,"umap.donors.svg"), plot = p1, height=16, width=16)

pd
# Out:
# plot without title
