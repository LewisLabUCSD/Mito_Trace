# %%
#se_f = "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/SE.rds"
#outdir = "/data/Mito_Trace/output/pipeline/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_3/concat/gff_A2_black/annotation_clones/umap_clones_overlay"
#se_f = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/clones/variants_init/knn/kparam_30/gff_A2_black/annotation_clones/SE.rds"
se_f = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/annotation/gff_A2_black/mergedSamples/allSamples.integrated.rds" 
cells_meta_f = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/single_clones/donor0/cloneMethod_variants_init_mt_bestparams_af.0.1_othaf.0.1_cov.10_othcov.10_ncells.10_othncells.0.25_mean.0/clonalShift_method_mt_as_clones_dendro/cells_meta.tsv"
#outdir = "/data/Mito_Trace/output/pipeline/v02/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/single_clones/donor0/cloneMethod_variants_init_mt_bestparams_af.0.1_othaf.0.1_cov.10_othcov.10_ncells.10_othncells.0.25_mean.0/clonalShift_method_mt_as_clones_dendro/umap_overlay"

# %%
library("Nebulosa")


library("Seurat")
#library("Seurat")
library(magrittr)
library(cowplot)
library(ggplot2)
library(Signac)
library(patchwork)
set.seed(1234)
library(magrittr)
library(cowplot)
library(metap)
library(dplyr)
library(future)
# Out:
# Loading required package: ggplot2
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.1.3”
# Loading required package: patchwork
#
# Registered S3 method overwritten by 'spatstat.core':
#   method          from
#   formula.glmmPQL MASS
#
# Attaching SeuratObject
#
# Attaching sp
#
# Warning message:
# “package ‘magrittr’ was built under R version 4.1.3”
#
# Attaching package: ‘cowplot’
#
#
# The following object is masked from ‘package:patchwork’:
#
#     align_plots
#
#
# Warning message:
# “package ‘dplyr’ was built under R version 4.1.3”
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# “package ‘future’ was built under R version 4.1.3”

# %%
#BiocManager::install("Nebulosa")

# %%
cells_meta <- as.data.frame(readr::read_tsv(cells_meta_f),) # %>% tidyr::unite(barcode)

curr.cols <- colnames(cells_meta) 
curr.cols[[1]] = "cell"
curr.cols
colnames(cells_meta)  <- curr.cols
row.names(cells_meta) <- cells_meta$cell
cells_meta
# Out:
# New names:
# • `` -> `...1`
# Rows: 8660 Columns: 5
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (4): ...1, cloneID, condition, clusterID
# dbl (1): donor
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# [1] "cell"      "donor"     "cloneID"   "condition" "clusterID"
#                            cell                       donor cloneID condition
# Input_GCGCCAAGTTGCCTGG-1   Input_GCGCCAAGTTGCCTGG-1   0     0_C8    Input
# Flt3l_GGTCATACAAGGCGTA-1   Flt3l_GGTCATACAAGGCGTA-1   0     0_C7    Flt3l
# Control_CAGTGCGAGGTTCTCA-1 Control_CAGTGCGAGGTTCTCA-1 0     0_C0    Control
# Input_ACTTTCAGTACTATGC-1   Input_ACTTTCAGTACTATGC-1   0     0_C8    Input
# Input_TTGACGATCCTCCATG-1   Input_TTGACGATCCTCCATG-1   0     0_C8    Input
# Flt3l_AGGCGAATCACCACAA-1   Flt3l_AGGCGAATCACCACAA-1   0     0_C0    Flt3l
# Control_TGCTCACTCGCTTGAA-1 Control_TGCTCACTCGCTTGAA-1 0     0_C5    Control
# Control_AGCTATGGTCCGCTTT-1 Control_AGCTATGGTCCGCTTT-1 0     0_C5    Control
# Input_CCACAGGGTGGACAGT-1   Input_CCACAGGGTGGACAGT-1   0     0_C5    Input
# Flt3l_TCACTCGAGGTTACAA-1   Flt3l_TCACTCGAGGTTACAA-1   0     0_C0    Flt3l
# Flt3l_TGGACATAGACACAAT-1   Flt3l_TGGACATAGACACAAT-1   0     0_C1    Flt3l
# Input_TCAGTTTTCGGTACTA-1   Input_TCAGTTTTCGGTACTA-1   0     0_C8    Input
# Flt3l_TACATGGTCCGCCTAT-1   Flt3l_TACATGGTCCGCCTAT-1   0     0_C5    Flt3l
# Input_TACATGGTCCATCTAT-1   Input_TACATGGTCCATCTAT-1   0     0_C7    Input
# Flt3l_AGCGTATGTAAAGCTA-1   Flt3l_AGCGTATGTAAAGCTA-1   0     0_C0    Flt3l
# Input_GCCAGCACATGATCGT-1   Input_GCCAGCACATGATCGT-1   0     0_C8    Input
# Flt3l_TTGAGTGGTGCGACCT-1   Flt3l_TTGAGTGGTGCGACCT-1   0     0_C0    Flt3l
# Control_TGATTTCAGGCAATTA-1 Control_TGATTTCAGGCAATTA-1 0     0_C0    Control
# Input_CAAAGCTAGGCACCTC-1   Input_CAAAGCTAGGCACCTC-1   0     0_C5    Input
# Flt3l_GGAACCCCACTGTCAA-1   Flt3l_GGAACCCCACTGTCAA-1   0     0_C6    Flt3l
# Flt3l_CATGCCTTCACACGTA-1   Flt3l_CATGCCTTCACACGTA-1   0     0_C5    Flt3l
# Flt3l_TGACAACTCGTTACAG-1   Flt3l_TGACAACTCGTTACAG-1   0     0_C8    Flt3l
# Control_CCCAGAGGTACGGAGT-1 Control_CCCAGAGGTACGGAGT-1 0     0_C8    Control
# Input_TAATCGGCATACAACC-1   Input_TAATCGGCATACAACC-1   0     0_C5    Input
# Input_ATGCATGTCCCGGGTA-1   Input_ATGCATGTCCCGGGTA-1   0     0_C5    Input
# Control_AATGGAACACCTGTGG-1 Control_AATGGAACACCTGTGG-1 0     0_C5    Control
# Input_TAGGTCACAAGGTTCT-1   Input_TAGGTCACAAGGTTCT-1   0     0_C5    Input
# Control_GCGAGAATCGGATGTT-1 Control_GCGAGAATCGGATGTT-1 0     0_C0    Control
# Input_CTAGCGGGTTTCACCC-1   Input_CTAGCGGGTTTCACCC-1   0     0_C5    Input
# Flt3l_TAGGAGGTCTCTGCGT-1   Flt3l_TAGGAGGTCTCTGCGT-1   0     0_C8    Flt3l
# ⋮                          ⋮                          ⋮     ⋮       ⋮
# Control_GAACCGCCACCTGAAT-1 Control_GAACCGCCACCTGAAT-1 0     0_C0    Control
# Input_GCTCAGGCACCTATTT-1   Input_GCTCAGGCACCTATTT-1   0     0_C5    Input
# Flt3l_CTGGGACGTAGGTCTT-1   Flt3l_CTGGGACGTAGGTCTT-1   0     0_C5    Flt3l
# Control_GTGCACGTCCACGGCA-1 Control_GTGCACGTCCACGGCA-1 0     0_C8    Control
# Input_TTACTCACATAGCCGC-1   Input_TTACTCACATAGCCGC-1   0     0_C8    Input
# Control_TTGCCCACACTAAACC-1 Control_TTGCCCACACTAAACC-1 0     0_C0    Control
# Input_GTGCCAGGTTTCCACC-1   Input_GTGCCAGGTTTCCACC-1   0     0_C5    Input
# Flt3l_TCCATCGGTTTCGACA-1   Flt3l_TCCATCGGTTTCGACA-1   0     0_C3    Flt3l
# Input_GTGACATCATGGATGG-1   Input_GTGACATCATGGATGG-1   0     0_C8    Input
# Input_ACAATCGGTCCGTAGC-1   Input_ACAATCGGTCCGTAGC-1   0     0_C8    Input
# Flt3l_TGCTATTCATTACCTT-1   Flt3l_TGCTATTCATTACCTT-1   0     0_C0    Flt3l
# Input_AGCGTGCCAGAGCCAA-1   Input_AGCGTGCCAGAGCCAA-1   0     0_C8    Input
# Input_GAGACTTAGGCCTAAG-1   Input_GAGACTTAGGCCTAAG-1   0     0_C8    Input
# Control_TAGGTGTGTCGGCTGT-1 Control_TAGGTGTGTCGGCTGT-1 0     0_C0    Control
# Input_TTAGGTGCAGAACTTC-1   Input_TTAGGTGCAGAACTTC-1   0     0_C8    Input
# Input_CAACGTAGTTTCCTAT-1   Input_CAACGTAGTTTCCTAT-1   0     0_C0    Input
# Flt3l_CTAGCGGCAAACCCTA-1   Flt3l_CTAGCGGCAAACCCTA-1   0     0_C0    Flt3l
# Flt3l_GGAGGATCAAGATTAG-1   Flt3l_GGAGGATCAAGATTAG-1   0     0_C0    Flt3l
# Flt3l_CTAACTTGTTCAGAAA-1   Flt3l_CTAACTTGTTCAGAAA-1   0     0_C0    Flt3l
# Flt3l_GAAACAACACTGTCGG-1   Flt3l_GAAACAACACTGTCGG-1   0     0_C0    Flt3l
# Flt3l_TAGCCGGAGAACCATA-1   Flt3l_TAGCCGGAGAACCATA-1   0     0_C0    Flt3l
# Input_TAGCATGCAATGTGCT-1   Input_TAGCATGCAATGTGCT-1   0     0_C0    Input
# Control_TACGCAACAGACTAAA-1 Control_TACGCAACAGACTAAA-1 0     0_C5    Control
# Input_TCTATTGTCGGTTAGT-1   Input_TCTATTGTCGGTTAGT-1   0     0_C5    Input
# Input_ATGTTTCGTGAGTAAT-1   Input_ATGTTTCGTGAGTAAT-1   0     0_C5    Input
# Control_GGATAGGAGCTCGTTA-1 Control_GGATAGGAGCTCGTTA-1 0     0_C1    Control
# Input_ACATGCAAGAAATACC-1   Input_ACATGCAAGAAATACC-1   0     0_C0    Input
# Input_TCCAGAAGTAGGGTCA-1   Input_TCCAGAAGTAGGGTCA-1   0     0_C5    Input
# Flt3l_CTGTTCGGTGGTTCTA-1   Flt3l_CTGTTCGGTGGTTCTA-1   0     0_C0    Flt3l
# Flt3l_CGGTGCAAGCGCGTTC-1   Flt3l_CGGTGCAAGCGCGTTC-1   0     0_C5    Flt3l
#                            clusterID
# Input_GCGCCAAGTTGCCTGG-1   MPP/CMP/GMP
# Flt3l_GGTCATACAAGGCGTA-1   neutrophil B
# Control_CAGTGCGAGGTTCTCA-1 eosonophil
# Input_ACTTTCAGTACTATGC-1   MPP/CMP/GMP
# Input_TTGACGATCCTCCATG-1   neutrophil B
# Flt3l_AGGCGAATCACCACAA-1   macrophage
# Control_TGCTCACTCGCTTGAA-1 macrophage
# Control_AGCTATGGTCCGCTTT-1 erythroid
# Input_CCACAGGGTGGACAGT-1   macrophage
# Flt3l_TCACTCGAGGTTACAA-1   neutrophil
# Flt3l_TGGACATAGACACAAT-1   MPP/CMP/GMP C
# Input_TCAGTTTTCGGTACTA-1   MEP
# Flt3l_TACATGGTCCGCCTAT-1   erythroid
# Input_TACATGGTCCATCTAT-1   MPP/CMP/GMP B
# Flt3l_AGCGTATGTAAAGCTA-1   eosonophil
# Input_GCCAGCACATGATCGT-1   MPP/CMP/GMP B
# Flt3l_TTGAGTGGTGCGACCT-1   MPP/CMP/GMP C
# Control_TGATTTCAGGCAATTA-1 macrophage
# Input_CAAAGCTAGGCACCTC-1   MPP/CMP/GMP B
# Flt3l_GGAACCCCACTGTCAA-1   eosonophil
# Flt3l_CATGCCTTCACACGTA-1   meg/erythroid
# Flt3l_TGACAACTCGTTACAG-1   neutrophil
# Control_CCCAGAGGTACGGAGT-1 neutrophil B
# Input_TAATCGGCATACAACC-1   meg/erythroid
# Input_ATGCATGTCCCGGGTA-1   MPP/CMP/GMP
# Control_AATGGAACACCTGTGG-1 eosonophil
# Input_TAGGTCACAAGGTTCT-1   MEP
# Control_GCGAGAATCGGATGTT-1 neutrophil B
# Input_CTAGCGGGTTTCACCC-1   MEP
# Flt3l_TAGGAGGTCTCTGCGT-1   erythroid
# ⋮                          ⋮
# Control_GAACCGCCACCTGAAT-1 macrophage
# Input_GCTCAGGCACCTATTT-1   MPP/CMP/GMP
# Flt3l_CTGGGACGTAGGTCTT-1   erythroid
# Control_GTGCACGTCCACGGCA-1 neutrophil
# Input_TTACTCACATAGCCGC-1   MPP/CMP/GMP
# Control_TTGCCCACACTAAACC-1 eosonophil
# Input_GTGCCAGGTTTCCACC-1   MPP/CMP/GMP B
# Flt3l_TCCATCGGTTTCGACA-1   erythroid
# Input_GTGACATCATGGATGG-1   CLP
# Input_ACAATCGGTCCGTAGC-1   MPP/CMP/GMP B
# Flt3l_TGCTATTCATTACCTT-1   neutrophil
# Input_AGCGTGCCAGAGCCAA-1   MPP/CMP/GMP
# Input_GAGACTTAGGCCTAAG-1   MPP/CMP/GMP B
# Control_TAGGTGTGTCGGCTGT-1 eosonophil
# Input_TTAGGTGCAGAACTTC-1   MPP/CMP/GMP
# Input_CAACGTAGTTTCCTAT-1   MPP/CMP/GMP B
# Flt3l_CTAGCGGCAAACCCTA-1   neutrophil B
# Flt3l_GGAGGATCAAGATTAG-1   neutrophil
# Flt3l_CTAACTTGTTCAGAAA-1   macrophage
# Flt3l_GAAACAACACTGTCGG-1   neutrophil
# Flt3l_TAGCCGGAGAACCATA-1   macrophage
# Input_TAGCATGCAATGTGCT-1   MPP/CMP/GMP B
# Control_TACGCAACAGACTAAA-1 neutrophil
# Input_TCTATTGTCGGTTAGT-1   MPP/CMP/GMP B
# Input_ATGTTTCGTGAGTAAT-1   MPP/CMP/GMP
# Control_GGATAGGAGCTCGTTA-1 neutrophil
# Input_ACATGCAAGAAATACC-1   MPP/CMP/GMP B
# Input_TCCAGAAGTAGGGTCA-1   MPP/CMP/GMP B
# Flt3l_CTGTTCGGTGGTTCTA-1   meg/erythroid
# Flt3l_CGGTGCAAGCGCGTTC-1   MPP/CMP/GMP D

# %% [markdown]
# ## Need to change the cell IDs to have condition as prefix

# %%
se <- readRDS(se_f)
se$ID <- apply(stringr::str_split((rownames(se[[]])), "_", simplify=T)[,1:2], 1, function(x) {paste0(x[[2]],  "_", x[[1]])})
se <- RenameCells(se, new.names=se$ID)

coord = max(max(Embeddings(se[["umap"]])), abs(min(Embeddings(se[["umap"]]))))
coord
se[[]]
# Out:
# [1] 9.523125
#                            orig.ident nCount_ATAC nFeature_ATAC total duplicate
# AAACGAAAGAATCAGT-1_Control Control    1972        1972           6432 1259
# AAACGAAAGCATACCT-1_Control Control    2674        2674          11858 1937
# AAACGAAAGCGAGAAA-1_Control Control    1939        1939           7365 1097
# AAACGAAAGTACAGAT-1_Control Control     862         862           4095  861
# AAACGAAAGTACAGTA-1_Control Control    1775        1775           8088 1091
# AAACGAAAGTGTCGGA-1_Control Control     756         756           3362  524
# AAACGAACACTCGCAG-1_Control Control    1444        1444           6285  831
# AAACGAAGTCTTAGCA-1_Control Control    1921        1921          10456 1353
# AAACGAAGTGAGGGTT-1_Control Control     425         425           1347  226
# AAACGAATCAGGCGCT-1_Control Control    7347        7347          33434 6309
# AAACGAATCCATCGAA-1_Control Control    3980        3980          19085 3491
# AAACGAATCCCACGGA-1_Control Control    2655        2655          10468 1550
# AAACGAATCTCGTAGA-1_Control Control    1487        1487           6532 1102
# AAACTCGAGTCTCTAG-1_Control Control    1521        1521           7080 1150
# AAACTCGAGTGAAGGA-1_Control Control    2323        2323           8492 1182
# AAACTCGCATGCACTA-1_Control Control    4322        4322          22421 3235
# AAACTCGGTCTCTGGG-1_Control Control    1038        1038           3433  636
# AAACTCGGTCTGCACG-1_Control Control    2226        2226          10751 1285
# AAACTCGGTTGGCTTA-1_Control Control    3507        3507          17456 2829
# AAACTCGTCGGGAAAC-1_Control Control    1727        1727           7197 1049
# AAACTCGTCTGCGTCT-1_Control Control    1650        1650           7665 1178
# AAACTGCAGCCCATGC-1_Control Control    2478        2478          11638 1560
# AAACTGCAGCGTTGCC-1_Control Control    4532        4532          17895 2441
# AAACTGCAGGATGTAT-1_Control Control    2149        2149          10499 1546
# AAACGAATCCCACGGA-1_Control 0               Low      NS < 4
# AAACGAATCTCGTAGA-1_Control 0               Low      NS < 4
# AAACTCGAGTCTCTAG-1_Control 0               Low      NS < 4
# AAACTCGAGTGAAGGA-1_Control 0               Low      NS < 4
# AAACTCGCATGCACTA-1_Control 0               High     NS < 4
# AAACTCGGTCTCTGGG-1_Control 0               High     NS < 4
# AAACTCGGTCTGCACG-1_Control 0               Low      NS < 4
# AAACTCGGTTGGCTTA-1_Control 0               Low      NS < 4
# AAACTCGTCGGGAAAC-1_Control 0               Low      NS < 4
# AAACTCGTCTGCGTCT-1_Control 0               Low      NS < 4
# AAACTGCAGCCCATGC-1_Control 0               Low      NS < 4
# AAACTGCAGCGTTGCC-1_Control 0               Low      NS < 4
# AAACTGCAGGATGTAT-1_Control 0               Low      NS < 4
# AAACTGCCAAGAGATT-1_Control 0               Low      NS < 4
# AAACTGCCACTCGCAG-1_Control 0               High     NS < 4
# AAACTGCGTAACTGAA-1_Control 0               Low      NS < 4
# AAACTGCGTGCAAGCA-1_Control 0               High     NS < 4
# AAACTGCGTTAACCAC-1_Control 0               Low      NS < 4
# AAACTGCGTTACGGAG-1_Control 0               Low      NS < 4
# ⋮                          ⋮               ⋮        ⋮
# TTTGGTTCATATAGAG-1_Input   0               Low      NS < 4
# TTTGGTTCATGGCCCA-1_Input   0               Low      NS < 4
# TTTGGTTGTTCTCGAA-1_Input   0               Low      NS < 4
# TTTGGTTTCACTCGGG-1_Input   0               Low      NS < 4
# TTTGGTTTCATCATGG-1_Input   0               Low      NS < 4
# TTTGGTTTCCAGAATC-1_Input   0               Low      NS < 4
# TTTGGTTTCCAGCACG-1_Input   0               Low      NS < 4
# TTTGGTTTCGGGAAAC-1_Input   0               Low      NS < 4
# TTTGGTTTCTGAGTCA-1_Input   0               Low      NS < 4
# TTTGGTTTCTGATCCC-1_Input   0               Low      NS < 4
# TTTGTGTAGAACCCGA-1_Input   0               Low      NS < 4
# TTTGTGTAGGTTGTTC-1_Input   0               Low      NS < 4
# TTTGTGTAGGTTTCTG-1_Input   0               Low      NS < 4
# TTTGTGTAGTAGACCG-1_Input   0               High     NS < 4
# TTTGTGTAGTTCGTTG-1_Input   0               Low      NS < 4
# TTTGTGTCAACTCGTA-1_Input   0               Low      NS < 4
# TTTGTGTCAAGCCAGA-1_Input   0               Low      NS < 4
# TTTGTGTCAATGACTC-1_Input   0               Low      NS < 4
# TTTGTGTCACACATTG-1_Input   0               Low      NS < 4
# TTTGTGTCAGAAAGAG-1_Input   0               Low      NS < 4
# TTTGTGTCATAGCCAT-1_Input   0               Low      NS < 4
# TTTGTGTGTAAGCCGA-1_Input   0               Low      NS < 4
# TTTGTGTGTAGATTAG-1_Input   0               Low      NS < 4
# TTTGTGTGTAGGGTCA-1_Input   0               Low      NS < 4
# TTTGTGTGTCATAGAA-1_Input   0               Low      NS < 4
# TTTGTGTGTTTCTTAC-1_Input   0               Low      NS < 4
# TTTGTGTTCGGGACAA-1_Input   3323         TTTGTGTTCGGGACAA-1_Input
# TTTGTGTTCTGGCACG-1_Input   7279         TTTGTGTTCTGGCACG-1_Input

# %%
cells_meta
# Out:
#                            cell                       donor cloneID condition
# Input_GCGCCAAGTTGCCTGG-1   Input_GCGCCAAGTTGCCTGG-1   0     0_C8    Input
# Flt3l_GGTCATACAAGGCGTA-1   Flt3l_GGTCATACAAGGCGTA-1   0     0_C7    Flt3l
# Control_CAGTGCGAGGTTCTCA-1 Control_CAGTGCGAGGTTCTCA-1 0     0_C0    Control
# Input_ACTTTCAGTACTATGC-1   Input_ACTTTCAGTACTATGC-1   0     0_C8    Input
# Input_TTGACGATCCTCCATG-1   Input_TTGACGATCCTCCATG-1   0     0_C8    Input
# Flt3l_AGGCGAATCACCACAA-1   Flt3l_AGGCGAATCACCACAA-1   0     0_C0    Flt3l
# Control_TGCTCACTCGCTTGAA-1 Control_TGCTCACTCGCTTGAA-1 0     0_C5    Control
# Control_AGCTATGGTCCGCTTT-1 Control_AGCTATGGTCCGCTTT-1 0     0_C5    Control
# Input_CCACAGGGTGGACAGT-1   Input_CCACAGGGTGGACAGT-1   0     0_C5    Input
# Flt3l_TCACTCGAGGTTACAA-1   Flt3l_TCACTCGAGGTTACAA-1   0     0_C0    Flt3l
# Flt3l_TGGACATAGACACAAT-1   Flt3l_TGGACATAGACACAAT-1   0     0_C1    Flt3l
# Input_TCAGTTTTCGGTACTA-1   Input_TCAGTTTTCGGTACTA-1   0     0_C8    Input
# Flt3l_TACATGGTCCGCCTAT-1   Flt3l_TACATGGTCCGCCTAT-1   0     0_C5    Flt3l
# Input_TACATGGTCCATCTAT-1   Input_TACATGGTCCATCTAT-1   0     0_C7    Input
# Flt3l_AGCGTATGTAAAGCTA-1   Flt3l_AGCGTATGTAAAGCTA-1   0     0_C0    Flt3l
# Input_GCCAGCACATGATCGT-1   Input_GCCAGCACATGATCGT-1   0     0_C8    Input
# Flt3l_TTGAGTGGTGCGACCT-1   Flt3l_TTGAGTGGTGCGACCT-1   0     0_C0    Flt3l
# Control_TGATTTCAGGCAATTA-1 Control_TGATTTCAGGCAATTA-1 0     0_C0    Control
# Input_CAAAGCTAGGCACCTC-1   Input_CAAAGCTAGGCACCTC-1   0     0_C5    Input
# Flt3l_GGAACCCCACTGTCAA-1   Flt3l_GGAACCCCACTGTCAA-1   0     0_C6    Flt3l
# Flt3l_CATGCCTTCACACGTA-1   Flt3l_CATGCCTTCACACGTA-1   0     0_C5    Flt3l
# Flt3l_TGACAACTCGTTACAG-1   Flt3l_TGACAACTCGTTACAG-1   0     0_C8    Flt3l
# Control_CCCAGAGGTACGGAGT-1 Control_CCCAGAGGTACGGAGT-1 0     0_C8    Control
# Input_TAATCGGCATACAACC-1   Input_TAATCGGCATACAACC-1   0     0_C5    Input
# Input_ATGCATGTCCCGGGTA-1   Input_ATGCATGTCCCGGGTA-1   0     0_C5    Input
# Control_AATGGAACACCTGTGG-1 Control_AATGGAACACCTGTGG-1 0     0_C5    Control
# Input_TAGGTCACAAGGTTCT-1   Input_TAGGTCACAAGGTTCT-1   0     0_C5    Input
# Control_GCGAGAATCGGATGTT-1 Control_GCGAGAATCGGATGTT-1 0     0_C0    Control
# Input_CTAGCGGGTTTCACCC-1   Input_CTAGCGGGTTTCACCC-1   0     0_C5    Input
# Flt3l_TAGGAGGTCTCTGCGT-1   Flt3l_TAGGAGGTCTCTGCGT-1   0     0_C8    Flt3l
# ⋮                          ⋮                          ⋮     ⋮       ⋮
# Control_GAACCGCCACCTGAAT-1 Control_GAACCGCCACCTGAAT-1 0     0_C0    Control
# Input_GCTCAGGCACCTATTT-1   Input_GCTCAGGCACCTATTT-1   0     0_C5    Input
# Flt3l_CTGGGACGTAGGTCTT-1   Flt3l_CTGGGACGTAGGTCTT-1   0     0_C5    Flt3l
# Control_GTGCACGTCCACGGCA-1 Control_GTGCACGTCCACGGCA-1 0     0_C8    Control
# Input_TTACTCACATAGCCGC-1   Input_TTACTCACATAGCCGC-1   0     0_C8    Input
# Control_TTGCCCACACTAAACC-1 Control_TTGCCCACACTAAACC-1 0     0_C0    Control
# Input_GTGCCAGGTTTCCACC-1   Input_GTGCCAGGTTTCCACC-1   0     0_C5    Input
# Flt3l_TCCATCGGTTTCGACA-1   Flt3l_TCCATCGGTTTCGACA-1   0     0_C3    Flt3l
# Input_GTGACATCATGGATGG-1   Input_GTGACATCATGGATGG-1   0     0_C8    Input
# Input_ACAATCGGTCCGTAGC-1   Input_ACAATCGGTCCGTAGC-1   0     0_C8    Input
# Flt3l_TGCTATTCATTACCTT-1   Flt3l_TGCTATTCATTACCTT-1   0     0_C0    Flt3l
# Input_AGCGTGCCAGAGCCAA-1   Input_AGCGTGCCAGAGCCAA-1   0     0_C8    Input
# Input_GAGACTTAGGCCTAAG-1   Input_GAGACTTAGGCCTAAG-1   0     0_C8    Input
# Control_TAGGTGTGTCGGCTGT-1 Control_TAGGTGTGTCGGCTGT-1 0     0_C0    Control
# Input_TTAGGTGCAGAACTTC-1   Input_TTAGGTGCAGAACTTC-1   0     0_C8    Input
# Input_CAACGTAGTTTCCTAT-1   Input_CAACGTAGTTTCCTAT-1   0     0_C0    Input
# Flt3l_CTAGCGGCAAACCCTA-1   Flt3l_CTAGCGGCAAACCCTA-1   0     0_C0    Flt3l
# Flt3l_GGAGGATCAAGATTAG-1   Flt3l_GGAGGATCAAGATTAG-1   0     0_C0    Flt3l
# Flt3l_CTAACTTGTTCAGAAA-1   Flt3l_CTAACTTGTTCAGAAA-1   0     0_C0    Flt3l
# Flt3l_GAAACAACACTGTCGG-1   Flt3l_GAAACAACACTGTCGG-1   0     0_C0    Flt3l
# Flt3l_TAGCCGGAGAACCATA-1   Flt3l_TAGCCGGAGAACCATA-1   0     0_C0    Flt3l
# Input_TAGCATGCAATGTGCT-1   Input_TAGCATGCAATGTGCT-1   0     0_C0    Input
# Control_TACGCAACAGACTAAA-1 Control_TACGCAACAGACTAAA-1 0     0_C5    Control
# Input_TCTATTGTCGGTTAGT-1   Input_TCTATTGTCGGTTAGT-1   0     0_C5    Input
# Input_ATGTTTCGTGAGTAAT-1   Input_ATGTTTCGTGAGTAAT-1   0     0_C5    Input
# Control_GGATAGGAGCTCGTTA-1 Control_GGATAGGAGCTCGTTA-1 0     0_C1    Control
# Input_ACATGCAAGAAATACC-1   Input_ACATGCAAGAAATACC-1   0     0_C0    Input
# Input_TCCAGAAGTAGGGTCA-1   Input_TCCAGAAGTAGGGTCA-1   0     0_C5    Input
# Flt3l_CTGTTCGGTGGTTCTA-1   Flt3l_CTGTTCGGTGGTTCTA-1   0     0_C0    Flt3l
# Flt3l_CGGTGCAAGCGCGTTC-1   Flt3l_CGGTGCAAGCGCGTTC-1   0     0_C5    Flt3l
#                            clusterID
# Input_GCGCCAAGTTGCCTGG-1   MPP/CMP/GMP
# Flt3l_GGTCATACAAGGCGTA-1   neutrophil B
# Control_CAGTGCGAGGTTCTCA-1 eosonophil
# Input_ACTTTCAGTACTATGC-1   MPP/CMP/GMP
# Input_TTGACGATCCTCCATG-1   neutrophil B
# Flt3l_AGGCGAATCACCACAA-1   macrophage
# Control_TGCTCACTCGCTTGAA-1 macrophage
# Control_AGCTATGGTCCGCTTT-1 erythroid
# Input_CCACAGGGTGGACAGT-1   macrophage
# Flt3l_TCACTCGAGGTTACAA-1   neutrophil
# Flt3l_TGGACATAGACACAAT-1   MPP/CMP/GMP C
# Input_TCAGTTTTCGGTACTA-1   MEP
# Flt3l_TACATGGTCCGCCTAT-1   erythroid
# Input_TACATGGTCCATCTAT-1   MPP/CMP/GMP B
# Flt3l_AGCGTATGTAAAGCTA-1   eosonophil
# Input_GCCAGCACATGATCGT-1   MPP/CMP/GMP B
# Flt3l_TTGAGTGGTGCGACCT-1   MPP/CMP/GMP C
# Control_TGATTTCAGGCAATTA-1 macrophage
# Input_CAAAGCTAGGCACCTC-1   MPP/CMP/GMP B
# Flt3l_GGAACCCCACTGTCAA-1   eosonophil
# Flt3l_CATGCCTTCACACGTA-1   meg/erythroid
# Flt3l_TGACAACTCGTTACAG-1   neutrophil
# Control_CCCAGAGGTACGGAGT-1 neutrophil B
# Input_TAATCGGCATACAACC-1   meg/erythroid
# Input_ATGCATGTCCCGGGTA-1   MPP/CMP/GMP
# Control_AATGGAACACCTGTGG-1 eosonophil
# Input_TAGGTCACAAGGTTCT-1   MEP
# Control_GCGAGAATCGGATGTT-1 neutrophil B
# Input_CTAGCGGGTTTCACCC-1   MEP
# Flt3l_TAGGAGGTCTCTGCGT-1   erythroid
# ⋮                          ⋮
# Control_GAACCGCCACCTGAAT-1 macrophage
# Input_GCTCAGGCACCTATTT-1   MPP/CMP/GMP
# Flt3l_CTGGGACGTAGGTCTT-1   erythroid
# Control_GTGCACGTCCACGGCA-1 neutrophil
# Input_TTACTCACATAGCCGC-1   MPP/CMP/GMP
# Control_TTGCCCACACTAAACC-1 eosonophil
# Input_GTGCCAGGTTTCCACC-1   MPP/CMP/GMP B
# Flt3l_TCCATCGGTTTCGACA-1   erythroid
# Input_GTGACATCATGGATGG-1   CLP
# Input_ACAATCGGTCCGTAGC-1   MPP/CMP/GMP B
# Flt3l_TGCTATTCATTACCTT-1   neutrophil
# Input_AGCGTGCCAGAGCCAA-1   MPP/CMP/GMP
# Input_GAGACTTAGGCCTAAG-1   MPP/CMP/GMP B
# Control_TAGGTGTGTCGGCTGT-1 eosonophil
# Input_TTAGGTGCAGAACTTC-1   MPP/CMP/GMP
# Input_CAACGTAGTTTCCTAT-1   MPP/CMP/GMP B
# Flt3l_CTAGCGGCAAACCCTA-1   neutrophil B
# Flt3l_GGAGGATCAAGATTAG-1   neutrophil
# Flt3l_CTAACTTGTTCAGAAA-1   macrophage
# Flt3l_GAAACAACACTGTCGG-1   neutrophil
# Flt3l_TAGCCGGAGAACCATA-1   macrophage
# Input_TAGCATGCAATGTGCT-1   MPP/CMP/GMP B
# Control_TACGCAACAGACTAAA-1 neutrophil
# Input_TCTATTGTCGGTTAGT-1   MPP/CMP/GMP B
# Input_ATGTTTCGTGAGTAAT-1   MPP/CMP/GMP
# Control_GGATAGGAGCTCGTTA-1 neutrophil
# Input_ACATGCAAGAAATACC-1   MPP/CMP/GMP B
# Input_TCCAGAAGTAGGGTCA-1   MPP/CMP/GMP B
# Flt3l_CTGTTCGGTGGTTCTA-1   meg/erythroid
# Flt3l_CGGTGCAAGCGCGTTC-1   MPP/CMP/GMP D

# %%
se <- AddMetaData(se, cells_meta)
se
# Out:
# An object of class Seurat
# 221404 features across 18672 samples within 2 assays
# Active assay: RNA (19039 features, 0 variable features)
#  1 other assay present: ATAC
#  2 dimensional reductions calculated: integrated_lsi, umap

# %%
se[[]]
# Out:
#                            orig.ident nCount_ATAC nFeature_ATAC total duplicate
# AAACGAAAGAATCAGT-1_Control Control    1972        1972           6432 1259
# AAACGAAAGCATACCT-1_Control Control    2674        2674          11858 1937
# AAACGAAAGCGAGAAA-1_Control Control    1939        1939           7365 1097
# AAACGAAAGTACAGAT-1_Control Control     862         862           4095  861
# AAACGAAAGTACAGTA-1_Control Control    1775        1775           8088 1091
# AAACGAAAGTGTCGGA-1_Control Control     756         756           3362  524
# AAACGAACACTCGCAG-1_Control Control    1444        1444           6285  831
# AAACGAAGTCTTAGCA-1_Control Control    1921        1921          10456 1353
# AAACGAAGTGAGGGTT-1_Control Control     425         425           1347  226
# AAACGAATCAGGCGCT-1_Control Control    7347        7347          33434 6309
# AAACGAATCCATCGAA-1_Control Control    3980        3980          19085 3491
# AAACGAATCCCACGGA-1_Control Control    2655        2655          10468 1550
# AAACGAATCTCGTAGA-1_Control Control    1487        1487           6532 1102
# AAACTCGAGTCTCTAG-1_Control Control    1521        1521           7080 1150
# AAACTCGAGTGAAGGA-1_Control Control    2323        2323           8492 1182
# AAACTCGCATGCACTA-1_Control Control    4322        4322          22421 3235
# AAACTCGGTCTCTGGG-1_Control Control    1038        1038           3433  636
# AAACTCGAGTGAAGGA-1_Control NA   NA    NA      NA        NA
# AAACTCGCATGCACTA-1_Control NA   NA    NA      NA        NA
# AAACTCGGTCTCTGGG-1_Control NA   NA    NA      NA        NA
# AAACTCGGTCTGCACG-1_Control NA   NA    NA      NA        NA
# AAACTCGGTTGGCTTA-1_Control NA   NA    NA      NA        NA
# AAACTCGTCGGGAAAC-1_Control NA   NA    NA      NA        NA
# AAACTCGTCTGCGTCT-1_Control NA   NA    NA      NA        NA
# AAACTGCAGCCCATGC-1_Control NA   NA    NA      NA        NA
# AAACTGCAGCGTTGCC-1_Control NA   NA    NA      NA        NA
# AAACTGCAGGATGTAT-1_Control NA   NA    NA      NA        NA
# AAACTGCCAAGAGATT-1_Control NA   NA    NA      NA        NA
# AAACTGCCACTCGCAG-1_Control NA   NA    NA      NA        NA
# AAACTGCGTAACTGAA-1_Control NA   NA    NA      NA        NA
# AAACTGCGTGCAAGCA-1_Control NA   NA    NA      NA        NA
# AAACTGCGTTAACCAC-1_Control NA   NA    NA      NA        NA
# AAACTGCGTTACGGAG-1_Control NA   NA    NA      NA        NA
# ⋮                          ⋮    ⋮     ⋮       ⋮         ⋮
# TTTGGTTCATATAGAG-1_Input   NA   NA    NA      NA        NA
# TTTGGTTCATGGCCCA-1_Input   NA   NA    NA      NA        NA
# TTTGGTTGTTCTCGAA-1_Input   NA   NA    NA      NA        NA
# TTTGGTTTCACTCGGG-1_Input   NA   NA    NA      NA        NA
# TTTGGTTTCATCATGG-1_Input   NA   NA    NA      NA        NA
# TTTGGTTTCCAGAATC-1_Input   NA   NA    NA      NA        NA
# TTTGGTTTCCAGCACG-1_Input   NA   NA    NA      NA        NA
# TTTGGTTTCGGGAAAC-1_Input   NA   NA    NA      NA        NA
# TTTGGTTTCTGAGTCA-1_Input   NA   NA    NA      NA        NA
# TTTGGTTTCTGATCCC-1_Input   NA   NA    NA      NA        NA
# TTTGTGTAGAACCCGA-1_Input   NA   NA    NA      NA        NA
# TTTGTGTAGGTTGTTC-1_Input   NA   NA    NA      NA        NA
# TTTGTGTAGGTTTCTG-1_Input   NA   NA    NA      NA        NA
# TTTGTGTAGTAGACCG-1_Input   NA   NA    NA      NA        NA
# TTTGTGTAGTTCGTTG-1_Input   NA   NA    NA      NA        NA
# TTTGTGTCAACTCGTA-1_Input   NA   NA    NA      NA        NA
# TTTGTGTCAAGCCAGA-1_Input   NA   NA    NA      NA        NA
# TTTGTGTCAATGACTC-1_Input   NA   NA    NA      NA        NA
# TTTGTGTCACACATTG-1_Input   NA   NA    NA      NA        NA
# TTTGTGTCAGAAAGAG-1_Input   NA   NA    NA      NA        NA
# TTTGTGTCATAGCCAT-1_Input   NA   NA    NA      NA        NA
# TTTGTGTGTAAGCCGA-1_Input   NA   NA    NA      NA        NA
# TTTGTGTGTAGATTAG-1_Input   NA   NA    NA      NA        NA
# TTTGTGTGTAGGGTCA-1_Input   NA   NA    NA      NA        NA
# TTTGTGTGTCATAGAA-1_Input   NA   NA    NA      NA        NA
# TTTGTGTGTTTCTTAC-1_Input   NA   NA    NA      NA        NA
# TTTGTGTTCCTGAAAC-1_Input   NA   NA    NA      NA        NA
# TTTGTGTTCGGGAAAC-1_Input   NA   NA    NA      NA        NA
# TTTGTGTTCGGGACAA-1_Input   NA   NA    NA      NA        NA
# TTTGTGTTCTGGCACG-1_Input   NA   NA    NA      NA        NA

# %%
cloneID <- (unique(cells_meta$cloneID))
cloneID <- cloneID[! cloneID=="None"]

# %%
cloneID
# Out:
#  [1] "0_C8" "0_C7" "0_C0" "0_C5" "0_C1" "0_C6" "0_C9" "0_C4" "0_C2" "0_C3"

# %%
cond <- (unique(cells_meta$condition))
cond <- cond[! cond=="None"]
cond
# Out:
# [1] "Input"   "Flt3l"   "Control"

# %%
donors <- levels(as.factor(cells_meta$donor))
donors <-  donors[donors != "None"]
donors
# Out:
# [1] "0"

# %%
dimplots.conditon.f <- function(cl, se)
    
{
    print(cl)  
    try({
        #curr.dir <- file.path(outdir, cl)
#         print('curr.dir')
#         print(curr.dir)
#         dir.create(curr.dir)
        plot_density(se, "cloneID") +
            xlim(-1*coord-0.01,coord+0.01) +
            ylim(-1*coord-0.01,coord+0.01)
        #ggsave(file.path(curr.dir, paste0("clone_", cl, "umap_density.png")))
        
        d <- DimPlot(object = subset(x = se, subset = cloneID == cl), label = FALSE, 
                     group.by=c("clusterID"), shape.by=c("condition"), pt.size=2) +
            xlim(-1*coord-0.01,coord+0.01) +
            ylim(-1*coord-0.01,coord+0.01)
        #ggsave(file.path(curr.dir, paste0("clone_", cl, "umap_clust_color.png")))
        #ggsave(file.path(curr.dir, paste0("clone_", cl, "clust_color.pdf")))

        if(length(cond)>1)
            d <- DimPlot(object = subset(x = se, subset = cloneID == cl), label = FALSE, 
                         group.by=c("condition"), pt.size=2) +
                xlim(-1*coord-0.01,coord+0.01) +
                ylim(-1*coord-0.01,coord+0.01)
            #ggsave(file.path(curr.dir, paste0("clone_", cl, ".umap_cond_color.png")))    
            #ggsave(file.path(curr.dir, paste0("clone_", cl, "cond_color.pdf")))
        

        

    })
}

# %%
se[[]]
# Out:
#                            orig.ident nCount_ATAC nFeature_ATAC total duplicate
# AAACGAAAGAATCAGT-1_Control Control    1972        1972           6432 1259
# AAACGAAAGCATACCT-1_Control Control    2674        2674          11858 1937
# AAACGAAAGCGAGAAA-1_Control Control    1939        1939           7365 1097
# AAACGAAAGTACAGAT-1_Control Control     862         862           4095  861
# AAACGAAAGTACAGTA-1_Control Control    1775        1775           8088 1091
# AAACGAAAGTGTCGGA-1_Control Control     756         756           3362  524
# AAACGAACACTCGCAG-1_Control Control    1444        1444           6285  831
# AAACGAAGTCTTAGCA-1_Control Control    1921        1921          10456 1353
# AAACGAAGTGAGGGTT-1_Control Control     425         425           1347  226
# AAACGAATCAGGCGCT-1_Control Control    7347        7347          33434 6309
# AAACGAATCCATCGAA-1_Control Control    3980        3980          19085 3491
# AAACGAATCCCACGGA-1_Control Control    2655        2655          10468 1550
# AAACGAAGTGAGGGTT-1_Control NA   NA    NA      NA        NA
# AAACGAATCAGGCGCT-1_Control NA   NA    NA      NA        NA
# AAACGAATCCATCGAA-1_Control NA   NA    NA      NA        NA
# AAACGAATCCCACGGA-1_Control NA   NA    NA      NA        NA
# AAACGAATCTCGTAGA-1_Control NA   NA    NA      NA        NA
# AAACTCGAGTCTCTAG-1_Control NA   NA    NA      NA        NA
# AAACTCGAGTGAAGGA-1_Control NA   NA    NA      NA        NA
# AAACTCGCATGCACTA-1_Control NA   NA    NA      NA        NA
# AAACTCGGTCTCTGGG-1_Control NA   NA    NA      NA        NA
# AAACTCGGTCTGCACG-1_Control NA   NA    NA      NA        NA
# AAACTCGGTTGGCTTA-1_Control NA   NA    NA      NA        NA
# AAACTCGTCGGGAAAC-1_Control NA   NA    NA      NA        NA
# AAACTCGTCTGCGTCT-1_Control NA   NA    NA      NA        NA
# AAACTGCAGCCCATGC-1_Control NA   NA    NA      NA        NA
# AAACTGCAGCGTTGCC-1_Control NA   NA    NA      NA        NA
# AAACTGCAGGATGTAT-1_Control NA   NA    NA      NA        NA
# AAACTGCCAAGAGATT-1_Control NA   NA    NA      NA        NA
# AAACTGCCACTCGCAG-1_Control NA   NA    NA      NA        NA
# AAACTGCGTAACTGAA-1_Control NA   NA    NA      NA        NA
# AAACTGCGTGCAAGCA-1_Control NA   NA    NA      NA        NA
# AAACTGCGTTAACCAC-1_Control NA   NA    NA      NA        NA
# AAACTGCGTTACGGAG-1_Control NA   NA    NA      NA        NA
# ⋮                          ⋮    ⋮     ⋮       ⋮         ⋮
# TTTGGTTCATATAGAG-1_Input   NA   NA    NA      NA        NA
# TTTGGTTCATGGCCCA-1_Input   NA   NA    NA      NA        NA
# TTTGGTTGTTCTCGAA-1_Input   NA   NA    NA      NA        NA
# TTTGGTTTCACTCGGG-1_Input   NA   NA    NA      NA        NA
# TTTGGTTTCATCATGG-1_Input   NA   NA    NA      NA        NA
# TTTGGTTTCCAGAATC-1_Input   NA   NA    NA      NA        NA
# TTTGGTTTCCAGCACG-1_Input   NA   NA    NA      NA        NA
# TTTGGTTTCGGGAAAC-1_Input   NA   NA    NA      NA        NA
# TTTGGTTTCTGAGTCA-1_Input   NA   NA    NA      NA        NA
# TTTGGTTTCTGATCCC-1_Input   NA   NA    NA      NA        NA
# TTTGTGTAGAACCCGA-1_Input   NA   NA    NA      NA        NA
# TTTGTGTAGGTTGTTC-1_Input   NA   NA    NA      NA        NA
# TTTGTGTAGGTTTCTG-1_Input   NA   NA    NA      NA        NA
# TTTGTGTAGTAGACCG-1_Input   NA   NA    NA      NA        NA
# TTTGTGTAGTTCGTTG-1_Input   NA   NA    NA      NA        NA
# TTTGTGTCAACTCGTA-1_Input   NA   NA    NA      NA        NA
# TTTGTGTCAAGCCAGA-1_Input   NA   NA    NA      NA        NA
# TTTGTGTCAATGACTC-1_Input   NA   NA    NA      NA        NA
# TTTGTGTCACACATTG-1_Input   NA   NA    NA      NA        NA
# TTTGTGTCAGAAAGAG-1_Input   NA   NA    NA      NA        NA
# TTTGTGTCATAGCCAT-1_Input   NA   NA    NA      NA        NA
# TTTGTGTGTAAGCCGA-1_Input   NA   NA    NA      NA        NA
# TTTGTGTGTAGATTAG-1_Input   NA   NA    NA      NA        NA
# TTTGTGTGTAGGGTCA-1_Input   NA   NA    NA      NA        NA
# TTTGTGTGTCATAGAA-1_Input   NA   NA    NA      NA        NA
# TTTGTGTGTTTCTTAC-1_Input   NA   NA    NA      NA        NA
# TTTGTGTTCCTGAAAC-1_Input   NA   NA    NA      NA        NA
# TTTGTGTTCGGGAAAC-1_Input   NA   NA    NA      NA        NA
# TTTGTGTTCGGGACAA-1_Input   NA   NA    NA      NA        NA
# TTTGTGTTCTGGCACG-1_Input   NA   NA    NA      NA        NA

# %%
cloneID
# Out:
#  [1] "0_C8" "0_C7" "0_C0" "0_C5" "0_C1" "0_C6" "0_C9" "0_C4" "0_C2" "0_C3"

# %%
dimplots <- sapply(cloneID, FUN=dimplots.conditon.f, se=se)
#d <- dimplots.conditon.f(names[[10]], se) 
#d
# Out:
# [1] "0_C8"
# Error in sum(w) : invalid 'type' (character) of argument
# [1] "0_C7"
# Error in sum(w) : invalid 'type' (character) of argument
# [1] "0_C0"
# Error in sum(w) : invalid 'type' (character) of argument
# [1] "0_C5"
# Error in sum(w) : invalid 'type' (character) of argument
# [1] "0_C1"
# Error in sum(w) : invalid 'type' (character) of argument
# [1] "0_C6"
# Error in sum(w) : invalid 'type' (character) of argument
# [1] "0_C9"
# Error in sum(w) : invalid 'type' (character) of argument
# [1] "0_C4"
# Error in sum(w) : invalid 'type' (character) of argument
# [1] "0_C2"
# Error in sum(w) : invalid 'type' (character) of argument
# [1] "0_C3"
# Error in sum(w) : invalid 'type' (character) of argument

# %%
RidgePlot(object = se, group.by="cloneID", features = c('UMAP_1', 'UMAP_2'), sort=F)

# %%
library(miloR)

# %%
library(SingleCellExperiment)
library(scater)
library(dplyr)
library(patchwork)

# %%
se_sce <- as.SingleCellExperiment(se)
se_milo <- Milo(se_sce)

# %%
traj_milo <- buildGraph(se_milo, k = 10, d = 30)

# %%
traj_milo <- makeNhoods(traj_milo, prop = 0.1, k = 10, d=30, refined = TRUE)

# %%
plotNhoodSizeHist(traj_milo)

# %%
traj_milo <- countCells(traj_milo, meta.data = data.frame(colData(traj_milo)), sample="Sample")

# %%
head(nhoodCounts(traj_milo))

# %%
traj_design <- data.frame(colData(traj_milo))[,c("Sample", "cloneID", "condition")]
traj_design <- distinct(traj_design)

traj_design

# %%
traj_milo <- calcNhoodDistance(traj_milo, d=30)

# %%
da_results <- testNhoods(traj_milo, design = ~ clone.id, design.df = traj_design)

# %%
da_results <- testNhoods(traj_milo, design = ~ clone.id + condition, design.df = traj_design)

# %%
da_results %>%
  arrange(- SpatialFDR) %>%
  head()

# %%
traj_milo <- buildNhoodGraph(traj_milo)

# %%
plotUMAP(traj_milo) + plotNhoodGraphDA(traj_milo, da_results, alpha=0.05) +
  plot_layout(guides="collect")
