# %%
# labels_f = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/mt_as_clones/variants_simpleUnion/anno_mt_af_v02/input/minCov10_donor1.labels.csv"
# af_f = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/mt_as_clones/variants_simpleUnion/anno_mt_af_v02/input/minCov10_donor1.af.csv"
# outdir = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/mt_as_clones/variants_simpleUnion/anno_mt_af_v02/input/method_bias/"
name = "donor1"


labels_f = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/mt_nuclear/variants_prefilterMerge_impute/method_bias/minCov10_donor1.labels.csv" 
af_f = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/mt_nuclear/variants_prefilterMerge_impute/method_bias/minCov10_donor1.af.csv" 
outdir = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/mt_nuclear/variants_prefilterMerge_impute/method_bias/"
af_max = 0.4

# %%
library(ComplexHeatmap)
library(dplyr)
# Out:
# Loading required package: grid
#
# ========================================
# ComplexHeatmap version 2.10.0
# Bioconductor page: http://bioconductor.org/packages/ComplexHeatmap/
# Github page: https://github.com/jokergoo/ComplexHeatmap
# Documentation: http://jokergoo.github.io/ComplexHeatmap-reference
#
# If you use it in published research, please cite:
# Gu, Z. Complex heatmaps reveal patterns and correlations in multidimensional
#   genomic data. Bioinformatics 2016.
#
# The new InteractiveComplexHeatmap package can directly export static
# complex heatmaps into an interactive Shiny app with zero effort. Have a try!
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(ComplexHeatmap))
# ========================================
#
#
# Warning message:
# “package ‘dplyr’ was built under R version 4.1.3”
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
af <- read.csv(af_f, row.names=1)
af
# Out:
#                          X1949A    X2514A     X3242A X3244A    X3630A
# TGGTCCTAGACAGCTG-1_Input 0.2264554 0.00000000 0      0         0.0000000
# GACCAATGTGACGCAA-1_Input 0.2696799 0.00000000 0      0         0.0000000
# TGAATCGGTTCAGTAC-1_Input 0.0000000 0.10752067 0      0         0.0000000
# ACTGCAATCTGAAAGA-1_Input 0.0000000 0.16783627 0      0         0.1020621
# TGGGTTATCCTAAGTG-1_Input 0.0000000 0.00000000 0      0         0.0000000
# TGGGTTATCCCAGCGA-1_Input 0.0000000 0.00000000 0      0         0.0000000
# ACTGCGGGTAAACCCT-1_Input 0.0000000 0.09513030 0      0         0.0000000
# GCAGCTGCAACTGCGC-1_Input 0.0000000 0.00000000 0      0         0.0000000
# GTCCATCTCACTTACT-1_Input 0.0000000 0.00000000 0      0         0.0000000
# ACTGTCCAGTACCACT-1_Input 0.0000000 0.10814761 0      0         0.0000000
# TGGGTTAGTTCCCAAA-1_Input 0.0000000 0.00000000 0      0         0.0000000
# ACTGTCCCATGGAGGT-1_Input 0.0000000 0.00000000 0      0         0.0000000
# GTCCATCTCGCACCTT-1_Input 0.0000000 0.14002801 0      0         0.0000000
# TTGCAGATCTGGGCGT-1_Input 0.0000000 0.0000000 0.0000000 0.9876538 0
# TACAGCAAGCAGAATT-1_Input 0.0000000 0.1458650 0.0000000 0.7738457 0
# TATGTGGGTCGAGGTA-1_Input 0.0000000 0.0000000 0.0000000 0.0000000 0
# CTCAGCTAGTGATCTC-1_Input 0.0000000 0.0000000 0.0000000 0.0000000 0
# CCTAAAGAGGATATCA-1_Input 0.0000000 0.0000000 0.0000000 0.0000000 0
# AAGGTTCCATTCCCGT-1_Input 0.0000000 0.0000000 0.0000000 0.0000000 0
# CCGAAGCGTTATGCAC-1_Input 0.0000000 0.0000000 0.0000000 0.1301889 0
# AGCCAGCAGCTGAAAT-1_Input 0.4120817 0.0000000 0.0000000 0.9061965 0
# AGGCGTCCATGATCGT-1_Input 0.0000000 0.0000000 0.0000000 0.9884389 0
# GTGTCCTTCTCATATC-1_Input 0.0000000 0.1754116 0.0000000 1.0000000 0
# TTGCTTATCTTCCACG-1_Input 0.0000000 0.0000000 0.0000000 1.0000000 0
# GCAGCCATCCTGGAAT-1_Input 0.0000000 0.0000000 0.0000000 1.0000000 0
# GCAGCCAAGAGAAGCA-1_Input 0.1290994 0.0000000 0.0000000 1.0000000 0
# CATTCATGTTACGAAA-1_Input 0.0000000 0.0000000 0.0000000 1.0000000 0
# AGATAGAAGCCTCGCA-1_Input 0.0000000 0.0000000 0.0000000 0.0000000 0
# CACATGAAGCAATAAC-1_Input 0.1543033 0.0000000 0.0000000 0.7825341 0
# GTGCCAGGTCACAGGA-1_Input 0.0000000 0.0000000 0.0000000 1.0000000 0
# GATGATCGTAGATTAG-1_Input 0.0000000 0.0000000 0.0000000 0.0000000 0
# CTCTCAGTCAAGTTGC-1_Input 0.0000000 0.0000000 0.0000000 1.0000000 0
# CTGAATGGTAGCAGGT-1_Input 0.3733550 0.0000000 0.0000000 0.0000000 0

# %%
labels <- read.csv(labels_f, row.names=1)
labels
# Out:
#                          seurat_clusters condition
# TGGTCCTAGACAGCTG-1_Input 0               Input
# GACCAATGTGACGCAA-1_Input 0               Input
# TGAATCGGTTCAGTAC-1_Input 0               Input
# ACTGCAATCTGAAAGA-1_Input 0               Input
# TGGGTTATCCTAAGTG-1_Input 0               Input
# TGGGTTATCCCAGCGA-1_Input 0               Input
# ACTGCGGGTAAACCCT-1_Input 0               Input
# GCAGCTGCAACTGCGC-1_Input 0               Input
# GTCCATCTCACTTACT-1_Input 0               Input
# ACTGTCCAGTACCACT-1_Input 0               Input
# TGGGTTAGTTCCCAAA-1_Input 0               Input
# ACTGTCCCATGGAGGT-1_Input 0               Input
# GTCCATCTCGCACCTT-1_Input 0               Input
# TACGCAAGTCGCTAGC-1_Input 0               Input
# CCGAAGCGTAGACGCA-1_Input 0               Input
# GCAGCCAGTACCAAGG-1_Input 0               Input
# TCAAAGCCACAGATGG-1_Input 0               Input
# TCACCACTCTAGCAAC-1_Input 0               Input
# CTGTATTTCTACTTTG-1_Input 0               Input
# ACTGCAAAGCACGTAG-1_Input 0               Input
# GCATTCCAGAGCCTGA-1_Input 0               Input
# ACTAGGTTCGTAGCGC-1_Input 0               Input
# TGGTCCTGTGTCCCAG-1_Input 0               Input
# GACCAATCATGACTGT-1_Input 0               Input
# GCATGATCATGCACTA-1_Input 0               Input
# CAGGATTCAAATGCTC-1_Input 0               Input
# GCATGATCAAGACACG-1_Input 0               Input
# GTCCATCGTAAGCCTT-1_Input 0               Input
# TGGTCAAGTAGTCTGT-1_Input 0               Input
# GACCAATGTCCCTTTG-1_Input 0               Input
# ⋮                        ⋮               ⋮
# GACCAATAGTAGACCG-1_Input 11              Input
# ACTAACGGTGAGGTCA-1_Input 11              Input
# GAACGTTAGAATACTG-1_Input 11              Input
# AACATCGTCCAGTACA-1_Input 11              Input
# GAACCGCTCCGGACTG-1_Input 11              Input
# ACCGGGTGTCTAAGAA-1_Input 11              Input
# CATAACGAGAGGAACA-1_Input 11              Input
# AACCTGAGTCAAACAA-1_Input 11              Input
# CTTCTAACACTTATGG-1_Input 11              Input
# TATGTGGAGGTCTTTG-1_Input 11              Input
# TTGCAGATCTGGGCGT-1_Input 11              Input
# TACAGCAAGCAGAATT-1_Input 11              Input
# TATGTGGGTCGAGGTA-1_Input 11              Input
# CTCAGCTAGTGATCTC-1_Input 11              Input
# CCTAAAGAGGATATCA-1_Input 11              Input
# AAGGTTCCATTCCCGT-1_Input 11              Input
# CCGAAGCGTTATGCAC-1_Input 11              Input
# AGCCAGCAGCTGAAAT-1_Input 11              Input
# AGGCGTCCATGATCGT-1_Input 11              Input
# GTGTCCTTCTCATATC-1_Input 11              Input
# TTGCTTATCTTCCACG-1_Input 11              Input
# GCAGCCATCCTGGAAT-1_Input 11              Input
# GCAGCCAAGAGAAGCA-1_Input 11              Input
# CATTCATGTTACGAAA-1_Input 11              Input
# AGATAGAAGCCTCGCA-1_Input 11              Input
# CACATGAAGCAATAAC-1_Input 11              Input
# GTGCCAGGTCACAGGA-1_Input 11              Input
# GATGATCGTAGATTAG-1_Input 11              Input
# CTCTCAGTCAAGTTGC-1_Input 11              Input
# CTGAATGGTAGCAGGT-1_Input 11              Input

# %%
#sum(is.na(af))
af <- Filter(function(x)!all((is.na(x) | x==0)), af)
af <- af[rowSums((is.na(af) | af==0)) != ncol(af), ]


labels <- labels[row.names(labels) %in% row.names(af),]

# %%
af[is.na(af)] <- 0

# %%
af[af>af_max] <- af_max

# %%
heat <- ComplexHeatmap::Heatmap(as.matrix(af),
        name = name,na_col = "black",
        row_split = labels[c("seurat_clusters")],
        show_row_names = FALSE, use_raster=FALSE
       )

# heat <- tryCatch({ComplexHeatmap::Heatmap(as.matrix(af),
#         name = name,na_col = "black",
#         row_split = labels[c("seurat_clusters")],
#         show_row_names = FALSE, use_raster=FALSE
#        )},
#        error = function(cond){
#         print(cond)
#         print("setting na to 0")
#         af[is.na(af)] <- 0
#         return(ComplexHeatmap::Heatmap(as.matrix(af),
#         name = name,na_col = "black",
#         row_split = labels[c("seurat_clusters")],
#         show_row_names = FALSE, use_raster=FALSE)
#        )}
#        )
heat
# Out:
# plot without title

# %%
# Run without the big variant 
top.var <- names(which.max(colSums(af, na.rm=TRUE)))
row_ha = rowAnnotation(condition = labels$condition)

heat <- ComplexHeatmap::Heatmap(select(af, -c(top.var)),
        name = name,
        row_split = labels[c("seurat_clusters")],
        show_row_names = FALSE, use_raster=FALSE, right_annotation=row_ha
       )
heat
# Out:
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(top.var)` instead of `top.var` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
# Warning message:
# “The input is a data frame, convert it to a matrix.”
# plot without title

# %%
# Run without the big variant 
row_ha = rowAnnotation(condition = labels$condition)

heat <- ComplexHeatmap::Heatmap(select(af, -c(top.var)),
        name = name,
        show_row_names = FALSE, use_raster=FALSE, right_annotation=row_ha
       )
heat
# Out:
# Warning message:
# “The input is a data frame, convert it to a matrix.”
# plot without title

# %%
# ComplexHeatmap
# split by a vector
pdf((file.path(outdir, paste0(name, "_heatmap.top.pdf"))), width=8,height=8)
heat <- ComplexHeatmap::Heatmap(af,
        name = name,
        row_split = labels[c("seurat_clusters")],
        show_row_names = FALSE, use_raster=TRUE
       )
ComplexHeatmap::draw(heat)
dev.off()
# Out:
# Warning message:
# “The input is a data frame, convert it to a matrix.”
# png
#   2

# %%
# Run without the big variant 
row_ha = rowAnnotation(condition = labels$condition, labs = as.factor(labels$seurat_clusters))

pdf((file.path(outdir, paste0(name, "_heatmap.top.noGroup.pdf"))), width=8,height=8)

#row_ha = rowAnnotation(labs = labels$seurat_clusters)

heat <- ComplexHeatmap::Heatmap(af,
        name = name, right_annotation=row_ha,
        show_row_names = FALSE, use_raster=TRUE, left_annotation=row_ha
       )
ComplexHeatmap::draw(heat)
dev.off()
# Out:
# Warning message:
# “The input is a data frame, convert it to a matrix.”
# png
#   2

# %%
# Run without the big variant 
row_ha = rowAnnotation(condition = labels$condition, labs = as.factor(labels$seurat_clusters))


pdf((file.path(outdir, paste0(name, "_heatmap.top.remove",top.var,".pdf"))), width=8,height=8)

heat <- ComplexHeatmap::Heatmap(select(af, -c(top.var)),
        name = name,
        row_split = labels[c("seurat_clusters")],
        show_row_names = FALSE, use_raster=TRUE, right_annotation=row_ha
       )
ComplexHeatmap::draw(heat)
dev.off()
# Out:
# Warning message:
# “The input is a data frame, convert it to a matrix.”
# png
#   2

# %%
# Run without the big variant 
row_ha = rowAnnotation(condition = labels$condition)

pdf((file.path(outdir, paste0(name, "_heatmap.top.remove.noGroup",top.var,".pdf"))), width=8,height=8)

heat <- ComplexHeatmap::Heatmap(select(af, -c(top.var)),
        name = name,
        show_row_names = FALSE, use_raster=TRUE, left_annotation=row_ha
       )
ComplexHeatmap::draw(heat)
dev.off()
# Out:
# Warning message:
# “The input is a data frame, convert it to a matrix.”
# png
#   2

# %%
outdir
# Out:
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/mt_nuclear/variants_prefilterMerge_impute/method_bias/"
