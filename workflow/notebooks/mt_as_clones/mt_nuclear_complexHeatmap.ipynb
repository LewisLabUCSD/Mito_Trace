# %%
# labels_f = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/mt_as_clones/variants_simpleUnion/anno_mt_af_v02/input/minCov10_donor0.labels.csv"
# af_f = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/mt_as_clones/variants_simpleUnion/anno_mt_af_v02/input/minCov10_donor0.af.csv"
# outdir = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/mt_as_clones/variants_simpleUnion/anno_mt_af_v02/input/method_bias/"
name = "donor0"


labels_f = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/mt_nuclear/variants_simpleUnion/method_bias/minCov10_donor0.labels.csv" 
af_f = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/mt_nuclear/variants_simpleUnion/method_bias/minCov10_donor0.af.csv" 
outdir = "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/mt_nuclear/variants_simpleUnion/method_bias/method_bias"

# %%
library(ComplexHeatmap)
library(dplyr)
# Out:
# Loading required package: grid
#
# ========================================
# ComplexHeatmap version 2.10.0
# Bioconductor page: http://bioconductor.org/packages/ComplexHeatmap/
# Github page: https://github.com/jokergoo/ComplexHeatmap
# Documentation: http://jokergoo.github.io/ComplexHeatmap-reference
#
# If you use it in published research, please cite:
# Gu, Z. Complex heatmaps reveal patterns and correlations in multidimensional
#   genomic data. Bioinformatics 2016.
#
# The new InteractiveComplexHeatmap package can directly export static
# complex heatmaps into an interactive Shiny app with zero effort. Have a try!
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(ComplexHeatmap))
# ========================================
#
#
# Warning message:
# “package ‘dplyr’ was built under R version 4.1.3”
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
af <- read.csv(af_f, row.names=1)
af
# Out:
#                          X4917G    X13434G   X12283T    X2857G    X1661G
# TTTGTGTTCTGGCACG-1_Input 0         0.0000000 0.00000000 0.0000000 0
# GTCACAAGTTGAATAG-1_Input 0         0.0000000 0.00000000 0.0000000 0
# GTCACAACATCGTACA-1_Input 0         0.0000000 0.00000000 0.0000000 0
# ACTGCAACAAACCCTA-1_Input 0         0.0000000 0.00000000 0.0000000 0
# ACTGCAACAGCAATGG-1_Input 0         0.0000000 0.00000000 0.0000000 0
# TGCTCGTGTTCAGAAA-1_Input 0         0.0000000 0.00000000 0.0000000 0
# ACTGCAACAGGTGGTA-1_Input 0         0.0000000 0.00000000 0.0000000 0
# ACTATTCGTTTGTCTT-1_Input 0         0.0000000 0.00000000 0.0000000 0
# ACTGCAACAGGTTATC-1_Input 0         0.0000000 0.00000000 0.0000000 0
# TGCTTCGTCCAGGTAT-1_Input 0         0.0000000 0.00000000 0.0000000 0
# TGCTTCGTCGTTCCGT-1_Input 0         0.0000000 0.00000000 0.0000000 0
# ACTGCAAGTGCGTTTA-1_Input 0         0.0000000 0.00000000 0.0000000 0
# GTCACAACAAGGAACC-1_Input 0         0.0000000 0.09578263 0.0000000 0
# TGCTTTAAGAGGTCCA-1_Input 0         0.1611646 0.00000000 0.0000000 0
# ACTATTCGTTTGTCTT-1_Input 0               Input
# ACTGCAACAGGTTATC-1_Input 0               Input
# TGCTTCGTCCAGGTAT-1_Input 0               Input
# TGCTTCGTCGTTCCGT-1_Input 0               Input
# ACTGCAAGTGCGTTTA-1_Input 0               Input
# GTCACAACAAGGAACC-1_Input 0               Input
# TGCTTTAAGAGGTCCA-1_Input 0               Input
# ACTGCGGAGGGAAGCG-1_Input 0               Input
# TGCTCGTTCTTTGCAT-1_Input 0               Input
# ACTGCGGCAAGGGAGG-1_Input 0               Input
# TGCTCGTCATCCCAAA-1_Input 0               Input
# ACTATTCGTCAAATCC-1_Input 0               Input
# ACTAACGTCATCATGG-1_Input 0               Input
# ACTAACGTCGGAGTTT-1_Input 0               Input
# ACTACCCAGCTATCGT-1_Input 0               Input
# GTCACTCTCCCGTAGG-1_Input 0               Input
# TGCTATTTCCCGTAGG-1_Input 0               Input
# GTCACGGAGGTACATA-1_Input 0               Input
# ACTATTCGTGGATTCT-1_Input 0               Input
# GTCACCTTCTTGTACT-1_Input 0               Input
# GTCACCTGTTAGTAGA-1_Input 0               Input
# TGCTATTTCGCGTTCT-1_Input 0               Input
# ACTACGAGTCAATACC-1_Input 0               Input
# ⋮                        ⋮               ⋮
# CTGAATGGTGCAAGAC-1_Input 11              Input
# TTGAGTGAGCATGTGG-1_Input 11              Input
# GGTCATAAGGTAGGCT-1_Input 11              Input
# CTGCTCACAACGGACA-1_Input 11              Input
# GCTGTTCAGTTTGGAA-1_Input 11              Input
# ACAAACCAGTGAGTGC-1_Input 11              Input
# CAACCAACACGGTTAT-1_Input 11              Input
# GGTGAAGGTGGACCAA-1_Input 11              Input
# TACTAGGTCCGCCTAT-1_Input 11              Input
# ATTGTGGAGAACAGGA-1_Input 11              Input
# TATCGAGGTCTCTGCT-1_Input 11              Input
# TTCTGTAAGCCTTTGA-1_Input 11              Input
# TAAACCGCAATGCACT-1_Input 11              Input
# TAGCCGGAGTGTCACT-1_Input 11              Input
# GGGTGTCTCCTTTGCG-1_Input 11              Input
# CTAGGATAGTAGTGTA-1_Input 11              Input
# CCCACATGTTGGACGA-1_Input 11              Input
# TTCGGTCCAGGCAAGT-1_Input 11              Input
# AAATGCCGTCTGGGAA-1_Input 11              Input
# CTAGGGCGTCGATAGG-1_Input 11              Input
# CTCACCAGTGGTAAGC-1_Input 11              Input
# GTCACAATCTCGCGTT-1_Input 11              Input
# TGTGTCCCACACATGT-1_Input 11              Input
# ATTCGTTAGTAGCAAT-1_Input 11              Input
# AAATGCCGTCTCGGGT-1_Input 11              Input
# GTTGGTAGTTTAGGAA-1_Input 11              Input
# ATAGGCTAGTGATAAC-1_Input 11              Input
# AATACGCGTACAAGCG-1_Input 11              Input
# GTGTCAATCTAAACGC-1_Input 11              Input
# TAGCGGCGTTTGAAGA-1_Input 11              Input

# %%
#sum(is.na(af))
af <- Filter(function(x)!all((is.na(x) | x==0)), af)
af <- af[rowSums((is.na(af) | af==0)) != ncol(af), ]


labels <- labels[row.names(labels) %in% row.names(af),]

# %%
af[is.na(af)] <- 0

# %%
heat <- ComplexHeatmap::Heatmap(as.matrix(af),
        name = name,na_col = "black",
        row_split = labels[c("seurat_clusters")],
        show_row_names = FALSE, use_raster=FALSE
       )

# heat <- tryCatch({ComplexHeatmap::Heatmap(as.matrix(af),
#         name = name,na_col = "black",
#         row_split = labels[c("seurat_clusters")],
#         show_row_names = FALSE, use_raster=FALSE
#        )},
#        error = function(cond){
#         print(cond)
#         print("setting na to 0")
#         af[is.na(af)] <- 0
#         return(ComplexHeatmap::Heatmap(as.matrix(af),
#         name = name,na_col = "black",
#         row_split = labels[c("seurat_clusters")],
#         show_row_names = FALSE, use_raster=FALSE)
#        )}
#        )
heat
# Out:
# plot without title

# %%
# Run without the big variant 
top.var <- names(which.max(colSums(af, na.rm=TRUE)))
row_ha = rowAnnotation(condition = labels$condition)

heat <- ComplexHeatmap::Heatmap(select(af, -c(top.var)),
        name = name,
        row_split = labels[c("seurat_clusters")],
        show_row_names = FALSE, use_raster=FALSE, right_annotation=row_ha
       )
heat
# Out:
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(top.var)` instead of `top.var` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
# Warning message:
# “The input is a data frame, convert it to a matrix.”
# The automatically generated colors map from the 1^st and 99^th of the
# values in the matrix. There are outliers in the matrix whose patterns
# might be hidden by this color mapping. You can manually set the color
# to `col` argument.
#
# Use `suppressMessages()` to turn off this message.
# plot without title

# %%
# Run without the big variant 
row_ha = rowAnnotation(condition = labels$condition)

heat <- ComplexHeatmap::Heatmap(select(af, -c(top.var)),
        name = name,
        show_row_names = FALSE, use_raster=FALSE, right_annotation=row_ha
       )
heat
# Out:
# Warning message:
# “The input is a data frame, convert it to a matrix.”
# The automatically generated colors map from the 1^st and 99^th of the
# values in the matrix. There are outliers in the matrix whose patterns
# might be hidden by this color mapping. You can manually set the color
# to `col` argument.
#
# Use `suppressMessages()` to turn off this message.
# plot without title

# %%
# ComplexHeatmap
# split by a vector
pdf((file.path(outdir, paste0(name, "_heatmap.top.pdf"))), width=8,height=8)
heat <- ComplexHeatmap::Heatmap(af,
        name = name,
        row_split = labels[c("seurat_clusters")],
        show_row_names = FALSE, use_raster=TRUE
       )
ComplexHeatmap::draw(heat)
dev.off()
# Out:
# Warning message:
# “The input is a data frame, convert it to a matrix.”
# png
#   2

# %%
# Run without the big variant 
row_ha = rowAnnotation(condition = labels$condition)

pdf((file.path(outdir, paste0(name, "_heatmap.top.remove",top.var,".pdf"))), width=8,height=8)

heat <- ComplexHeatmap::Heatmap(select(af, -c(top.var)),
        name = name,
        row_split = labels[c("seurat_clusters")],
        show_row_names = FALSE, use_raster=TRUE, right_annotation=row_ha
       )
ComplexHeatmap::draw(heat)
dev.off()
# Out:
# Warning message:
# “The input is a data frame, convert it to a matrix.”
# The automatically generated colors map from the 1^st and 99^th of the
# values in the matrix. There are outliers in the matrix whose patterns
# might be hidden by this color mapping. You can manually set the color
# to `col` argument.
#
# Use `suppressMessages()` to turn off this message.
# png
#   2

# %%
outdir
# Out:
# [1] "/data/Mito_Trace/output/pipeline/v04/CHIP_b1/MTBlacklist_A2/data/merged/MT/cellr_True/numread_200/filters/minC10_minR50_topN0_hetT0.001_hetC10_hetCount5_bq20/mgatk/vireoIn/mt_nuclear/variants_simpleUnion/method_bias/method_bias"
